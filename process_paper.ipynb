# %%
import table_utils
import process_paper_utils as utils
import os
from bs4 import BeautifulSoup
import html
from datetime import datetime
import pandas as pd

# %%
#Enter PMC here:
PMC = "PMC5373957"

# %% [markdown]
# Imports paper from PMC

# %%
os.makedirs("papers", exist_ok=True)
if os.path.isfile(f"papers/{PMC}.xml"):
    with open(f"papers/{PMC}.xml", 'r', encoding='utf-8') as f:
        paper_xml = f.read()
else:
    paper_xml = utils.fetch_xml(PMC)
    with open(f"papers/{PMC}.xml", "w", encoding="utf-8") as f:
        f.write(paper_xml)
print(paper_xml)
# Out:
# <?xml version="1.0" encoding="UTF-8"?><!DOCTYPE collection SYSTEM "BioC.dtd"><collection><source>BioC-API</source><date>20250617</date><key>collection.key</key><document><id>5373957</id><infon key="license">author_manuscript</infon><passage><infon key="article-id_doi">10.1002/jat.3387</infon><infon key="article-id_manuscript">NIHMS817236</infon><infon key="article-id_pmc">5373957</infon><infon key="article-id_pmid">27696470</infon><infon key="fpage">530</infon><infon key="issue">5</infon><infon key="kwd">Silver nanoparticles in vivo distribution pregnant rats maternal-fetal transfer metabolomics analysis biomarkers oral gavage intravenous injection cytokines oxidative stress</infon><infon key="license">
#           This file is available for text mining. It may also be used consistent with the principles of fair use under the copyright law.
#         </infon><infon key="lpage">544</infon><infon key="name_0">surname:Fennell;given-names:Timothy R.</infon><infon key="name_1">surname:Mortensen;given-names:Ninell P.</infon><infon key="name_10">surname:Sumner;given-names:Susan C.J.</infon><infon key="name_2">surname:Black;given-names:Sherry R.</infon><infon key="name_3">surname:Snyder;given-names:Rodney W.</infon><infon key="name_4">surname:Levine;given-names:Keith E.</infon><infon key="name_5">surname:Poitras;given-names:Eric</infon><infon key="name_6">surname:Harrington;given-names:James M.</infon><infon key="name_7">surname:Wingard;given-names:Christopher J.</infon><infon key="name_8">surname:Holland;given-names:Nathan A.</infon><infon key="name_9">surname:Pathmasiri;given-names:Wimal</infon><infon key="section_type">TITLE</infon><infon key="type">front</infon><infon key="volume">37</infon><infon key="year">2018</infon><offset>0</offset><text>Disposition of Intravenously or Orally Administered Silver Nanoparticles in Pregnant Rats and the Effect on the Biochemical Profile in Urine</text></passage><passage><infon key="section_type">ABSTRACT</infon><infon key="type">abstract</infon><offset>141</offset><text>Here is presented a comprehensive investigation of the distribution of polyvinylpyrrolidone (PVP)-stabilized AgNP (20 or 110 nm) in pregnant rats after a single injection or oral gavage dose. The biological impacts of AgNP exposure were evaluated by metabolomic analysis, and measurement of biomarkers of cardiovascular injury, oxidative stress, and inflammation. The investigation provided a basic understanding of the distribution, internal dose, persistence, metabolomics, and elimination of AgNP following exposure in pregnant rats.</text></passage><passage><infon key="section_type">ABSTRACT</infon><infon key="type">abstract</infon><offset>678</offset><text>Few investigations have been conducted on the disposition and fate of silver nanoparticles (AgNP) in pregnancy. The distribution of a single dose of polyvinylpyrrolidone (PVP)-stabilized AgNP was investigated in pregnant rats. Two sizes of AgNP, 20 and 110 nm, and silver acetate (AgAc) were used to investigate the role of AgNP diameter and particle dissolution in tissue distribution, internal dose, and persistence. Dams were administered AgNP or AgAc intravenously (i.v.) (1 mg/kg) or by gavage (p.o.) (10 mg/kg), or vehicle alone, on gestation day 18 and euthanized at 24 or 48 h post-exposure. The silver concentration in tissues was measured using inductively-coupled plasma mass spectrometry. The distribution of silver in dams was influenced by route of administration and AgNP size. The highest concentration of silver (mug Ag/g tissue) at 48 h was found in spleen for i.v. administered AgNP, and in lungs for AgAc. At 48 h following p.o. administration of AgNP, the highest concentration was measured in cecum and large intestine, and for AgAc in placenta. Silver was detected in placenta and fetuses for all groups. Markers of cardiovascular injury, oxidative stress marker, cytokines, and chemokines were not significantly elevated in exposed dams compared to vehicle-dosed control. NMR metabolomics analysis of urine indicated that AgNP and AgAc exposure impact the carbohydrate, and amino acid metabolism. This study demonstrates that silver crosses the placenta and is transferred to the fetus regardless of the form of silver.</text></passage><passage><infon key="section_type">INTRO</infon><infon key="type">title_1</infon><offset>2222</offset><text>INTRODUCTION</text></passage><passage><infon key="section_type">INTRO</infon><infon key="type">paragraph</infon><offset>2235</offset><text>The broad-spectrum bactericidal properties of silver nanoparticles (AgNP) have led to their widespread use in industries, including textile, personal hygiene, medical applications, and other consumer products. The integration of silver nanomaterials to such a broad selection of products increases the risk of human exposure, both through direct  ...
# &lt;table frame=&quot;void&quot; rules=&quot;groups&quot;&gt;
#         &lt;thead&gt;
#           &lt;tr&gt;
#             &lt;th align=&quot;left&quot; valign=&quot;top&quot; rowspan=&quot;1&quot; colspan=&quot;1&quot;&gt;Characterization Assay&lt;/th&gt;
#             &lt;th align=&quot;center&quot; valign=&quot;top&quot; rowspan=&quot;1&quot; colspan=&quot;1&quot;&gt;Method ID&lt;/th&gt;
#             &lt;th align=&quot;center&quot; valign=&quot;top&quot; rowspan=&quot;1&quot; colspan=&quot;1&quot;&gt;20 nm AgNP (NIEHS-2)&lt;/th&gt;
#             &lt;th align=&quot;center&quot; valign=&quot;top&quot; rowspan=&quot;1&quot; colspan=&quot;1&quot;&gt;110 nm AgNP (NIEHS-4)&lt;/th&gt;
#           &lt;/tr&gt;
#         &lt;/thead&gt;
#         &lt;tbody&gt;
#           &lt;tr&gt;
#             &lt;td align=&quot;left&quot; valign=&quot;top&quot; rowspan=&quot;1&quot; colspan=&quot;1&quot;&gt;Endotoxin Quantification - Kinetic Turbidity (EU/mL)&lt;/td&gt;
#             &lt;td align=&quot;center&quot; valign=&quot;top&quot; rowspan=&quot;1&quot; colspan=&quot;1&quot;&gt;STE-1.2&lt;/td&gt;
#             &lt;td align=&quot;center&quot; valign=&quot;top&quot; rowspan=&quot;1&quot; colspan=&quot;1&quot;&gt;1.1&lt;/td&gt;
#             &lt;td align=&quot;center&quot; valign=&quot;top&quot; rowspan=&quot;1&quot; colspan=&quot;1&quot;&gt;&amp;lt;0.5&lt;/td&gt;
#           &lt;/tr&gt;
#           &lt;tr&gt;
#             &lt;td align=&quot;left&quot; valign=&quot;top&quot; rowspan=&quot;1&quot; colspan=&quot;1&quot;&gt;Hydrodynamic Size/Size Distribution by DLS (Z-Avg [nm])&lt;/td&gt;
#             &lt;td align=&quot;center&quot; valign=&quot;top&quot; rowspan=&quot;1&quot; colspan=&quot;1&quot;&gt;PCC-1&lt;/td&gt;
#             &lt;td align=&quot;center&quot; valign=&quot;top&quot; rowspan=&quot;1&quot; colspan=&quot;1&quot;&gt;26&lt;/td&gt;
#             &lt;td align=&quot;center&quot; valign=&quot;top&quot; rowspan=&quot;1&quot; colspan=&quot;1&quot;&gt;112.3&lt;/td&gt;
#           &lt;/tr&gt;
#           &lt;tr&gt;
#             &lt;td align=&quot;left&quot; valign=&quot;top&quot; rowspan=&quot;1&quot; colspan=&quot;1&quot;&gt;Size by TEM (nm)&lt;/td&gt;
#             &lt;td align=&quot;center&quot; valign=&quot;top&quot; rowspan=&quot;1&quot; colspan=&quot;1&quot;&gt;PCC-7&lt;/td&gt;
#             &lt;td align=&quot;center&quot; valign=&quot;top&quot; rowspan=&quot;1&quot; colspan=&quot;1&quot;&gt;20.5&lt;sup&gt;&lt;xref ref-type=&quot;table-fn&quot; rid=&quot;TFN1&quot;&gt;a&lt;/xref&gt;&lt;/sup&gt;&lt;/td&gt;
#             &lt;td align=&quot;center&quot; valign=&quot;top&quot; rowspan=&quot;1&quot; colspan=&quot;1&quot;&gt;111.3&lt;sup&gt;&lt;xref ref-type=&quot;table-fn&quot; rid=&quot;TFN2&quot;&gt;b&lt;/xref&gt;&lt;/sup&gt;&lt;/td&gt;
#           &lt;/tr&gt;
#           &lt;tr&gt;
#             &lt;td align=&quot;left&quot; valign=&quot;top&quot; rowspan=&quot;1&quot; colspan=&quot;1&quot;&gt;Surface Charge by Zeta Potential (mV)&lt;/td&gt;
#             &lt;td align=&quot;center&quot; valign=&quot;top&quot; rowspan=&quot;1&quot; colspan=&quot;1&quot;&gt;PCC-2&lt;/td&gt;
#             &lt;td align=&quot;center&quot; valign=&quot;top&quot; rowspan=&quot;1&quot; colspan=&quot;1&quot;&gt;-37.1&lt;/td&gt;
#             &lt;td align=&quot;center&quot; valign=&quot;top&quot; rowspan=&quot;1&quot; colspan=&quot;1&quot;&gt;-25.9&lt;/td&gt;
#           &lt;/tr&gt;
#           &lt;tr&gt;
#             &lt;td align=&quot;left&quot; valign=&quot;top&quot; rowspan=&quot;1&quot; colspan=&quot;1&quot;&gt;Silver concentration by ICP-MS (mg/g)&lt;/td&gt;
#             &lt;td align=&quot;center&quot; valign=&quot;top&quot; rowspan=&quot;1&quot; colspan=&quot;1&quot;&gt;PCC-8&lt;/td&gt;
#             &lt;td align=&quot;center&quot; valign=&quot;top&quot; rowspan=&quot;1&quot; colspan=&quot;1&quot;&gt;1.09&lt;/td&gt;
#             &lt;td align=&quot;center&quot; valign=&quot;top&quot; rowspan=&quot;1&quot; colspan=&quot;1&quot;&gt;1.10&lt;/td&gt;
#           &lt;/tr&gt;
#         &lt;/tbody&gt;
#       &lt;/table&gt;
# </infon><offset>49814</offset><text>Characterization Assay	Method ID	20 nm AgNP (NIEHS-2)	110 nm AgNP (NIEHS-4)	 	Endotoxin Quantification - Kinetic Turbidity (EU/mL)	STE-1.2	1.1	&lt;0.5	 	Hydrodynamic Size/Size Distribution by DLS (Z-Avg [nm])	PCC-1	26	112.3	 	Size by TEM (nm)	PCC-7	20.5a	111.3b	 	Surface Charge by Zeta Potential (mV)	PCC-2	-37.1	-25.9	 	Silver concentration by ICP-MS (mg/g)	PCC-8	1.09	1.10	 	</text></passage><passage><infon key="file">T1.xml</infon><infon key="id">T1</infon><infon key="section_type">TABLE</infon><infon key="type">table_footnote</infon><offset>50196</offset><text>Two populations observed; &lt;9% were smaller than 10 nm, the remainder averaged 20 nm</text></passage><passage><infon key="file">T1.xml</infon><infon key="id">T1</infon><infon key="section_type">TABLE</infon><infon key="type">table_footnote</infon><offset>50280</offset><text>Two populations observed; &lt;13% were smaller than 60 nm, the remainder averaged 111 nm</text></passage><passage><infon key="file">T2.xml</infon><infon key="id">T2</infon><infon key="section_type">TABLE</infon><infon key="type">table_caption</infon><offset>50366</offset><text>Concentration of silver (mug Ag/g) in tissues following i.v. administration (1 mg/kg) of AgAc, 20 nm AgNP or 110 nm AgNP to pregnant rats.</text></passage><passage><infon key="file">T2.xml</infon><infon key="id">T2</infon><infon key="section_type">TABLE</infon><infon key="type">table</infon><infon key="xml">&lt;?xml version=&quot;1.0&quot; encoding=&quot;UTF-8&quot;?&gt;
# &lt;table frame=&quot;void&quot; rules=&quot;groups&quot;&gt;
#         &lt;thead&gt;
#           &lt;tr&gt;
#             &lt;th rowspan=&quot;2&quot; align=&quot;left&quot; valign=&quot;middle&quot; colspan=&quot;1&quot;&gt;Tissue&lt;/th&gt;
#             &lt;th colspan=&quot;2&quot; align=&quot;center&quot; valign=&quot;top&quot; rowspan=&quot;1&quot;&gt;AgAc&lt;/th&gt;
#             &lt;th colspan=&quot;2&quot; align=&quot;center&quot; valign=&quot;top&quot; rowspan=&quot;1&quot;&gt;20 nm AgNP&lt;/th&gt;
#             &lt;th colspan=&quot;2&quot; align=&quot;center&quot; valign=&quot;top&quot; rowspan=&quot;1&quot;&gt;110 nm AgNP&lt;/th&gt;
#           &lt;/tr&gt;
#           &lt;tr&gt;
#             &lt;th align=&quot;center&quot; valign=&quot;top&quot; rowspan=&quot;1&quot; colspan=&quot;1&quot;&gt;24 h&lt;/th&gt;
#             &lt;th align=&quot;center&quot; valign=&quot;top&quot; rowspan=&quot;1&quot; colspan=&quot;1&quot;&gt;48 h&lt;/th&gt;
#             &lt;th align=&quot;center&quot; valign=&quot;top&quot; rowspan=&quot;1&quot; colspan=&quot;1&quot;&gt;24 h&lt;/th&gt;
#             &lt;th align=&quot;center&quot; valign=&quot;top&quot; rowspan=&quot;1&quot; colspan=&quot;1&quot;&gt;48 h&lt;/th&gt;
#             &lt;th align=&quot;center&quot; valign=&quot;top&quot; rowspan=&quot;1&quot; colspan=&quot;1&quot;&gt;24 h&lt;/th&gt;
#             &lt;th align=&quot;center&quot; valign=&quot;top&quot; rowspan=&quot;1&quot; colspan=&quot;1&quot;&gt;48 h&lt;/th&gt;
#           &lt;/tr&gt;
#         &lt;/thead&gt;
#         &lt;tbody&gt;
#           &lt;tr&gt;
#             &lt;td align=&quot;left&quot; valign=&quot;top&quot; rowspan=&quot;1&quot; colspan=&quot;1&quot;&gt;Liver&lt;/td&gt;
#             &lt;td align=&quot;center&quot; valign=&quot;top&quot; rowspan=&quot;1&quot; colspan=&quot;1&quot;&gt;1.03+-0.399&lt;/td&gt;
#             &lt;td align=&quot;center&quot; valign=&quot;top&quot; rowspan=&quot;1&quot; colspan=&quot;1&quot;&gt;0.511+-0.534&lt;/td&gt;
#             &lt;td align=&quot;center&quot; valign=&quot;top&quot; rowspan=&quot;1&quot; colspan=&quot;1&quot;&gt;0.312+-0.044&lt;/td&gt;
#             &lt;td align=&quot;center&quot; valign=&quot;top&quot; rowspan=&quot;1&quot; colspan=&quot;1&quot;&gt;0.228+-0.130&lt;/td&gt;
#             &lt;td align=&quot;center&quot; valign=&quot;top&quot; rowspan=&quot;1&quot; colspan=&quot;1&quot;&gt;2.28+-1.69&lt;/td&gt;
#             &lt;td align=&quot;center&quot; valign=&quot;top&quot; rowspan=&quot;1&quot; colspan=&quot;1&quot;&gt;2.71+-1.63&lt;/td&gt;
#           &lt;/tr&gt;
#           &lt;tr&gt;
#             &lt;td align=&quot;left&quot; valign=&quot;top&quot; rowspan=&quot;1&quot; colspan=&quot;1&quot;&gt;Blood&lt;/td&gt;
#             &lt;td align=&quot;center&quot; valign=&quot;top&quot; rowspan=&quot;1&quot; colspan=&quot;1&quot;&gt;0.663+-0.195&lt;/td&gt;
#             &lt;td align=&quot;center&quot; valign=&quot;top&quot; rowspan=&quot;1&quot; colspan=&quot;1&quot;&gt;0.180+-0.033&lt;/td&gt;
#             &lt;td align=&quot;center&quot; valign=&quot;top&quot; rowspan=&quot;1&quot; colspan=&quot;1&quot;&gt;0.375+-0.0485&lt;/td&gt;
#             &lt;td align=&quot;center&quot; valign=&quot;top&quot; rowspan=&quot;1&quot; colspan=&quot;1&quot;&gt;0.214+-0.0916&lt;/td&gt;
#             &lt;td align=&quot;center&quot; valign=&quot;top&quot; rowspan=&quot;1&quot; colspan=&quot;1&quot;&gt;0.594+-0.0566&lt;/td&gt;
#             &lt;td align=&quot;center&quot; valign=&quot;top&quot; rowspan=&quot;1&quot; colspan=&quot;1&quot;&gt;0.348+-0.0720&lt;/td&gt;
#           &lt;/tr&gt;
#           &lt;tr&gt;
#             &lt;td align=&quot;left&quot; valign=&quot;top&quot; rowspan=&quot;1&quot; colspan=&quot;1&quot;&gt;Spleen&lt;/td&gt;
#             &lt;td align=&quot;center&quot; valign=&quot;top&quot; rowspan=&quot;1&quot; colspan=&quot;1&quot;&gt;2.95+-0.927&lt;/td&gt;
#             &lt;td align=&quot;center&quot; valign=&quot;top&quot; rowspan=&quot;1&quot; colspan=&quot;1&quot;&gt;0.524+-0.493&lt;/td&gt;
#             &lt;td align=&quot;center&quot; valign=&quot;top&quot; rowspan=&quot;1&quot; colspan=&quot;1&quot;&gt;1.42+-0.499&lt;/td&gt;
#             &lt;td align=&quot;center&quot; valign=&quot;top&quot; rowspan=&quot;1&quot; colspan=&quot;1&quot;&gt;1.14+-0.636&lt;/td&gt;
#             &lt;td align=&quot;center&quot; valign=&quot;top&quot; rowspan=&quot;1&quot; colspan=&quot;1&quot;&gt;6.79+-2.16&lt;/td&gt;
#             &lt;td align=&quot;center&quot; valign=&quot;top&quot; rowspan=&quot;1&quot; colspan=&quot;1&quot;&gt;3.60+-0.467&lt;/td&gt;
#           &lt;/tr&gt;
#           &lt;tr&gt;
#             &lt;td align=&quot;left&quot; valign=&quot;top&quot; rowspan=&quot;1&quot; colspan=&quot;1&quot;&gt;Lungs&lt;/td&gt;
#             &lt;td align=&quot;center&quot; valign=&quot;top&quot; rowspan=&quot;1&quot; colspan=&quot;1&quot;&gt;1.38+-0.958&lt;/td&gt;
#             &lt;td align=&quot;center&quot; valign=&quot;top&quot; rowspan=&quot;1&quot; colspan=&quot;1&quot;&gt;1.31+-0.906&lt;/td&gt;
#             &lt;td align=&quot;center&quot; valign=&quot;top&quot; rowspan=&quot;1&quot; colspan=&quot;1&quot;&gt;0.519+-0.103&lt;/td&gt;
#             &lt;td align=&quot;center&quot; valign=&quot;top&quot; rowspan=&quot;1&quot; colspan=&quot;1&quot;&gt;0.397+-0.0950&lt;/td&gt;
#             &lt;td align=&quot;center&quot; valign=&quot;top&quot; rowspan=&quot;1&quot; colspan=&quot;1&quot;&gt;0.436+-0.0839&lt;/td&gt;
#             &lt;td align=&quot;center&quot; valign=&quot;top&quot; rowspan=&quot;1&quot; colspan=&quot;1&quot;&gt;0.305+-0.0831&lt;/td&gt;
#           &lt;/tr&gt;
#           &lt;tr&gt;
#             &lt;td align=&quot;left&quot; valign=&quot;top&quot; rowspan=&quot;1&quot; colspan=&quot;1&quot;&gt;Heart&lt;/td&gt;
#             &lt;td align=&quot;center&quot; valign=&quot;top&quot; rowspan=&quot;1&quot; colspan=&quot;1&quot;&gt;0.162+-0.0306&lt;/td&gt;
#             &lt;td align=&quot;center&quot; valign=&quot;top&quot; rowspan=&quot;1&quot; colspan=&quot;1&quot;&gt;0.0584+-0.000479&lt;/td&gt;
#             &lt;td align=&quot;center&quot; valign=&quot;top&quot; rowspan=&quot;1&quot; colspan=&quot;1&quot;&gt;0.127+-0.0168&lt;/td&gt;
#             &lt;td align=&quot;center&quot; valign=&quot;top&quot; rowspan=&quot;1&quot; colspan=&quot;1&quot;&gt;0.0863&lt;sup&gt;&lt;xref ref-type=&quot;table-fn&quot; rid=&quot;TFN3&quot;&gt;a&lt;/xref&gt;&lt;/sup&gt;&lt;/td&gt;
#             &lt;td align=&quot;center&quot; valign=&quot;top&quot; rowspan=&quot;1&quot; colspan=&quot;1&quot;&gt;0.119+-0.0204&lt;/td&gt;
#             &lt;td align=&quot;center&quot; valign=&quot;top&quot; rowspan=&quot;1&quot; colspan=&quot;1&quot;&gt;0.104+-0.0144&lt;/td&gt;
#           &lt;/tr&gt;
#           &lt;tr&gt;
#             &lt;td align=&quot;left&quot; valign=&quot;top&quot; rowspan=&quot;1&quot; colspan=&quot;1&quot;&gt;Kidney&lt;/td&gt;
#             &lt;td align=&quot;center&quot; valign=&quot;top&quot; rowspan=&quot;1&quot; colspan=&quot;1&quot;&gt;0.405+-0.0944&lt;/td&gt;
#             &lt;td align=&quot;center&quot; valign=&quot;top&quot; rowspan=&quot;1&quot; colspan=&quot;1&quot;&gt;0.233+-0.0364&lt;/td&gt;
#             &lt;td align=&quot;center&quot; valign=&quot;top&quot; rowspan=&quot;1&quot; colspan=&quot;1&quot;&gt;0.431+-0.0520&lt;/td&gt;
#             &lt;td align=&quot;center&quot; valign=&quot;top&quot; rowspan=&quot;1&quot; colspan=&quot;1&quot;&gt;0.222+-0.0843&lt;/td&gt;
#             &lt;td align=&quot;center&quot; valign=&quot;top&quot; rowspan=&quot;1&quot; colspan=&quot;1&quot;&gt;0.472+-0.0968&lt;/td&gt;
#             &lt;td align=&quot;center&quot; valign=&quot;top&quot; rowspan=&quot;1&quot; colspan=&quot;1&quot;&gt;0.373+-0.161&lt;/td&gt;
#           &lt;/tr&gt;
#           &lt;tr&gt;
#             &lt;td align=&quot;left&quot; valign=&quot;top&quot; rowspan=&quot;1&quot; colspan=&quot;1&quot;&gt;Brain&lt;/td&gt;
#             &lt;td align=&quot;center&quot; valign=&quot;top&quot; rowspan=&quot;1&quot; colspan=&quot;1&quot;&gt;0.0358+-0.000661&lt;/td&gt;
#             &lt;td align=&quot;center&quot; valign=&quot;top&quot; rowspan=&quot;1&quot; colspan=&quot;1&quot;&gt;0.0233+-0.00150&lt;/td&gt;
#             &lt;td align=&quot;center&quot; valign=&quot;top&quot; rowspan=&quot;1&quot; colspan=&quot;1&quot;&gt;0.0297&lt;sup&gt;&lt;xref ref-type=&quot;table-fn&quot; rid=&quot;TFN3&quot;&gt;a&lt;/xref&gt;&lt;/sup&gt;&lt;/td&gt;
#             &lt;td align=&quot;center&quot; valign=&quot;top&quot; rowspan=&quot;1&quot; colspan=&quot;1&quot;&gt;0.0424&lt;sup&gt;&lt;xref ref-type=&quot;table-fn&quot; rid=&quot;TFN3&quot;&gt;a&lt;/xref&gt;&lt;/sup&gt;&lt;/td&gt;
#             &lt;td align=&quot;center&quot; valign=&quot;top&quot; rowspan=&quot;1&quot; colspan=&quot;1&quot;&gt;&amp;lt;LOQ&lt;sup&gt;&lt;xref ref-type=&quot;table-fn&quot; rid=&quot;TFN4&quot;&gt;b&lt;/xref&gt;&lt;/sup&gt;&lt;/td&gt;
#             &lt;td align=&quot;center&quot; valign=&quot;top&quot; rowspan=&quot;1&quot; colspan=&quot;1&quot;&gt;&amp;lt;LOQ&lt;/td&gt;
#           &lt;/tr&gt;
#           &lt;tr&gt;
#             &lt;td align=&quot;left&quot; valign=&quot;top&quot; rowspan=&quot;1&quot; colspan=&quot;1&quot;&gt;Skin&lt;/td&gt;
#             &lt;td align=&quot;center&quot; valign=&quot;top&quot; rowspan=&quot;1&quot; colspan=&quot;1&quot;&gt;0.224+-0.0488&lt;/td&gt;
#             &lt;td align=&quot;center&quot; valign=&quot;top&quot; rowspan=&quot;1&quot; colspan=&quot;1&quot;&gt;0.265+-0.141&lt;/td&gt;
#             &lt;td align=&quot;center&quot; valign=&quot;top&quot; rowspan=&quot;1&quot; colspan=&quot;1&quot;&gt;0.196+-0.147&lt;/td&gt;
#             &lt;td align=&quot;center&quot; valign=&quot;top&quot; rowspan=&quot;1&quot; colspan=&quot;1&quot;&gt;0.194+-0.0735&lt;/td&gt;
#             &lt;td align=&quot;center&quot; valign=&quot;top&quot; rowspan=&quot;1&quot; colspan=&quot;1&quot;&gt;0.188+-0.107&lt;/td&gt;
#             &lt;td align=&quot;center&quot; valign=&quot;top&quot; rowspan=&quot;1&quot; colspan=&quot;1&quot;&gt;0.248+-0.189&lt;/td&gt;
#           &lt;/tr&gt;
#           &lt;tr&gt;
#             &lt;td align=&quot;left&quot; valign=&quot;top&quot; rowspan=&quot;1&quot; colspan=&quot;1&quot;&gt;Muscle&lt;/td&gt;
#             &lt;td align=&quot;center&quot; valign=&quot;top&quot; rowspan=&quot;1&quot; colspan=&quot;1&quot;&gt;0.0833+-0.0616&lt;/td&gt;
#             &lt;td align=&quot;center&quot; valign=&quot;top&quot; rowspan=&quot;1&quot; colspan=&quot;1&quot;&gt;0.0556+-0.0210&lt;/td&gt;
#             &lt;td align=&quot;center&quot; valign=&quot;top&quot; rowspan=&quot;1&quot; colspan=&quot;1&quot;&gt;0.0284+-0.00378&lt;/td&gt;
#             &lt;td align=&quot;center&quot; valign=&quot;top&quot; rowspan=&quot;1&quot; colspan=&quot;1&quot;&gt;0.0146+-0.00525&lt;/td&gt;
#             &lt;td align=&quot;center&quot; valign=&quot;top&quot; rowspan=&quot;1&quot; colspan=&quot;1&quot;&gt;&amp;lt;LOQ&lt;/td&gt;
#             &lt;td align=&quot;center&quot; valign=&quot;top&quot; rowspan=&quot;1&quot; colspan=&quot;1&quot;&gt;&amp;lt;LOQ&lt;/td&gt;
#           &lt;/tr&gt;
#           &lt;tr&gt;
#             &lt;td align=&quot;left&quot; valign=&quot;top&quot; rowspan=&quot;1&quot; colspan=&quot;1&quot;&gt;Adipose&lt;/td&gt;
#             &lt;td align=&quot;center&quot; valign=&quot;top&quot; rowspan=&quot;1&quot; colspan=&quot;1&quot;&gt;0.0453+-0.0191&lt;/td&gt;
#             &lt;td align=&quot;center&quot; valign=&quot;top&quot; rowspan=&quot;1&quot; colspan=&quot;1&quot;&gt;&amp;lt;LOQ&lt;/td&gt;
#             &lt;td align=&quot;center&quot; valign=&quot;top&quot; rowspan=&quot;1&quot; colspan=&quot;1&quot;&gt;&amp;lt;LOQ&lt;/td&gt;
#             &lt;td align=&quot;center&quot; valign=&quot;top&quot; rowspan=&quot;1&quot; colspan=&quot;1&quot;&gt;&amp;lt;LOQ&lt;/td&gt;
#             &lt;td align=&quot;center&quot; valign=&quot;top&quot; rowspan=&quot;1&quot; colspan=&quot;1&quot;&gt;&amp;lt;LOQ&lt;/td&gt;
#             &lt;td align=&quot;center&quot; valign=&quot;top&quot; rowspan=&quot;1&quot; colspan=&quot;1&quot;&gt;&amp;lt;LOQ&lt;/td&gt;
#           &lt;/tr&gt;
#           &lt;tr&gt;
#             &lt;td align=&quot;left&quot; valign=&quot;top&quot; rowspan=&quot;1&quot; colspan=&quot;1&quot;&gt;Bone&lt;/td&gt;
#             &lt;td align=&quot;center&quot; valign=&quot;top&quot; rowspan=&quot;1&quot; colspan=&quot;1&quot;&gt;0.311+-0.0455&lt;/td&gt;
#             &lt;td align=&quot;center&quot; valign=&quot;top&quot; rowspan=&quot;1&quot; colspan=&quot;1&quot;&gt;0.119+-0.0370&lt;/td&gt;
#             &lt;td align=&quot;center&quot; valign=&quot;top&quot; rowspan=&quot;1&quot; colspan=&quot;1&quot;&gt;0.243+-0.0780&lt;/td&gt;
#             &lt;td align=&quot;center&quot; valign=&quot;top&quot; rowspan=&quot;1&quot; colspan=&quot;1&quot;&gt;0.144+-0.0789&lt;/td&gt;
#             &lt;td align=&quot;center&quot; valign=&quot;top&quot; rowspan=&quot;1&quot; colspan=&quot;1&quot;&gt;0.120+-0.0386&lt;/td&gt;
#             &lt;td align=&quot;center&quot; valign=&quot;top&quot; rowspan=&quot;1&quot; colspan=&quot;1&quot;&gt;0.136+-0.0299&lt;/td&gt;
#           &lt;/tr&gt;
#           &lt;tr&gt;
#             &lt;td align=&quot;left&quot; valign=&quot;top&quot; rowspan=&quot;1&quot; colspan=&quot;1&quot;&gt;Stomach and Small Intestine&lt;/td&gt;
#             &lt;td align=&quot;center&quot; valign=&quot;top&quot; rowspan=&quot;1&quot; colspan=&quot;1&quot;&gt;0.377+-0.215&lt;/td&gt;
#             &lt;td align=&quot;center&quot; valign=&quot;top&quot; rowspan=&quot;1&quot; colspan=&quot;1&quot;&gt;0.145+-0.0958&lt;/td&gt;
#             &lt;td align=&quot;center&quot; valign=&quot;top&quot; rowspan=&quot;1&quot; colspan=&quot;1&quot;&gt;0.319+-0.0378&lt;/td&gt;
#             &lt;td align=&quot;center&quot; valign=&quot;top&quot; rowspan=&quot;1&quot; colspan=&quot;1&quot;&gt;0.167+-0.148&lt;/td&gt;
#             &lt;td align=&quot;center&quot; valign=&quot;top&quot; rowspan=&quot;1&quot; colspan=&quot;1&quot;&gt;0.214+-0.165&lt;/td&gt;
#             &lt;td align=&quot;center&quot; valign=&quot;top&quot; rowspan=&quot;1&quot; colspan=&quot;1&quot;&gt;0.136+-0.0376&lt;/td&gt;
#           &lt;/tr&gt;
#           &lt;tr&gt;
#             &lt;td align=&quot;left&quot; valign=&quot;top&quot; rowspan=&quot;1&quot; colspan=&quot;1&quot;&gt;Cecum and Large Intestine&lt;/td&gt;
#             &lt;td align=&quot;center&quot; valign=&quot;top&quot; rowspan=&quot;1&quot; colspan=&quot;1&quot;&gt;0.414+-0.118&lt;/td&gt;
#             &lt;td align=&quot;center&quot; valign=&quot;top&quot; rowspan=&quot;1&quot; colspan=&quot;1&quot;&gt;0.443+-0.175&lt;/td&gt;
#             &lt;td align=&quot;center&quot; valign=&quot;top&quot; rowspan=&quot;1&quot; colspan=&quot;1&quot;&gt;0.976+-0.431&lt;/td&gt;
#             &lt;td align=&quot;center&quot; valign=&quot;top&quot; rowspan=&quot;1&quot; colspan=&quot;1&quot;&gt;0.370+-0.222&lt;/td&gt;
#             &lt;td align=&quot;center&quot; valign=&quot;top&quot; rowspan=&quot;1&quot; colspan=&quot;1&quot;&gt;0.554+-0.150&lt;/td&gt;
#             &lt;td align=&quot;center&quot; valign=&quot;top&quot; rowspan=&quot;1&quot; colspan=&quot;1&quot;&gt;0.459+-0.153&lt;/td&gt;
#           &lt;/tr&gt;
#           &lt;tr&gt;
#             &lt;td align=&quot;left&quot; valign=&quot;top&quot; rowspan=&quot;1&quot; colspan=&quot;1&quot;&gt;Pancreas&lt;/td&gt;
#             &lt;td align=&quot;center&quot; valign=&quot;top&quot; rowspan=&quot;1&quot; colspan=&quot;1&quot;&gt;0.196+-0.0561&lt;/td&gt;
#             &lt;td align=&quot;center&quot; valign=&quot;top&quot; rowspan=&quot;1&quot; colspan=&quot;1&quot;&gt;0.170+-0.116&lt;/td&gt;
#             &lt;td align=&quot;center&quot; valign=&quot;top&quot; rowspan=&quot;1&quot; colspan=&quot;1&quot;&gt;0.321+-0.204&lt;/td&gt;
#             &lt;td align=&quot;center&quot; valign=&quot;top&quot; rowspan=&quot;1&quot; colspan=&quot;1&quot;&gt;0.138+-0.0553&lt;/td&gt;
#             &lt;td align=&quot;center&quot; valign=&quot;top&quot; rowspan=&quot;1&quot; colspan=&quot;1&quot;&gt;0.0732+-0.0214&lt;/td&gt;
#             &lt;td align=&quot;center&quot; valign=&quot;top&quot; rowspan=&quot;1&quot; colspan=&quot;1&quot;&gt;0.0831+-0.0485&lt;/td&gt;
#           &lt;/tr&gt;
#           &lt;tr&gt;
#             &lt;td align=&quot;left&quot; valign=&quot;top&quot; rowspan=&quot;1&quot; colspan=&quot;1&quot;&gt;Placenta&lt;/td&gt;
#             &lt;td align=&quot;center&quot; valign=&quot;top&quot; rowspan=&quot;1&quot; colspan=&quot;1&quot;&gt;0.881+-0.337&lt;/td&gt;
#             &lt;td align=&quot;center&quot; valign=&quot;top&quot; rowspan=&quot;1&quot; colspan=&quot;1&quot;&gt;0.756+-0.184&lt;/td&gt;
#             &lt;td align=&quot;center&quot; valign=&quot;top&quot; rowspan=&quot;1&quot; colspan=&quot;1&quot;&gt;0.696+-0.0682&lt;/td&gt;
#             &lt;td align=&quot;center&quot; valign=&quot;top&quot; rowspan=&quot;1&quot; colspan=&quot;1&quot;&gt;0.926+-0.436&lt;/td&gt;
#             &lt;td align=&quot;center&quot; valign=&quot;top&quot; rowspan=&quot;1&quot; colspan=&quot;1&quot;&gt;0.719+-0.0364&lt;/td&gt;
#             &lt;td align=&quot;center&quot; valign=&quot;top&quot; rowspan=&quot;1&quot; colspan=&quot;1&quot;&gt;1.15+-0.239&lt;/td&gt;
#           &lt;/tr&gt;
#           &lt;tr&gt;
#             &lt;td align=&quot;left&quot; valign=&quot;top&quot; rowspan=&quot;1&quot; colspan=&quot;1&quot;&gt;Fetus&lt;/td&gt;
#             &lt;td align=&quot;center&quot; valign=&quot;top&quot; rowspan=&quot;1&quot; colspan=&quot;1&quot;&gt;0.0603+-0.0106&lt;/td&gt;
#             &lt;td align=&quot;center&quot; valign=&quot;top&quot; rowspan=&quot;1&quot; colspan=&quot;1&quot;&gt;0.0759+-0.019&lt;/td&gt;
#             &lt;td align=&quot;center&quot; valign=&quot;top&quot; rowspan=&quot;1&quot; colspan=&quot;1&quot;&gt;0.0445+-0.00763&lt;/td&gt;
#             &lt;td align=&quot;center&quot; valign=&quot;top&quot; rowspan=&quot;1&quot; colspan=&quot;1&quot;&gt;0.0549+-0.0174&lt;/td&gt;
#             &lt;td align=&quot;center&quot; valign=&quot;top&quot; rowspan=&quot;1&quot; colspan=&quot;1&quot;&gt;0.0316+-0.000507&lt;/td&gt;
#             &lt;td align=&quot;center&quot; valign=&quot;top&quot; rowspan=&quot;1&quot; colspan=&quot;1&quot;&gt;0.0492+-0.00674&lt;/td&gt;
#           &lt;/tr&gt;
#         &lt;/tbody&gt;
#       &lt;/table&gt;
# </infon><offset>50505</offset><text>Tissue	AgAc	20 nm AgNP	110 nm AgNP	 	24 h	48 h	24 h	48 h	24 h	48 h	 	Liver	1.03+-0.399	0.511+-0.534	0.312+-0.044	0.228+-0.130	2.28+-1.69	2.71+-1.63	 	Blood	0.663+-0.195	0.180+-0.033	0.375+-0.0485	0.214+-0.0916	0.594+-0.0566	0.348+-0.0720	 	Spleen	2.95+-0.927	0.524+-0.493	1.42+-0.499	1.14+-0.636	6.79+-2.16	3.60+-0.467	 	Lungs	1.38+-0.958	1.31+-0.906	0.519+-0.103	0.397+-0.0950	0.436+-0.0839	0.305+-0.0831	 	Heart	0.162+-0.0306	0.0584+-0.000479	0.127+-0.0168	0.0863a	0.119+-0.0204	0.104+-0.0144	 	Kidney	0.405+-0.0944	0.233+-0.0364	0.431+-0.0520	0.222+-0.0843	0.472+-0.0968	0.373+-0.161	 	Brain	0.0358+-0.000661	0.0233+-0.00150	0.0297a	0.0424a	&lt;LOQb	&lt;LOQ	 	Skin	0.224+-0.0488	0.265+-0.141	0.196+-0.147	0.194+-0.0735	0.188+-0.107	0.248+-0.189	 	Muscle	0.0833+-0.0616	0.0556+-0.0210	0.0284+-0.00378	0.0146+-0.00525	&lt;LOQ	&lt;LOQ	 	Adipose	0.0453+-0.0191	&lt;LOQ	&lt;LOQ	&lt;LOQ	&lt;LOQ	&lt;LOQ	 	Bone	0.311+-0.0455	0.119+-0.0370	0.243+-0.0780	0.144+-0.0789	0.120+-0.0386	0.136+-0.0299	 	Stomach and Small Intestine	0.377+-0.215	0.145+-0.0958	0.319+-0.0378	0.167+-0.148	0.214+-0.165	0.136+-0.0376	 	Cecum and Large Intestine	0.414+-0.118	0.443+-0.175	0.976+-0.431	0.370+-0.222	0.554+-0.150	0.459+-0.153	 	Pancreas	0.196+-0.0561	0.170+-0.116	0.321+-0.204	0.138+-0.0553	0.0732+-0.0214	0.0831+-0.0485	 	Placenta	0.881+-0.337	0.756+-0.184	0.696+-0.0682	0.926+-0.436	0.719+-0.0364	1.15+-0.239	 	Fetus	0.0603+-0.0106	0.0759+-0.019	0.0445+-0.00763	0.0549+-0.0174	0.0316+-0.000507	0.0492+-0.00674	 	</text></passage><passage><infon key="file">T2.xml</infon><infon key="id">T2</infon><infon key="section_type">TABLE</infon><infon key="type">table_foot</infon><offset>51975</offset><text>All data are reported as Mean +- SD (n= 3)</text></passage><passage><infon key="file">T2.xml</infon><infon key="id">T2</infon><infon key="section_type">TABLE</infon><infon key="type">table_footnote</infon><offset>52018</offset><text>Only one rat had levels above quantitation limit.</text></passage><passage><infon key="file">T2.xml</infon><infon key="id">T2</infon><infon key="section_type">TABLE</infon><infon key="type">table_footnote</infon><offset>52068</offset><text>&lt;LOQ = below limit of quantitation = quantitation limit; 0.0125 mug/g for tissues.</text></passage><passage><infon key="file">T3.xml</infon><infon key="id">T3</infon><infon key="section_type">TABLE</infon><infon key="type">table_caption</infon><offset>52151</offset><text>Percent recovered of administered dose of silver in tissues following i.v. administration (1 mg/kg) of AgAc, 20 nm AgNP or 110 nm AgNP to pregnant rats</text></passage><passage><infon key="file">T3.xml</infon><infon key="id">T3</infon><infon key="section_type">TABLE</infon><infon key="type">table</infon><infon key="xml">&lt;?xml version=&quot;1.0&quot; encoding=&quot;UTF-8&quot;?&gt;
# &lt;table frame=&quot;void&quot; rules=&quot;groups&quot;&gt;
#         &lt;thead&gt;
#           &lt;tr&gt;
#             &lt;th rowspan=&quot;2&quot; align=&quot;left&quot; valign=&quot;middle&quot; colspan=&quot;1&quot;&gt;Tissue&lt;/th&gt;
#             &lt;th colspan=&quot;2&quot; align=&quot;center&quot; valign=&quot;top&quot; rowspan=&quot;1&quot;&gt;AgAc&lt;/th&gt;
#             &lt;th colspan=&quot;2&quot; align=&quot;center&quot; valign=&quot;top&quot; rowspan=&quot;1&quot;&gt;20 nm AgNP&lt;/th&gt;
#             &lt;th colspan=&quot;2&quot; align=&quot;center&quot; valign=&quot;top&quot; rowspan=&quot;1&quot;&gt;110 nm AgNP&lt;/th&gt;
#           &lt;/tr&gt;
#           &lt;tr&gt;
#             &lt;th align=&quot;center&quot; valign=&quot;top&quot; rowspan=&quot;1&quot; colspan=&quot;1&quot;&gt;24 h&lt;/th&gt;
#             &lt;th align=&quot;center&quot; valign=&quot;top&quot; rowspan=&quot;1&quot; colspan=&quot;1&quot;&gt;48 h&lt;/th&gt;
#             &lt;th align=&quot;center&quot; valign=&quot;top&quot; rowspan=&quot;1&quot; colspan=&quot;1&quot;&gt;24 h&lt;/th&gt;
#             &lt;th align=&quot;center&quot; valign=&quot;top&quot; rowspan=&quot;1&quot; colspan=&quot;1&quot;&gt;48 h&lt;/th&gt;
#             &lt;th align=&quot;center&quot; valign=&quot;top&quot; rowspan=&quot;1&quot; colspan=&quot;1&quot;&gt;24 h&lt;/th&gt;
#             &lt;th align=&quot;center&quot; valign=&quot;top&quot; rowspan=&quot;1&quot; colspan=&quot;1&quot;&gt;48 h&lt;/th&gt;
#           &lt;/tr&gt;
#         &lt;/thead&gt;
#         &lt;tbody&gt;
#           &lt;tr&gt;
#             &lt;td align=&quot;left&quot; valign=&quot;top&quot; rowspan=&quot;1&quot; colspan=&quot;1&quot;&gt;Liver&lt;/td&gt;
#             &lt;td align=&quot;center&quot; valign=&quot;top&quot; rowspan=&quot;1&quot; colspan=&quot;1&quot;&gt;4.33+-1.63&lt;/td&gt;
#             &lt;td align=&quot;center&quot; valign=&quot;top&quot; rowspan=&quot;1&quot; colspan=&quot;1&quot;&gt;2.08+-2.02&lt;/td&gt;
#             &lt;td align=&quot;center&quot; valign=&quot;top&quot; rowspan=&quot;1&quot; colspan=&quot;1&quot;&gt;1.44+-0.203&lt;/td&gt;
#             &lt;td align=&quot;center&quot; valign=&quot;top&quot; rowspan=&quot;1&quot; colspan=&quot;1&quot;&gt;1.02+-0.635&lt;/td&gt;
#             &lt;td align=&quot;center&quot; valign=&quot;top&quot; rowspan=&quot;1&quot; colspan=&quot;1&quot;&gt;8.69+-6.04&lt;/td&gt;
#             &lt;td align=&quot;center&quot; valign=&quot;top&quot; rowspan=&quot;1&quot; colspan=&quot;1&quot;&gt;12.1+-7.11&lt;/td&gt;
#           &lt;/tr&gt;
#           &lt;tr&gt;
#             &lt;td align=&quot;left&quot; valign=&quot;top&quot; rowspan=&quot;1&quot; colspan=&quot;1&quot;&gt;Blood&lt;/td&gt;
#             &lt;td align=&quot;center&quot; valign=&quot;top&quot; rowspan=&quot;1&quot; colspan=&quot;1&quot;&gt;4.88+-1.39&lt;/td&gt;
#             &lt;td align=&quot;center&quot; valign=&quot;top&quot; rowspan=&quot;1&quot; colspan=&quot;1&quot;&gt;1.33+-0.257&lt;/td&gt;
#             &lt;td align=&quot;center&quot; valign=&quot;top&quot; rowspan=&quot;1&quot; colspan=&quot;1&quot;&gt;2.80+-0.346&lt;/td&gt;
#             &lt;td align=&quot;center&quot; valign=&quot;top&quot; rowspan=&quot;1&quot; colspan=&quot;1&quot;&gt;1.57+-0.664&lt;/td&gt;
#             &lt;td align=&quot;center&quot; valign=&quot;top&quot; rowspan=&quot;1&quot; colspan=&quot;1&quot;&gt;4.41+-0.418&lt;/td&gt;
#             &lt;td align=&quot;center&quot; valign=&quot;top&quot; rowspan=&quot;1&quot; colspan=&quot;1&quot;&gt;2.55+-0.516&lt;/td&gt;
#           &lt;/tr&gt;
#           &lt;tr&gt;
#             &lt;td align=&quot;left&quot; valign=&quot;top&quot; rowspan=&quot;1&quot; colspan=&quot;1&quot;&gt;Spleen&lt;/td&gt;
#             &lt;td align=&quot;center&quot; valign=&quot;top&quot; rowspan=&quot;1&quot; colspan=&quot;1&quot;&gt;0.529+-0.124&lt;/td&gt;
#             &lt;td align=&quot;center&quot; valign=&quot;top&quot; rowspan=&quot;1&quot; colspan=&quot;1&quot;&gt;0.114+-0.118&lt;/td&gt;
#             &lt;td align=&quot;center&quot; valign=&quot;top&quot; rowspan=&quot;1&quot; colspan=&quot;1&quot;&gt;0.274+-0.0631&lt;/td&gt;
#             &lt;td align=&quot;center&quot; valign=&quot;top&quot; rowspan=&quot;1&quot; colspan=&quot;1&quot;&gt;0.193+-0.110&lt;/td&gt;
#             &lt;td align=&quot;center&quot; valign=&quot;top&quot; rowspan=&quot;1&quot; colspan=&quot;1&quot;&gt;1.44+-0.587&lt;/td&gt;
#             &lt;td align=&quot;center&quot; valign=&quot;top&quot; rowspan=&quot;1&quot; colspan=&quot;1&quot;&gt;0.780+-0.0878&lt;/td&gt;
#           &lt;/tr&gt;
#           &lt;tr&gt;
#             &lt;td align=&quot;left&quot; valign=&quot;top&quot; rowspan=&quot;1&quot; colspan=&quot;1&quot;&gt;Lungs&lt;/td&gt;
#             &lt;td align=&quot;center&quot; valign=&quot;top&quot; rowspan=&quot;1&quot; colspan=&quot;1&quot;&gt;0.534+-0.402&lt;/td&gt;
#             &lt;td align=&quot;center&quot; valign=&quot;top&quot; rowspan=&quot;1&quot; colspan=&quot;1&quot;&gt;0.496+-0.325&lt;/td&gt;
#             &lt;td align=&quot;center&quot; valign=&quot;top&quot; rowspan=&quot;1&quot; colspan=&quot;1&quot;&gt;0.204+-0.0454&lt;/td&gt;
#             &lt;td align=&quot;center&quot; valign=&quot;top&quot; rowspan=&quot;1&quot; colspan=&quot;1&quot;&gt;0.138+-0.0379&lt;/td&gt;
#             &lt;td align=&quot;center&quot; valign=&quot;top&quot; rowspan=&quot;1&quot; colspan=&quot;1&quot;&gt;0.157+-0.0247&lt;/td&gt;
#             &lt;td align=&quot;center&quot; valign=&quot;top&quot; rowspan=&quot;1&quot; colspan=&quot;1&quot;&gt;0.0974+-0.0139&lt;/td&gt;
#           &lt;/tr&gt;
#           &lt;tr&gt;
#             &lt;td align=&quot;left&quot; valign=&quot;top&quot; rowspan=&quot;1&quot; colspan=&quot;1&quot;&gt;Heart&lt;/td&gt;
#             &lt;td align=&quot;center&quot; valign=&quot;top&quot; rowspan=&quot;1&quot; colspan=&quot;1&quot;&gt;0.0504+-0.005&lt;/td&gt;
#             &lt;td align=&quot;center&quot; valign=&quot;top&quot; rowspan=&quot;1&quot; colspan=&quot;1&quot;&gt;0.0181+-0.00348&lt;/td&gt;
#             &lt;td align=&quot;center&quot; valign=&quot;top&quot; rowspan=&quot;1&quot; colspan=&quot;1&quot;&gt;0.0404+-0.00715&lt;/td&gt;
#             &lt;td align=&quot;center&quot; valign=&quot;top&quot; rowspan=&quot;1&quot; colspan=&quot;1&quot;&gt;0.0234&lt;sup&gt;&lt;xref ref-type=&quot;table-fn&quot; rid=&quot;TFN5&quot;&gt;a&lt;/xref&gt;&lt;/sup&gt;&lt;/td&gt;
#             &lt;td align=&quot;center&quot; valign=&quot;top&quot; rowspan=&quot;1&quot; colspan=&quot;1&quot;&gt;0.0332+-0.00344&lt;/td&gt;
#             &lt;td align=&quot;center&quot; valign=&quot;top&quot; rowspan=&quot;1&quot; colspan=&quot;1&quot;&gt;0.0317+-0.000950&lt;/td&gt;
#           &lt;/tr&gt;
#           &lt;tr&gt;
#             &lt;td align=&quot;left&quot; valign=&quot;top&quot; rowspan=&quot;1&quot; colspan=&quot;1&quot;&gt;Kidney&lt;/td&gt;
#             &lt;td align=&quot;center&quot; valign=&quot;top&quot; rowspan=&quot;1&quot; colspan=&quot;1&quot;&gt;0.248+-0.0583&lt;/td&gt;
#             &lt;td align=&quot;center&quot; valign=&quot;top&quot; rowspan=&quot;1&quot; colspan=&quot;1&quot;&gt;0.125+-0.0233&lt;/td&gt;
#             &lt;td align=&quot;center&quot; valign=&quot;top&quot; rowspan=&quot;1&quot; colspan=&quot;1&quot;&gt;0.265+-0.0367&lt;/td&gt;
#             &lt;td align=&quot;center&quot; valign=&quot;top&quot; rowspan=&quot;1&quot; colspan=&quot;1&quot;&gt;0.125+-0.0454&lt;/td&gt;
#             &lt;td align=&quot;center&quot; valign=&quot;top&quot; rowspan=&quot;1&quot; colspan=&quot;1&quot;&gt;0.274+-0.0505&lt;/td&gt;
#             &lt;td align=&quot;center&quot; valign=&quot;top&quot; rowspan=&quot;1&quot; colspan=&quot;1&quot;&gt;0.221+-0.0734&lt;/td&gt;
#           &lt;/tr&gt;
#           &lt;tr&gt;
#             &lt;td align=&quot;left&quot; valign=&quot;top&quot; rowspan=&quot;1&quot; colspan=&quot;1&quot;&gt;Brain&lt;/td&gt;
#             &lt;td align=&quot;center&quot; valign=&quot;top&quot; rowspan=&quot;1&quot; colspan=&quot;1&quot;&gt;0.0213+-0.00126&lt;/td&gt;
#             &lt;td align=&quot;center&quot; valign=&quot;top&quot; rowspan=&quot;1&quot; colspan=&quot;1&quot;&gt;0.0215+-0.000908&lt;/td&gt;
#             &lt;td align=&quot;center&quot; valign=&quot;top&quot; rowspan=&quot;1&quot; colspan=&quot;1&quot;&gt;0.0169&lt;sup&gt;&lt;xref ref-type=&quot;table-fn&quot; rid=&quot;TFN5&quot;&gt;a&lt;/xref&gt;&lt;/sup&gt;&lt;/td&gt;
#             &lt;td align=&quot;center&quot; valign=&quot;top&quot; rowspan=&quot;1&quot; colspan=&quot;1&quot;&gt;0.0240&lt;sup&gt;&lt;xref ref-type=&quot;table-fn&quot; rid=&quot;TFN5&quot;&gt;a&lt;/xref&gt;&lt;/sup&gt;&lt;/td&gt;
#             &lt;td align=&quot;center&quot; valign=&quot;top&quot; rowspan=&quot;1&quot; colspan=&quot;1&quot;&gt;&amp;lt;LOQ&lt;sup&gt;&lt;xref ref-type=&quot;table-fn&quot; rid=&quot;TFN6&quot;&gt;b&lt;/xref&gt;&lt;/sup&gt;&lt;/td&gt;
#             &lt;td align=&quot;center&quot; valign=&quot;top&quot; rowspan=&quot;1&quot; colspan=&quot;1&quot;&gt;&amp;lt;LOQ&lt;/td&gt;
#           &lt;/tr&gt;
#           &lt;tr&gt;
#             &lt;td align=&quot;left&quot; valign=&quot;top&quot; rowspan=&quot;1&quot; colspan=&quot;1&quot;&gt;Skin&lt;/td&gt;
#             &lt;td align=&quot;center&quot; valign=&quot;top&quot; rowspan=&quot;1&quot; colspan=&quot;1&quot;&gt;4.34+-0.995&lt;/td&gt;
#             &lt;td align=&quot;center&quot; valign=&quot;top&quot; rowspan=&quot;1&quot; colspan=&quot;1&quot;&gt;5.49+-2.95&lt;/td&gt;
#             &lt;td align=&quot;center&quot; valign=&quot;top&quot; rowspan=&quot;1&quot; colspan=&quot;1&quot;&gt;3.89+-3.00&lt;/td&gt;
#             &lt;td align=&quot;center&quot; valign=&quot;top&quot; rowspan=&quot;1&quot; colspan=&quot;1&quot;&gt;3.80+-1.47&lt;/td&gt;
#             &lt;td align=&quot;center&quot; valign=&quot;top&quot; rowspan=&quot;1&quot; colspan=&quot;1&quot;&gt;3.75+-2.11&lt;/td&gt;
#             &lt;td align=&quot;center&quot; valign=&quot;top&quot; rowspan=&quot;1&quot; colspan=&quot;1&quot;&gt;5.23+-4.08&lt;/td&gt;
#           &lt;/tr&gt;
#           &lt;tr&gt;
#             &lt;td align=&quot;left&quot; valign=&quot;top&quot; rowspan=&quot;1&quot; colspan=&quot;1&quot;&gt;Muscle&lt;/td&gt;
#             &lt;td align=&quot;center&quot; valign=&quot;top&quot; rowspan=&quot;1&quot; colspan=&quot;1&quot;&gt;3.42+-2.53&lt;/td&gt;
#             &lt;td align=&quot;center&quot; valign=&quot;top&quot; rowspan=&quot;1&quot; colspan=&quot;1&quot;&gt;2.44+-0.901&lt;/td&gt;
#             &lt;td align=&quot;center&quot; valign=&quot;top&quot; rowspan=&quot;1&quot; colspan=&quot;1&quot;&gt;1.19+-0.158&lt;/td&gt;
#             &lt;td align=&quot;center&quot; valign=&quot;top&quot; rowspan=&quot;1&quot; colspan=&quot;1&quot;&gt;0.605+-0.137&lt;/td&gt;
#             &lt;td align=&quot;center&quot; valign=&quot;top&quot; rowspan=&quot;1&quot; colspan=&quot;1&quot;&gt;&amp;lt;LOQ&lt;/td&gt;
#             &lt;td align=&quot;center&quot; valign=&quot;top&quot; rowspan=&quot;1&quot; colspan=&quot;1&quot;&gt;&amp;lt;LOQ&lt;/td&gt;
#           &lt;/tr&gt;
#           &lt;tr&gt;
#             &lt;td align=&quot;left&quot; valign=&quot;top&quot; rowspan=&quot;1&quot; colspan=&quot;1&quot;&gt;Adipose&lt;/td&gt;
#             &lt;td align=&quot;center&quot; valign=&quot;top&quot; rowspan=&quot;1&quot; colspan=&quot;1&quot;&gt;0.324+-0.143&lt;/td&gt;
#             &lt;td align=&quot;center&quot; valign=&quot;top&quot; rowspan=&quot;1&quot; colspan=&quot;1&quot;&gt;&amp;lt;LOQ&lt;/td&gt;
#             &lt;td align=&quot;center&quot; valign=&quot;top&quot; rowspan=&quot;1&quot; colspan=&quot;1&quot;&gt;&amp;lt;LOQ&lt;/td&gt;
#             &lt;td align=&quot;center&quot; valign=&quot;top&quot; rowspan=&quot;1&quot; colspan=&quot;1&quot;&gt;&amp;lt;LOQ&lt;/td&gt;
#             &lt;td align=&quot;center&quot; valign=&quot;top&quot; rowspan=&quot;1&quot; colspan=&quot;1&quot;&gt;&amp;lt;LOQ&lt;/td&gt;
#             &lt;td align=&quot;center&quot; valign=&quot;top&quot; rowspan=&quot;1&quot; colspan=&quot;1&quot;&gt;&amp;lt;LOQ&lt;/td&gt;
#           &lt;/tr&gt;
#           &lt;tr&gt;
#             &lt;td align=&quot;left&quot; valign=&quot;top&quot; rowspan=&quot;1&quot; colspan=&quot;1&quot;&gt;Bone&lt;/td&gt;
#             &lt;td align=&quot;center&quot; valign=&quot;top&quot; rowspan=&quot;1&quot; colspan=&quot;1&quot;&gt;2.21+-0.302&lt;/td&gt;
#             &lt;td align=&quot;center&quot; valign=&quot;top&quot; rowspan=&quot;1&quot; colspan=&quot;1&quot;&gt;0.902+-0.273&lt;/td&gt;
#             &lt;td align=&quot;center&quot; valign=&quot;top&quot; rowspan=&quot;1&quot; colspan=&quot;1&quot;&gt;1.77+-0.609&lt;/td&gt;
#             &lt;td align=&quot;center&quot; valign=&quot;top&quot; rowspan=&quot;1&quot; colspan=&quot;1&quot;&gt;0.995+-0.486&lt;/td&gt;
#             &lt;td align=&quot;center&quot; valign=&quot;top&quot; rowspan=&quot;1&quot; colspan=&quot;1&quot;&gt;0.881+-0.275&lt;/td&gt;
#             &lt;td align=&quot;center&quot; valign=&quot;top&quot; rowspan=&quot;1&quot; colspan=&quot;1&quot;&gt;1.05+-0.214&lt;/td&gt;
#           &lt;/tr&gt;
#           &lt;tr&gt;
#             &lt;td align=&quot;left&quot; valign=&quot;top&quot; rowspan=&quot;1&quot; colspan=&quot;1&quot;&gt;Stomach and Small Intestine&lt;/td&gt;
#             &lt;td align=&quot;center&quot; valign=&quot;top&quot; rowspan=&quot;1&quot; colspan=&quot;1&quot;&gt;1.11+-0.567&lt;/td&gt;
#             &lt;td align=&quot;center&quot; valign=&quot;top&quot; rowspan=&quot;1&quot; colspan=&quot;1&quot;&gt;0.530+-0.197&lt;/td&gt;
#             &lt;td align=&quot;center&quot; valign=&quot;top&quot; rowspan=&quot;1&quot; colspan=&quot;1&quot;&gt;1.36+-0.442&lt;/td&gt;
#             &lt;td align=&quot;center&quot; valign=&quot;top&quot; rowspan=&quot;1&quot; colspan=&quot;1&quot;&gt;0.593+-0.419&lt;/td&gt;
#             &lt;td align=&quot;center&quot; valign=&quot;top&quot; rowspan=&quot;1&quot; colspan=&quot;1&quot;&gt;0.681+-0.533&lt;/td&gt;
#             &lt;td align=&quot;center&quot; valign=&quot;top&quot; rowspan=&quot;1&quot; colspan=&quot;1&quot;&gt;0.627+-0.250&lt;/td&gt;
#           &lt;/tr&gt;
#           &lt;tr&gt;
#             &lt;td align=&quot;left&quot; valign=&quot;top&quot; rowspan=&quot;1&quot; colspan=&quot;1&quot;&gt;Cecum and Large Intestine&lt;/td&gt;
#             &lt;td align=&quot;center&quot; valign=&quot;top&quot; rowspan=&quot;1&quot; colspan=&quot;1&quot;&gt;1.33+-0.0429&lt;/td&gt;
#             &lt;td align=&quot;center&quot; valign=&quot;top&quot; rowspan=&quot;1&quot; colspan=&quot;1&quot;&gt;1.49+-0.599&lt;/td&gt;
#             &lt;td align=&quot;center&quot; valign=&quot;top&quot; rowspan=&quot;1&quot; colspan=&quot;1&quot;&gt;3.63+-1.58&lt;/td&gt;
#             &lt;td align=&quot;center&quot; valign=&quot;top&quot; rowspan=&quot;1&quot; colspan=&quot;1&quot;&gt;1.15+-0.563&lt;/td&gt;
#             &lt;td align=&quot;center&quot; valign=&quot;top&quot; rowspan=&quot;1&quot; colspan=&quot;1&quot;&gt;0.167+-0.0650&lt;/td&gt;
#             &lt;td align=&quot;center&quot; valign=&quot;top&quot; rowspan=&quot;1&quot; colspan=&quot;1&quot;&gt;0.145+-0.387&lt;/td&gt;
#           &lt;/tr&gt;
#           &lt;tr&gt;
#             &lt;td align=&quot;left&quot; valign=&quot;top&quot; rowspan=&quot;1&quot; colspan=&quot;1&quot;&gt;Pancreas&lt;/td&gt;
#             &lt;td align=&quot;center&quot; valign=&quot;top&quot; rowspan=&quot;1&quot; colspan=&quot;1&quot;&gt;0.141+-0.0523&lt;/td&gt;
#             &lt;td align=&quot;center&quot; valign=&quot;top&quot; rowspan=&quot;1&quot; colspan=&quot;1&quot;&gt;0.109+-0.0832&lt;/td&gt;
#             &lt;td align=&quot;center&quot; valign=&quot;top&quot; rowspan=&quot;1&quot; colspan=&quot;1&quot;&gt;0.161+-0.114&lt;/td&gt;
#             &lt;td align=&quot;center&quot; valign=&quot;top&quot; rowspan=&quot;1&quot; colspan=&quot;1&quot;&gt;0.103+-0.0475&lt;/td&gt;
#             &lt;td align=&quot;center&quot; valign=&quot;top&quot; rowspan=&quot;1&quot; colspan=&quot;1&quot;&gt;0.0843+-0.047&lt;/td&gt;
#             &lt;td align=&quot;center&quot; valign=&quot;top&quot; rowspan=&quot;1&quot; colspan=&quot;1&quot;&gt;0.0797+-0.037&lt;/td&gt;
#           &lt;/tr&gt;
#           &lt;tr&gt;
#             &lt;td align=&quot;left&quot; valign=&quot;top&quot; rowspan=&quot;1&quot; colspan=&quot;1&quot;&gt;Placenta&lt;/td&gt;
#             &lt;td align=&quot;center&quot; valign=&quot;top&quot; rowspan=&quot;1&quot; colspan=&quot;1&quot;&gt;1.41+-0.304&lt;/td&gt;
#             &lt;td align=&quot;center&quot; valign=&quot;top&quot; rowspan=&quot;1&quot; colspan=&quot;1&quot;&gt;1.60+-0.470&lt;/td&gt;
#             &lt;td align=&quot;center&quot; valign=&quot;top&quot; rowspan=&quot;1&quot; colspan=&quot;1&quot;&gt;1.28+-0.274&lt;/td&gt;
#             &lt;td align=&quot;center&quot; valign=&quot;top&quot; rowspan=&quot;1&quot; colspan=&quot;1&quot;&gt;2.10+-1.10&lt;/td&gt;
# ...
#             &lt;td align=&quot;center&quot; valign=&quot;top&quot; rowspan=&quot;1&quot; colspan=&quot;1&quot;&gt;(-1.1)&lt;/td&gt;
#             &lt;td align=&quot;center&quot; valign=&quot;top&quot; rowspan=&quot;1&quot; colspan=&quot;1&quot;&gt;1.3&lt;/td&gt;
#             &lt;td align=&quot;center&quot; valign=&quot;top&quot; rowspan=&quot;1&quot; colspan=&quot;1&quot;&gt;1.1&lt;/td&gt;
#           &lt;/tr&gt;
#           &lt;tr&gt;
#             &lt;td align=&quot;left&quot; valign=&quot;top&quot; rowspan=&quot;1&quot; colspan=&quot;1&quot;&gt;Succinate&lt;/td&gt;
#             &lt;td align=&quot;center&quot; valign=&quot;top&quot; rowspan=&quot;1&quot; colspan=&quot;1&quot;&gt;4.9&lt;/td&gt;
#             &lt;td align=&quot;center&quot; valign=&quot;top&quot; rowspan=&quot;1&quot; colspan=&quot;1&quot;&gt;2.0&lt;/td&gt;
#             &lt;td align=&quot;center&quot; valign=&quot;top&quot; rowspan=&quot;1&quot; colspan=&quot;1&quot;&gt;2.8&lt;/td&gt;
#             &lt;td align=&quot;center&quot; valign=&quot;top&quot; rowspan=&quot;1&quot; colspan=&quot;1&quot;&gt;(-1.6)&lt;/td&gt;
#             &lt;td align=&quot;center&quot; valign=&quot;top&quot; rowspan=&quot;1&quot; colspan=&quot;1&quot;/&gt;
#             &lt;td align=&quot;center&quot; valign=&quot;top&quot; rowspan=&quot;1&quot; colspan=&quot;1&quot;/&gt;
#           &lt;/tr&gt;
#           &lt;tr&gt;
#             &lt;td align=&quot;left&quot; valign=&quot;top&quot; rowspan=&quot;1&quot; colspan=&quot;1&quot;&gt;Sucrose&lt;/td&gt;
#             &lt;td align=&quot;center&quot; valign=&quot;top&quot; rowspan=&quot;1&quot; colspan=&quot;1&quot;/&gt;
#             &lt;td align=&quot;center&quot; valign=&quot;top&quot; rowspan=&quot;1&quot; colspan=&quot;1&quot;/&gt;
#             &lt;td align=&quot;center&quot; valign=&quot;top&quot; rowspan=&quot;1&quot; colspan=&quot;1&quot;&gt;1.5&lt;/td&gt;
#             &lt;td align=&quot;center&quot; valign=&quot;top&quot; rowspan=&quot;1&quot; colspan=&quot;1&quot;&gt;1.3&lt;/td&gt;
#             &lt;td align=&quot;center&quot; valign=&quot;top&quot; rowspan=&quot;1&quot; colspan=&quot;1&quot;/&gt;
#             &lt;td align=&quot;center&quot; valign=&quot;top&quot; rowspan=&quot;1&quot; colspan=&quot;1&quot;/&gt;
#           &lt;/tr&gt;
#           &lt;tr&gt;
#             &lt;td align=&quot;left&quot; valign=&quot;top&quot; rowspan=&quot;1&quot; colspan=&quot;1&quot;&gt;Sucrose | Creatinine&lt;/td&gt;
#             &lt;td align=&quot;center&quot; valign=&quot;top&quot; rowspan=&quot;1&quot; colspan=&quot;1&quot;/&gt;
#             &lt;td align=&quot;center&quot; valign=&quot;top&quot; rowspan=&quot;1&quot; colspan=&quot;1&quot;/&gt;
#             &lt;td align=&quot;center&quot; valign=&quot;top&quot; rowspan=&quot;1&quot; colspan=&quot;1&quot;&gt;1.6&lt;/td&gt;
#             &lt;td align=&quot;center&quot; valign=&quot;top&quot; rowspan=&quot;1&quot; colspan=&quot;1&quot;&gt;1.2&lt;/td&gt;
#             &lt;td align=&quot;center&quot; valign=&quot;top&quot; rowspan=&quot;1&quot; colspan=&quot;1&quot;/&gt;
#             &lt;td align=&quot;center&quot; valign=&quot;top&quot; rowspan=&quot;1&quot; colspan=&quot;1&quot;/&gt;
#           &lt;/tr&gt;
#           &lt;tr&gt;
#             &lt;td align=&quot;left&quot; valign=&quot;top&quot; rowspan=&quot;1&quot; colspan=&quot;1&quot;&gt;Trans-Aconitate&lt;/td&gt;
#             &lt;td align=&quot;center&quot; valign=&quot;top&quot; rowspan=&quot;1&quot; colspan=&quot;1&quot;/&gt;
#             &lt;td align=&quot;center&quot; valign=&quot;top&quot; rowspan=&quot;1&quot; colspan=&quot;1&quot;/&gt;
#             &lt;td align=&quot;center&quot; valign=&quot;top&quot; rowspan=&quot;1&quot; colspan=&quot;1&quot;&gt;1.2&lt;/td&gt;
#             &lt;td align=&quot;center&quot; valign=&quot;top&quot; rowspan=&quot;1&quot; colspan=&quot;1&quot;&gt;(-1.4)&lt;/td&gt;
#             &lt;td align=&quot;center&quot; valign=&quot;top&quot; rowspan=&quot;1&quot; colspan=&quot;1&quot;/&gt;
#             &lt;td align=&quot;center&quot; valign=&quot;top&quot; rowspan=&quot;1&quot; colspan=&quot;1&quot;/&gt;
#           &lt;/tr&gt;
#           &lt;tr&gt;
#             &lt;td align=&quot;left&quot; valign=&quot;top&quot; rowspan=&quot;1&quot; colspan=&quot;1&quot;&gt;Valine/Leucine&lt;/td&gt;
#             &lt;td align=&quot;center&quot; valign=&quot;top&quot; rowspan=&quot;1&quot; colspan=&quot;1&quot;/&gt;
#             &lt;td align=&quot;center&quot; valign=&quot;top&quot; rowspan=&quot;1&quot; colspan=&quot;1&quot;/&gt;
#             &lt;td align=&quot;center&quot; valign=&quot;top&quot; rowspan=&quot;1&quot; colspan=&quot;1&quot;&gt;1.4&lt;/td&gt;
#             &lt;td align=&quot;center&quot; valign=&quot;top&quot; rowspan=&quot;1&quot; colspan=&quot;1&quot;&gt;1.4&lt;/td&gt;
#             &lt;td align=&quot;center&quot; valign=&quot;top&quot; rowspan=&quot;1&quot; colspan=&quot;1&quot;/&gt;
#             &lt;td align=&quot;center&quot; valign=&quot;top&quot; rowspan=&quot;1&quot; colspan=&quot;1&quot;/&gt;
#           &lt;/tr&gt;
#           &lt;tr&gt;
#             &lt;td align=&quot;left&quot; valign=&quot;top&quot; rowspan=&quot;1&quot; colspan=&quot;1&quot;&gt;Unknowns (3-8 bins)&lt;/td&gt;
#             &lt;td align=&quot;center&quot; valign=&quot;top&quot; rowspan=&quot;1&quot; colspan=&quot;1&quot;&gt;1.0 - 2.8&lt;/td&gt;
#             &lt;td align=&quot;center&quot; valign=&quot;top&quot; rowspan=&quot;1&quot; colspan=&quot;1&quot;&gt;(-1.6) - 1.5&lt;/td&gt;
#             &lt;td align=&quot;center&quot; valign=&quot;top&quot; rowspan=&quot;1&quot; colspan=&quot;1&quot;&gt;1.1 - 3.4&lt;/td&gt;
#             &lt;td align=&quot;center&quot; valign=&quot;top&quot; rowspan=&quot;1&quot; colspan=&quot;1&quot;&gt;(-1.1) - 1.2&lt;/td&gt;
#             &lt;td align=&quot;center&quot; valign=&quot;top&quot; rowspan=&quot;1&quot; colspan=&quot;1&quot;&gt;1.4 - 2.1&lt;/td&gt;
#             &lt;td align=&quot;center&quot; valign=&quot;top&quot; rowspan=&quot;1&quot; colspan=&quot;1&quot;&gt;(-1.2) - 1.2&lt;/td&gt;
#           &lt;/tr&gt;
#         &lt;/tbody&gt;
#       &lt;/table&gt;
# </infon><offset>61380</offset><text>	AgAc vs Vehicle	20 nm AgNP vs Vehicle	110 nm AgNP vs Vehicle	 			 	Library Matched Metabolite	VIPa Range	Fold Change rangeb	VIP Range	Fold Change range	VIP Range	Fold Change range	 	1-Methylnicotinamide | Lactose | Trigonelline	1.2	(-1.2)			1.5	(-1.1)	 	2-Oxoglutarate (2 bins)			3.1 - 3.3	1.5 - 1.6			 	3-Hydroxyphenylacetate					1.0	(-1.5)	 	3-Hydroxyphenylacetate | N-Acetylglutamine			1.5	(-1.6)	1.3	(-1.2)	 	Acetate	5.5	2.3	1.3	(-1.3)			 	Acetoacetate | trans-Aconitate			2.3	(-1.2)			 	Alanine	1.1	1.1			1.1	1.0	 	Allantoin	3.3	(-1.7)			1.3	(-1.6)	 	Benzorate (2-3 bins)	1.7 - 2.5	2.9 - 11.5			1.2 - 1.8	1.3 - 2.7	 	Citrate (2 bins)			4.9 - 5.6	(-1.4)			 	Dimethylsulfone			1.0	1.1	1.7	1.1	 	Glucose	1.6	(-1.4)					 	Glucose | Lactose			1.1	1.2			 	Glucose | Sucrose	2.7	1.8	1.4	1.2			 	Glucose | Taurine	2.2	(-1.5)					 	Hippurate (3 bins)					2.9 - 4.4	1.6	 	Hippurate | Glycolate					4.4	1.2	 	Homocystine					1.7	(-1.2)	 	Isoleucine	1.0	1.1					 	Lactate (2 bins)	1.8 - 3.5	1.2 -2.0	1.1	1.1			 	Lactose | Glucose	2.3	1.9					 	Leucine | Isoleucine | Fatty acids			1.7	1.3	2.0	1.2	 	N,N-Dimethylglycine	2.1	1.4					 	N-Acetylglutamine	1.5	(-1.1)	1.5	(-1.2)	1.8	(-1.1)	 	N-Acetylglycine | N-Acetylaminoacids			1.2	(-1.0)			 	Proline			1.0	(-1.1)	1.3	1.1	 	Succinate	4.9	2.0	2.8	(-1.6)			 	Sucrose			1.5	1.3			 	Sucrose | Creatinine			1.6	1.2			 	Trans-Aconitate			1.2	(-1.4)			 	Valine/Leucine			1.4	1.4			 	Unknowns (3-8 bins)	1.0 - 2.8	(-1.6) - 1.5	1.1 - 3.4	(-1.1) - 1.2	1.4 - 2.1	(-1.2) - 1.2	 	</text></passage><passage><infon key="file">T10.xml</infon><infon key="id">T10</infon><infon key="section_type">TABLE</infon><infon key="type">table_footnote</infon><offset>62967</offset><text>VIP = variable importance for projection</text></passage><passage><infon key="file">T10.xml</infon><infon key="id">T10</infon><infon key="section_type">TABLE</infon><infon key="type">table_footnote</infon><offset>63008</offset><text>A negative fold change means that the vehicle median was higher than the AgNP median, while a positive fold change means that the AgNP median was higher than the vehicle median.</text></passage><passage><infon key="file">T11.xml</infon><infon key="id">T11</infon><infon key="section_type">TABLE</infon><infon key="type">table_caption</infon><offset>63186</offset><text>List of the most perturbed pathways in the library matched metabolomics analysis and the metabolites that distinguish the AgAc, 20 nm or 110 nm AgNP and the vehicle control 48 h post i.v. or p.o. exposure.</text></passage><passage><infon key="file">T11.xml</infon><infon key="id">T11</infon><infon key="section_type">TABLE</infon><infon key="type">table</infon><infon key="xml">&lt;?xml version=&quot;1.0&quot; encoding=&quot;UTF-8&quot;?&gt;
# &lt;table frame=&quot;below&quot; rules=&quot;rows&quot;&gt;
#         &lt;thead&gt;
#           &lt;tr&gt;
#             &lt;th align=&quot;left&quot; valign=&quot;top&quot; rowspan=&quot;1&quot; colspan=&quot;1&quot;&gt;Treatment&lt;/th&gt;
#             &lt;th align=&quot;center&quot; valign=&quot;top&quot; rowspan=&quot;1&quot; colspan=&quot;1&quot;&gt;Route&lt;/th&gt;
#             &lt;th align=&quot;left&quot; valign=&quot;top&quot; rowspan=&quot;1&quot; colspan=&quot;1&quot;&gt;Most perturbed pathway&lt;/th&gt;
#             &lt;th align=&quot;center&quot; valign=&quot;top&quot; rowspan=&quot;1&quot; colspan=&quot;1&quot;&gt;p-Value&lt;/th&gt;
#             &lt;th align=&quot;left&quot; valign=&quot;top&quot; rowspan=&quot;1&quot; colspan=&quot;1&quot;&gt;Pathway metabolites that differ from silver and vehicle&lt;/th&gt;
#           &lt;/tr&gt;
#         &lt;/thead&gt;
#         &lt;tbody&gt;
#           &lt;tr&gt;
#             &lt;td rowspan=&quot;2&quot; align=&quot;left&quot; valign=&quot;middle&quot; colspan=&quot;1&quot;&gt;
# &lt;bold&gt;AgAc vs Vehicle&lt;/bold&gt;
# &lt;/td&gt;
#             &lt;td align=&quot;center&quot; valign=&quot;top&quot; rowspan=&quot;1&quot; colspan=&quot;1&quot;&gt;
# &lt;bold&gt;i.v.&lt;/bold&gt;
# &lt;/td&gt;
#             &lt;td align=&quot;left&quot; valign=&quot;top&quot; rowspan=&quot;1&quot; colspan=&quot;1&quot;&gt;Ala,Ser,Cys,Met,His,Pro,Gly,Glu, and Gln metabolism and transport&lt;/td&gt;
#             &lt;td align=&quot;center&quot; valign=&quot;top&quot; rowspan=&quot;1&quot; colspan=&quot;1&quot;&gt;9.0x10&lt;sup&gt;-5&lt;/sup&gt;&lt;/td&gt;
#             &lt;td align=&quot;left&quot; valign=&quot;top&quot; rowspan=&quot;1&quot; colspan=&quot;1&quot;&gt;  Betaine&lt;break/&gt;  Glycolic acid&lt;break/&gt;  L-Glutamine&lt;break/&gt;  L-Proline&lt;/td&gt;
#           &lt;/tr&gt;
#           &lt;tr&gt;
#             &lt;td align=&quot;center&quot; valign=&quot;top&quot; rowspan=&quot;1&quot; colspan=&quot;1&quot;&gt;
# &lt;bold&gt;p.o.&lt;/bold&gt;
# &lt;/td&gt;
#             &lt;td align=&quot;left&quot; valign=&quot;top&quot; rowspan=&quot;1&quot; colspan=&quot;1&quot;&gt;Carbohydrate metabolism: Sucrose metabolism and transport&lt;/td&gt;
#             &lt;td align=&quot;center&quot; valign=&quot;top&quot; rowspan=&quot;1&quot; colspan=&quot;1&quot;&gt;5.4x10&lt;sup&gt;-4&lt;/sup&gt;&lt;/td&gt;
#             &lt;td align=&quot;left&quot; valign=&quot;top&quot; rowspan=&quot;1&quot; colspan=&quot;1&quot;&gt;  D-Sucrose&lt;break/&gt;  D-Glucose&lt;break/&gt;  Lactose&lt;/td&gt;
#           &lt;/tr&gt;
#           &lt;tr&gt;
#             &lt;td rowspan=&quot;2&quot; align=&quot;left&quot; valign=&quot;middle&quot; colspan=&quot;1&quot;&gt;
# &lt;bold&gt;20 nm AgNP vs Vehicle&lt;/bold&gt;
# &lt;/td&gt;
#             &lt;td align=&quot;center&quot; valign=&quot;top&quot; rowspan=&quot;1&quot; colspan=&quot;1&quot;&gt;
# &lt;bold&gt;i.v.&lt;/bold&gt;
# &lt;/td&gt;
#             &lt;td align=&quot;left&quot; valign=&quot;top&quot; rowspan=&quot;1&quot; colspan=&quot;1&quot;&gt;Ala,Ser,Cys,Met,His,Pro,Gly,Glu, and Gln metabolism and transport&lt;/td&gt;
#             &lt;td align=&quot;center&quot; valign=&quot;top&quot; rowspan=&quot;1&quot; colspan=&quot;1&quot;&gt;3.6x10&lt;sup&gt;-6&lt;/sup&gt;&lt;/td&gt;
#             &lt;td align=&quot;left&quot; valign=&quot;top&quot; rowspan=&quot;1&quot; colspan=&quot;1&quot;&gt;  2-Oxoglutaric acid&lt;break/&gt;  Glycolic acid&lt;break/&gt;  L-Glutamine&lt;break/&gt;  L-Methionine&lt;break/&gt;  L-Proline&lt;/td&gt;
#           &lt;/tr&gt;
#           &lt;tr&gt;
#             &lt;td align=&quot;center&quot; valign=&quot;top&quot; rowspan=&quot;1&quot; colspan=&quot;1&quot;&gt;
# &lt;bold&gt;p.o.&lt;/bold&gt;
# &lt;/td&gt;
#             &lt;td align=&quot;left&quot; valign=&quot;top&quot; rowspan=&quot;1&quot; colspan=&quot;1&quot;&gt;TCA metabolism and transport&lt;/td&gt;
#             &lt;td align=&quot;center&quot; valign=&quot;top&quot; rowspan=&quot;1&quot; colspan=&quot;1&quot;&gt;2.1x10&lt;sup&gt;-9&lt;/sup&gt;&lt;/td&gt;
#             &lt;td align=&quot;left&quot; valign=&quot;top&quot; rowspan=&quot;1&quot; colspan=&quot;1&quot;&gt;  2-Oxoglutaric&lt;break/&gt;  Citric acid&lt;break/&gt;  Succinic acid&lt;/td&gt;
#           &lt;/tr&gt;
#           &lt;tr&gt;
#             &lt;td rowspan=&quot;2&quot; align=&quot;left&quot; valign=&quot;middle&quot; colspan=&quot;1&quot;&gt;
# &lt;bold&gt;110 nm AgNP vs Vehicle&lt;/bold&gt;
# &lt;/td&gt;
#             &lt;td align=&quot;center&quot; valign=&quot;top&quot; rowspan=&quot;1&quot; colspan=&quot;1&quot;&gt;
# &lt;bold&gt;i.v.&lt;/bold&gt;
# &lt;/td&gt;
#             &lt;td align=&quot;left&quot; valign=&quot;top&quot; rowspan=&quot;1&quot; colspan=&quot;1&quot;&gt;TCA metabolism and transport&lt;/td&gt;
#             &lt;td align=&quot;center&quot; valign=&quot;top&quot; rowspan=&quot;1&quot; colspan=&quot;1&quot;&gt;2.1x10&lt;sup&gt;-9&lt;/sup&gt;&lt;/td&gt;
#             &lt;td align=&quot;left&quot; valign=&quot;top&quot; rowspan=&quot;1&quot; colspan=&quot;1&quot;&gt;  2-Oxoglutaric acid&lt;break/&gt;  Citric acid&lt;break/&gt;  Succinic acid&lt;/td&gt;
#           &lt;/tr&gt;
#           &lt;tr&gt;
#             &lt;td align=&quot;center&quot; valign=&quot;top&quot; rowspan=&quot;1&quot; colspan=&quot;1&quot;&gt;
# &lt;bold&gt;p.o.&lt;/bold&gt;
# &lt;/td&gt;
#             &lt;td align=&quot;left&quot; valign=&quot;top&quot; rowspan=&quot;1&quot; colspan=&quot;1&quot;&gt;Alanine, Glycine, and Cysteine metabolism and transport&lt;/td&gt;
#             &lt;td align=&quot;center&quot; valign=&quot;top&quot; rowspan=&quot;1&quot; colspan=&quot;1&quot;&gt;3.6x10&lt;sup&gt;-6&lt;/sup&gt;&lt;/td&gt;
#             &lt;td align=&quot;left&quot; valign=&quot;top&quot; rowspan=&quot;1&quot; colspan=&quot;1&quot;&gt;  Glycolic acid&lt;break/&gt;  L-Alanine&lt;break/&gt;  L-Leucine&lt;/td&gt;
#           &lt;/tr&gt;
#         &lt;/tbody&gt;
#       &lt;/table&gt;
# </infon><offset>63392</offset><text>Treatment	Route	Most perturbed pathway	p-Value	Pathway metabolites that differ from silver and vehicle	 	AgAc vs Vehicle	i.v.	Ala,Ser,Cys,Met,His,Pro,Gly,Glu, and Gln metabolism and transport	9.0x10-5	  Betaine  Glycolic acid  L-Glutamine  L-Proline	 	p.o.	Carbohydrate metabolism: Sucrose metabolism and transport	5.4x10-4	  D-Sucrose  D-Glucose  Lactose	 	20 nm AgNP vs Vehicle	i.v.	Ala,Ser,Cys,Met,His,Pro,Gly,Glu, and Gln metabolism and transport	3.6x10-6	  2-Oxoglutaric acid  Glycolic acid  L-Glutamine  L-Methionine  L-Proline	 	p.o.	TCA metabolism and transport	2.1x10-9	  2-Oxoglutaric  Citric acid  Succinic acid	 	110 nm AgNP vs Vehicle	i.v.	TCA metabolism and transport	2.1x10-9	  2-Oxoglutaric acid  Citric acid  Succinic acid	 	p.o.	Alanine, Glycine, and Cysteine metabolism and transport	3.6x10-6	  Glycolic acid  L-Alanine  L-Leucine	 	</text></passage><passage><infon key="file">T11.xml</infon><infon key="id">T11</infon><infon key="section_type">TABLE</infon><infon key="type">table_foot</infon><offset>64305</offset><text>Ala (Alanine), Ser (Serine), Cys (Cystine), Met (Methionine), His (Histidine), Pro (Proline), Gly (Glycine), Glu (Glutamic acid), Gln (Glutamine)</text></passage></document>
# </collection>

# %% [markdown]
# Extracts abstract and tables from paper

# %%
from collections import defaultdict

soup = BeautifulSoup(paper_xml, "lxml-xml")

#abstract
abstract_passages = [p for p in soup.find_all("passage") if p.find("infon", {"key": "section_type"}) and 
        p.find("infon", {"key": "section_type"}).text.strip().upper() == "ABSTRACT"]
abstract_text_list = [p.find("text").get_text() for p in abstract_passages if p.find("text")]
abstract = "\n".join(abstract_text_list)

#methods
methods_passages = [p for p in soup.find_all("passage") if p.find("infon", {"key": "section_type"}) and 
        p.find("infon", {"key": "section_type"}).text.strip().upper() == "METHODS"]
methods_text_list = [p.find("text").get_text() for p in methods_passages if p.find("text")]
methods = "\n".join(methods_text_list)

#results
results_passages = [p for p in soup.find_all("passage") if p.find("infon", {"key": "section_type"}) and 
        p.find("infon", {"key": "section_type"}).text.strip().upper() == "RESULTS"]
results_text_list = [p.find("text").get_text() for p in results_passages if p.find("text")]
results = "\n".join(results_text_list)

#tables
table_passages = [p for p in soup.find_all("passage") if (sect := p.find("infon", {"key": "section_type"})) and sect.text.strip() == "TABLE"]
tables = defaultdict(lambda: {"label": "o", "caption": None, "markdown": None, "footnotes": [], "col_labels": None, "group_cols": [], "biomarker_cols": []})
for p in table_passages:
    table_id = p.find("infon", {"key": "id"}).text.strip()
    passage_type = p.find("infon", {"key": "type"}).text.strip()
    if passage_type == "table_caption":
        tables[table_id]["caption"] = p.find("text").text.strip()
    elif passage_type == "table":
        table_xml = p.find("infon", {"key": "xml"}).text
        if "<table" not in table_xml:
            continue
        table = table_utils.single_html_table_to_markdown(html.unescape(table_xml))
        tables[table_id]["markdown"] = table_utils.transpose_markdown_table(table_utils.transpose_markdown_table(table))
    elif passage_type in ("table_foot", "table_footnote"):
        tables[table_id]["footnotes"].append(p.find("text").text.strip())
# Out:
# c:\Users\jelli\Desktop\Animal Toxicity Trials\process_table\table_utils.py:411: XMLParsedAsHTMLWarning: It looks like you're using an HTML parser to parse an XML document.
#
# Assuming this really is an XML document, what you're doing might work, but you should know that using an XML parser will be more reliable. To parse this document as XML, make sure you have the Python package 'lxml' installed, and pass the keyword argument `features="xml"` into the BeautifulSoup constructor.
#
# If you want or need to use an HTML parser on this document, you can make this warning go away by filtering it. To do that, run this code before calling the BeautifulSoup constructor:
#
#     from bs4 import XMLParsedAsHTMLWarning
#     import warnings
#
#     warnings.filterwarnings("ignore", category=XMLParsedAsHTMLWarning)
#
#   soup = BeautifulSoup(html_content, "html.parser")
# c:\Users\jelli\Desktop\Animal Toxicity Trials\process_table\table_utils.py:19: XMLParsedAsHTMLWarning: It looks like you're using an HTML parser to parse an XML document.
#
# Assuming this really is an XML document, what you're doing might work, but you should know that using an XML parser will be more reliable. To parse this document as XML, make sure you have the Python package 'lxml' installed, and pass the keyword argument `features="xml"` into the BeautifulSoup constructor.
#
# If you want or need to use an HTML parser on this document, you can make this warning go away by filtering it. To do that, run this code before calling the BeautifulSoup constructor:
#
#     from bs4 import XMLParsedAsHTMLWarning
#     import warnings
#
#     warnings.filterwarnings("ignore", category=XMLParsedAsHTMLWarning)
#
#   soup = BeautifulSoup(html, "html.parser")

# %% [markdown]
# Generate prompt for identifying each table

# %%
id_tables_prompt = utils.id_tables_prompt(abstract, tables)
print(id_tables_prompt)
# Out:
# # Instructions
# You will be given the abstract of a research paper which includes at least one animal toxicity study then a list of all the tables included in that paper, each one labeled with its title. For each table identify it as one of three categories: treatment group table (G), biomarker table (B), or other (O). Treatment group tables should contain information on the specific treatment groups, such as the medications, the dosages, the sample size, etc. Tables that only give information on the chemicals used (such as the sourcing) should not be labeled G and should instead be labeled O. Even if the table meets these criteria, only label the table G if it describes the groups of specifically an animal toxicity study within the paper. Otherwise, label it O. Biomarker tables may contain treatment group dosage information, but the main difference between is that biomarker tables should contain biomarker data observed from the treatment groups. This can frequency data (such as survival or number occurences of a condition) or metric data (such as ALT levels or compound concentration), and the table must describe the results of specifically an animal toxicity study within the paper to be labeled B. Otherwise, label it O. Any other irrelevant papers should be labeled O, such as results of in vitro assays or gene expression tables. For each table on a new line, include the label in the following format in the order that the tables are given: <table name|label>. Do not include any extra text in your answer or extra whitespace inside the labels. Here is an example input and output:
# # Example Input
# <abstract>Abstract
# Background: Compound ABC is a novel small molecule with potential therapeutic applications in metabolic disorders. To evaluate its safety profile, we conducted two complementary toxicity studies: an in vitro cytotoxicity assay and an in vivo rodent toxicity assessment.
# Methods:
# In vitro assay: Human hepatocellular carcinoma (HepG2) and rat cardiomyoblast (H9c2) cell lines were exposed to ABC at concentrations of 1-200 µM for 24, 48, and 72 hours. Cell viability was measured by MTT assay, and apoptosis was assessed by flow cytometry using Annexin V/PI staining and caspase-3 activation.
# In vivo study: Male and female Sprague-Dawley rats (n = 10 per sex per group) received daily oral doses of ABC at 0 (vehicle control), 10, 50, or 200 mg/kg for 28 days. Clinical observations, body weight, and food consumption were recorded. At study termination, hematology, serum biochemistry (ALT, AST, BUN, creatinine), and organ histopathology (liver, kidney, heart) were evaluated.
# Results:
# In vitro, ABC induced a concentration- and time-dependent decrease in cell viability, with IC₅₀ values of 45 µM (HepG2) and 120 µM (H9c2) at 48 h. Apoptotic indices increased significantly at ≥50 µM, accompanied by a 3-fold rise in caspase-3 activity. In vivo, no mortality or adverse clinical signs were observed at ≤50 mg/kg. Rats dosed at 200 mg/kg exhibited transient body weight suppression (5% lower vs. control), mild elevations in ALT and creatinine (1.4- and 1.3-fold, respectively), and minimal hepatocellular vacuolation on histology. No significant changes were seen in hematological parameters or cardiac histopathology.
# Conclusions: ABC demonstrates moderate cytotoxicity in vitro, primarily via apoptosis, and is well tolerated in rats at doses up to 50 mg/kg/day. The no-observed-adverse-effect level (NOAEL) in this 28-day study is 50 mg/kg. These findings support further preclinical development of ABC, with emphasis on mechanistic studies of hepatic metabolism and long-term safety.</abstract>
# <example table 1>Caption: Overview of dosing regimens for both in vitro and in vivo studies.
# | Study | Model | Group | Dose / Concentration | Frequency / Exposure | Route | Replicates (n) |
# | --- | --- | --- | --- | --- | --- | --- |
# | In vitro | HepG2 & H9c2 cell lines | Control | 0 µM | 48 h single exposure | N/A | 3 per timepoint |
# | In vitro | HepG2 & H9c2 cell lines | Low | 10 µM | 48 h single exposure | N/A | 3 per timepoint |
# | In vitro | HepG2 & H9c2 cell lines | Medium | 50 µM | 48 h single exposure | N/A | 3 per timepoint |
# | In vitro | HepG2 & H9c2 cell lines | High | 100 µM | 48 h single exposure | N/A | 3 per timepoint |
# | In vivo | Sprague-Dawley rat | Control | 0 mg/kg/day | Once daily 28 days | Oral gavage | 10 rats/sex/group |
# | In vivo | Sprague-Dawley rat | Low | 10 mg/kg/day | Once daily 28 days | Oral gavage | 10 rats/sex/group |
# | In vivo | Sprague-Dawley rat | Medium | 50 mg/kg/day | Once daily 28 days | Oral gavage | 10 rats/sex/group |
# | In vivo | Sprague-Dawley rat | High | 200 mg/kg/day | Once daily 28 days | Oral gavage | 10 rats/sex/group |
# Footnotes:
# 1 In vitro replicates refer to independent wells measured per concentration and timepoint.
# 2 In vivo 'n' indicates number of animals per sex in each treatment group.
# </example table 1>
# <example table 2>Caption: Summary of cell-based toxicity endpoints following 48 h exposure to ABC.
# | Group | Viability (% of control) | Apoptotic Cells (%) | Caspase-3 Activity (fold of control) |
# | --- | --- | --- | --- |
# | Control (0 µM) | 100 +- 5 | 5 +- 1 | 1.0 +- 0.1 |
# | Low (10 µM) | 95 +- 4 |  8 +- 2 | 1.2 +- 0.1 |
# | Medium (50 µM) | 60 +- 6 | 25 +- 3 | 3.0 +- 0.2 |
# | High (100 µM) | 30 +- 5 | 50 +- 4 | 5.5 +- 0.4 |
# Footnotes:
# 3 Viability measured by MTT assay, expressed as percent of untreated control.
# 4 Apoptotic fraction determined by Annexin V/PI staining via flow cytometry.
# 5 Caspase-3 activity normalized to control, measured enzymatically.
# </example table 2>
# <example table 3>Caption: Key serum biomarker changes in Sprague-Dawley rats after 28 days of ABC dosing.
# | Group | ALT (U/L) | AST (U/L) | Creatinine (mg/dL) | BUN (mg/dL) |
# | --- | --- | --- | --- | --- |
# | Control (0 mg/kg) | 35 +- 5 | 42 +- 6 | 0.6 +- 0.1 | 14 +- 2 |
# | Low (10 mg/kg) | 38 +- 6 | 45 +- 7 | 0.7 +- 0.1 | 15 +- 2 |
# | Medium (50 mg/kg) | 45 +- 7 | 52 +- 8 | 0.8 +- 0.1 | 18 +- 3 |
# | High (200 mg/kg) | 50 +- 8 | 60 +- 10 | 0.9 +- 0.1 | 20 +- 3 |
# Footnotes:
# 6 Alanine aminotransferase (ALT) and aspartate aminotransferase (AST) reflect hepatic function.
# 7 BUN: blood urea nitrogen, indicates renal function.
# </example table 3>
# # Example output
# <example table 1|G>
# <example table 2|O>
# <example table 3|B>
# # Input
# <abstract>Here is presented a comprehensive investigation of the distribution of polyvinylpyrrolidone (PVP)-stabilized AgNP (20 or 110 nm) in pregnant rats after a single injection or oral gavage dose. The biological impacts of AgNP exposure were evaluated by metabolomic analysis, and measurement of biomarkers of cardiovascular injury, oxidative stress, and inflammation. The investigation provided a basic understanding of the distribution, internal dose, persistence, metabolomics, and elimination of AgNP following exposure in pregnant rats.
# Few investigations have been conducted on the disposition and fate of silver nanoparticles (AgNP) in pregnancy. The distribution of a single dose of polyvinylpyrrolidone (PVP)-stabilized AgNP was investigated in pregnant rats. Two sizes of AgNP, 20 and 110 nm, and silver acetate (AgAc) were used to investigate the role of AgNP diameter and particle dissolution in tissue distribution, internal dose, and persistence. Dams were administered AgNP or AgAc intravenously (i.v.) (1 mg/kg) or by gavage (p.o.) (10 mg/kg), or vehicle alone, on gestation day 18 and euthanized at 24 or 48 h post-exposure. The silver concentration in tissues was measured using inductively-coupled plasma mass spectrometry. The distribution of silver in dams was influenced by route of administration and AgNP size. The highest concentration of silver (mug Ag/g tissue) at 48 h was found in spleen for i.v. administered AgNP, and in lungs for AgAc. At 48 h following p.o. administration of AgNP, the highest concentration was measured in cecum and large intestine, and for AgAc in placenta. Silver was detected in placenta and fetuses for all groups. Markers of cardiovascular injury, oxidative stress marker, cytokines, and chemokines were not significantly elevated in exposed dams compared to vehicle-dosed control. NMR metabolomics analysis of urine indicated that AgNP and AgAc exposure impact the carbohydrate, and amino acid metabolism. This study demonstrates that silver crosses the placenta and is transferred to the fetus regardless of the form of silver.</abstract>
# <T1>Caption: Methods for analysis of AgNP stock standard solutions and characteristics.
# | Characterization Assay | Method ID | 20 nm AgNP (NIEHS-2) | 110 nm AgNP (NIEHS-4) |
# | --- | --- | --- | --- |
# | Endotoxin Quantification - Kinetic Turbidity (EU/mL) | STE-1.2 | 1.1 | <0.5 |
# | Hydrodynamic Size/Size Distribution by DLS (Z-Avg [nm]) | PCC-1 | 26 | 112.3 |
# | Size by TEM (nm) | PCC-7 | 20.5 | 111.3 |
# | Surface Charge by Zeta Potential (mV) | PCC-2 | -37.1 | -25.9 |
# | Silver concentration by ICP-MS (mg/g) | PCC-8 | 1.09 | 1.10 |
# Footnotes:
# Two populations observed; <9% were smaller than 10 nm, the remainder averaged 20 nm
# Two populations observed; <13% were smaller than 60 nm, the remainder averaged 111 nm
# </T1>
# <T2>Caption: Concentration of silver (mug Ag/g) in tissues following i.v. administration (1 mg/kg) of AgAc, 20 nm AgNP or 110 nm AgNP to pregnant rats.
# | Tissue | AgAc.24 h | AgAc.48 h | 20 nm AgNP.24 h | 20 nm AgNP.48 h | 110 nm AgNP.24 h | 110 nm AgNP .48 h |
# | --- | --- | --- | --- | --- | --- | --- |
# | Liver | 1.03+-0.399 | 0.511+-0.534 | 0.312+-0.044 | 0.228+-0.130 | 2.28+-1.69 | 2.71+-1.63 |
# | Blood | 0.663+-0.195 | 0.180+-0.033 | 0.375+-0.0485 | 0.214+-0.0916 | 0.594+-0.0566 | 0.348+-0.0720 |
# | Spleen | 2.95+-0.927 | 0.524+-0.493 | 1.42+-0.499 | 1.14+-0.636 | 6.79+-2.16 | 3.60+-0.467 |
# | Lungs | 1.38+-0.958 | 1.31+-0.906 | 0.519+-0.103 | 0.397+-0.0950 | 0.436+-0.0839 | 0.305+-0.0831 |
# | Heart | 0.162+-0.0306 | 0.0584+-0.000479 | 0.127+-0.0168 | 0.0863 | 0.119+-0.0204 | 0.104+-0.0144 |
# | Kidney | 0.405+-0.0944 | 0.233+-0.0364 | 0.431+-0.0520 | 0.222+-0.0843 | 0.472+-0.0968 | 0.373+-0.161 |
# | Brain | 0.0358+-0.000661 | 0.0233+-0.00150 | 0.0297 | 0.0424 | b |  |
# | Skin | 0.224+-0.0488 | 0.265+-0.141 | 0.196+-0.147 | 0.194+-0.0735 | 0.188+-0.107 | 0.248+-0.189 |
# | Muscle | 0.0833+-0.0616 | 0.0556+-0.0210 | 0.0284+-0.00378 | 0.0146+-0.00525 |  |  |
# | Adipose | 0.0453+-0.0191 |  |  |  |  |  |
# | Bone | 0.311+-0.0455 | 0.119+-0.0370 | 0.243+-0.0780 | 0.144+-0.0789 | 0.120+-0.0386 | 0.136+-0.0299 |
# | Stomach and Small Intestine | 0.377+-0.215 | 0.145+-0.0958 | 0.319+-0.0378 | 0.167+-0.148 | 0.214+-0.165 | 0.136+-0.0376 |
# | Cecum and Large Intestine | 0.414+-0.118 | 0.443+-0.175 | 0.976+-0.431 | 0.370+-0.222 | 0.554+-0.150 | 0.459+-0.153 |
# | Pancreas | 0.196+-0.0561 | 0.170+-0.116 | 0.321+-0.204 | 0.138+-0.0553 | 0.0732+-0.0214 | 0.0831+-0.0485 |
# | Placenta | 0.881+-0.337 | 0.756+-0.184 | 0.696+-0.0682 | 0.926+-0.436 | 0.719+-0.0364 | 1.15+-0.239 |
# | Fetus | 0.0603+-0.0106 | 0.0759+-0.019 | 0.0445+-0.00763 | 0.0549+-0.0174 | 0.0316+-0.000507 | 0.0492+-0.00674 |
# Footnotes:
# All data are reported as Mean +- SD (n= 3)
# Only one rat had levels above quantitation limit.
# <LOQ = below limit of quantitation = quantitation limit; 0.0125 mug/g for tissues.
# </T2>
# <T3>Caption: Percent recovered of administered dose of silver in tissues following i.v. administration (1 mg/kg) of AgAc, 20 nm AgNP or 110 nm AgNP to pregnant rats
# | Tissue | AgAc.24 h | AgAc.48 h | 20 nm AgNP.24 h | 20 nm AgNP.48 h | 110 nm AgNP.24 h | 110 nm AgNP .48 h |
# | --- | --- | --- | --- | --- | --- | --- |
# | Liver | 4.33+-1.63 | 2.08+-2.02 | 1.44+-0.203 | 1.02+-0.635 | 8.69+-6.04 | 12.1+-7.11 |
# | Blood | 4.88+-1.39 | 1.33+-0.257 | 2.80+-0.346 | 1.57+-0.664 | 4.41+-0.418 | 2.55+-0.516 |
# | Spleen | 0.529+-0.124 | 0.114+-0.118 | 0.274+-0.0631 | 0.193+-0.110 | 1.44+-0.587 | 0.780+-0.0878 |
# | Lungs | 0.534+-0.402 | 0.496+-0.325 | 0.204+-0.0454 | 0.138+-0.0379 | 0.157+-0.0247 | 0.0974+-0.0139 |
# | Heart | 0.0504+-0.005 | 0.0181+-0.00348 | 0.0404+-0.00715 | 0.0234 | 0.0332+-0.00344 | 0.0317+-0.000950 |
# | Kidney | 0.248+-0.0583 | 0.125+-0.0233 | 0.265+-0.0367 | 0.125+-0.0454 | 0.274+-0.0505 | 0.221+-0.0734 |
# | Brain | 0.0213+-0.00126 | 0.0215+-0.000908 | 0.0169 | 0.0240 | b |  |
# | Skin | 4.34+-0.995 | 5.49+-2.95 | 3.89+-3.00 | 3.80+-1.47 | 3.75+-2.11 | 5.23+-4.08 |
# | Muscle | 3.42+-2.53 | 2.44+-0.901 | 1.19+-0.158 | 0.605+-0.137 |  |  |
# | Adipose | 0.324+-0.143 |  |  |  |  |  |
# | Bone | 2.21+-0.302 | 0.902+-0.273 | 1.77+-0.609 | 0.995+-0.486 | 0.881+-0.275 | 1.05+-0.214 |
# | Stomach and Small Intestine | 1.11+-0.567 | 0.530+-0.197 | 1.36+-0.442 | 0.593+-0.419 | 0.681+-0.533 | 0.627+-0.250 |
# | Cecum and Large Intestine | 1.33+-0.0429 | 1.49+-0.599 | 3.63+-1.58 | 1.15+-0.563 | 0.167+-0.0650 | 0.145+-0.387 |
# | Pancreas | 0.141+-0.0523 | 0.109+-0.0832 | 0.161+-0.114 | 0.103+-0.0475 | 0.0843+-0.047 | 0.0797+-0.037 |
# | Placenta | 1.41+-0.304 | 1.60+-0.470 | 1.28+-0.274 | 2.10+-1.10 | 1.26+-0.181 | 1.93+-0.483 |
# | Fetus | 0.529+-0.0521 | 1.01+-0.214 | 0.379+-0.108 | 0.835+-0.253 | 0.263+-0.0333 | 0.751+-0.0456 |
# Footnotes:
# All data are reported as Mean +- SD (n= 3)
# Only one rat had levels above quantitation limit.
# <LOQ = below limit of quantitation = quantitation limit; 0.0125 mug/g for tissues.
# </T3>
# <T4>Caption: Total percent recovery of administered dose 48 h following i.v. (1 mg/kg) or p.o. (10 mg/kg) of AgAc, 20 nm AgNP or 110 nm AgNP to pregnant rats.
# | Sample | AgAc.i.v. | AgAc.p.o. | 20 nm AgNP.i.v. | 20 nm AgNP.p.o. | 110 nm AgNP.i.v. | 110 nm AgNP .p.o. |
# | --- | --- | --- | --- | --- | --- | --- |
# | Tissues | 17.7+-6.90 | 0.601+-0.198 | 12.9+-4.01 | 0.53+-0.29 | 26.95+-4.97 | 0.430+-0.159 |
# | Urine | 0.0722+-0.0244 | b | 0.0297+-0.0044 | 0.0268 |  |  |
# | Feces | 38.9+-11.2 | 88.4+-20.9 | 9.68+-5.94 | 27.2+-8.97 | 5.97+-2.62 | 92.7+-6.76 |
# | Overall | 56.7+-5.96 | 89.0+-20.7 | 22.6+-9.30 | 27.7+-8.73 | 32.92+-6.96 | 93.1+-6.66 |
# Footnotes:
# All data are reported as Mean +- SD (n= 3)
# Only one rat had levels above the reportable limit
# <LOQ = below limit of quantitation = quantitation limit; 0.050 mug/g for feces, 0.005 mug/g for urine, and 0.0125 mug/g for tissues.
# Data for feces from 0-48 h
# </T4>
# <T5>Caption: Concentration of silver (mug Ag/g) in tissues following p.o. administration (10 mg/kg) of AgAc, 20 nm AgNP or 110 nm AgNP to pregnant rats.
# | Tissue | AgAc.24 h | AgAc.48 h | 20 nm AgNP.24 h | 20 nm AgNP.48 h | 110 nm AgNP.24 h | 110 nm AgNP .48 h |
# | --- | --- | --- | --- | --- | --- | --- |
# | Liver | 0.187+-0.106 | 0.324+-0.380 | 0.0592+-0.0293 | 0.0380+-0.0126 | 0.0205+-0.0150 | 0.0170+-0.00377 |
# | Blood | b | 0.117+-0.0168 | 0.124+-0.0120 | 0.0646+-0.00519 |  |  |
# | Spleen | 0.0802+-0.0648 | 0.104+-0.0702 | 0.220+-0.0329 | 0.172 | 0.172 |  |
# | Lungs | 0.137+-0.0239 | 0.177 | 0.965 |  |  |  |
# | Heart | 0.0604 |  |  |  |  |  |
# | Kidney | 0.461+-0.506 | 0.147+-0.0413 | 0.187+-0.0545 | 0.0868+-0.0136 | 0.104+-0.0387 | 0.0795+-0.0179 |
# | Brain |  |  |  |  |  |  |
# | Stomach and Small Intestine | 1.55+-2.51 | 0.0726+-0.0286 | 0.0657+-0.0324 | 0.0307+-0.0141 | 0.584+-0.468 | 0.0193+-0.00657 |
# | Cecum and Large Intestine | 16.0+-25.6 | 0.400+-0.0248 | 3.76+-2.24 | 0.884+-0.750 | 3.02+-1.04 | 0.901+-0.449 |
# | Placenta | 0.751+-0.0249 | 0.919+-0.271 | 0.518+-0.0302 | 0.354+-0.307 | 0.201+-0.125 | 0.351+-0.106 |
# | Fetus | 0.0537+-0.000831 | 0.0663+-0.0165 | 0.0266+-0.00239 | 0.0207+-0.0180 | 0.0211+-0.00183 | 0.0353+-0.00848 |
# Footnotes:
# All data are reported as Mean +- SD (n= 3)
# Only one rat had concentrations > quantitation limit.
# <LOQ = below limit of quantitation = quantitation limit; 0.0125 mug/g for tissues.
# </T5>
# <T6>Caption: Percent recovered of administered dose of silver following p.o. administration (10 mg/kg) of AgAc, 20 nm AgNP or 110 nm AgNP to pregnant rats.
# | Tissue | AgAc.24 h | AgAc.48 h | 20 nm AgNP.24 h | 20 nm AgNP.48 h | 110 nm AgNP.24 h | 110 nm AgNP .48 h |
# | --- | --- | --- | --- | --- | --- | --- |
# | Liver | 0.0836+-0.0628 | 0.134+-0.150 | 0.0287+-0.0143 | 0.0168+-0.00584 | 0.00967+-0.00739 | 0.00753+-0.00139 |
# | Blood | b | 0.0866+-0.0117 | 0.0993+-0.0127 | 0.0525+-0.00494 |  |  |
# | Spleen | 0.00165+-0.00155 | 0.00233+-0.00116 | 0.00540+-0.00181 | 0.00402 | 0.00402 |  |
# | Lungs | 0.00403+-0.000107 | 0.00628 | 0.00316 |  |  |  |
# | Heart | 0.00229 |  |  |  |  |  |
# | Kidney | 0.0286+-0.0307 | 0.00785+-0.00210 | 0.0123+-0.00380 | 0.00535+-0.000782 | 0.00631+-0.00260 | 0.00444+-0.00107 |
# | Brain |  |  |  |  |  |  |
# | Stomach and Small Intestine | 0.524+-0.841 | 0.0270+-0.007 | 0.276+-0.175 | 0.144+-0.048 | 0.239+-0.214 | 0.0079+-0.004 |
# | Cecum and Large Intestine | 7.06+-11.48 | 0.139+-0.084 | 15.0+-12.28 | 2.37+-1.95 | 0.975+-0.130 | 0.314+-0.151 |
# | Placenta | 0.112+-0.00432 | 0.161+-0.0216 | 0.0908+-0.00605 | 0.116+-0.00232 | 0.0372+-0.0258 | 0.0638+-0.0104 |
# | Fetus | 0.0531+-0.000121 | 0.0863+-0.0244 | 0.0230+-0.00103 | 0.0486+-0.00456 | 0.0205+-0.00326 | 0.0511+-0.00691 |
# Footnotes:
# All data are reported as Mean +- SD (n= 3)
# Only one rat had concentrations > quantitation limit.
# <LOQ = below limit of quantitation = quantitation limit; 0.0125 mug/g for tissues.
# </T6>
# <T7>Caption: Markers of cardiovascular injury from serum of pregnant rats at 24 or 48 h following i.v. or p.o. administration of AgAc, 20 or 110 nm AgNP.
# | Sample | Exposure duration | Route | PAI-1 (mean +- std.) | vWF (mean +- std.) |
# | --- | --- | --- | --- | --- |
# | Vehicle | 24 h | i.v. | 1,314+-156 | 222+-49.6 |
# | Vehicle | 48 h | 1,632+-1073 | 272+-236 |  |
# | AgAc | 24 h | 1,328+-437 | 258+-135 |  |
# | AgAc | 48 h | 970+-266 | 502+-167 |  |
# | 20 nm AgNP | 24 h | 1,723+-482 | 291+-77.3 |  |
# | 20 nm AgNP | 48 h | 759 | 322 |  |
# | 110 nm AgNP | 24 h | 62.1+-87.9 | 126+-58.2 |  |
# | 110 nm AgNP | 48 h | 406+-72.9 | 88.1+-77.1 |  |
# | Vehicle | 24 h | p.o. | 315+-68.4 | 71.5+-101 |
# | Vehicle | 48 h | 406+-73 | 88.1+-77.1 |  |
# | AgAc | 24 h | 398+-53.3 | 119+-29.6 |  |
# | AgAc | 48 h | 151+-95.6 | 26.5+-41.7 |  |
# | 110 nm AgNP | 24 h | 307+-56.2 | ND |  |
# | 110 nm AgNP | 48 h | 265+-116 | 6.73+-11.7 |  |
# Footnotes:
# All data are reported as Mean +- SEM ng/ml plasma of duplicates from n = 3.
# ND = not detected
# n=1 (for vehicle - Error for all readings on rats 2 and 3, for 20 nm AgNP 48 h - only one sample analyzed.)
# </T7>
# <T8>Caption: Cytokine/Chemokine expression for pregnant rats exposed i.v. to AgAc, 20 nm AgNP and vehicle after 24 or 48 h. All data are reported as mean +- SEM pg/ml of plasma of duplicates.
# | Cytokine | Vehicle.24 h | Vehicle.48 h | AgAc.24 h | AgAc.48 h | 20 nm AgNP.24 h | 20 nm AgNP .48 h |
# | --- | --- | --- | --- | --- | --- | --- |
# | Eotaxin | 146 | 336+-475 | ND | ND | ND | 55.3 |
# | IL-1beta | ND | ND | ND | ND | ND | ND |
# | IL-4 | 263 | 779+-1,072 | 44.5+-77.2 | ND | ND | ND |
# | IL-5 | ND | ND | ND | ND | ND | ND |
# | IL-6 | 489 | 3,561+-5,036 | 91.5+-158 | 4.66+-8.07 | 30.3+-27.2 | ND |
# | MCP-1 | 78.1 | 57.7+-81.6 | 57.4+-52.1 | 42.2+-36.5 | 62.8+-42.7 | ND |
# | TNF-alpha | ND | ND | ND | ND | ND | ND |
# | VEGF | ND | ND | ND | ND | ND | ND |
# Footnotes:
# All data are reported as Mean +- SD pg/ml of plasma of duplicates (n= 3)
# ND = not detected
# n=1 (for vehicle - Error for all readings on rats 2 and 3, for 20 nm AgNP 48 h - only one sample analyzed.)
# </T8>
# <T9>Caption: Library matched metabolites that are deemed to be important for differentiating pregnant rats administered a single i.v. (1 mg/kg) dose of 110 nm AgNP from vehicle at 48 h. Metabolites often fall in multiple bins, which is noted by the parenthesis.
# | Library Matched Metabolite | AgAc vs Vehicle.VIPRange | AgAc vs Vehicle.Fold Change range | 20 nm AgNP vs Vehicle.VIP Range | 20 nm AgNP vs Vehicle.Fold Change range | 110 nm AgNP vs Vehicle.VIP Range | 110 nm AgNP vs Vehicle .Fold Change range |
# | --- | --- | --- | --- | --- | --- | --- |
# | 1-Methylnicotinamide | 1.4 | (-1.7) |  |  |  |  |
# | 1-Methylnicotinamide | Lactose | Trigonelline | 1.3 | (-1.1) | 1.6 | (-1.2) |
# | 2-Oxoglutarate (1-2 bins) |  |  | 3.1 | 1.2 | 3.7 - 3.9 | (-2.3) - (-2.1) |
# | 3-Hydroxyphenylacetate (1-2 bins) | 1.1 | (-1.9) | 1.1 - 1.2 | (-2.8) - (-2.7) |  |  |
# | 3-Hydroxyphenylacetate | N-acetylglutamine | 1.7 | (-1.3) | 2.1 | (-1.7) | 1.0 |
# | Acetate | 3.8 | 1.4 |  |  | 4.0 | 2.9 |
# | Acetoacetate |  |  | 1.0 | 1.1 | 2.3 | 1.7 |
# | Acetoin | 2-Hydroxyisobutyrate |  |  | 1.0 | (-1.2) |  |
# | Allantoin |  |  |  |  | 3.5 | (-1.9) |
# | Choline |  |  | 1.0 | (-1.1) |  |  |
# | Citrate (1-2 bins) | 1.4 | (-1.3) | 4.9 | 1.3 | 1.1 - 4.4 | (-1.5) - 1.5 |
# | Creatinine |  |  | 2.2 | (-1.1) | 2.1 | (-1.3) |
# | Dimethylamine |  |  |  |  | 3.1 | (-2.3) |
# | Dimethylsulfone |  |  | 1.4 | (-1.2) |  |  |
# | Formate | 1.2 | (-1.7) |  |  |  |  |
# | Glucose |  |  |  |  | 1.3 | (-1.4) |
# | Glucose | Lactose |  |  | 1.5 | (-1.3) | 1.0 |
# | Glucose | Sucrose |  |  | 1.3 | (-1.1) |  |
# | Glutamine | 3.4 | (-1.6) | 3.1 | (-1.8) | 1.9 | (-1.7) |
# | Hippurate (3 bins) |  |  | 2.6 - 3.8 | 1.6 |  |  |
# | Hippurate | Glycolate | 3.0 | 1.1 | 3.7 | 1.2 |  |
# | Homocystine | 2.2 | (-1.3) | 2.7 | (-1.8) |  |  |
# | Isoleucine |  |  | 1.1 | (-1.1) |  |  |
# | Lactate |  |  | 1.8 | (-1.2) | 1.8 | 1.5 |
# | Leucine | Isoleucine | Fatty acids | 1.4 | 1.1 |  |  |
# | Methionine |  |  |  |  | 1.3 | 1.7 |
# | N-Acetylglutamine |  |  | 1.6 | (-1.2) |  |  |
# | N-Acetylglutamine | Glutamine | Methionine |  |  | 1.1 | (-1.1) |
# | N-Acetylglycine | N-Acetylaminoacids |  |  | 2.2 | (-1.1) |  |
# | Proline (1-2 bins) | 1.3 | (-1.1) | 1.3 | -1.1 | 1.2 | (-1.3) |
# | Succinate |  |  |  |  | 4.1 | 3.6 |
# | Sucrose |  |  | 1.1 | (-1.1) |  |  |
# | Taurine | Betaine | TMAO | 3.1 | (-1.1) |  |  |
# | Trans-Aconitate | 1.4 | (-1.2) |  |  |  |  |
# | Unknowns (5 - 13 bins) | 1.1 - 1.6 | (-1.8) - (-1.1) | 1.0 - 1.4 | (-2.2) - 1.3 | 1.1 - 2.4 | (-8.3) - 2.0 |
# Footnotes:
# VIP = variable importance for projection
# A negative fold change means that the vehicle median was higher than the AgNP median, while a positive fold change means that the AgNP median was higher than the vehicle median.
# </T9>
# <T10>Caption: Library matched metabolites that are deemed to be important for separating pregnant rats administered a single p.o. (10 mg/kg) dose of 20 nm AgNP from vehicle at 48 h. Metabolites often fall in multiple bins, which is noted by the parenthesis.
# | Library Matched Metabolite | AgAc vs Vehicle.VIPRange | AgAc vs Vehicle.Fold Change range | 20 nm AgNP vs Vehicle.VIP Range | 20 nm AgNP vs Vehicle.Fold Change range | 110 nm AgNP vs Vehicle.VIP Range | 110 nm AgNP vs Vehicle .Fold Change range |
# | --- | --- | --- | --- | --- | --- | --- |
# | 1-Methylnicotinamide | Lactose | Trigonelline | 1.2 | (-1.2) |  |  |
# | 2-Oxoglutarate (2 bins) |  |  | 3.1 - 3.3 | 1.5 - 1.6 |  |  |
# | 3-Hydroxyphenylacetate |  |  |  |  | 1.0 | (-1.5) |
# | 3-Hydroxyphenylacetate | N-Acetylglutamine |  |  | 1.5 | (-1.6) | 1.3 |
# | Acetate | 5.5 | 2.3 | 1.3 | (-1.3) |  |  |
# | Acetoacetate | trans-Aconitate |  |  | 2.3 | (-1.2) |  |
# | Alanine | 1.1 | 1.1 |  |  | 1.1 | 1.0 |
# | Allantoin | 3.3 | (-1.7) |  |  | 1.3 | (-1.6) |
# | Benzorate (2-3 bins) | 1.7 - 2.5 | 2.9 - 11.5 |  |  | 1.2 - 1.8 | 1.3 - 2.7 |
# | Citrate (2 bins) |  |  | 4.9 - 5.6 | (-1.4) |  |  |
# | Dimethylsulfone |  |  | 1.0 | 1.1 | 1.7 | 1.1 |
# | Glucose | 1.6 | (-1.4) |  |  |  |  |
# | Glucose | Lactose |  |  | 1.1 | 1.2 |  |
# | Glucose | Sucrose | 2.7 | 1.8 | 1.4 | 1.2 |  |
# | Glucose | Taurine | 2.2 | (-1.5) |  |  |  |
# | Hippurate (3 bins) |  |  |  |  | 2.9 - 4.4 | 1.6 |
# | Hippurate | Glycolate |  |  |  |  | 4.4 |
# | Homocystine |  |  |  |  | 1.7 | (-1.2) |
# | Isoleucine | 1.0 | 1.1 |  |  |  |  |
# | Lactate (2 bins) | 1.8 - 3.5 | 1.2 -2.0 | 1.1 | 1.1 |  |  |
# | Lactose | Glucose | 2.3 | 1.9 |  |  |  |
# | Leucine | Isoleucine | Fatty acids |  |  | 1.7 | 1.3 |
# | N,N-Dimethylglycine | 2.1 | 1.4 |  |  |  |  |
# | N-Acetylglutamine | 1.5 | (-1.1) | 1.5 | (-1.2) | 1.8 | (-1.1) |
# | N-Acetylglycine | N-Acetylaminoacids |  |  | 1.2 | (-1.0) |  |
# | Proline |  |  | 1.0 | (-1.1) | 1.3 | 1.1 |
# | Succinate | 4.9 | 2.0 | 2.8 | (-1.6) |  |  |
# | Sucrose |  |  | 1.5 | 1.3 |  |  |
# | Sucrose | Creatinine |  |  | 1.6 | 1.2 |  |
# | Trans-Aconitate |  |  | 1.2 | (-1.4) |  |  |
# | Valine/Leucine |  |  | 1.4 | 1.4 |  |  |
# | Unknowns (3-8 bins) | 1.0 - 2.8 | (-1.6) - 1.5 | 1.1 - 3.4 | (-1.1) - 1.2 | 1.4 - 2.1 | (-1.2) - 1.2 |
# Footnotes:
# VIP = variable importance for projection
# A negative fold change means that the vehicle median was higher than the AgNP median, while a positive fold change means that the AgNP median was higher than the vehicle median.
# </T10>
# <T11>Caption: List of the most perturbed pathways in the library matched metabolomics analysis and the metabolites that distinguish the AgAc, 20 nm or 110 nm AgNP and the vehicle control 48 h post i.v. or p.o. exposure.
# | Treatment | Route | Most perturbed pathway | p-Value | Pathway metabolites that differ from silver and vehicle |
# | --- | --- | --- | --- | --- |
# | AgAc vs Vehicle | i.v. | Ala,Ser,Cys,Met,His,Pro,Gly,Glu, and Gln metabolism and transport | 9.0x10 | BetaineGlycolic acidL-GlutamineL-Proline |
# | AgAc vs Vehicle | p.o. | Carbohydrate metabolism: Sucrose metabolism and transport | 5.4x10 | D-SucroseD-GlucoseLactose |
# | 20 nm AgNP vs Vehicle | i.v. | Ala,Ser,Cys,Met,His,Pro,Gly,Glu, and Gln metabolism and transport | 3.6x10 | 2-Oxoglutaric acidGlycolic acidL-GlutamineL-MethionineL-Proline |
# | 20 nm AgNP vs Vehicle | p.o. | TCA metabolism and transport | 2.1x10 | 2-OxoglutaricCitric acidSuccinic acid |
# | 110 nm AgNP vs Vehicle | i.v. | TCA metabolism and transport | 2.1x10 | 2-Oxoglutaric acidCitric acidSuccinic acid |
# | 110 nm AgNP vs Vehicle | p.o. | Alanine, Glycine, and Cysteine metabolism and transport | 3.6x10 | Glycolic acidL-AlanineL-Leucine |
# Footnotes:
# Ala (Alanine), Ser (Serine), Cys (Cystine), Met (Methionine), His (Histidine), Pro (Proline), Gly (Glycine), Glu (Glutamic acid), Gln (Glutamine)
# </T11>

# %% [markdown]
# API call to identify tables

# %%
id_tables_output = utils.chatgpt_request(id_tables_prompt, 100, 0)

time = datetime.now().strftime("%Y-%m-%d_%H-%M-%S")
with open(f"responses/table_id/{time}.txt", "w", encoding="utf-8") as file:
    file.write(f"{PMC}\n---\n{id_tables_prompt}\n---\n{id_tables_output}")
# Out:
# ChatGPT Request Status: 200

# %% [markdown]
# Assigning labels to table dict

# %%
for label in id_tables_output.split("\n"):
    label = label.strip()
    if not label: continue

    content = label[1:-1]
    tid, label = content.split("|")
    tables[tid.strip()]["label"] = label.strip().lower()

print(tables)
# Out:
# defaultdict(<function <lambda> at 0x00000199B350E520>, {'T1': {'label': 'o', 'caption': 'Methods for analysis of AgNP stock standard solutions and characteristics.', 'markdown': '| Characterization Assay | Method ID | 20 nm AgNP (NIEHS-2) | 110 nm AgNP (NIEHS-4) |\n| --- | --- | --- | --- |\n| Endotoxin Quantification - Kinetic Turbidity (EU/mL) | STE-1.2 | 1.1 | <0.5 |\n| Hydrodynamic Size/Size Distribution by DLS (Z-Avg [nm]) | PCC-1 | 26 | 112.3 |\n| Size by TEM (nm) | PCC-7 | 20.5 | 111.3 |\n| Surface Charge by Zeta Potential (mV) | PCC-2 | -37.1 | -25.9 |\n| Silver concentration by ICP-MS (mg/g) | PCC-8 | 1.09 | 1.10 |', 'footnotes': ['Two populations observed; <9% were smaller than 10 nm, the remainder averaged 20 nm', 'Two populations observed; <13% were smaller than 60 nm, the remainder averaged 111 nm'], 'col_labels': None, 'group_cols': [], 'biomarker_cols': []}, 'T2': {'label': 'b', 'caption': 'Concentration of silver (mug Ag/g) in tissues following i.v. administration (1 mg/kg) of AgAc, 20 nm AgNP or 110 nm AgNP to pregnant rats.', 'markdown': '| Tissue | AgAc.24 h | AgAc.48 h | 20 nm AgNP.24 h | 20 nm AgNP.48 h | 110 nm AgNP.24 h | 110 nm AgNP .48 h |\n| --- | --- | --- | --- | --- | --- | --- |\n| Liver | 1.03+-0.399 | 0.511+-0.534 | 0.312+-0.044 | 0.228+-0.130 | 2.28+-1.69 | 2.71+-1.63 |\n| Blood | 0.663+-0.195 | 0.180+-0.033 | 0.375+-0.0485 | 0.214+-0.0916 | 0.594+-0.0566 | 0.348+-0.0720 |\n| Spleen | 2.95+-0.927 | 0.524+-0.493 | 1.42+-0.499 | 1.14+-0.636 | 6.79+-2.16 | 3.60+-0.467 |\n| Lungs | 1.38+-0.958 | 1.31+-0.906 | 0.519+-0.103 | 0.397+-0.0950 | 0.436+-0.0839 | 0.305+-0.0831 |\n| Heart | 0.162+-0.0306 | 0.0584+-0.000479 | 0.127+-0.0168 | 0.0863 | 0.119+-0.0204 | 0.104+-0.0144 |\n| Kidney | 0.405+-0.0944 | 0.233+-0.0364 | 0.431+-0.0520 | 0.222+-0.0843 | 0.472+-0.0968 | 0.373+-0.161 |\n| Brain | 0.0358+-0.000661 | 0.0233+-0.00150 | 0.0297 | 0.0424 | b |  |\n| Skin | 0.224+-0.0488 | 0.265+-0.141 | 0.196+-0.147 | 0.194+-0.0735 | 0.188+-0.107 | 0.248+-0.189 |\n| Muscle | 0.0833+-0.0616 | 0.0556+-0.0210 | 0.0284+-0.00378 | 0.0146+-0.00525 |  |  |\n| Adipose | 0.0453+-0.0191 |  |  |  |  |  |\n| Bone | 0.311+-0.0455 | 0.119+-0.0370 | 0.243+-0.0780 | 0.144+-0.0789 | 0.120+-0.0386 | 0.136+-0.0299 |\n| Stomach and Small Intestine | 0.377+-0.215 | 0.145+-0.0958 | 0.319+-0.0378 | 0.167+-0.148 | 0.214+-0.165 | 0.136+-0.0376 |\n| Cecum and Large Intestine | 0.414+-0.118 | 0.443+-0.175 | 0.976+-0.431 | 0.370+-0.222 | 0.554+-0.150 | 0.459+-0.153 |\n| Pancreas | 0.196+-0.0561 | 0.170+-0.116 | 0.321+-0.204 | 0.138+-0.0553 | 0.0732+-0.0214 | 0.0831+-0.0485 |\n| Placenta | 0.881+-0.337 | 0.756+-0.184 | 0.696+-0.0682 | 0.926+-0.436 | 0.719+-0.0364 | 1.15+-0.239 |\n| Fetus | 0.0603+-0.0106 | 0.0759+-0.019 | 0.0445+-0.00763 | 0.0549+-0.0174 | 0.0316+-0.000507 | 0.0492+-0.00674 |', 'footnotes': ['All data are reported as Mean +- SD (n= 3)', 'Only one rat had levels above quantitation limit.', '<LOQ = below limit of quantitation = quantitation limit; 0.0125 mug/g for tissues.'], 'col_labels': None, 'group_cols': [], 'biomarker_cols': []}, 'T3': {'label': 'b', 'caption': 'Percent recovered of administered dose of silver in tissues following i.v. administration (1 mg/kg) of AgAc, 20 nm AgNP or 110 nm AgNP to pregnant rats', 'markdown': '| Tissue | AgAc.24 h | AgAc.48 h | 20 nm AgNP.24 h | 20 nm AgNP.48 h | 110 nm AgNP.24 h | 110 nm AgNP .48 h |\n| --- | --- | --- | --- | --- | --- | --- |\n| Liver | 4.33+-1.63 | 2.08+-2.02 | 1.44+-0.203 | 1.02+-0.635 | 8.69+-6.04 | 12.1+-7.11 |\n| Blood | 4.88+-1.39 | 1.33+-0.257 | 2.80+-0.346 | 1.57+-0.664 | 4.41+-0.418 | 2.55+-0.516 |\n| Spleen | 0.529+-0.124 | 0.114+-0.118 | 0.274+-0.0631 | 0.193+-0.110 | 1.44+-0.587 | 0.780+-0.0878 |\n| Lungs | 0.534+-0.402 | 0.496+-0.325 | 0.204+-0.0454 | 0.138+-0.0379 | 0.157+-0.0247 | 0.0974+-0.0139 |\n| Heart | 0.0504+-0.005 | 0.0181+-0.00348 | 0.0404+-0.00715 | 0.0234 | 0.0332+-0.00344 | 0.0317+-0.000950 |\n| Kidney | 0.248+-0.0583 | 0.125+-0.0233 | 0.265+ ...

# %% [markdown]
# Formatting Tables and converting to df

# %%
#Note: 1 LLM API call per table
formatted_tables = utils.format_tables(PMC, abstract, methods, tables)

for tid, info in formatted_tables.items():
    print(f"###{tid}###")
    if info["markdown"]: print(info["markdown"])
    info["df"] = table_utils.markdown_to_dataframe(info["markdown"])
# Out:
# ChatGPT Request Status: 200
# Tissue
# 0            AgAc.24 h
# 1            AgAc.48 h
# 2      20 nm AgNP.24 h
# 3      20 nm AgNP.48 h
# 4     110 nm AgNP.24 h
# 5    110 nm AgNP .48 h
# Name: Tissue, dtype: object
# Liver
# 0     1.03+-0.399
# 1    0.511+-0.534
# 2    0.312+-0.044
# 3    0.228+-0.130
# 4      2.28+-1.69
# 5      2.71+-1.63
# Name: Liver, dtype: object
# Blood
# 0     0.663+-0.195
# 1     0.180+-0.033
# 2    0.375+-0.0485
# 3    0.214+-0.0916
# 4    0.594+-0.0566
# 5    0.348+-0.0720
# Name: Blood, dtype: object
# Spleen
# 0     2.95+-0.927
# 1    0.524+-0.493
# 2     1.42+-0.499
# 3     1.14+-0.636
# 4      6.79+-2.16
# 5     3.60+-0.467
# Name: Spleen, dtype: object
# Lungs
# 0      1.38+-0.958
# 1      1.31+-0.906
# 2     0.519+-0.103
# 3    0.397+-0.0950
# 4    0.436+-0.0839
# 5    0.305+-0.0831
# Name: Lungs, dtype: object
# Heart
# 0       0.162+-0.0306
# 1    0.0584+-0.000479
# 2       0.127+-0.0168
# 3              0.0863
# 4       0.119+-0.0204
# 5       0.104+-0.0144
# Name: Heart, dtype: object
# Kidney
# 0    0.405+-0.0944
# 1    0.233+-0.0364
# 2    0.431+-0.0520
# 3    0.222+-0.0843
# 4    0.472+-0.0968
# 5     0.373+-0.161
# Name: Kidney, dtype: object
# Brain
# 0    0.0358+-0.000661
# 1     0.0233+-0.00150
# 2              0.0297
# 3              0.0424
# 4                   b
# 5
# Name: Brain, dtype: object
# Skin
# 0    0.224+-0.0488
# 1     0.265+-0.141
# 2     0.196+-0.147
# 3    0.194+-0.0735
# 4     0.188+-0.107
# 5     0.248+-0.189
# Name: Skin, dtype: object
# Muscle
# 0     0.0833+-0.0616
# 1     0.0556+-0.0210
# 2    0.0284+-0.00378
# 3    0.0146+-0.00525
# 4
# 5
# Name: Muscle, dtype: object
# Adipose
# 0    0.0453+-0.0191
# 1
# 2
# 3
# 4
# 5
# Name: Adipose, dtype: object
# Bone
# 0    0.311+-0.0455
# 1    0.119+-0.0370
# 2    0.243+-0.0780
# 3    0.144+-0.0789
# 4    0.120+-0.0386
# 5    0.136+-0.0299
# Name: Bone, dtype: object
# Stomach and Small Intestine
# 0     0.377+-0.215
# 1    0.145+-0.0958
# 2    0.319+-0.0378
# 3     0.167+-0.148
# 4     0.214+-0.165
# 5    0.136+-0.0376
# Name: Stomach and Small Intestine, dtype: object
# Cecum and Large Intestine
# 0    0.414+-0.118
# 1    0.443+-0.175
# 2    0.976+-0.431
# 3    0.370+-0.222
# 4    0.554+-0.150
# 5    0.459+-0.153
# Name: Cecum and Large Intestine, dtype: object
# Pancreas
# 0     0.196+-0.0561
# 1      0.170+-0.116
# 2      0.321+-0.204
# 3     0.138+-0.0553
# 4    0.0732+-0.0214
# 5    0.0831+-0.0485
# Name: Pancreas, dtype: object
# Placenta
# 0     0.881+-0.337
# 1     0.756+-0.184
# 2    0.696+-0.0682
# 3     0.926+-0.436
# 4    0.719+-0.0364
# 5      1.15+-0.239
# Name: Placenta, dtype: object
# ChatGPT Request Status: 200
# Tissue
# 0            AgAc.24 h
# 1            AgAc.48 h
# 2      20 nm AgNP.24 h
# 3      20 nm AgNP.48 h
# 4     110 nm AgNP.24 h
# 5    110 nm AgNP .48 h
# Name: Tissue, dtype: object
# Liver
# 0     4.33+-1.63
# 1     2.08+-2.02
# 2    1.44+-0.203
# 3    1.02+-0.635
# 4     8.69+-6.04
# 5     12.1+-7.11
# Name: Liver, dtype: object
# Blood
# 0     4.88+-1.39
# 1    1.33+-0.257
# 2    2.80+-0.346
# 3    1.57+-0.664
# 4    4.41+-0.418
# 5    2.55+-0.516
# Name: Blood, dtype: object
# Spleen
# 0     0.529+-0.124
# 1     0.114+-0.118
# 2    0.274+-0.0631
# 3     0.193+-0.110
# 4      1.44+-0.587
# 5    0.780+-0.0878
# Name: Spleen, dtype: object
# Lungs
# 0      0.534+-0.402
# 1      0.496+-0.325
# 2     0.204+-0.0454
# 3     0.138+-0.0379
# 4     0.157+-0.0247
# 5    0.0974+-0.0139
# Name: Lungs, dtype: object
# Heart
# 0       0.0504+-0.005
# 1     0.0181+-0.00348
# 2     0.0404+-0.00715
# 3              0.0234
# 4     0.0332+-0.00344
# 5    0.0317+-0.000950
# Name: Heart, dtype: object
# Kidney
# 0    0.248+-0.0583
# 1    0.125+-0.0233
# 2    0.265+-0.0367
# 3    0.125+-0.0454
# 4    0.274+-0.0505
# 5    0.221+-0.0734
# Name: Kidney, dtype: object
# Brain
# 0     0.0213+-0.00126
# 1    0.0215+-0.000908
# 2              0.0169
# 3              0.0240
# 4                   b
# 5
# Name: Brain, dtype: object
# Skin
# 0    4.34+-0.995
# 1     5.49+-2.95
# 2     3.89+-3.00
# 3     3.80+-1.47
# 4     3.75+-2.11
# 5     5.23+-4.08
# Name: Skin, dtype: object
# Muscle
# 0      3.42+-2.53
# 1     2.44+-0.901
# 2     1.19+-0.158
# 3    0.605+-0.137
# 4
# 5
# Name: Muscle, dtype: object
# Adipose
# 0    0.324+-0.143
# 1
# 2
# 3
# 4
# 5
# Name: Adipose, dtype: object
# Bone
# 0     2.21+-0.302
# 1    0.902+-0.273
# 2     1.77+-0.609
# 3    0.995+-0.486
# 4    0.881+-0.275
# 5     1.05+-0.214
# Name: Bone, dtype: object
# Stomach and Small Intestine
# 0     1.11+-0.567
# 1    0.530+-0.197
# 2     1.36+-0.442
# 3    0.593+-0.419
# 4    0.681+-0.533
# 5    0.627+-0.250
# Name: Stomach and Small Intestine, dtype: object
# Cecum and Large Intestine
# 0     1.33+-0.0429
# 1      1.49+-0.599
# 2       3.63+-1.58
# 3      1.15+-0.563
# 4    0.167+-0.0650
# 5     0.145+-0.387
# Name: Cecum and Large Intestine, dtype: object
# Pancreas
# 0    0.141+-0.0523
# 1    0.109+-0.0832
# 2     0.161+-0.114
# 3    0.103+-0.0475
# 4    0.0843+-0.047
# 5    0.0797+-0.037
# Name: Pancreas, dtype: object
# Placenta
# 0    1.41+-0.304
# 1    1.60+-0.470
# 2    1.28+-0.274
# 3     2.10+-1.10
# 4    1.26+-0.181
# 5    1.93+-0.483
# Name: Placenta, dtype: object
# ChatGPT Request Status: 200
# Tissue
# 0            AgAc.24 h
# 1            AgAc.48 h
# 2      20 nm AgNP.24 h
# 3      20 nm AgNP.48 h
# 4     110 nm AgNP.24 h
# 5    110 nm AgNP .48 h
# Name: Tissue, dtype: object
# Liver
# 0       0.187+-0.106
# 1       0.324+-0.380
# 2     0.0592+-0.0293
# 3     0.0380+-0.0126
# 4     0.0205+-0.0150
# 5    0.0170+-0.00377
# Name: Liver, dtype: object
# Blood
# 0                  b
# 1      0.117+-0.0168
# 2      0.124+-0.0120
# 3    0.0646+-0.00519
# 4
# 5
# Name: Blood, dtype: object
# Spleen
# 0    0.0802+-0.0648
# 1     0.104+-0.0702
# 2     0.220+-0.0329
# 3             0.172
# 4             0.172
# 5
# Name: Spleen, dtype: object
# Lungs
# 0    0.137+-0.0239
# 1            0.177
# 2            0.965
# 3
# 4
# 5
# Name: Lungs, dtype: object
# Heart
# 0    0.0604
# 1
# 2
# 3
# 4
# 5
# Name: Heart, dtype: object
# Kidney
# 0      0.461+-0.506
# 1     0.147+-0.0413
# 2     0.187+-0.0545
# 3    0.0868+-0.0136
# 4     0.104+-0.0387
# 5    0.0795+-0.0179
# Name: Kidney, dtype: object
# Brain
# 0
# 1
# 2
# 3
# 4
# 5
# Name: Brain, dtype: object
# Stomach and Small Intestine
# 0         1.55+-2.51
# 1     0.0726+-0.0286
# 2     0.0657+-0.0324
# 3     0.0307+-0.0141
# 4       0.584+-0.468
# 5    0.0193+-0.00657
# Name: Stomach and Small Intestine, dtype: object
# Cecum and Large Intestine
# 0       16.0+-25.6
# 1    0.400+-0.0248
# 2       3.76+-2.24
# 3     0.884+-0.750
# 4       3.02+-1.04
# 5     0.901+-0.449
# Name: Cecum and Large Intestine, dtype: object
# Placenta
# 0    0.751+-0.0249
# 1     0.919+-0.271
# 2    0.518+-0.0302
# 3     0.354+-0.307
# 4     0.201+-0.125
# 5     0.351+-0.106
# Name: Placenta, dtype: object
# ChatGPT Request Status: 200
# Tissue
# 0            AgAc.24 h
# 1            AgAc.48 h
# 2      20 nm AgNP.24 h
# 3      20 nm AgNP.48 h
# 4     110 nm AgNP.24 h
# 5    110 nm AgNP .48 h
# Name: Tissue, dtype: object
# Liver
# 0      0.0836+-0.0628
# 1        0.134+-0.150
# 2      0.0287+-0.0143
# 3     0.0168+-0.00584
# 4    0.00967+-0.00739
# 5    0.00753+-0.00139
# Name: Liver, dtype: object
# Blood
# 0                  b
# 1     0.0866+-0.0117
# 2     0.0993+-0.0127
# 3    0.0525+-0.00494
# 4
# 5
# Name: Blood, dtype: object
# Spleen
# 0    0.00165+-0.00155
# 1    0.00233+-0.00116
# 2    0.00540+-0.00181
# 3             0.00402
# 4             0.00402
# 5
# Name: Spleen, dtype: object
# Lungs
# 0    0.00403+-0.000107
# 1              0.00628
# 2              0.00316
# 3
# 4
# 5
# Name: Lungs, dtype: object
# Heart
# 0    0.00229
# 1
# 2
# 3
# 4
# 5
# Name: Heart, dtype: object
# Kidney
# 0       0.0286+-0.0307
# 1     0.00785+-0.00210
# 2      0.0123+-0.00380
# 3    0.00535+-0.000782
# 4     0.00631+-0.00260
# 5     0.00444+-0.00107
# Name: Kidney, dtype: object
# Brain
# 0
# 1
# 2
# 3
# 4
# 5
# Name: Brain, dtype: object
# Stomach and Small Intestine
# 0     0.524+-0.841
# 1    0.0270+-0.007
# 2     0.276+-0.175
# 3     0.144+-0.048
# 4     0.239+-0.214
# 5    0.0079+-0.004
# Name: Stomach and Small Intestine, dtype: object
# Cecum and Large Intestine
# 0     7.06+-11.48
# 1    0.139+-0.084
# 2     15.0+-12.28
# 3      2.37+-1.95
# 4    0.975+-0.130
# 5    0.314+-0.151
# Name: Cecum and Large Intestine, dtype: object
# Placenta
# 0     0.112+-0.00432
# 1      0.161+-0.0216
# 2    0.0908+-0.00605
# 3     0.116+-0.00232
# 4     0.0372+-0.0258
# 5     0.0638+-0.0104
# Name: Placenta, dtype: object
# ChatGPT Request Status: 200
# Sample.Exposure duration.Route
# 0    PAI-1 (mean +- std.)
# 1      vWF (mean +- std.)
# Name: Sample.Exposure duration.Route, dtype: object
# Vehicle.24 h.i.v.
# 0    1,314+-156
# 1     222+-49.6
# Name: Vehicle.24 h.i.v., dtype: object
# Vehicle.48 h.1,632+-1073
# 0    272+-236
# 1
# Name: Vehicle.48 h.1,632+-1073, dtype: object
# AgAc.24 h.1,328+-437
# 0    258+-135
# 1
# Name: AgAc.24 h.1,328+-437, dtype: object
# AgAc.48 h.970+-266
# 0    502+-167
# 1
# Name: AgAc.48 h.970+-266, dtype: object
# 20 nm AgNP.24 h.1,723+-482
# 0    291+-77.3
# 1
# Name: 20 nm AgNP.24 h.1,723+-482, dtype: object
# 20 nm AgNP.48 h.759
# 0    322
# 1
# Name: 20 nm AgNP.48 h.759, dtype: object
# 110 nm AgNP.24 h.62.1+-87.9
# 0    126+-58.2
# 1
# Name: 110 nm AgNP.24 h.62.1+-87.9, dtype: object
# 110 nm AgNP.48 h.406+-72.9
# 0    88.1+-77.1
# 1
# Name: 110 nm AgNP.48 h.406+-72.9, dtype: object
# Vehicle.24 h.p.o.
# 0    315+-68.4
# 1    71.5+-101
# Name: Vehicle.24 h.p.o., dtype: object
# Vehicle.48 h.406+-73
# 0    88.1+-77.1
# 1
# Name: Vehicle.48 h.406+-73, dtype: object
# AgAc.24 h.398+-53.3
# 0    119+-29.6
# 1
# Name: AgAc.24 h.398+-53.3, dtype: object
# AgAc.48 h.151+-95.6
# 0    26.5+-41.7
# 1
# Name: AgAc.48 h.151+-95.6, dtype: object
# 110 nm AgNP.24 h.307+-56.2
# 0    ND
# 1
# Name: 110 nm AgNP.24 h.307+-56.2, dtype: object
# ChatGPT Request Status: 200
# Cytokine
# 0      Eotaxin
# 1     IL-1beta
# 2         IL-4
# 3         IL-5
# 4         IL-6
# 5        MCP-1
# 6    TNF-alpha
# 7         VEGF
# Name: Cytokine, dtype: object
# Vehicle.24 h
# 0     146
# 1      ND
# 2     263
# 3      ND
# 4     489
# 5    78.1
# 6      ND
# 7      ND
# Name: Vehicle.24 h, dtype: object
# Vehicle.48 h
# 0        336+-475
# 1              ND
# 2      779+-1,072
# 3              ND
# 4    3,561+-5,036
# 5      57.7+-81.6
# 6              ND
# 7              ND
# Name: Vehicle.48 h, dtype: object
# AgAc.24 h
# 0            ND
# 1            ND
# 2    44.5+-77.2
# 3            ND
# 4     91.5+-158
# 5    57.4+-52.1
# 6            ND
# 7            ND
# Name: AgAc.24 h, dtype: object
# AgAc.48 h
# 0            ND
# 1            ND
# 2            ND
# 3            ND
# 4    4.66+-8.07
# 5    42.2+-36.5
# 6            ND
# 7            ND
# Name: AgAc.48 h, dtype: object
# 20 nm AgNP.24 h
# 0            ND
# 1            ND
# 2            ND
# 3            ND
# 4    30.3+-27.2
# 5    62.8+-42.7
# 6            ND
# 7            ND
# Name: 20 nm AgNP.24 h, dtype: object
# 20 nm AgNP .48 h
# 0    55.3
# 1      ND
# 2      ND
# 3      ND
# 4      ND
# 5      ND
# 6      ND
# 7      ND
# Name: 20 nm AgNP .48 h, dtype: object
# ###T1###
# | Characterization Assay | Method ID | 20 nm AgNP (NIEHS-2) | 110 nm AgNP (NIEHS-4) |
# | --- | --- | --- | --- |
# | Endotoxin Quantification - Kinetic Turbidity (EU/mL) | STE-1.2 | 1.1 | <0.5 |
# | Hydrodynamic Size/Size Distribution by DLS (Z-Avg [nm]) | PCC-1 | 26 | 112.3 |
# | Size by TEM (nm) | PCC-7 | 20.5 | 111.3 |
# | Surface Charge by Zeta Potential (mV) | PCC-2 | -37.1 | -25.9 |
# | Silver concentration by ICP-MS (mg/g) | PCC-8 | 1.09 | 1.10 |
# ###T2###
# | Tissue | Liver.mean | Liver.SD | Blood.mean | Blood.SD | Spleen.mean | Spleen.SD | Lungs.mean | Lungs.SD | Heart.mean | Heart.SD | Kidney.mean | Kidney.SD | Brain.mean | Brain.SD | Skin.mean | Skin.SD | Muscle.mean | Muscle.SD | Adipose.mean | Adipose.SD | Bone.mean | Bone.SD | Stomach and Small Intestine.mean | Stomach and Small Intestine.SD | Cecum and Large Intestine.mean | Cecum and Large Intestine.SD | Pancreas.mean | Pancreas.SD | Placenta.mean | Placenta.SD |
# | --- | --- | --- | --- | --- | --- | --- | --- | --- | --- | --- | --- | --- | --- | --- | --- | --- | --- | --- | --- | --- | --- | --- | --- | --- | --- | --- | --- | --- | --- | --- |
# | AgAc.24 h | 1.03 | 0.399 | 0.663 | 0.195 | 2.95 | 0.927 | 1.38 | 0.958 | 0.162 | 0.0306 | 0.405 | 0.0944 | 0.0358 | 0.000661 | 0.224 | 0.0488 | 0.0833 | 0.0616 | 0.0453 | 0.0191 | 0.311 | 0.0455 | 0.377 | 0.215 | 0.414 | 0.118 | 0.196 | 0.0561 | 0.881 | 0.337 |
# | AgAc.48 h | 0.511 | 0.534 | 0.180 | 0.033 | 0.524 | 0.493 | 1.31 | 0.906 | 0.0584 | 0.000479 | 0.233 | 0.0364 | 0.0233 | 0.00150 | 0.265 | 0.141 | 0.0556 | 0.0210 |  | nan | 0.119 | 0.0370 | 0.145 | 0.0958 | 0.443 | 0.175 | 0.170 | 0.116 | 0.756 | 0.184 |
# | 20 nm AgNP.24 h | 0.312 | 0.044 | 0.375 | 0.0485 | 1.42 | 0.499 | 0.519 | 0.103 | 0.127 | 0.0168 | 0.431 | 0.0520 | 0.0297 | nan | 0.196 | 0.147 | 0.0284 | 0.00378 |  | nan | 0.243 | 0.0780 | 0.319 | 0.0378 | 0.976 | 0.431 | 0.321 | 0.204 | 0.696 | 0.0682 |
# | 20 nm AgNP.48 h | 0.228 | 0.130 | 0.214 | 0.0916 | 1.14 | 0.636 | 0.397 | 0.0950 | 0.0863 | nan | 0.222 | 0.0843 | 0.0424 | nan | 0.194 | 0.0735 | 0.0146 | 0.00525 |  | nan | 0.144 | 0.0789 | 0.167 | 0.148 | 0.370 | 0.222 | 0.138 | 0.0553 | 0.926 | 0.436 |
# | 110 nm AgNP.24 h | 2.28 | 1.69 | 0.594 | 0.0566 | 6.79 | 2.16 | 0.436 | 0.0839 | 0.119 | 0.0204 | 0.472 | 0.0968 | b | nan | 0.188 | 0.107 |  | nan |  | nan | 0.120 | 0.0386 | 0.214 | 0.165 | 0.554 | 0.150 | 0.0732 | 0.0214 | 0.719 | 0.0364 |
# | 110 nm AgNP .48 h | 2.71 | 1.63 | 0.348 | 0.0720 | 3.60 | 0.467 | 0.305 | 0.0831 | 0.104 | 0.0144 | 0.373 | 0.161 |  | nan | 0.248 | 0.189 |  | nan |  | nan | 0.136 | 0.0299 | 0.136 | 0.0376 | 0.459 | 0.153 | 0.0831 | 0.0485 | 1.15 | 0.239 |
# ###T3###
# | Tissue | Liver.mean | Liver.SD | Blood.mean | Blood.SD | Spleen.mean | Spleen.SD | Lungs.mean | Lungs.SD | Heart.mean | Heart.SD | Kidney.mean | Kidney.SD | Brain.mean | Brain.SD | Skin.mean | Skin.SD | Muscle.mean | Muscle.SD | Adipose.mean | Adipose.SD | Bone.mean | Bone.SD | Stomach and Small Intestine.mean | Stomach and Small Intestine.SD | Cecum and Large Intestine.mean | Cecum and Large Intestine.SD | Pancreas.mean | Pancreas.SD | Placenta.mean | Placenta.SD |
# | --- | --- | --- | --- | --- | --- | --- | --- | --- | --- | --- | --- | --- | --- | --- | --- | --- | --- | --- | --- | --- | --- | --- | --- | --- | --- | --- | --- | --- | --- | --- |
# | AgAc.24 h | 4.33 | 1.63 | 4.88 | 1.39 | 0.529 | 0.124 | 0.534 | 0.402 | 0.0504 | 0.005 | 0.248 | 0.0583 | 0.0213 | 0.00126 | 4.34 | 0.995 | 3.42 | 2.53 | 0.324 | 0.143 | 2.21 | 0.302 | 1.11 | 0.567 | 1.33 | 0.0429 | 0.141 | 0.0523 | 1.41 | 0.304 |
# | AgAc.48 h | 2.08 | 2.02 | 1.33 | 0.257 | 0.114 | 0.118 | 0.496 | 0.325 | 0.0181 | 0.00348 | 0.125 | 0.0233 | 0.0215 | 0.000908 | 5.49 | 2.95 | 2.44 | 0.901 |  | nan | 0.902 | 0.273 | 0.530 | 0.197 | 1.49 | 0.599 | 0.109 | 0.0832 | 1.60 | 0.470 |
# | 20 nm AgNP.24 h | 1.44 | 0.203 | 2.80 | 0.346 | 0.274 | 0.0631 | 0.204 | 0.0454 | 0.0404 | 0.00715 | 0.265 | 0.0367 | 0.0169 | nan | 3.89 | 3.00 | 1.19 | 0.158 |  | nan | 1.77 | 0.609 | 1.36 | 0.442 | 3.63 | 1.58 | 0.161 | 0.114 | 1.28 | 0.274 |
# | 20 nm AgNP.48 h | 1.02 | 0.635 | 1.57 | 0.664 | 0.193 | 0.110 | 0.138 | 0.0379 | 0.0234 | nan | 0.125 | 0.0454 | 0.0240 | nan | 3.80 | 1.47 | 0.605 | 0.137 |  | nan | 0.995 | 0.486 | 0.593 | 0.419 | 1.15 | 0.563 | 0.103 | 0.0475 | 2.10 | 1.10 |
# | 110 nm AgNP.24 h | 8.69 | 6.04 | 4.41 | 0.418 | 1.44 | 0.587 | 0.157 | 0.0247 | 0.0332 | 0.00344 | 0.274 | 0.0505 | b | nan | 3.75 | 2.11 |  | nan |  | nan | 0.881 | 0.275 | 0.681 | 0.533 | 0.167 | 0.0650 | 0.0843 | 0.047 | 1.26 | 0.181 |
# | 110 nm AgNP .48 h | 12.1 | 7.11 | 2.55 | 0.516 | 0.780 | 0.0878 | 0.0974 | 0.0139 | 0.0317 | 0.000950 | 0.221 | 0.0734 |  | nan | 5.23 | 4.08 |  | nan |  | nan | 1.05 | 0.214 | 0.627 | 0.250 | 0.145 | 0.387 | 0.0797 | 0.037 | 1.93 | 0.483 |
# ###T4###
# | Sample | AgAc.i.v. | AgAc.p.o. | 20 nm AgNP.i.v. | 20 nm AgNP.p.o. | 110 nm AgNP.i.v. | 110 nm AgNP .p.o. |
# | --- | --- | --- | --- | --- | --- | --- |
# | Tissues | 17.7+-6.90 | 0.601+-0.198 | 12.9+-4.01 | 0.53+-0.29 | 26.95+-4.97 | 0.430+-0.159 |
# | Urine | 0.0722+-0.0244 | b | 0.0297+-0.0044 | 0.0268 |  |  |
# | Feces | 38.9+-11.2 | 88.4+-20.9 | 9.68+-5.94 | 27.2+-8.97 | 5.97+-2.62 | 92.7+-6.76 |
# | Overall | 56.7+-5.96 | 89.0+-20.7 | 22.6+-9.30 | 27.7+-8.73 | 32.92+-6.96 | 93.1+-6.66 |
# ###T5###
# | Tissue | Liver.mean | Liver.SD | Blood.mean | Blood.SD | Spleen.mean | Spleen.SD | Lungs.mean | Lungs.SD | Heart | Kidney.mean | Kidney.SD | Brain | Stomach and Small Intestine.mean | Stomach and Small Intestine.SD | Cecum and Large Intestine.mean | Cecum and Large Intestine.SD | Placenta.mean | Placenta.SD |
# | --- | --- | --- | --- | --- | --- | --- | --- | --- | --- | --- | --- | --- | --- | --- | --- | --- | --- | --- |
# | AgAc.24 h | 0.187 | 0.106 | b | nan | 0.0802 | 0.0648 | 0.137 | 0.0239 | 0.0604 | 0.461 | 0.506 |  | 1.55 | 2.51 | 16.0 | 25.6 | 0.751 | 0.0249 |
# | AgAc.48 h | 0.324 | 0.380 | 0.117 | 0.0168 | 0.104 | 0.0702 | 0.177 | nan |  | 0.147 | 0.0413 |  | 0.0726 | 0.0286 | 0.400 | 0.0248 | 0.919 | 0.271 |
# | 20 nm AgNP.24 h | 0.0592 | 0.0293 | 0.124 | 0.0120 | 0.220 | 0.0329 | 0.965 | nan |  | 0.187 | 0.0545 |  | 0.0657 | 0.0324 | 3.76 | 2.24 | 0.518 | 0.0302 |
# | 20 nm AgNP.48 h | 0.0380 | 0.0126 | 0.0646 | 0.00519 | 0.172 | nan |  | nan |  | 0.0868 | 0.0136 |  | 0.0307 | 0.0141 | 0.884 | 0.750 | 0.354 | 0.307 |
# | 110 nm AgNP.24 h | 0.0205 | 0.0150 |  | nan | 0.172 | nan |  | nan |  | 0.104 | 0.0387 |  | 0.584 | 0.468 | 3.02 | 1.04 | 0.201 | 0.125 |
# | 110 nm AgNP .48 h | 0.0170 | 0.00377 |  | nan |  | nan |  | nan |  | 0.0795 | 0.0179 |  | 0.0193 | 0.00657 | 0.901 | 0.449 | 0.351 | 0.106 |
# ###T6###
# | Tissue | Liver.mean | Liver.SD | Blood.mean | Blood.SD | Spleen.mean | Spleen.SD | Lungs.mean | Lungs.SD | Heart | Kidney.mean | Kidney.SD | Brain | Stomach and Small Intestine.mean | Stomach and Small Intestine.SD | Cecum and Large Intestine.mean | Cecum and Large Intestine.SD | Placenta.mean | Placenta.SD |
# | --- | --- | --- | --- | --- | --- | --- | --- | --- | --- | --- | --- | --- | --- | --- | --- | --- | --- | --- |
# | AgAc.24 h | 0.0836 | 0.0628 | b | nan | 0.00165 | 0.00155 | 0.00403 | 0.000107 | 0.00229 | 0.0286 | 0.0307 |  | 0.524 | 0.841 | 7.06 | 11.48 | 0.112 | 0.00432 |
# | AgAc.48 h | 0.134 | 0.150 | 0.0866 | 0.0117 | 0.00233 | 0.00116 | 0.00628 | nan |  | 0.00785 | 0.00210 |  | 0.0270 | 0.007 | 0.139 | 0.084 | 0.161 | 0.0216 |
# | 20 nm AgNP.24 h | 0.0287 | 0.0143 | 0.0993 | 0.0127 | 0.00540 | 0.00181 | 0.00316 | nan |  | 0.0123 | 0.00380 |  | 0.276 | 0.175 | 15.0 | 12.28 | 0.0908 | 0.00605 |
# | 20 nm AgNP.48 h | 0.0168 | 0.00584 | 0.0525 | 0.00494 | 0.00402 | nan |  | nan |  | 0.00535 | 0.000782 |  | 0.144 | 0.048 | 2.37 | 1.95 | 0.116 | 0.00232 |
# | 110 nm AgNP.24 h | 0.00967 | 0.00739 |  | nan | 0.00402 | nan |  | nan |  | 0.00631 | 0.00260 |  | 0.239 | 0.214 | 0.975 | 0.130 | 0.0372 | 0.0258 |
# | 110 nm AgNP .48 h | 0.00753 | 0.00139 |  | nan |  | nan |  | nan |  | 0.00444 | 0.00107 |  | 0.0079 | 0.004 | 0.314 | 0.151 | 0.0638 | 0.0104 |
# ###T7###
# | Sample.Exposure duration.Route.mean | Sample.Exposure duration.Route.SD | Vehicle.24 h.i.v..mean | Vehicle.24 h.i.v..SD | Vehicle.48 h.1,632+-1073.mean | Vehicle.48 h.1,632+-1073.SD | AgAc.24 h.1,328+-437.mean | AgAc.24 h.1,328+-437.SD | AgAc.48 h.970+-266.mean | AgAc.48 h.970+-266.SD | 20 nm AgNP.24 h.1,723+-482.mean | 20 nm AgNP.24 h.1,723+-482.SD | 20 nm AgNP.48 h.759 | 110 nm AgNP.24 h.62.1+-87.9.mean | 110 nm AgNP.24 h.62.1+-87.9.SD | 110 nm AgNP.48 h.406+-72.9.mean | 110 nm AgNP.48 h.406+-72.9.SD | Vehicle.24 h.p.o..mean | Vehicle.24 h.p.o..SD | Vehicle.48 h.406+-73.mean | Vehicle.48 h.406+-73.SD | AgAc.24 h.398+-53.3.mean | AgAc.24 h.398+-53.3.SD | AgAc.48 h.151+-95.6.mean | AgAc.48 h.151+-95.6.SD | 110 nm AgNP.24 h.307+-56.2 |
# | --- | --- | --- | --- | --- | --- | --- | --- | --- | --- | --- | --- | --- | --- | --- | --- | --- | --- | --- | --- | --- | --- | --- | --- | --- | --- |
# | PAI-1 (mean | std.) | 1,314 | 156 | 272 | 236 | 258 | 135 | 502 | 167 | 291 | 77.3 | 322 | 126 | 58.2 | 88.1 | 77.1 | 315 | 68.4 | 88.1 | 77.1 | 119 | 29.6 | 26.5 | 41.7 | ND |
# | vWF (mean | std.) | 222 | 49.6 |  | nan |  | nan |  | nan |  | nan |  |  | nan |  | nan | 71.5 | 101 |  | nan |  | nan |  | nan |  |
# ###T8###
# | Cytokine | Vehicle.24 h | Vehicle.48 h.mean | Vehicle.48 h.SD | AgAc.24 h.mean | AgAc.24 h.SD | AgAc.48 h.mean | AgAc.48 h.SD | 20 nm AgNP.24 h.mean | 20 nm AgNP.24 h.SD | 20 nm AgNP .48 h |
# | --- | --- | --- | --- | --- | --- | --- | --- | --- | --- | --- |
# | Eotaxin | 146 | 336 | 475 | ND | nan | ND | nan | ND | nan | 55.3 |
# | IL-1beta | ND | ND | nan | ND | nan | ND | nan | ND | nan | ND |
# | IL-4 | 263 | 779 | 1,072 | 44.5 | 77.2 | ND | nan | ND | nan | ND |
# | IL-5 | ND | ND | nan | ND | nan | ND | nan | ND | nan | ND |
# | IL-6 | 489 | 3,561 | 5,036 | 91.5 | 158 | 4.66 | 8.07 | 30.3 | 27.2 | ND |
# | MCP-1 | 78.1 | 57.7 | 81.6 | 57.4 | 52.1 | 42.2 | 36.5 | 62.8 | 42.7 | ND |
# | TNF-alpha | ND | ND | nan | ND | nan | ND | nan | ND | nan | ND |
# | VEGF | ND | ND | nan | ND | nan | ND | nan | ND | nan | ND |
# ###T9###
# | Library Matched Metabolite | AgAc vs Vehicle.VIPRange | AgAc vs Vehicle.Fold Change range | 20 nm AgNP vs Vehicle.VIP Range | 20 nm AgNP vs Vehicle.Fold Change range | 110 nm AgNP vs Vehicle.VIP Range | 110 nm AgNP vs Vehicle .Fold Change range |
# | --- | --- | --- | --- | --- | --- | --- |
# | 1-Methylnicotinamide | 1.4 | (-1.7) |  |  |  |  |
# | 1-Methylnicotinamide | Lactose | Trigonelline | 1.3 | (-1.1) | 1.6 | (-1.2) |
# | 2-Oxoglutarate (1-2 bins) |  |  | 3.1 | 1.2 | 3.7 - 3.9 | (-2.3) - (-2.1) |
# | 3-Hydroxyphenylacetate (1-2 bins) | 1.1 | (-1.9) | 1.1 - 1.2 | (-2.8) - (-2.7) |  |  |
# | 3-Hydroxyphenylacetate | N-acetylglutamine | 1.7 | (-1.3) | 2.1 | (-1.7) | 1.0 |
# | Acetate | 3.8 | 1.4 |  |  | 4.0 | 2.9 |
# | Acetoacetate |  |  | 1.0 | 1.1 | 2.3 | 1.7 |
# | Acetoin | 2-Hydroxyisobutyrate |  |  | 1.0 | (-1.2) |  |
# | Allantoin |  |  |  |  | 3.5 | (-1.9) |
# | Choline |  |  | 1.0 | (-1.1) |  |  |
# | Citrate (1-2 bins) | 1.4 | (-1.3) | 4.9 | 1.3 | 1.1 - 4.4 | (-1.5) - 1.5 |
# | Creatinine |  |  | 2.2 | (-1.1) | 2.1 | (-1.3) |
# | Dimethylamine |  |  |  |  | 3.1 | (-2.3) |
# | Dimethylsulfone |  |  | 1.4 | (-1.2) |  |  |
# | Formate | 1.2 | (-1.7) |  |  |  |  |
# | Glucose |  |  |  |  | 1.3 | (-1.4) |
# | Glucose | Lactose |  |  | 1.5 | (-1.3) | 1.0 |
# | Glucose | Sucrose |  |  | 1.3 | (-1.1) |  |
# | Glutamine | 3.4 | (-1.6) | 3.1 | (-1.8) | 1.9 | (-1.7) |
# | Hippurate (3 bins) |  |  | 2.6 - 3.8 | 1.6 |  |  |
# | Hippurate | Glycolate | 3.0 | 1.1 | 3.7 | 1.2 |  |
# | Homocystine | 2.2 | (-1.3) | 2.7 | (-1.8) |  |  |
# | Isoleucine |  |  | 1.1 | (-1.1) |  |  |
# | Lactate |  |  | 1.8 | (-1.2) | 1.8 | 1.5 |
# | Leucine | Isoleucine | Fatty acids | 1.4 | 1.1 |  |  |
# | Methionine |  |  |  |  | 1.3 | 1.7 |
# | N-Acetylglutamine |  |  | 1.6 | (-1.2) |  |  |
# | N-Acetylglutamine | Glutamine | Methionine |  |  | 1.1 | (-1.1) |
# | N-Acetylglycine | N-Acetylaminoacids |  |  | 2.2 | (-1.1) |  |
# | Proline (1-2 bins) | 1.3 | (-1.1) | 1.3 | -1.1 | 1.2 | (-1.3) |
# | Succinate |  |  |  |  | 4.1 | 3.6 |
# | Sucrose |  |  | 1.1 | (-1.1) |  |  |
# | Taurine | Betaine | TMAO | 3.1 | (-1.1) |  |  |
# | Trans-Aconitate | 1.4 | (-1.2) |  |  |  |  |
# | Unknowns (5 - 13 bins) | 1.1 - 1.6 | (-1.8) - (-1.1) | 1.0 - 1.4 | (-2.2) - 1.3 | 1.1 - 2.4 | (-8.3) - 2.0 |
# ###T10###
# | Library Matched Metabolite | AgAc vs Vehicle.VIPRange | AgAc vs Vehicle.Fold Change range | 20 nm AgNP vs Vehicle.VIP Range | 20 nm AgNP vs Vehicle.Fold Change range | 110 nm AgNP vs Vehicle.VIP Range | 110 nm AgNP vs Vehicle .Fold Change range |
# | --- | --- | --- | --- | --- | --- | --- |
# | 1-Methylnicotinamide | Lactose | Trigonelline | 1.2 | (-1.2) |  |  |
# | 2-Oxoglutarate (2 bins) |  |  | 3.1 - 3.3 | 1.5 - 1.6 |  |  |
# | 3-Hydroxyphenylacetate |  |  |  |  | 1.0 | (-1.5) |
# | 3-Hydroxyphenylacetate | N-Acetylglutamine |  |  | 1.5 | (-1.6) | 1.3 |
# | Acetate | 5.5 | 2.3 | 1.3 | (-1.3) |  |  |
# | Acetoacetate | trans-Aconitate |  |  | 2.3 | (-1.2) |  |
# | Alanine | 1.1 | 1.1 |  |  | 1.1 | 1.0 |
# | Allantoin | 3.3 | (-1.7) |  |  | 1.3 | (-1.6) |
# | Benzorate (2-3 bins) | 1.7 - 2.5 | 2.9 - 11.5 |  |  | 1.2 - 1.8 | 1.3 - 2.7 |
# | Citrate (2 bins) |  |  | 4.9 - 5.6 | (-1.4) |  |  |
# | Dimethylsulfone |  |  | 1.0 | 1.1 | 1.7 | 1.1 |
# | Glucose | 1.6 | (-1.4) |  |  |  |  |
# | Glucose | Lactose |  |  | 1.1 | 1.2 |  |
# | Glucose | Sucrose | 2.7 | 1.8 | 1.4 | 1.2 |  |
# | Glucose | Taurine | 2.2 | (-1.5) |  |  |  |
# | Hippurate (3 bins) |  |  |  |  | 2.9 - 4.4 | 1.6 |
# | Hippurate | Glycolate |  |  |  |  | 4.4 |
# | Homocystine |  |  |  |  | 1.7 | (-1.2) |
# | Isoleucine | 1.0 | 1.1 |  |  |  |  |
# | Lactate (2 bins) | 1.8 - 3.5 | 1.2 -2.0 | 1.1 | 1.1 |  |  |
# | Lactose | Glucose | 2.3 | 1.9 |  |  |  |
# | Leucine | Isoleucine | Fatty acids |  |  | 1.7 | 1.3 |
# | N,N-Dimethylglycine | 2.1 | 1.4 |  |  |  |  |
# | N-Acetylglutamine | 1.5 | (-1.1) | 1.5 | (-1.2) | 1.8 | (-1.1) |
# | N-Acetylglycine | N-Acetylaminoacids |  |  | 1.2 | (-1.0) |  |
# | Proline |  |  | 1.0 | (-1.1) | 1.3 | 1.1 |
# | Succinate | 4.9 | 2.0 | 2.8 | (-1.6) |  |  |
# | Sucrose |  |  | 1.5 | 1.3 |  |  |
# | Sucrose | Creatinine |  |  | 1.6 | 1.2 |  |
# | Trans-Aconitate |  |  | 1.2 | (-1.4) |  |  |
# | Valine/Leucine |  |  | 1.4 | 1.4 |  |  |
# | Unknowns (3-8 bins) | 1.0 - 2.8 | (-1.6) - 1.5 | 1.1 - 3.4 | (-1.1) - 1.2 | 1.4 - 2.1 | (-1.2) - 1.2 |
# ###T11###
# | Treatment | Route | Most perturbed pathway | p-Value | Pathway metabolites that differ from silver and vehicle |
# | --- | --- | --- | --- | --- |
# | AgAc vs Vehicle | i.v. | Ala,Ser,Cys,Met,His,Pro,Gly,Glu, and Gln metabolism and transport | 9.0x10 | BetaineGlycolic acidL-GlutamineL-Proline |
# | AgAc vs Vehicle | p.o. | Carbohydrate metabolism: Sucrose metabolism and transport | 5.4x10 | D-SucroseD-GlucoseLactose |
# | 20 nm AgNP vs Vehicle | i.v. | Ala,Ser,Cys,Met,His,Pro,Gly,Glu, and Gln metabolism and transport | 3.6x10 | 2-Oxoglutaric acidGlycolic acidL-GlutamineL-MethionineL-Proline |
# | 20 nm AgNP vs Vehicle | p.o. | TCA metabolism and transport | 2.1x10 | 2-OxoglutaricCitric acidSuccinic acid |
# | 110 nm AgNP vs Vehicle | i.v. | TCA metabolism and transport | 2.1x10 | 2-Oxoglutaric acidCitric acidSuccinic acid |
# | 110 nm AgNP vs Vehicle | p.o. | Alanine, Glycine, and Cysteine metabolism and transport | 3.6x10 | Glycolic acidL-AlanineL-Leucine |

# %% [markdown]
# IDing columns via LLM

# %%
for tid, info in formatted_tables.items():
    if info["label"] != "b": continue
    info_combined = ""
    if not info["markdown"]: continue
    if info["caption"]:
        info_combined += f"Caption: {info["caption"]}\n"
    info_combined += info["markdown"] + "\n"
    if len(info["footnotes"]) > 0:
        info_combined += "Footnotes:\n"
        for fn in info["footnotes"]:
            info_combined += fn + "\n"
    prompt = utils.id_columns_prompt(info_combined)
    answer = utils.chatgpt_request(prompt, 5000, 0)
    info["col_labels"] = [[elt.strip() for elt in label.strip().lstrip('<').rstrip('>').split("|")] for label in answer.split("\n")]
    time = datetime.now().strftime("%Y-%m-%d_%H-%M-%S")
    with open(f"responses/column_id/{time}.txt", "w", encoding="utf-8") as file:
        file.write(f"{PMC}\n---\n{tid}\n---\n{prompt}\n---\n{answer}")
# Out:
# ChatGPT Request Status: 200
# ChatGPT Request Status: 200
# ChatGPT Request Status: 200
# ChatGPT Request Status: 200
# ChatGPT Request Status: 200
# ChatGPT Request Status: 200

# %% [markdown]
# Processing column IDs

# %%
for tid, info in formatted_tables.items():
    if info["label"] != "b":
        continue
    info["biomarker_cols"] = []
    info["group_cols"] = []
    column_info = {}
    for label in info["col_labels"]:
        if label[1].lower() not in ["biomarker", "group", "dose", "size", "animal", "time"]: continue
        print(label[1].lower())
        if label[1].lower() == "biomarker":
            if label[3].lower() not in ["mean", "variation", "frequency", "severity"]: continue
            biomarker_label = {"column": label[0], "label": "biomarker", "type": label[3].lower(), "units": None, "name": label[2]}
            if label[3].lower() == "mean" and len(label) > 4:
                biomarker_label["units"] = label[4]
            elif label[3].lower() == "variation" and len(label) > 4:
                biomarker_label["units"] = label[4]
            elif label[3].lower() == "frequency":
                if len(label) > 4 and label[4].lower() in ["percent", "percents", "percentage", "percentages", "%", "count", "counts", "decimal", "decimals"]:
                    biomarker_label["units"] = label[4]
                else:
                    print("ERROR: Invalid type for count label -> skipping")
                    continue
            info["biomarker_cols"].append(biomarker_label)
        else:
            group_label = {"column": label[0], "label": label[1].strip().lower(), "units": [], "link": None, "name": None}
            if label[1].lower() == "dose":
                for i in range(2,len(label)):
                    if label[i].strip()[:5].lower() == "name:":
                        group_label["name"] = label[i].strip()[5:].strip()
                    elif label[i].strip()[:6].lower() == "units:":
                        group_label["units"].append(label[i].strip()[6:].strip())
                    elif label[i].strip()[:5].lower() == "link:":
                        group_label["link"] = label[i].strip()[5:].strip()
            elif label[1].lower() == "animal":
                if len(label) > 2:
                    group_label["name"] = label[2]
            info["group_cols"].append(group_label)
# Out:
# biomarker
# biomarker
# biomarker
# biomarker
# biomarker
# biomarker
# biomarker
# biomarker
# biomarker
# biomarker
# biomarker
# biomarker
# biomarker
# biomarker
# biomarker
# biomarker
# biomarker
# biomarker
# biomarker
# biomarker
# biomarker
# biomarker
# biomarker
# biomarker
# biomarker
# biomarker
# biomarker
# biomarker
# biomarker
# biomarker
# group
# biomarker
# biomarker
# biomarker
# biomarker
# biomarker
# biomarker
# biomarker
# biomarker
# biomarker
# biomarker
# biomarker
# biomarker
# biomarker
# biomarker
# biomarker
# biomarker
# biomarker
# biomarker
# biomarker
# biomarker
# biomarker
# biomarker
# biomarker
# biomarker
# biomarker
# biomarker
# biomarker
# biomarker
# biomarker
# biomarker
# group
# biomarker
# biomarker
# biomarker
# biomarker
# biomarker
# biomarker
# biomarker
# biomarker
# biomarker
# biomarker
# biomarker
# biomarker
# biomarker
# biomarker
# biomarker
# biomarker
# biomarker
# biomarker
# biomarker
# biomarker
# biomarker
# biomarker
# biomarker
# biomarker
# biomarker
# biomarker
# biomarker
# biomarker
# biomarker
# biomarker
# biomarker
# biomarker
# biomarker
# biomarker
# biomarker
# biomarker
# biomarker
# biomarker
# biomarker
# biomarker
# biomarker
# biomarker
# biomarker
# biomarker
# biomarker
# biomarker
# biomarker
# biomarker
# biomarker
# biomarker
# biomarker
# biomarker
# biomarker
# biomarker
# biomarker
# biomarker
# biomarker
# biomarker
# biomarker
# biomarker
# biomarker
# biomarker
# biomarker
# biomarker
# biomarker
# biomarker
# biomarker
# biomarker
# biomarker
# biomarker
# biomarker
# biomarker
# biomarker
# biomarker
# biomarker
# biomarker
# biomarker
# biomarker
# biomarker
# biomarker
# biomarker
# biomarker
# biomarker
# biomarker
# biomarker
# biomarker
# biomarker
# biomarker
# biomarker
# biomarker
# biomarker
# biomarker
# biomarker
# biomarker
# biomarker
# biomarker

# %%
for tid, info in formatted_tables.items():
    if info["label"] != "b": continue
    print(info["col_labels"])
    print(f"GROUP COLUMNS:\n{info["group_cols"]}")
    print(f"BIOMARKER COLUMNS:\n{info["biomarker_cols"]}")
# Out:
# [['Liver.mean', 'biomarker', 'Liver', 'mean', 'mug/g'], ['Liver.SD', 'biomarker', 'Liver', 'variation', 'mug/g'], ['Blood.mean', 'biomarker', 'Blood', 'mean', 'mug/g'], ['Blood.SD', 'biomarker', 'Blood', 'variation', 'mug/g'], ['Spleen.mean', 'biomarker', 'Spleen', 'mean', 'mug/g'], ['Spleen.SD', 'biomarker', 'Spleen', 'variation', 'mug/g'], ['Lungs.mean', 'biomarker', 'Lungs', 'mean', 'mug/g'], ['Lungs.SD', 'biomarker', 'Lungs', 'variation', 'mug/g'], ['Heart.mean', 'biomarker', 'Heart', 'mean', 'mug/g'], ['Heart.SD', 'biomarker', 'Heart', 'variation', 'mug/g'], ['Kidney.mean', 'biomarker', 'Kidney', 'mean', 'mug/g'], ['Kidney.SD', 'biomarker', 'Kidney', 'variation', 'mug/g'], ['Brain.mean', 'biomarker', 'Brain', 'mean', 'mug/g'], ['Brain.SD', 'biomarker', 'Brain', 'variation', 'mug/g'], ['Skin.mean', 'biomarker', 'Skin', 'mean', 'mug/g'], ['Skin.SD', 'biomarker', 'Skin', 'variation', 'mug/g'], ['Muscle.mean', 'biomarker', 'Muscle', 'mean', 'mug/g'], ['Muscle.SD', 'biomarker', 'Muscle', 'variation', 'mug/g'], ['Adipose.mean', 'biomarker', 'Adipose', 'mean', 'mug/g'], ['Adipose.SD', 'biomarker', 'Adipose', 'variation', 'mug/g'], ['Bone.mean', 'biomarker', 'Bone', 'mean', 'mug/g'], ['Bone.SD', 'biomarker', 'Bone', 'variation', 'mug/g'], ['Stomach and Small Intestine.mean', 'biomarker', 'Stomach and Small Intestine', 'mean', 'mug/g'], ['Stomach and Small Intestine.SD', 'biomarker', 'Stomach and Small Intestine', 'variation', 'mug/g'], ['Cecum and Large Intestine.mean', 'biomarker', 'Cecum and Large Intestine', 'mean', 'mug/g'], ['Cecum and Large Intestine.SD', 'biomarker', 'Cecum and Large Intestine', 'variation', 'mug/g'], ['Pancreas.mean', 'biomarker', 'Pancreas', 'mean', 'mug/g'], ['Pancreas.SD', 'biomarker', 'Pancreas', 'variation', 'mug/g'], ['Placenta.mean', 'biomarker', 'Placenta', 'mean', 'mug/g'], ['Placenta.SD', 'biomarker', 'Placenta', 'variation', 'mug/g']]
# GROUP COLUMNS:
# []
# BIOMARKER COLUMNS:
# [{'column': 'Liver.mean', 'label': 'biomarker', 'type': 'mean', 'units': 'mug/g', 'name': 'Liver'}, {'column': 'Liver.SD', 'label': 'biomarker', 'type': 'variation', 'units': 'mug/g', 'name': 'Liver'}, {'column': 'Blood.mean', 'label': 'biomarker', 'type': 'mean', 'units': 'mug/g', 'name': 'Blood'}, {'column': 'Blood.SD', 'label': 'biomarker', 'type': 'variation', 'units': 'mug/g', 'name': 'Blood'}, {'column': 'Spleen.mean', 'label': 'biomarker', 'type': 'mean', 'units': 'mug/g', 'name': 'Spleen'}, {'column': 'Spleen.SD', 'label': 'biomarker', 'type': 'variation', 'units': 'mug/g', 'name': 'Spleen'}, {'column': 'Lungs.mean', 'label': 'biomarker', 'type': 'mean', 'units': 'mug/g', 'name': 'Lungs'}, {'column': 'Lungs.SD', 'label': 'biomarker', 'type': 'variation', 'units': 'mug/g', 'name': 'Lungs'}, {'column': 'Heart.mean', 'label': 'biomarker', 'type': 'mean', 'units': 'mug/g', 'name': 'Heart'}, {'column': 'Heart.SD', 'label': 'biomarker', 'type': 'variation', 'units': 'mug/g', 'name': 'Heart'}, {'column': 'Kidney.mean', 'label': 'biomarker', 'type': 'mean', 'units': 'mug/g', 'name': 'Kidney'}, {'column': 'Kidney.SD', 'label': 'biomarker', 'type': 'variation', 'units': 'mug/g', 'name': 'Kidney'}, {'column': 'Brain.mean', 'label': 'biomarker', 'type': 'mean', 'units': 'mug/g', 'name': 'Brain'}, {'column': 'Brain.SD', 'label': 'biomarker', 'type': 'variation', 'units': 'mug/g', 'name': 'Brain'}, {'column': 'Skin.mean', 'label': 'biomarker', 'type': 'mean', 'units': 'mug/g', 'name': 'Skin'}, {'column': 'Skin.SD', 'label': 'biomarker', 'type': 'variation', 'units': 'mug/g', 'name': 'Skin'}, {'column': 'Muscle.mean', 'label': 'biomarker', 'type': 'mean', 'units': 'mug/g', 'name': 'Muscle'}, {'column': 'Muscle.SD', 'label': 'biomarker', 'type': 'variation', 'units': 'mug/g', 'name': 'Muscle'}, {'column': 'Adipose.mean', 'label': 'biomarker', 'type': 'mean', 'units': 'mug/g', 'name': 'Adipose'}, {'column': 'Adipose.SD', 'label': 'biomarker', 'type': 'variation', 'units': 'mug/g', 'name': 'Adipose'}, {'column': 'Bone.mean', 'label': 'biomarker', 'type': 'mean', 'units': 'mug/g', 'name': 'Bone'}, {'column': 'Bone.SD', 'label': 'biomarker', 'type': 'variation', 'units': 'mug/g', 'name': 'Bone'}, {'column': 'Stomach and Small Intestine.mean', 'label': 'biomarker', 'type': 'mean', 'units': 'mug/g', 'name': 'Stomach and Small Intestine'}, {'column': 'Stomach and Small Intestine.SD', 'label': 'biomarker', 'type': 'variation', 'units': 'mug/g', 'name': 'Stomach and Small Intestine'}, {'column': 'Cecum and Large Intestine.mean', 'label': 'biomarker', 'type': 'mean', 'units': 'mug/g', 'name': 'Cecum and Large Intestine'}, {'column': 'Cecum and Large Intestine.SD', 'label': 'biomarker', 'type': 'variation', 'units': 'mug/g', 'name': 'Cecum and Large Intestine'}, {'column': 'Pancreas.mean', 'label': 'biomarker', 'type': 'mean', 'units': 'mug/g', 'name': 'Pancreas'}, {'column': 'Pancreas.SD', 'label': 'biomarker', 'type': 'variation', 'units': 'mug/g', 'name': 'Pancreas'}, {'column': 'Placenta.mean', 'label': 'biomarker', 'type': 'mean', 'units': 'mug/g', 'name': 'Placenta'}, {'column': 'Placenta.SD', 'label': 'biomarker', 'type': 'variation', 'units': 'mug/g', 'name': 'Placenta'}]
# [['Tissue', 'group'], ['Liver.mean', 'biomarker', 'Liver', 'mean', 'percent'], ['Liver.SD', 'biomarker', 'Liver', 'variation', 'percent'], ['Blood.mean', 'biomarker', 'Blood', 'mean', 'percent'], ['Blood.SD', 'biomarker', 'Blood', 'variation', 'percent'], ['Spleen.mean', 'biomarker', 'Spleen', 'mean', 'percent'], ['Spleen.SD', 'biomarker', 'Spleen', 'variation', 'percent'], ['Lungs.mean', 'biomarker', 'Lungs', 'mean', 'percent'], ['Lungs.SD', 'biomarker', 'Lungs', 'variation', 'percent'], ['Heart.mean', 'biomarker', 'Heart', 'mean', 'percent'], ['Heart.SD', 'biomarker', 'Heart', 'variation', 'percent'], ['Kidney.mean', 'biomarker', 'Kidney', 'mean', 'percent'], ['Kidney.SD', 'biomarker', 'Kidney', 'variation', 'percent'], ['Brain.mean', 'biomarker', 'Brain', 'mean', 'percent'], ['Brain.SD', 'biomarker', 'Brain', 'variation', 'percent'], ['Skin.mean', 'biomarker', 'Skin', 'mean', 'percent'], ['Skin.SD', 'biomarker', 'Skin', 'variation', 'percent'], ['Muscle.mean', 'biomarker', 'Muscle', 'mean', 'percent'], ['Muscle.SD', 'biomarker', 'Muscle', 'variation', 'percent'], ['Adipose.mean', 'biomarker', 'Adipose', 'mean', 'percent'], ['Adipose.SD', 'biomarker', 'Adipose', 'variation', 'percent'], ['Bone.mean', 'biomarker', 'Bone', 'mean', 'percent'], ['Bone.SD', 'biomarker', 'Bone', 'variation', 'percent'], ['Stomach and Small Intestine.mean', 'biomarker', 'Stomach and Small Intestine', 'mean', 'percent'], ['Stomach and Small Intestine.SD', 'biomarker', 'Stomach and Small Intestine', 'variation', 'percent'], ['Cecum and Large Intestine.mean', 'biomarker', 'Cecum and Large Intestine', 'mean', 'percent'], ['Cecum and Large Intestine.SD', 'biomarker', 'Cecum and Large Intestine', 'variation', 'percent'], ['Pancreas.mean', 'biomarker', 'Pancreas', 'mean', 'percent'], ['Pancreas.SD', 'biomarker', 'Pancreas', 'variation', 'percent'], ['Placenta.mean', 'biomarker', 'Placenta', 'mean', 'percent'], ['Placenta.SD', 'biomarker', 'Placenta', 'variation', 'percent']]
# GROUP COLUMNS:
# [{'column': 'Tissue', 'label': 'group', 'units': [], 'link': None, 'name': None}]
# BIOMARKER COLUMNS:
# [{'column': 'Liver.mean', 'label': 'biomarker', 'type': 'mean', 'units': 'percent', 'name': 'Liver'}, {'column': 'Liver.SD', 'label': 'biomarker', 'type': 'variation', 'units': 'percent', 'name': 'Liver'}, {'column': 'Blood.mean', 'label': 'biomarker', 'type': 'mean', 'units': 'percent', 'name': 'Blood'}, {'column': 'Blood.SD', 'label': 'biomarker', 'type': 'variation', 'units': 'percent', 'name': 'Blood'}, {'column': 'Spleen.mean', 'label': 'biomarker', 'type': 'mean', 'units': 'percent', 'name': 'Spleen'}, {'column': 'Spleen.SD', 'label': 'biomarker', 'type': 'variation', 'units': 'percent', 'name': 'Spleen'}, {'column': 'Lungs.mean', 'label': 'biomarker', 'type': 'mean', 'units': 'percent', 'name': 'Lungs'}, {'column': 'Lungs.SD', 'label': 'biomarker', 'type': 'variation', 'units': 'percent', 'name': 'Lungs'}, {'column': 'Heart.mean', 'label': 'biomarker', 'type': 'mean', 'units': 'percent', 'name': 'Heart'}, {'column': 'Heart.SD', 'label': 'biomarker', 'type': 'variation', 'units': 'percent', 'name': 'Heart'}, {'column': 'Kidney.mean', 'label': 'biomarker', 'type': 'mean', 'units': 'percent', 'name': 'Kidney'}, {'column': 'Kidney.SD', 'label': 'biomarker', 'type': 'variation', 'units': 'percent', 'name': 'Kidney'}, {'column': 'Brain.mean', 'label': 'biomarker', 'type': 'mean', 'units': 'percent', 'name': 'Brain'}, {'column': 'Brain.SD', 'label': 'biomarker', 'type': 'variation', 'units': 'percent', 'name': 'Brain'}, {'column': 'Skin.mean', 'label': 'biomarker', 'type': 'mean', 'units': 'percent', 'name': 'Skin'}, {'column': 'Skin.SD', 'label': 'biomarker', 'type': 'variation', 'units': 'percent', 'name': 'Skin'}, {'column': 'Muscle.mean', 'label': 'biomarker', 'type': 'mean', 'units': 'percent', 'name': 'Muscle'}, {'column': 'Muscle.SD', 'label': 'biomarker', 'type': 'variation', 'units': 'percent', 'name': 'Muscle'}, {'column': 'Adipose.mean', 'label': 'biomarker', 'type': 'mean', 'units': 'percent', 'name': 'Adipose'}, {'column': 'Adipose.SD', 'label': 'biomarker', 'type': 'variation', 'units': 'percent', 'name': 'Adipose'}, {'column': 'Bone.mean', 'label': 'biomarker', 'type': 'mean', 'units': 'percent', 'name': 'Bone'}, {'column': 'Bone.SD', 'label': 'biomarker', 'type': 'variation', 'units': 'percent', 'name': 'Bone'}, {'column': 'Stomach and Small Intestine.mean', 'label': 'biomarker', 'type': 'mean', 'units': 'percent', 'name': 'Stomach and Small Intestine'}, {'column': 'Stomach and Small Intestine.SD', 'label': 'biomarker', 'type': 'variation', 'units': 'percent', 'name': 'Stomach and Small Intestine'}, {'column': 'Cecum and Large Intestine.mean', 'label': 'biomarker', 'type': 'mean', 'units': 'percent', 'name': 'Cecum and Large Intestine'}, {'column': 'Cecum and Large Intestine.SD', 'label': 'biomarker', 'type': 'variation', 'units': 'percent', 'name': 'Cecum and Large Intestine'}, {'column': 'Pancreas.mean', 'label': 'biomarker', 'type': 'mean', 'units': 'percent', 'name': 'Pancreas'}, {'column': 'Pancreas.SD', 'label': 'biomarker', 'type': 'variation', 'units': 'percent', 'name': 'Pancreas'}, {'column': 'Placenta.mean', 'label': 'biomarker', 'type': 'mean', 'units': 'percent', 'name': 'Placenta'}, {'column': 'Placenta.SD', 'label': 'biomarker', 'type': 'variation', 'units': 'percent', 'name': 'Placenta'}]
# [['Tissue', 'group'], ['Liver.mean', 'biomarker', 'Liver', 'mean', 'mug Ag/g'], ['Liver.SD', 'biomarker', 'Liver', 'variation', 'mug Ag/g'], ['Blood.mean', 'biomarker', 'Blood', 'mean', 'mug Ag/g'], ['Blood.SD', 'biomarker', 'Blood', 'variation', 'mug Ag/g'], ['Spleen.mean', 'biomarker', 'Spleen', 'mean', 'mug Ag/g'], ['Spleen.SD', 'biomarker', 'Spleen', 'variation', 'mug Ag/g'], ['Lungs.mean', 'biomarker', 'Lungs', 'mean', 'mug Ag/g'], ['Lungs.SD', 'biomarker', 'Lungs', 'variation', 'mug Ag/g'], ['Heart', 'biomarker', 'Heart', 'mean', 'mug Ag/g'], ['Kidney.mean', 'biomarker', 'Kidney', 'mean', 'mug Ag/g'], ['Kidney.SD', 'biomarker', 'Kidney', 'variation', 'mug Ag/g'], ['Brain', 'biomarker', 'Brain', 'mean', 'mug Ag/g'], ['Stomach and Small Intestine.mean', 'biomarker', 'Stomach and Small Intestine', 'mean', 'mug Ag/g'], ['Stomach and Small Intestine.SD', 'biomarker', 'Stomach and Small Intestine', 'variation', 'mug Ag/g'], ['Cecum and Large Intestine.mean', 'biomarker', 'Cecum and Large Intestine', 'mean', 'mug Ag/g'], ['Cecum and Large Intestine.SD', 'biomarker', 'Cecum and Large Intestine', 'variation', 'mug Ag/g'], ['Placenta.mean', 'biomarker', 'Placenta', 'mean', 'mug Ag/g'], ['Placenta.SD', 'biomarker', 'Placenta', 'variation', 'mug Ag/g']]
# GROUP COLUMNS:
# [{'column': 'Tissue', 'label': 'group', 'units': [], 'link': None, 'name': None}]
# BIOMARKER COLUMNS:
# [{'column': 'Liver.mean', 'label': 'biomarker', 'type': 'mean', 'units': 'mug Ag/g', 'name': 'Liver'}, {'column': 'Liver.SD', 'label': 'biomarker', 'type': 'variation', 'units': 'mug Ag/g', 'name': 'Liver'}, {'column': 'Blood.mean', 'label': 'biomarker', 'type': 'mean', 'units': 'mug Ag/g', 'name': 'Blood'}, {'column': 'Blood.SD', 'label': 'biomarker', 'type': 'variation', 'units': 'mug Ag/g', 'name': 'Blood'}, {'column': 'Spleen.mean', 'label': 'biomarker', 'type': 'mean', 'units': 'mug Ag/g', 'name': 'Spleen'}, {'column': 'Spleen.SD', 'label': 'biomarker', 'type': 'variation', 'units': 'mug Ag/g', 'name': 'Spleen'}, {'column': 'Lungs.mean', 'label': 'biomarker', 'type': 'mean', 'units': 'mug Ag/g', 'name': 'Lungs'}, {'column': 'Lungs.SD', 'label': 'biomarker', 'type': 'variation', 'units': 'mug Ag/g', 'name': 'Lungs'}, {'column': 'Heart', 'label': 'biomarker', 'type': 'mean', 'units': 'mug Ag/g', 'name': 'Heart'}, {'column': 'Kidney.mean', 'label': 'biomarker', 'type': 'mean', 'units': 'mug Ag/g', 'name': 'Kidney'}, {'column': 'Kidney.SD', 'label': 'biomarker', 'type': 'variation', 'units': 'mug Ag/g', 'name': 'Kidney'}, {'column': 'Brain', 'label': 'biomarker', 'type': 'mean', 'units': 'mug Ag/g', 'name': 'Brain'}, {'column': 'Stomach and Small Intestine.mean', 'label': 'biomarker', 'type': 'mean', 'units': 'mug Ag/g', 'name': 'Stomach and Small Intestine'}, {'column': 'Stomach and Small Intestine.SD', 'label': 'biomarker', 'type': 'variation', 'units': 'mug Ag/g', 'name': 'Stomach and Small Intestine'}, {'column': 'Cecum and Large Intestine.mean', 'label': 'biomarker', 'type': 'mean', 'units': 'mug Ag/g', 'name': 'Cecum and Large Intestine'}, {'column': 'Cecum and Large Intestine.SD', 'label': 'biomarker', 'type': 'variation', 'units': 'mug Ag/g', 'name': 'Cecum and Large Intestine'}, {'column': 'Placenta.mean', 'label': 'biomarker', 'type': 'mean', 'units': 'mug Ag/g', 'name': 'Placenta'}, {'column': 'Placenta.SD', 'label': 'biomarker', 'type': 'variation', 'units': 'mug Ag/g', 'name': 'Placenta'}]
# [['Liver.mean', 'biomarker', 'Liver', 'mean', 'percent'], ['Liver.SD', 'biomarker', 'Liver', 'variation', 'percent'], ['Blood.mean', 'biomarker', 'Blood', 'mean', 'percent'], ['Blood.SD', 'biomarker', 'Blood', 'variation', 'percent'], ['Spleen.mean', 'biomarker', 'Spleen', 'mean', 'percent'], ['Spleen.SD', 'biomarker', 'Spleen', 'variation', 'percent'], ['Lungs.mean', 'biomarker', 'Lungs', 'mean', 'percent'], ['Lungs.SD', 'biomarker', 'Lungs', 'variation', 'percent'], ['Kidney.mean', 'biomarker', 'Kidney', 'mean', 'percent'], ['Kidney.SD', 'biomarker', 'Kidney', 'variation', 'percent'], ['Stomach and Small Intestine.mean', 'biomarker', 'Stomach and Small Intestine', 'mean', 'percent'], ['Stomach and Small Intestine.SD', 'biomarker', 'Stomach and Small Intestine', 'variation', 'percent'], ['Cecum and Large Intestine.mean', 'biomarker', 'Cecum and Large Intestine', 'mean', 'percent'], ['Cecum and Large Intestine.SD', 'biomarker', 'Cecum and Large Intestine', 'variation', 'percent'], ['Placenta.mean', 'biomarker', 'Placenta', 'mean', 'percent'], ['Placenta.SD', 'biomarker', 'Placenta', 'variation', 'percent']]
# GROUP COLUMNS:
# []
# BIOMARKER COLUMNS:
# [{'column': 'Liver.mean', 'label': 'biomarker', 'type': 'mean', 'units': 'percent', 'name': 'Liver'}, {'column': 'Liver.SD', 'label': 'biomarker', 'type': 'variation', 'units': 'percent', 'name': 'Liver'}, {'column': 'Blood.mean', 'label': 'biomarker', 'type': 'mean', 'units': 'percent', 'name': 'Blood'}, {'column': 'Blood.SD', 'label': 'biomarker', 'type': 'variation', 'units': 'percent', 'name': 'Blood'}, {'column': 'Spleen.mean', 'label': 'biomarker', 'type': 'mean', 'units': 'percent', 'name': 'Spleen'}, {'column': 'Spleen.SD', 'label': 'biomarker', 'type': 'variation', 'units': 'percent', 'name': 'Spleen'}, {'column': 'Lungs.mean', 'label': 'biomarker', 'type': 'mean', 'units': 'percent', 'name': 'Lungs'}, {'column': 'Lungs.SD', 'label': 'biomarker', 'type': 'variation', 'units': 'percent', 'name': 'Lungs'}, {'column': 'Kidney.mean', 'label': 'biomarker', 'type': 'mean', 'units': 'percent', 'name': 'Kidney'}, {'column': 'Kidney.SD', 'label': 'biomarker', 'type': 'variation', 'units': 'percent', 'name': 'Kidney'}, {'column': 'Stomach and Small Intestine.mean', 'label': 'biomarker', 'type': 'mean', 'units': 'percent', 'name': 'Stomach and Small Intestine'}, {'column': 'Stomach and Small Intestine.SD', 'label': 'biomarker', 'type': 'variation', 'units': 'percent', 'name': 'Stomach and Small Intestine'}, {'column': 'Cecum and Large Intestine.mean', 'label': 'biomarker', 'type': 'mean', 'units': 'percent', 'name': 'Cecum and Large Intestine'}, {'column': 'Cecum and Large Intestine.SD', 'label': 'biomarker', 'type': 'variation', 'units': 'percent', 'name': 'Cecum and Large Intestine'}, {'column': 'Placenta.mean', 'label': 'biomarker', 'type': 'mean', 'units': 'percent', 'name': 'Placenta'}, {'column': 'Placenta.SD', 'label': 'biomarker', 'type': 'variation', 'units': 'percent', 'name': 'Placenta'}]
# [['Sample.Exposure duration.Route.mean', 'biomarker', 'PAI-1', 'mean', 'ng/ml'], ['Sample.Exposure duration.Route.SD', 'biomarker', 'PAI-1', 'variation', 'ng/ml'], ['Vehicle.24 h.i.v..mean', 'biomarker', 'PAI-1', 'mean', 'ng/ml'], ['Vehicle.24 h.i.v..SD', 'biomarker', 'PAI-1', 'variation', 'ng/ml'], ['Vehicle.48 h.1,632+-1073.mean', 'biomarker', 'PAI-1', 'mean', 'ng/ml'], ['Vehicle.48 h.1,632+-1073.SD', 'biomarker', 'PAI-1', 'variation', 'ng/ml'], ['AgAc.24 h.1,328+-437.mean', 'biomarker', 'PAI-1', 'mean', 'ng/ml'], ['AgAc.24 h.1,328+-437.SD', 'biomarker', 'PAI-1', 'variation', 'ng/ml'], ['AgAc.48 h.970+-266.mean', 'biomarker', 'PAI-1', 'mean', 'ng/ml'], ['AgAc.48 h.970+-266.SD', 'biomarker', 'PAI-1', 'variation', 'ng/ml'], ['20 nm AgNP.24 h.1,723+-482.mean', 'biomarker', 'PAI-1', 'mean', 'ng/ml'], ['20 nm AgNP.24 h.1,723+-482.SD', 'biomarker', 'PAI-1', 'variation', 'ng/ml'], ['20 nm AgNP.48 h.759', 'biomarker', 'PAI-1', 'mean', 'ng/ml'], ['110 nm AgNP.24 h.62.1+-87.9.mean', 'biomarker', 'PAI-1', 'mean', 'ng/ml'], ['110 nm AgNP.24 h.62.1+-87.9.SD', 'biomarker', 'PAI-1', 'variation', 'ng/ml'], ['110 nm AgNP.48 h.406+-72.9.mean', 'biomarker', 'PAI-1', 'mean', 'ng/ml'], ['110 nm AgNP.48 h.406+-72.9.SD', 'biomarker', 'PAI-1', 'variation', 'ng/ml'], ['Vehicle.24 h.p.o..mean', 'biomarker', 'PAI-1', 'mean', 'ng/ml'], ['Vehicle.24 h.p.o..SD', 'biomarker', 'PAI-1', 'variation', 'ng/ml'], ['Vehicle.48 h.406+-73.mean', 'biomarker', 'PAI-1', 'mean', 'ng/ml'], ['Vehicle.48 h.406+-73.SD', 'biomarker', 'PAI-1', 'variation', 'ng/ml'], ['AgAc.24 h.398+-53.3.mean', 'biomarker', 'PAI-1', 'mean', 'ng/ml'], ['AgAc.24 h.398+-53.3.SD', 'biomarker', 'PAI-1', 'variation', 'ng/ml'], ['AgAc.48 h.151+-95.6.mean', 'biomarker', 'PAI-1', 'mean', 'ng/ml'], ['AgAc.48 h.151+-95.6.SD', 'biomarker', 'PAI-1', 'variation', 'ng/ml'], ['110 nm AgNP.24 h.307+-56.2', 'biomarker', 'PAI-1', 'mean', 'ng/ml'], ['Sample.Exposure duration.Route.mean', 'biomarker', 'vWF', 'mean', 'ng/ml'], ['Sample.Exposure duration.Route.SD', 'biomarker', 'vWF', 'variation', 'ng/ml'], ['Vehicle.24 h.i.v..mean', 'biomarker', 'vWF', 'mean', 'ng/ml'], ['Vehicle.24 h.i.v..SD', 'biomarker', 'vWF', 'variation', 'ng/ml'], ['Vehicle.48 h.1,632+-1073.mean', 'biomarker', 'vWF', 'mean', 'ng/ml'], ['Vehicle.48 h.1,632+-1073.SD', 'biomarker', 'vWF', 'variation', 'ng/ml'], ['AgAc.24 h.1,328+-437.mean', 'biomarker', 'vWF', 'mean', 'ng/ml'], ['AgAc.24 h.1,328+-437.SD', 'biomarker', 'vWF', 'variation', 'ng/ml'], ['AgAc.48 h.970+-266.mean', 'biomarker', 'vWF', 'mean', 'ng/ml'], ['AgAc.48 h.970+-266.SD', 'biomarker', 'vWF', 'variation', 'ng/ml'], ['20 nm AgNP.24 h.1,723+-482.mean', 'biomarker', 'vWF', 'mean', 'ng/ml'], ['20 nm AgNP.24 h.1,723+-482.SD', 'biomarker', 'vWF', 'variation', 'ng/ml'], ['20 nm AgNP.48 h.759', 'biomarker', 'vWF', 'mean', 'ng/ml'], ['110 nm AgNP.24 h.62.1+-87.9.mean', 'biomarker', 'vWF', 'mean', 'ng/ml'], ['110 nm AgNP.24 h.62.1+-87.9.SD', 'biomarker', 'vWF', 'variation', 'ng/ml'], ['110 nm AgNP.48 h.406+-72.9.mean', 'biomarker', 'vWF', 'mean', 'ng/ml'], ['110 nm AgNP.48 h.406+-72.9.SD', 'biomarker', 'vWF', 'variation', 'ng/ml'], ['Vehicle.24 h.p.o..mean', 'biomarker', 'vWF', 'mean', 'ng/ml'], ['Vehicle.24 h.p.o..SD', 'biomarker', 'vWF', 'variation', 'ng/ml'], ['Vehicle.48 h.406+-73.mean', 'biomarker', 'vWF', 'mean', 'ng/ml'], ['Vehicle.48 h.406+-73.SD', 'biomarker', 'vWF', 'variation', 'ng/ml'], ['AgAc.24 h.398+-53.3.mean', 'biomarker', 'vWF', 'mean', 'ng/ml'], ['AgAc.24 h.398+-53.3.SD', 'biomarker', 'vWF', 'variation', 'ng/ml'], ['AgAc.48 h.151+-95.6.mean', 'biomarker', 'vWF', 'mean', 'ng/ml'], ['AgAc.48 h.151+-95.6.SD', 'biomarker', 'vWF', 'variation', 'ng/ml'], ['110 nm AgNP.24 h.307+-56.2', 'biomarker', 'vWF', 'mean', 'ng/ml']]
# GROUP COLUMNS:
# []
# BIOMARKER COLUMNS:
# [{'column': 'Sample.Exposure duration.Route.mean', 'label': 'biomarker', 'type': 'mean', 'units': 'ng/ml', 'name': 'PAI-1'}, {'column': 'Sample.Exposure duration.Route.SD', 'label': 'biomarker', 'type': 'variation', 'units': 'ng/ml', 'name': 'PAI-1'}, {'column': 'Vehicle.24 h.i.v..mean', 'label': 'biomarker', 'type': 'mean', 'units': 'ng/ml', 'name': 'PAI-1'}, {'column': 'Vehicle.24 h.i.v..SD', 'label': 'biomarker', 'type': 'variation', 'units': 'ng/ml', 'name': 'PAI-1'}, {'column': 'Vehicle.48 h.1,632+-1073.mean', 'label': 'biomarker', 'type': 'mean', 'units': 'ng/ml', 'name': 'PAI-1'}, {'column': 'Vehicle.48 h.1,632+-1073.SD', 'label': 'biomarker', 'type': 'variation', 'units': 'ng/ml', 'name': 'PAI-1'}, {'column': 'AgAc.24 h.1,328+-437.mean', 'label': 'biomarker', 'type': 'mean', 'units': 'ng/ml', 'name': 'PAI-1'}, {'column': 'AgAc.24 h.1,328+-437.SD', 'label': 'biomarker', 'type': 'variation', 'units': 'ng/ml', 'name': 'PAI-1'}, {'column': 'AgAc.48 h.970+-266.mean', 'label': 'biomarker', 'type': 'mean', 'units': 'ng/ml', 'name': 'PAI-1'}, {'column': 'AgAc.48 h.970+-266.SD', 'label': 'biomarker', 'type': 'variation', 'units': 'ng/ml', 'name': 'PAI-1'}, {'column': '20 nm AgNP.24 h.1,723+-482.mean', 'label': 'biomarker', 'type': 'mean', 'units': 'ng/ml', 'name': 'PAI-1'}, {'column': '20 nm AgNP.24 h.1,723+-482.SD', 'label': 'biomarker', 'type': 'variation', 'units': 'ng/ml', 'name': 'PAI-1'}, {'column': '20 nm AgNP.48 h.759', 'label': 'biomarker', 'type': 'mean', 'units': 'ng/ml', 'name': 'PAI-1'}, {'column': '110 nm AgNP.24 h.62.1+-87.9.mean', 'label': 'biomarker', 'type': 'mean', 'units': 'ng/ml', 'name': 'PAI-1'}, {'column': '110 nm AgNP.24 h.62.1+-87.9.SD', 'label': 'biomarker', 'type': 'variation', 'units': 'ng/ml', 'name': 'PAI-1'}, {'column': '110 nm AgNP.48 h.406+-72.9.mean', 'label': 'biomarker', 'type': 'mean', 'units': 'ng/ml', 'name': 'PAI-1'}, {'column': '110 nm AgNP.48 h.406+-72.9.SD', 'label': 'biomarker', 'type': 'variation', 'units': 'ng/ml', 'name': 'PAI-1'}, {'column': 'Vehicle.24 h.p.o..mean', 'label': 'biomarker', 'type': 'mean', 'units': 'ng/ml', 'name': 'PAI-1'}, {'column': 'Vehicle.24 h.p.o..SD', 'label': 'biomarker', 'type': 'variation', 'units': 'ng/ml', 'name': 'PAI-1'}, {'column': 'Vehicle.48 h.406+-73.mean', 'label': 'biomarker', 'type': 'mean', 'units': 'ng/ml', 'name': 'PAI-1'}, {'column': 'Vehicle.48 h.406+-73.SD', 'label': 'biomarker', 'type': 'variation', 'units': 'ng/ml', 'name': 'PAI-1'}, {'column': 'AgAc.24 h.398+-53.3.mean', 'label': 'biomarker', 'type': 'mean', 'units': 'ng/ml', 'name': 'PAI-1'}, {'column': 'AgAc.24 h.398+-53.3.SD', 'label': 'biomarker', 'type': 'variation', 'units': 'ng/ml', 'name': 'PAI-1'}, {'column': 'AgAc.48 h.151+-95.6.mean', 'label': 'biomarker', 'type': 'mean', 'units': 'ng/ml', 'name': 'PAI-1'}, {'column': 'AgAc.48 h.151+-95.6.SD', 'label': 'biomarker', 'type': 'variation', 'units': 'ng/ml', 'name': 'PAI-1'}, {'column': '110 nm AgNP.24 h.307+-56.2', 'label': 'biomarker', 'type': 'mean', 'units': 'ng/ml', 'name': 'PAI-1'}, {'column': 'Sample.Exposure duration.Route.mean', 'label': 'biomarker', 'type': 'mean', 'units': 'ng/ml', 'name': 'vWF'}, {'column': 'Sample.Exposure duration.Route.SD', 'label': 'biomarker', 'type': 'variation', 'units': 'ng/ml', 'name': 'vWF'}, {'column': 'Vehicle.24 h.i.v..mean', 'label': 'biomarker', 'type': 'mean', 'units': 'ng/ml', 'name': 'vWF'}, {'column': 'Vehicle.24 h.i.v..SD', 'label': 'biomarker', 'type': 'variation', 'units': 'ng/ml', 'name': 'vWF'}, {'column': 'Vehicle.48 h.1,632+-1073.mean', 'label': 'biomarker', 'type': 'mean', 'units': 'ng/ml', 'name': 'vWF'}, {'column': 'Vehicle.48 h.1,632+-1073.SD', 'label': 'biomarker', 'type': 'variation', 'units': 'ng/ml', 'name': 'vWF'}, {'column': 'AgAc.24 h.1,328+-437.mean', 'label': 'biomarker', 'type': 'mean', 'units': 'ng/ml', 'name': 'vWF'}, {'column': 'AgAc.24 h.1,328+-437.SD', 'label': 'biomarker', 'type': 'variation', 'units': 'ng/ml', 'name': 'vWF'}, {'column': 'AgAc.48 h.970+-2 ...
# [['Vehicle.24 h', 'biomarker', 'Vehicle.24 h', 'mean', 'pg/ml'], ['Vehicle.48 h.mean', 'biomarker', 'Vehicle.48 h', 'mean', 'pg/ml'], ['Vehicle.48 h.SD', 'biomarker', 'Vehicle.48 h', 'variation', 'pg/ml'], ['AgAc.24 h.mean', 'biomarker', 'AgAc.24 h', 'mean', 'pg/ml'], ['AgAc.24 h.SD', 'biomarker', 'AgAc.24 h', 'variation', 'pg/ml'], ['AgAc.48 h.mean', 'biomarker', 'AgAc.48 h', 'mean', 'pg/ml'], ['AgAc.48 h.SD', 'biomarker', 'AgAc.48 h', 'variation', 'pg/ml'], ['20 nm AgNP.24 h.mean', 'biomarker', '20 nm AgNP.24 h', 'mean', 'pg/ml'], ['20 nm AgNP.24 h.SD', 'biomarker', '20 nm AgNP.24 h', 'variation', 'pg/ml'], ['20 nm AgNP .48 h', 'biomarker', '20 nm AgNP .48 h', 'mean', 'pg/ml']]
# GROUP COLUMNS:
# []
# BIOMARKER COLUMNS:
# [{'column': 'Vehicle.24 h', 'label': 'biomarker', 'type': 'mean', 'units': 'pg/ml', 'name': 'Vehicle.24 h'}, {'column': 'Vehicle.48 h.mean', 'label': 'biomarker', 'type': 'mean', 'units': 'pg/ml', 'name': 'Vehicle.48 h'}, {'column': 'Vehicle.48 h.SD', 'label': 'biomarker', 'type': 'variation', 'units': 'pg/ml', 'name': 'Vehicle.48 h'}, {'column': 'AgAc.24 h.mean', 'label': 'biomarker', 'type': 'mean', 'units': 'pg/ml', 'name': 'AgAc.24 h'}, {'column': 'AgAc.24 h.SD', 'label': 'biomarker', 'type': 'variation', 'units': 'pg/ml', 'name': 'AgAc.24 h'}, {'column': 'AgAc.48 h.mean', 'label': 'biomarker', 'type': 'mean', 'units': 'pg/ml', 'name': 'AgAc.48 h'}, {'column': 'AgAc.48 h.SD', 'label': 'biomarker', 'type': 'variation', 'units': 'pg/ml', 'name': 'AgAc.48 h'}, {'column': '20 nm AgNP.24 h.mean', 'label': 'biomarker', 'type': 'mean', 'units': 'pg/ml', 'name': '20 nm AgNP.24 h'}, {'column': '20 nm AgNP.24 h.SD', 'label': 'biomarker', 'type': 'variation', 'units': 'pg/ml', 'name': '20 nm AgNP.24 h'}, {'column': '20 nm AgNP .48 h', 'label': 'biomarker', 'type': 'mean', 'units': 'pg/ml', 'name': '20 nm AgNP .48 h'}]

# %% [markdown]
# Deriving Groups via Tables

# %%
for tid, info in formatted_tables.items():
    if info["label"] != "b": continue
    table_groups = []
    group_names = []
    info["df"].reset_index(drop=True, inplace=True)
    for idx, row in info["df"].iterrows():
        group_row = {"group": None, "animal_model": None, "sample_size": None, "terminal_time": None,"treatment1": None, "dose1": None, "units1": None,"treatment2": None, "dose2": None, "units2": None}
        group_name = ""
        for label in info["group_cols"]:
            print(label)
            col_val = info["df"].loc[idx, label["column"]]
            if label["label"] == "group":
                group_name += f".{col_val}"
            elif label["label"] == "dose":
                if not group_row["dose1"]:
                    group_row["dose1"] = col_val
                    if label["name"]:
                        group_row["treatment1"] = label["name"]
                    elif label["link"]:
                        group_row["treatment1"] = info["df"].loc[idx, label["link"]]
                elif not group_row["dose2"]:
                    group_row["dose2"] = col_val
                    if label["name"]:
                        group_row["treatment2"] = label["name"]
                    elif label["link"]:
                        group_row["treatment2"] = info["df"].loc[idx, label["link"]]
                else:
                    print("ERROR: >2 treatments")
            elif label["label"] == "size":
                group_row["sample_size"] = col_val
            elif label["label"] == "animal":
                group_row["animal_model"] = col_val
            elif label["label"] == "time":
                group_row["terminal_time"] = col_val
        table_groups.append(group_row)
        group_name = group_name.lstrip(".") if group_name else f"Group {idx}"
        group_names.append(group_name.lower() if group_name else group_name)
        group_row["group"] = group_name
        print(group_names)
    info["df"].index = [name.lower().strip() for name in group_names]
    info["table_groups"] = pd.DataFrame(data=table_groups, index=group_names)
    print(tid)
    print(info["table_groups"])

# group_label = {"column": label[0], "label": label[1].strip().lower(), "type": None, "units": [], "link": None, "name": None}
# Out:
# ['group 0']
# ['group 0', 'group 1']
# ['group 0', 'group 1', 'group 2']
# ['group 0', 'group 1', 'group 2', 'group 3']
# ['group 0', 'group 1', 'group 2', 'group 3', 'group 4']
# ['group 0', 'group 1', 'group 2', 'group 3', 'group 4', 'group 5']
# T2
#            group animal_model sample_size terminal_time treatment1 dose1  \
# group 0  Group 0         None        None          None       None  None
# group 1  Group 1         None        None          None       None  None
# group 2  Group 2         None        None          None       None  None
# group 3  Group 3         None        None          None       None  None
# group 4  Group 4         None        None          None       None  None
# group 5  Group 5         None        None          None       None  None
#
#         units1 treatment2 dose2 units2
# group 0   None       None  None   None
# group 1   None       None  None   None
# group 2   None       None  None   None
# group 3   None       None  None   None
# group 4   None       None  None   None
# group 5   None       None  None   None
# {'column': 'Tissue', 'label': 'group', 'units': [], 'link': None, 'name': None}
# ['agac.24 h']
# {'column': 'Tissue', 'label': 'group', 'units': [], 'link': None, 'name': None}
# ['agac.24 h', 'agac.48 h']
# {'column': 'Tissue', 'label': 'group', 'units': [], 'link': None, 'name': None}
# ['agac.24 h', 'agac.48 h', '20 nm agnp.24 h']
# {'column': 'Tissue', 'label': 'group', 'units': [], 'link': None, 'name': None}
# ['agac.24 h', 'agac.48 h', '20 nm agnp.24 h', '20 nm agnp.48 h']
# {'column': 'Tissue', 'label': 'group', 'units': [], 'link': None, 'name': None}
# ['agac.24 h', 'agac.48 h', '20 nm agnp.24 h', '20 nm agnp.48 h', '110 nm agnp.24 h']
# {'column': 'Tissue', 'label': 'group', 'units': [], 'link': None, 'name': None}
# ['agac.24 h', 'agac.48 h', '20 nm agnp.24 h', '20 nm agnp.48 h', '110 nm agnp.24 h', '110 nm agnp .48 h']
# T3
#                                group animal_model sample_size terminal_time  \
# agac.24 h                  AgAc.24 h         None        None          None
# agac.48 h                  AgAc.48 h         None        None          None
# 20 nm agnp.24 h      20 nm AgNP.24 h         None        None          None
# 20 nm agnp.48 h      20 nm AgNP.48 h         None        None          None
# 110 nm agnp.24 h    110 nm AgNP.24 h         None        None          None
# 110 nm agnp .48 h  110 nm AgNP .48 h         None        None          None
#
#                   treatment1 dose1 units1 treatment2 dose2 units2
# agac.24 h               None  None   None       None  None   None
# agac.48 h               None  None   None       None  None   None
# 20 nm agnp.24 h         None  None   None       None  None   None
# 20 nm agnp.48 h         None  None   None       None  None   None
# 110 nm agnp.24 h        None  None   None       None  None   None
# 110 nm agnp .48 h       None  None   None       None  None   None
# {'column': 'Tissue', 'label': 'group', 'units': [], 'link': None, 'name': None}
# ['agac.24 h']
# {'column': 'Tissue', 'label': 'group', 'units': [], 'link': None, 'name': None}
# ['agac.24 h', 'agac.48 h']
# {'column': 'Tissue', 'label': 'group', 'units': [], 'link': None, 'name': None}
# ['agac.24 h', 'agac.48 h', '20 nm agnp.24 h']
# {'column': 'Tissue', 'label': 'group', 'units': [], 'link': None, 'name': None}
# ['agac.24 h', 'agac.48 h', '20 nm agnp.24 h', '20 nm agnp.48 h']
# {'column': 'Tissue', 'label': 'group', 'units': [], 'link': None, 'name': None}
# ['agac.24 h', 'agac.48 h', '20 nm agnp.24 h', '20 nm agnp.48 h', '110 nm agnp.24 h']
# {'column': 'Tissue', 'label': 'group', 'units': [], 'link': None, 'name': None}
# ['agac.24 h', 'agac.48 h', '20 nm agnp.24 h', '20 nm agnp.48 h', '110 nm agnp.24 h', '110 nm agnp .48 h']
# T5
#                                group animal_model sample_size terminal_time  \
# agac.24 h                  AgAc.24 h         None        None          None
# agac.48 h                  AgAc.48 h         None        None          None
# 20 nm agnp.24 h      20 nm AgNP.24 h         None        None          None
# 20 nm agnp.48 h      20 nm AgNP.48 h         None        None          None
# 110 nm agnp.24 h    110 nm AgNP.24 h         None        None          None
# 110 nm agnp .48 h  110 nm AgNP .48 h         None        None          None
#
#                   treatment1 dose1 units1 treatment2 dose2 units2
# agac.24 h               None  None   None       None  None   None
# agac.48 h               None  None   None       None  None   None
# 20 nm agnp.24 h         None  None   None       None  None   None
# 20 nm agnp.48 h         None  None   None       None  None   None
# 110 nm agnp.24 h        None  None   None       None  None   None
# 110 nm agnp .48 h       None  None   None       None  None   None
# ['group 0']
# ['group 0', 'group 1']
# ['group 0', 'group 1', 'group 2']
# ['group 0', 'group 1', 'group 2', 'group 3']
# ['group 0', 'group 1', 'group 2', 'group 3', 'group 4']
# ['group 0', 'group 1', 'group 2', 'group 3', 'group 4', 'group 5']
# T6
#            group animal_model sample_size terminal_time treatment1 dose1  \
# group 0  Group 0         None        None          None       None  None
# group 1  Group 1         None        None          None       None  None
# group 2  Group 2         None        None          None       None  None
# group 3  Group 3         None        None          None       None  None
# group 4  Group 4         None        None          None       None  None
# group 5  Group 5         None        None          None       None  None
#
#         units1 treatment2 dose2 units2
# group 0   None       None  None   None
# group 1   None       None  None   None
# group 2   None       None  None   None
# group 3   None       None  None   None
# group 4   None       None  None   None
# group 5   None       None  None   None
# ['group 0']
# ['group 0', 'group 1']
# T7
#            group animal_model sample_size terminal_time treatment1 dose1  \
# group 0  Group 0         None        None          None       None  None
# group 1  Group 1         None        None          None       None  None
#
#         units1 treatment2 dose2 units2
# group 0   None       None  None   None
# group 1   None       None  None   None
# ['group 0']
# ['group 0', 'group 1']
# ['group 0', 'group 1', 'group 2']
# ['group 0', 'group 1', 'group 2', 'group 3']
# ['group 0', 'group 1', 'group 2', 'group 3', 'group 4']
# ['group 0', 'group 1', 'group 2', 'group 3', 'group 4', 'group 5']
# ['group 0', 'group 1', 'group 2', 'group 3', 'group 4', 'group 5', 'group 6']
# ['group 0', 'group 1', 'group 2', 'group 3', 'group 4', 'group 5', 'group 6', 'group 7']
# T8
#            group animal_model sample_size terminal_time treatment1 dose1  \
# group 0  Group 0         None        None          None       None  None
# group 1  Group 1         None        None          None       None  None
# group 2  Group 2         None        None          None       None  None
# group 3  Group 3         None        None          None       None  None
# group 4  Group 4         None        None          None       None  None
# group 5  Group 5         None        None          None       None  None
# group 6  Group 6         None        None          None       None  None
# group 7  Group 7         None        None          None       None  None
#
#         units1 treatment2 dose2 units2
# group 0   None       None  None   None
# group 1   None       None  None   None
# group 2   None       None  None   None
# group 3   None       None  None   None
# group 4   None       None  None   None
# group 5   None       None  None   None
# group 6   None       None  None   None
# group 7   None       None  None   None

# %% [markdown]
# Deriving Groups form Text via LLM

# %%
text_groups = []
group_names = []
for row in utils.groups_from_text(PMC, abstract, methods, results):
    if len(row) not in [4, 7, 10] and len(row) < 10:
        print("ERROR: Invalid text_groups label")
        continue
    text_group = {}
    text_group["group"] = row[0]
    text_group["animal_model"] = row[1] if row[1] else None
    text_group["sample_size"] = row[2] if row[2] else None
    text_group["terminal_time"] = row[3] if row[3] else None
    if len(row) == 4:
        text_group["treatment1"] = None
        text_group["dose1"] = None
        text_group["units1"] = None
        text_group["treatment2"] = None
        text_group["dose2"] = None
        text_group["units2"] = None
    elif len(row) == 7:
        text_group["treatment1"] = row[4]
        text_group["dose1"] = row[5]
        text_group["units1"] = row[6]
        text_group["treatment2"] = None
        text_group["dose2"] = None
        text_group["units2"] = None
    else:
        text_group["treatment1"] = row[4]
        text_group["dose1"] = row[5]
        text_group["units1"] = row[6]
        text_group["treatment2"] = row[7]
        text_group["dose2"] = row[8]
        text_group["units2"] = row[9]
    text_groups.append(text_group)
    group_names.append(row[0].strip().lower())
text_groups_df = pd.DataFrame(data=text_groups, index=group_names)
# Out:
# ChatGPT Request Status: 200
# <control_iv|rat|6|24 hours||||||>
# <control_iv|rat|6|48 hours||||||>
# <control_po|rat|6|24 hours||||||>
# <control_po|rat|6|48 hours||||||>
# <AgAc_iv|rat|6|24 hours|silver acetate|1|mg/kg|||>
# <AgAc_iv|rat|6|48 hours|silver acetate|1|mg/kg|||>
# <AgAc_po|rat|6|24 hours|silver acetate|10|mg/kg|||>
# <AgAc_po|rat|6|48 hours|silver acetate|10|mg/kg|||>
# <AgNP20_iv|rat|6|24 hours|silver nanoparticles (20 nm)|1|mg/kg|||>
# <AgNP20_iv|rat|6|48 hours|silver nanoparticles (20 nm)|1|mg/kg|||>
# <AgNP20_po|rat|6|24 hours|silver nanoparticles (20 nm)|10|mg/kg|||>
# <AgNP20_po|rat|6|48 hours|silver nanoparticles (20 nm)|10|mg/kg|||>
# <AgNP110_iv|rat|6|24 hours|silver nanoparticles (110 nm)|1|mg/kg|||>
# <AgNP110_iv|rat|6|48 hours|silver nanoparticles (110 nm)|1|mg/kg|||>
# <AgNP110_po|rat|6|24 hours|silver nanoparticles (110 nm)|10|mg/kg|||>
# <AgNP110_po|rat|6|48 hours|silver nanoparticles (110 nm)|10|mg/kg|||>
# [['control_iv', 'rat', '6', '24 hours', '', '', '', '', '', ''], ['control_iv', 'rat', '6', '48 hours', '', '', '', '', '', ''], ['control_po', 'rat', '6', '24 hours', '', '', '', '', '', ''], ['control_po', 'rat', '6', '48 hours', '', '', '', '', '', ''], ['AgAc_iv', 'rat', '6', '24 hours', 'silver acetate', '1', 'mg/kg', '', '', ''], ['AgAc_iv', 'rat', '6', '48 hours', 'silver acetate', '1', 'mg/kg', '', '', ''], ['AgAc_po', 'rat', '6', '24 hours', 'silver acetate', '10', 'mg/kg', '', '', ''], ['AgAc_po', 'rat', '6', '48 hours', 'silver acetate', '10', 'mg/kg', '', '', ''], ['AgNP20_iv', 'rat', '6', '24 hours', 'silver nanoparticles (20 nm)', '1', 'mg/kg', '', '', ''], ['AgNP20_iv', 'rat', '6', '48 hours', 'silver nanoparticles (20 nm)', '1', 'mg/kg', '', '', ''], ['AgNP20_po', 'rat', '6', '24 hours', 'silver nanoparticles (20 nm)', '10', 'mg/kg', '', '', ''], ['AgNP20_po', 'rat', '6', '48 hours', 'silver nanoparticles (20 nm)', '10', 'mg/kg', '', '', ''], ['AgNP110_iv', 'rat', '6', '24 hours', 'silver nanoparticles (110 nm)', '1', 'mg/kg', '', '', ''], ['AgNP110_iv', 'rat', '6', '48 hours', 'silver nanoparticles (110 nm)', '1', 'mg/kg', '', '', ''], ['AgNP110_po', 'rat', '6', '24 hours', 'silver nanoparticles (110 nm)', '10', 'mg/kg', '', '', ''], ['AgNP110_po', 'rat', '6', '48 hours', 'silver nanoparticles (110 nm)', '10', 'mg/kg', '', '', '']]

# %% [markdown]
# Linking table and text treatment groups

# %%
for tid, info in formatted_tables.items():
    if info["label"] != "b": continue
    utils.link_groups(PMC, tid, methods, info["table_groups"], text_groups_df)
    print(table_utils.dataframe_to_markdown(info["table_groups"]))
# Out:
# ChatGPT Request Status: 200
# | group | animal_model | sample_size | terminal_time | treatment1 | dose1 | units1 | treatment2 | dose2 | units2 |
# | --- | --- | --- | --- | --- | --- | --- | --- | --- | --- |
# | Group 0 | control_iv    rat
# control_iv    rat
# Name: animal_model, dtype: object | control_iv    6
# control_iv    6
# Name: sample_size, dtype: object | control_iv    24 hours
# control_iv    48 hours
# Name: terminal_time, dtype: object | control_iv
# control_iv
# Name: treatment1, dtype: object | control_iv
# control_iv
# Name: dose1, dtype: object | control_iv
# control_iv
# Name: units1, dtype: object | control_iv
# control_iv
# Name: treatment2, dtype: object | control_iv
# control_iv
# Name: dose2, dtype: object | control_iv
# control_iv
# Name: units2, dtype: object |
# | Group 1 | control_po    rat
# control_po    rat
# Name: animal_model, dtype: object | control_po    6
# control_po    6
# Name: sample_size, dtype: object | control_po    24 hours
# control_po    48 hours
# Name: terminal_time, dtype: object | control_po
# control_po
# Name: treatment1, dtype: object | control_po
# control_po
# Name: dose1, dtype: object | control_po
# control_po
# Name: units1, dtype: object | control_po
# control_po
# Name: treatment2, dtype: object | control_po
# control_po
# Name: dose2, dtype: object | control_po
# control_po
# Name: units2, dtype: object |
# | Group 2 | agac_iv    rat
# agac_iv    rat
# Name: animal_model, dtype: object | agac_iv    6
# agac_iv    6
# Name: sample_size, dtype: object | agac_iv    24 hours
# agac_iv    48 hours
# Name: terminal_time, dtype: object | agac_iv    silver acetate
# agac_iv    silver acetate
# Name: treatment1, dtype: object | agac_iv    1
# agac_iv    1
# Name: dose1, dtype: object | agac_iv    mg/kg
# agac_iv    mg/kg
# Name: units1, dtype: object | agac_iv
# agac_iv
# Name: treatment2, dtype: object | agac_iv
# agac_iv
# Name: dose2, dtype: object | agac_iv
# agac_iv
# Name: units2, dtype: object |
# | Group 3 | agac_po    rat
# agac_po    rat
# Name: animal_model, dtype: object | agac_po    6
# agac_po    6
# Name: sample_size, dtype: object | agac_po    24 hours
# agac_po    48 hours
# Name: terminal_time, dtype: object | agac_po    silver acetate
# agac_po    silver acetate
# Name: treatment1, dtype: object | agac_po    10
# agac_po    10
# Name: dose1, dtype: object | agac_po    mg/kg
# agac_po    mg/kg
# Name: units1, dtype: object | agac_po
# agac_po
# Name: treatment2, dtype: object | agac_po
# agac_po
# Name: dose2, dtype: object | agac_po
# agac_po
# Name: units2, dtype: object |
# | Group 4 | agnp20_iv    rat
# agnp20_iv    rat
# Name: animal_model, dtype: object | agnp20_iv    6
# agnp20_iv    6
# Name: sample_size, dtype: object | agnp20_iv    24 hours
# agnp20_iv    48 hours
# Name: terminal_time, dtype: object | agnp20_iv    silver nanoparticles (20 nm)
# agnp20_iv    silver nanoparticles (20 nm)
# Name: treatment1, dtype: object | agnp20_iv    1
# agnp20_iv    1
# Name: dose1, dtype: object | agnp20_iv    mg/kg
# agnp20_iv    mg/kg
# Name: units1, dtype: object | agnp20_iv
# agnp20_iv
# Name: treatment2, dtype: object | agnp20_iv
# agnp20_iv
# Name: dose2, dtype: object | agnp20_iv
# agnp20_iv
# Name: units2, dtype: object |
# | Group 5 | agnp20_po    rat
# agnp20_po    rat
# Name: animal_model, dtype: object | agnp20_po    6
# agnp20_po    6
# Name: sample_size, dtype: object | agnp20_po    24 hours
# agnp20_po    48 hours
# Name: terminal_time, dtype: object | agnp20_po    silver nanoparticles (20 nm)
# agnp20_po    silver nanoparticles (20 nm)
# Name: treatment1, dtype: object | agnp20_po    10
# agnp20_po    10
# Name: dose1, dtype: object | agnp20_po    mg/kg
# agnp20_po    mg/kg
# Name: units1, dtype: object | agnp20_po
# agnp20_po
# Name: treatment2, dtype: object | agnp20_po
# agnp20_po
# Name: dose2, dtype: object | agnp20_po
# agnp20_po
# Name: units2, dtype: object |
# ChatGPT Request Status: 200
# | group | animal_model | sample_size | terminal_time | treatment1 | dose1 | units1 | treatment2 | dose2 | units2 |
# | --- | --- | --- | --- | --- | --- | --- | --- | --- | --- |
# | AgAc.24 h | agac_iv    rat
# agac_iv    rat
# Name: animal_model, dtype: object | agac_iv    6
# agac_iv    6
# Name: sample_size, dtype: object | agac_iv    24 hours
# agac_iv    48 hours
# Name: terminal_time, dtype: object | agac_iv    silver acetate
# agac_iv    silver acetate
# Name: treatment1, dtype: object | agac_iv    1
# agac_iv    1
# Name: dose1, dtype: object | agac_iv    mg/kg
# agac_iv    mg/kg
# Name: units1, dtype: object | agac_iv
# agac_iv
# Name: treatment2, dtype: object | agac_iv
# agac_iv
# Name: dose2, dtype: object | agac_iv
# agac_iv
# Name: units2, dtype: object |
# | AgAc.48 h | agac_iv    rat
# agac_iv    rat
# Name: animal_model, dtype: object | agac_iv    6
# agac_iv    6
# Name: sample_size, dtype: object | agac_iv    24 hours
# agac_iv    48 hours
# Name: terminal_time, dtype: object | agac_iv    silver acetate
# agac_iv    silver acetate
# Name: treatment1, dtype: object | agac_iv    1
# agac_iv    1
# Name: dose1, dtype: object | agac_iv    mg/kg
# agac_iv    mg/kg
# Name: units1, dtype: object | agac_iv
# agac_iv
# Name: treatment2, dtype: object | agac_iv
# agac_iv
# Name: dose2, dtype: object | agac_iv
# agac_iv
# Name: units2, dtype: object |
# | 20 nm AgNP.24 h | agnp20_iv    rat
# agnp20_iv    rat
# Name: animal_model, dtype: object | agnp20_iv    6
# agnp20_iv    6
# Name: sample_size, dtype: object | agnp20_iv    24 hours
# agnp20_iv    48 hours
# Name: terminal_time, dtype: object | agnp20_iv    silver nanoparticles (20 nm)
# agnp20_iv    silver nanoparticles (20 nm)
# Name: treatment1, dtype: object | agnp20_iv    1
# agnp20_iv    1
# Name: dose1, dtype: object | agnp20_iv    mg/kg
# agnp20_iv    mg/kg
# Name: units1, dtype: object | agnp20_iv
# agnp20_iv
# Name: treatment2, dtype: object | agnp20_iv
# agnp20_iv
# Name: dose2, dtype: object | agnp20_iv
# agnp20_iv
# Name: units2, dtype: object |
# | 20 nm AgNP.48 h | agnp20_iv    rat
# agnp20_iv    rat
# Name: animal_model, dtype: object | agnp20_iv    6
# agnp20_iv    6
# Name: sample_size, dtype: object | agnp20_iv    24 hours
# agnp20_iv    48 hours
# Name: terminal_time, dtype: object | agnp20_iv    silver nanoparticles (20 nm)
# agnp20_iv    silver nanoparticles (20 nm)
# Name: treatment1, dtype: object | agnp20_iv    1
# agnp20_iv    1
# Name: dose1, dtype: object | agnp20_iv    mg/kg
# agnp20_iv    mg/kg
# Name: units1, dtype: object | agnp20_iv
# agnp20_iv
# Name: treatment2, dtype: object | agnp20_iv
# agnp20_iv
# Name: dose2, dtype: object | agnp20_iv
# agnp20_iv
# Name: units2, dtype: object |
# | 110 nm AgNP.24 h | agnp110_iv    rat
# agnp110_iv    rat
# Name: animal_model, dtype: object | agnp110_iv    6
# agnp110_iv    6
# Name: sample_size, dtype: object | agnp110_iv    24 hours
# agnp110_iv    48 hours
# Name: terminal_time, dtype: object | agnp110_iv    silver nanoparticles (110 nm)
# agnp110_iv    silver nanoparticles (110 nm)
# Name: treatment1, dtype: object | agnp110_iv    1
# agnp110_iv    1
# Name: dose1, dtype: object | agnp110_iv    mg/kg
# agnp110_iv    mg/kg
# Name: units1, dtype: object | agnp110_iv
# agnp110_iv
# Name: treatment2, dtype: object | agnp110_iv
# agnp110_iv
# Name: dose2, dtype: object | agnp110_iv
# agnp110_iv
# Name: units2, dtype: object |
# | 110 nm AgNP .48 h | agnp110_iv    rat
# agnp110_iv    rat
# Name: animal_model, dtype: object | agnp110_iv    6
# agnp110_iv    6
# Name: sample_size, dtype: object | agnp110_iv    24 hours
# agnp110_iv    48 hours
# Name: terminal_time, dtype: object | agnp110_iv    silver nanoparticles (110 nm)
# agnp110_iv    silver nanoparticles (110 nm)
# Name: treatment1, dtype: object | agnp110_iv    1
# agnp110_iv    1
# Name: dose1, dtype: object | agnp110_iv    mg/kg
# agnp110_iv    mg/kg
# Name: units1, dtype: object | agnp110_iv
# agnp110_iv
# Name: treatment2, dtype: object | agnp110_iv
# agnp110_iv
# Name: dose2, dtype: object | agnp110_iv
# agnp110_iv
# Name: units2, dtype: object |
# ChatGPT Request Status: 200
# | group | animal_model | sample_size | terminal_time | treatment1 | dose1 | units1 | treatment2 | dose2 | units2 |
# | --- | --- | --- | --- | --- | --- | --- | --- | --- | --- |
# | AgAc.24 h | agac_iv    rat
# agac_iv    rat
# Name: animal_model, dtype: object | agac_iv    6
# agac_iv    6
# Name: sample_size, dtype: object | agac_iv    24 hours
# agac_iv    48 hours
# Name: terminal_time, dtype: object | agac_iv    silver acetate
# agac_iv    silver acetate
# Name: treatment1, dtype: object | agac_iv    1
# agac_iv    1
# Name: dose1, dtype: object | agac_iv    mg/kg
# agac_iv    mg/kg
# Name: units1, dtype: object | agac_iv
# agac_iv
# Name: treatment2, dtype: object | agac_iv
# agac_iv
# Name: dose2, dtype: object | agac_iv
# agac_iv
# Name: units2, dtype: object |
# | AgAc.48 h | agac_iv    rat
# agac_iv    rat
# Name: animal_model, dtype: object | agac_iv    6
# agac_iv    6
# Name: sample_size, dtype: object | agac_iv    24 hours
# agac_iv    48 hours
# Name: terminal_time, dtype: object | agac_iv    silver acetate
# agac_iv    silver acetate
# Name: treatment1, dtype: object | agac_iv    1
# agac_iv    1
# Name: dose1, dtype: object | agac_iv    mg/kg
# agac_iv    mg/kg
# Name: units1, dtype: object | agac_iv
# agac_iv
# Name: treatment2, dtype: object | agac_iv
# agac_iv
# Name: dose2, dtype: object | agac_iv
# agac_iv
# Name: units2, dtype: object |
# | 20 nm AgNP.24 h | agnp20_iv    rat
# agnp20_iv    rat
# Name: animal_model, dtype: object | agnp20_iv    6
# agnp20_iv    6
# Name: sample_size, dtype: object | agnp20_iv    24 hours
# agnp20_iv    48 hours
# Name: terminal_time, dtype: object | agnp20_iv    silver nanoparticles (20 nm)
# agnp20_iv    silver nanoparticles (20 nm)
# Name: treatment1, dtype: object | agnp20_iv    1
# agnp20_iv    1
# Name: dose1, dtype: object | agnp20_iv    mg/kg
# agnp20_iv    mg/kg
# Name: units1, dtype: object | agnp20_iv
# agnp20_iv
# Name: treatment2, dtype: object | agnp20_iv
# agnp20_iv
# Name: dose2, dtype: object | agnp20_iv
# agnp20_iv
# Name: units2, dtype: object |
# | 20 nm AgNP.48 h | agnp20_iv    rat
# agnp20_iv    rat
# Name: animal_model, dtype: object | agnp20_iv    6
# agnp20_iv    6
# Name: sample_size, dtype: object | agnp20_iv    24 hours
# agnp20_iv    48 hours
# Name: terminal_time, dtype: object | agnp20_iv    silver nanoparticles (20 nm)
# agnp20_iv    silver nanoparticles (20 nm)
# Name: treatment1, dtype: object | agnp20_iv    1
# agnp20_iv    1
# Name: dose1, dtype: object | agnp20_iv    mg/kg
# agnp20_iv    mg/kg
# Name: units1, dtype: object | agnp20_iv
# agnp20_iv
# Name: treatment2, dtype: object | agnp20_iv
# agnp20_iv
# Name: dose2, dtype: object | agnp20_iv
# agnp20_iv
# Name: units2, dtype: object |
# | 110 nm AgNP.24 h | agnp110_iv    rat
# agnp110_iv    rat
# Name: animal_model, dtype: object | agnp110_iv    6
# agnp110_iv    6
# Name: sample_size, dtype: object | agnp110_iv    24 hours
# agnp110_iv    48 hours
# Name: terminal_time, dtype: object | agnp110_iv    silver nanoparticles (110 nm)
# agnp110_iv    silver nanoparticles (110 nm)
# Name: treatment1, dtype: object | agnp110_iv    1
# agnp110_iv    1
# Name: dose1, dtype: object | agnp110_iv    mg/kg
# agnp110_iv    mg/kg
# Name: units1, dtype: object | agnp110_iv
# agnp110_iv
# Name: treatment2, dtype: object | agnp110_iv
# agnp110_iv
# Name: dose2, dtype: object | agnp110_iv
# agnp110_iv
# Name: units2, dtype: object |
# | 110 nm AgNP .48 h | agnp110_iv    rat
# agnp110_iv    rat
# Name: animal_model, dtype: object | agnp110_iv    6
# agnp110_iv    6
# Name: sample_size, dtype: object | agnp110_iv    24 hours
# agnp110_iv    48 hours
# Name: terminal_time, dtype: object | agnp110_iv    silver nanoparticles (110 nm)
# agnp110_iv    silver nanoparticles (110 nm)
# Name: treatment1, dtype: object | agnp110_iv    1
# agnp110_iv    1
# Name: dose1, dtype: object | agnp110_iv    mg/kg
# agnp110_iv    mg/kg
# Name: units1, dtype: object | agnp110_iv
# agnp110_iv
# Name: treatment2, dtype: object | agnp110_iv
# agnp110_iv
# Name: dose2, dtype: object | agnp110_iv
# agnp110_iv
# Name: units2, dtype: object |
# ChatGPT Request Status: 200
# | group | animal_model | sample_size | terminal_time | treatment1 | dose1 | units1 | treatment2 | dose2 | units2 |
# | --- | --- | --- | --- | --- | --- | --- | --- | --- | --- |
# | Group 0 | control_iv    rat
# control_iv    rat
# Name: animal_model, dtype: object | control_iv    6
# control_iv    6
# Name: sample_size, dtype: object | control_iv    24 hours
# control_iv    48 hours
# Name: terminal_time, dtype: object | control_iv
# control_iv
# Name: treatment1, dtype: object | control_iv
# control_iv
# Name: dose1, dtype: object | control_iv
# control_iv
# Name: units1, dtype: object | control_iv
# control_iv
# Name: treatment2, dtype: object | control_iv
# control_iv
# Name: dose2, dtype: object | control_iv
# control_iv
# Name: units2, dtype: object |
# | Group 1 | control_po    rat
# control_po    rat
# Name: animal_model, dtype: object | control_po    6
# control_po    6
# Name: sample_size, dtype: object | control_po    24 hours
# control_po    48 hours
# Name: terminal_time, dtype: object | control_po
# control_po
# Name: treatment1, dtype: object | control_po
# control_po
# Name: dose1, dtype: object | control_po
# control_po
# Name: units1, dtype: object | control_po
# control_po
# Name: treatment2, dtype: object | control_po
# control_po
# Name: dose2, dtype: object | control_po
# control_po
# Name: units2, dtype: object |
# | Group 2 | agac_iv    rat
# agac_iv    rat
# Name: animal_model, dtype: object | agac_iv    6
# agac_iv    6
# Name: sample_size, dtype: object | agac_iv    24 hours
# agac_iv    48 hours
# Name: terminal_time, dtype: object | agac_iv    silver acetate
# agac_iv    silver acetate
# Name: treatment1, dtype: object | agac_iv    1
# agac_iv    1
# Name: dose1, dtype: object | agac_iv    mg/kg
# agac_iv    mg/kg
# Name: units1, dtype: object | agac_iv
# agac_iv
# Name: treatment2, dtype: object | agac_iv
# agac_iv
# Name: dose2, dtype: object | agac_iv
# agac_iv
# Name: units2, dtype: object |
# | Group 3 | agac_po    rat
# agac_po    rat
# Name: animal_model, dtype: object | agac_po    6
# agac_po    6
# Name: sample_size, dtype: object | agac_po    24 hours
# agac_po    48 hours
# Name: terminal_time, dtype: object | agac_po    silver acetate
# agac_po    silver acetate
# Name: treatment1, dtype: object | agac_po    10
# agac_po    10
# Name: dose1, dtype: object | agac_po    mg/kg
# agac_po    mg/kg
# Name: units1, dtype: object | agac_po
# agac_po
# Name: treatment2, dtype: object | agac_po
# agac_po
# Name: dose2, dtype: object | agac_po
# agac_po
# Name: units2, dtype: object |
# | Group 4 | agnp20_iv    rat
# agnp20_iv    rat
# Name: animal_model, dtype: object | agnp20_iv    6
# agnp20_iv    6
# Name: sample_size, dtype: object | agnp20_iv    24 hours
# agnp20_iv    48 hours
# Name: terminal_time, dtype: object | agnp20_iv    silver nanoparticles (20 nm)
# agnp20_iv    silver nanoparticles (20 nm)
# Name: treatment1, dtype: object | agnp20_iv    1
# agnp20_iv    1
# Name: dose1, dtype: object | agnp20_iv    mg/kg
# agnp20_iv    mg/kg
# Name: units1, dtype: object | agnp20_iv
# agnp20_iv
# Name: treatment2, dtype: object | agnp20_iv
# agnp20_iv
# Name: dose2, dtype: object | agnp20_iv
# agnp20_iv
# Name: units2, dtype: object |
# | Group 5 | agnp20_po    rat
# agnp20_po    rat
# Name: animal_model, dtype: object | agnp20_po    6
# agnp20_po    6
# Name: sample_size, dtype: object | agnp20_po    24 hours
# agnp20_po    48 hours
# Name: terminal_time, dtype: object | agnp20_po    silver nanoparticles (20 nm)
# agnp20_po    silver nanoparticles (20 nm)
# Name: treatment1, dtype: object | agnp20_po    10
# agnp20_po    10
# Name: dose1, dtype: object | agnp20_po    mg/kg
# agnp20_po    mg/kg
# Name: units1, dtype: object | agnp20_po
# agnp20_po
# Name: treatment2, dtype: object | agnp20_po
# agnp20_po
# Name: dose2, dtype: object | agnp20_po
# agnp20_po
# Name: units2, dtype: object |
# ChatGPT Request Status: 200
# | group | animal_model | sample_size | terminal_time | treatment1 | dose1 | units1 | treatment2 | dose2 | units2 |
# | --- | --- | --- | --- | --- | --- | --- | --- | --- | --- |
# | Group 0 | None | None | None | None | None | None | None | None | None |
# | Group 1 | None | None | None | None | None | None | None | None | None |
# ChatGPT Request Status: 200
# | group | animal_model | sample_size | terminal_time | treatment1 | dose1 | units1 | treatment2 | dose2 | units2 |
# | --- | --- | --- | --- | --- | --- | --- | --- | --- | --- |
# | Group 0 | control_iv    rat
# control_iv    rat
# Name: animal_model, dtype: object | control_iv    6
# control_iv    6
# Name: sample_size, dtype: object | control_iv    24 hours
# control_iv    48 hours
# Name: terminal_time, dtype: object | control_iv
# control_iv
# Name: treatment1, dtype: object | control_iv
# control_iv
# Name: dose1, dtype: object | control_iv
# control_iv
# Name: units1, dtype: object | control_iv
# control_iv
# Name: treatment2, dtype: object | control_iv
# control_iv
# Name: dose2, dtype: object | control_iv
# control_iv
# Name: units2, dtype: object |
# | Group 1 | control_po    rat
# control_po    rat
# Name: animal_model, dtype: object | control_po    6
# control_po    6
# Name: sample_size, dtype: object | control_po    24 hours
# control_po    48 hours
# Name: terminal_time, dtype: object | control_po
# control_po
# Name: treatment1, dtype: object | control_po
# control_po
# Name: dose1, dtype: object | control_po
# control_po
# Name: units1, dtype: object | control_po
# control_po
# Name: treatment2, dtype: object | control_po
# control_po
# Name: dose2, dtype: object | control_po
# control_po
# Name: units2, dtype: object |
# | Group 2 | agac_iv    rat
# agac_iv    rat
# Name: animal_model, dtype: object | agac_iv    6
# agac_iv    6
# Name: sample_size, dtype: object | agac_iv    24 hours
# agac_iv    48 hours
# Name: terminal_time, dtype: object | agac_iv    silver acetate
# agac_iv    silver acetate
# Name: treatment1, dtype: object | agac_iv    1
# agac_iv    1
# Name: dose1, dtype: object | agac_iv    mg/kg
# agac_iv    mg/kg
# Name: units1, dtype: object | agac_iv
# agac_iv
# Name: treatment2, dtype: object | agac_iv
# agac_iv
# Name: dose2, dtype: object | agac_iv
# agac_iv
# Name: units2, dtype: object |
# | Group 3 | agac_po    rat
# agac_po    rat
# Name: animal_model, dtype: object | agac_po    6
# agac_po    6
# Name: sample_size, dtype: object | agac_po    24 hours
# agac_po    48 hours
# Name: terminal_time, dtype: object | agac_po    silver acetate
# agac_po    silver acetate
# Name: treatment1, dtype: object | agac_po    10
# agac_po    10
# Name: dose1, dtype: object | agac_po    mg/kg
# agac_po    mg/kg
# Name: units1, dtype: object | agac_po
# agac_po
# Name: treatment2, dtype: object | agac_po
# agac_po
# Name: dose2, dtype: object | agac_po
# agac_po
# Name: units2, dtype: object |
# | Group 4 | agnp20_iv    rat
# agnp20_iv    rat
# Name: animal_model, dtype: object | agnp20_iv    6
# agnp20_iv    6
# Name: sample_size, dtype: object | agnp20_iv    24 hours
# agnp20_iv    48 hours
# Name: terminal_time, dtype: object | agnp20_iv    silver nanoparticles (20 nm)
# agnp20_iv    silver nanoparticles (20 nm)
# Name: treatment1, dtype: object | agnp20_iv    1
# agnp20_iv    1
# Name: dose1, dtype: object | agnp20_iv    mg/kg
# agnp20_iv    mg/kg
# Name: units1, dtype: object | agnp20_iv
# agnp20_iv
# Name: treatment2, dtype: object | agnp20_iv
# agnp20_iv
# Name: dose2, dtype: object | agnp20_iv
# agnp20_iv
# Name: units2, dtype: object |
# | Group 5 | agnp20_po    rat
# agnp20_po    rat
# Name: animal_model, dtype: object | agnp20_po    6
# agnp20_po    6
# Name: sample_size, dtype: object | agnp20_po    24 hours
# agnp20_po    48 hours
# Name: terminal_time, dtype: object | agnp20_po    silver nanoparticles (20 nm)
# agnp20_po    silver nanoparticles (20 nm)
# Name: treatment1, dtype: object | agnp20_po    10
# agnp20_po    10
# Name: dose1, dtype: object | agnp20_po    mg/kg
# agnp20_po    mg/kg
# Name: units1, dtype: object | agnp20_po
# agnp20_po
# Name: treatment2, dtype: object | agnp20_po
# agnp20_po
# Name: dose2, dtype: object | agnp20_po
# agnp20_po
# Name: units2, dtype: object |
# | Group 6 | agnp110_iv    rat
# agnp110_iv    rat
# Name: animal_model, dtype: object | agnp110_iv    6
# agnp110_iv    6
# Name: sample_size, dtype: object | agnp110_iv    24 hours
# agnp110_iv    48 hours
# Name: terminal_time, dtype: object | agnp110_iv    silver nanoparticles (110 nm)
# agnp110_iv    silver nanoparticles (110 nm)
# Name: treatment1, dtype: object | agnp110_iv    1
# agnp110_iv    1
# Name: dose1, dtype: object | agnp110_iv    mg/kg
# agnp110_iv    mg/kg
# Name: units1, dtype: object | agnp110_iv
# agnp110_iv
# Name: treatment2, dtype: object | agnp110_iv
# agnp110_iv
# Name: dose2, dtype: object | agnp110_iv
# agnp110_iv
# Name: units2, dtype: object |
# | Group 7 | agnp110_po    rat
# agnp110_po    rat
# Name: animal_model, dtype: object | agnp110_po    6
# agnp110_po    6
# Name: sample_size, dtype: object | agnp110_po    24 hours
# agnp110_po    48 hours
# Name: terminal_time, dtype: object | agnp110_po    silver nanoparticles (110 nm)
# agnp110_po    silver nanoparticles (110 nm)
# Name: treatment1, dtype: object | agnp110_po    10
# agnp110_po    10
# Name: dose1, dtype: object | agnp110_po    mg/kg
# agnp110_po    mg/kg
# Name: units1, dtype: object | agnp110_po
# agnp110_po
# Name: treatment2, dtype: object | agnp110_po
# agnp110_po
# Name: dose2, dtype: object | agnp110_po
# agnp110_po
# Name: units2, dtype: object |

# %% [markdown]
# Process Biomarkers

# %%
for tid, info in formatted_tables.items():
    if info["label"] != "b": continue
    mean_columns = defaultdict(lambda: {"mean_col": None, "variation_col": None, "units": None})
    freq_columns = defaultdict(lambda: {"freq_col": None, "severity_col": None, "units": None})
    for label in info["biomarker_cols"]:
        if label["type"] == "mean":
            mean_columns[label["name"]]["mean_col"] = label["column"]
            if label["units"]: mean_columns[label["name"]]["units"] = label["units"]
        elif label["type"] == "variation":
            mean_columns[label["name"]]["variation_col"] = label["column"]
            if label["units"]: mean_columns[label["name"]]["units"] = label["units"]
        elif label["type"] == "frequency":
            freq_columns[label["name"]]["freq_col"] = label["column"]
            if label["units"]: mean_columns[label["name"]]["units"] = label["units"]
        elif label["type"] == "severity":
            freq_columns[label["name"]]["severity_col"] = label["column"]
    info["mean_cols"] = mean_columns
    info["freq_cols"] = freq_columns

# %%
for tid, info in formatted_tables.items():
    if info["label"] != "b": continue
    table_df = table_utils.markdown_to_dataframe(info["markdown"])
    print(info)
    table_df.index = info["table_groups"].index
    output_mean = []
    output_freq = []
    for row_index in table_df.index:
        for col_index, col_params in info["mean_cols"].items():
            if not table_df.at[row_index, col_params["mean_col"]]: continue
            output_mean.append({
                "Animal Model": info["table_groups"].at[row_index, "animal_model"],
                "Sample Size": info["table_groups"].at[row_index, "sample_size"],
                "Treatment 1": info["table_groups"].at[row_index, "treatment1"],
                "Dose 1": info["table_groups"].at[row_index, "dose1"],
                "Units 1": info["table_groups"].at[row_index, "units1"],
                "Treatment 2": info["table_groups"].at[row_index, "treatment2"],
                "Dose 2": info["table_groups"].at[row_index, "dose2"],
                "Units 2": info["table_groups"].at[row_index, "units2"],
                "Terminal Time": info["table_groups"].at[row_index, "terminal_time"],
                "Biomarker": col_index,
                "Value": table_df.at[row_index, col_params["mean_col"]],
                "Units": col_params["units"],
                "Variation": table_df.at[row_index, col_params["variation_col"]] if col_params["variation_col"] else None,
            })
        for col_index, col_params in info["freq_cols"].items():
            if not table_df.at[row_index, col_params["freq_col"]] and not table_df.at[row_index, col_params["severity_col"]]: continue
            if table_df.at[row_index, col_params["freq_col"]]:
                if col_params["units"] in ["percent", "percents", "percentage", "percentages", "%"]:
                    frequency = table_df.at[row_index, col_params["frequency"]]/info["table_groups"].at[row_index, "sample_size"] * 100
                elif col_params["units"] in ["count", "counts"]:
                    frequency = table_df.at[row_index, col_params["frequency"]]/info["table_groups"].at[row_index, "sample_size"]
                else:
                    frequency = table_df.at[row_index, col_params["frequency"]]
            output_mean.append({
                "Animal Model": info["table_groups"].at[row_index, "animal_model"],
                "Sample Size": info["table_groups"].at[row_index, "sample_size"],
                "Treatment 1": info["table_groups"].at[row_index, "treatment1"],
                "Dose 1": info["table_groups"].at[row_index, "dose1"],
                "Units 1": info["table_groups"].at[row_index, "units1"],
                "Treatment 2": info["table_groups"].at[row_index, "treatment2"],
                "Dose 2": info["table_groups"].at[row_index, "dose2"],
                "Units 2": info["table_groups"].at[row_index, "units2"],
                "Terminal Time": info["table_groups"].at[row_index, "terminal_time"],
                "Biomarker": col_index,
                "Frequency": frequency,
                "Severity": table_df.at[row_index, col_params["severity_col"]],
            })
    info["output_mean"] = pd.DataFrame(output_mean)
    info["output_freq"] = pd.DataFrame(output_freq)
# Out:
# {'label': 'b', 'caption': 'Concentration of silver (mug Ag/g) in tissues following i.v. administration (1 mg/kg) of AgAc, 20 nm AgNP or 110 nm AgNP to pregnant rats.', 'markdown': '| Tissue | Liver.mean | Liver.SD | Blood.mean | Blood.SD | Spleen.mean | Spleen.SD | Lungs.mean | Lungs.SD | Heart.mean | Heart.SD | Kidney.mean | Kidney.SD | Brain.mean | Brain.SD | Skin.mean | Skin.SD | Muscle.mean | Muscle.SD | Adipose.mean | Adipose.SD | Bone.mean | Bone.SD | Stomach and Small Intestine.mean | Stomach and Small Intestine.SD | Cecum and Large Intestine.mean | Cecum and Large Intestine.SD | Pancreas.mean | Pancreas.SD | Placenta.mean | Placenta.SD |\n| --- | --- | --- | --- | --- | --- | --- | --- | --- | --- | --- | --- | --- | --- | --- | --- | --- | --- | --- | --- | --- | --- | --- | --- | --- | --- | --- | --- | --- | --- | --- |\n| AgAc.24 h | 1.03 | 0.399 | 0.663 | 0.195 | 2.95 | 0.927 | 1.38 | 0.958 | 0.162 | 0.0306 | 0.405 | 0.0944 | 0.0358 | 0.000661 | 0.224 | 0.0488 | 0.0833 | 0.0616 | 0.0453 | 0.0191 | 0.311 | 0.0455 | 0.377 | 0.215 | 0.414 | 0.118 | 0.196 | 0.0561 | 0.881 | 0.337 |\n| AgAc.48 h | 0.511 | 0.534 | 0.180 | 0.033 | 0.524 | 0.493 | 1.31 | 0.906 | 0.0584 | 0.000479 | 0.233 | 0.0364 | 0.0233 | 0.00150 | 0.265 | 0.141 | 0.0556 | 0.0210 |  | nan | 0.119 | 0.0370 | 0.145 | 0.0958 | 0.443 | 0.175 | 0.170 | 0.116 | 0.756 | 0.184 |\n| 20 nm AgNP.24 h | 0.312 | 0.044 | 0.375 | 0.0485 | 1.42 | 0.499 | 0.519 | 0.103 | 0.127 | 0.0168 | 0.431 | 0.0520 | 0.0297 | nan | 0.196 | 0.147 | 0.0284 | 0.00378 |  | nan | 0.243 | 0.0780 | 0.319 | 0.0378 | 0.976 | 0.431 | 0.321 | 0.204 | 0.696 | 0.0682 |\n| 20 nm AgNP.48 h | 0.228 | 0.130 | 0.214 | 0.0916 | 1.14 | 0.636 | 0.397 | 0.0950 | 0.0863 | nan | 0.222 | 0.0843 | 0.0424 | nan | 0.194 | 0.0735 | 0.0146 | 0.00525 |  | nan | 0.144 | 0.0789 | 0.167 | 0.148 | 0.370 | 0.222 | 0.138 | 0.0553 | 0.926 | 0.436 |\n| 110 nm AgNP.24 h | 2.28 | 1.69 | 0.594 | 0.0566 | 6.79 | 2.16 | 0.436 | 0.0839 | 0.119 | 0.0204 | 0.472 | 0.0968 | b | nan | 0.188 | 0.107 |  | nan |  | nan | 0.120 | 0.0386 | 0.214 | 0.165 | 0.554 | 0.150 | 0.0732 | 0.0214 | 0.719 | 0.0364 |\n| 110 nm AgNP .48 h | 2.71 | 1.63 | 0.348 | 0.0720 | 3.60 | 0.467 | 0.305 | 0.0831 | 0.104 | 0.0144 | 0.373 | 0.161 |  | nan | 0.248 | 0.189 |  | nan |  | nan | 0.136 | 0.0299 | 0.136 | 0.0376 | 0.459 | 0.153 | 0.0831 | 0.0485 | 1.15 | 0.239 |', 'footnotes': ['All data are reported as Mean +- SD (n= 3)', 'Only one rat had levels above quantitation limit.', '<LOQ = below limit of quantitation = quantitation limit; 0.0125 mug/g for tissues.'], 'col_labels': [['Liver.mean', 'biomarker', 'Liver', 'mean', 'mug/g'], ['Liver.SD', 'biomarker', 'Liver', 'variation', 'mug/g'], ['Blood.mean', 'biomarker', 'Blood', 'mean', 'mug/g'], ['Blood.SD', 'biomarker', 'Blood', 'variation', 'mug/g'], ['Spleen.mean', 'biomarker', 'Spleen', 'mean', 'mug/g'], ['Spleen.SD', 'biomarker', 'Spleen', 'variation', 'mug/g'], ['Lungs.mean', 'biomarker', 'Lungs', 'mean', 'mug/g'], ['Lungs.SD', 'biomarker', 'Lungs', 'variation', 'mug/g'], ['Heart.mean', 'biomarker', 'Heart', 'mean', 'mug/g'], ['Heart.SD', 'biomarker', 'Heart', 'variation', 'mug/g'], ['Kidney.mean', 'biomarker', 'Kidney', 'mean', 'mug/g'], ['Kidney.SD', 'biomarker', 'Kidney', 'variation', 'mug/g'], ['Brain.mean', 'biomarker', 'Brain', 'mean', 'mug/g'], ['Brain.SD', 'biomarker', 'Brain', 'variation', 'mug/g'], ['Skin.mean', 'biomarker', 'Skin', 'mean', 'mug/g'], ['Skin.SD', 'biomarker', 'Skin', 'variation', 'mug/g'], ['Muscle.mean', 'biomarker', 'Muscle', 'mean', 'mug/g'], ['Muscle.SD', 'biomarker', 'Muscle', 'variation', 'mug/g'], ['Adipose.mean', 'biomarker', 'Adipose', 'mean', 'mug/g'], ['Adipose.SD', 'biomarker', 'Adipose', 'variation', 'mug/g'], ['Bone.mean', 'biomarker', 'Bone', 'mean', 'mug/g'], ['Bone.SD', 'biomarker', 'Bone', 'variation', 'mug/g'], ['Stomach and Small Intestine.mean', 'biomarker', 'Stomach and Small Intestine', 'mean', 'mug/g'], ['Stomach and Small Intestine.SD', 'biomarker', 'S ...
# group 0          AgAc.24 h       1.03    0.399      0.663    0.195
# group 1          AgAc.48 h      0.511    0.534      0.180    0.033
# group 2    20 nm AgNP.24 h      0.312    0.044      0.375   0.0485
# group 3    20 nm AgNP.48 h      0.228    0.130      0.214   0.0916
# group 4   110 nm AgNP.24 h       2.28     1.69      0.594   0.0566
# group 5  110 nm AgNP .48 h       2.71     1.63      0.348   0.0720
#
#         Spleen.mean Spleen.SD Lungs.mean Lungs.SD Heart.mean  ... Bone.mean  \
# group 0        2.95     0.927       1.38    0.958      0.162  ...     0.311
# group 1       0.524     0.493       1.31    0.906     0.0584  ...     0.119
# group 2        1.42     0.499      0.519    0.103      0.127  ...     0.243
# group 3        1.14     0.636      0.397   0.0950     0.0863  ...     0.144
# group 4        6.79      2.16      0.436   0.0839      0.119  ...     0.120
# group 5        3.60     0.467      0.305   0.0831      0.104  ...     0.136
#
#         Bone.SD Stomach and Small Intestine.mean  \
# group 0  0.0455                            0.377
# group 1  0.0370                            0.145
# group 2  0.0780                            0.319
# group 3  0.0789                            0.167
# group 4  0.0386                            0.214
# group 5  0.0299                            0.136
#
#         Stomach and Small Intestine.SD Cecum and Large Intestine.mean  \
# group 0                          0.215                          0.414
# group 1                         0.0958                          0.443
# group 2                         0.0378                          0.976
# group 3                          0.148                          0.370
# group 4                          0.165                          0.554
# group 5                         0.0376                          0.459
#
#         Cecum and Large Intestine.SD Pancreas.mean Pancreas.SD Placenta.mean  \
# group 0                        0.118         0.196      0.0561         0.881
# group 1                        0.175         0.170       0.116         0.756
# group 2                        0.431         0.321       0.204         0.696
# group 3                        0.222         0.138      0.0553         0.926
# group 4                        0.150        0.0732      0.0214         0.719
# group 5                        0.153        0.0831      0.0485          1.15
#
#         Placenta.SD
# group 0       0.337
# group 1       0.184
# group 2      0.0682
# group 3       0.436
# group 4      0.0364
# group 5       0.239
#
# [6 rows x 31 columns], 'table_groups':            group                                       animal_model  \
# group 0  Group 0  control_iv    rat
# control_iv    rat
# Name: anim...
# group 1  Group 1  control_po    rat
# control_po    rat
# Name: anim...
# group 2  Group 2  agac_iv    rat
# agac_iv    rat
# Name: animal_mod...
# group 3  Group 3  agac_po    rat
# agac_po    rat
# Name: animal_mod...
# group 4  Group 4  agnp20_iv    rat
# agnp20_iv    rat
# Name: animal...
# group 5  Group 5  agnp20_po    rat
# agnp20_po    rat
# Name: animal...
#
#                                                sample_size  \
# group 0  control_iv    6
# control_iv    6
# Name: sample_s...
# group 1  control_po    6
# control_po    6
# Name: sample_s...
# group 2  agac_iv    6
# agac_iv    6
# Name: sample_size, d...
# group 3  agac_po    6
# agac_po    6
# Name: sample_size, d...
# group 4  agnp20_iv    6
# agnp20_iv    6
# Name: sample_siz...
# group 5  agnp20_po    6
# agnp20_po    6
# Name: sample_siz...
#
#                                              terminal_time  \
# group 0  control_iv    24 hours
# control_iv    48 hours
# ...
# group 1  control_po    24 hours
# control_po    48 hours
# ...
# group 2  agac_iv    24 hours
# agac_iv    48 hours
# Name: ...
# group 3  agac_po    24 hours
# agac_po    48 hours
# Name: ...
# group 4  agnp20_iv    24 hours
# agnp20_iv    48 hours
# Na...
# group 5  agnp20_po    24 hours
# agnp20_po    48 hours
# Na...
#
#                                                 treatment1  \
# group 0  control_iv
# control_iv
# Name: treatment1...
# group 1  control_po
# control_po
# Name: treatment1...
# group 2  agac_iv    silver acetate
# agac_iv    silver ac...
# group 3  agac_po    silver acetate
# agac_po    silver ac...
# group 4  agnp20_iv    silver nanoparticles (20 nm)
# agnp...
# group 5  agnp20_po    silver nanoparticles (20 nm)
# agnp...
#
#                                                      dose1  \
# group 0  control_iv
# control_iv
# Name: dose1, dty...
# group 1  control_po
# control_po
# Name: dose1, dty...
# group 2  agac_iv    1
# agac_iv    1
# Name: dose1, dtype: ...
# group 3  agac_po    10
# agac_po    10
# Name: dose1, dtype...
# group 4  agnp20_iv    1
# agnp20_iv    1
# Name: dose1, dty...
# group 5  agnp20_po    10
# agnp20_po    10
# Name: dose1, d...
#
#                                                     units1  \
# group 0  control_iv
# control_iv
# Name: units1, dt...
# group 1  control_po
# control_po
# Name: units1, dt...
# group 2  agac_iv    mg/kg
# agac_iv    mg/kg
# Name: units1...
# group 3  agac_po    mg/kg
# agac_po    mg/kg
# Name: units1...
# group 4  agnp20_iv    mg/kg
# agnp20_iv    mg/kg
# Name: un...
# group 5  agnp20_po    mg/kg
# agnp20_po    mg/kg
# Name: un...
#
#                                                 treatment2  \
# group 0  control_iv
# control_iv
# Name: treatment2...
# group 1  control_po
# control_po
# Name: treatment2...
# group 2  agac_iv
# agac_iv
# Name: treatment2, dtyp...
# group 3  agac_po
# agac_po
# Name: treatment2, dtyp...
# group 4  agnp20_iv
# agnp20_iv
# Name: treatment2, ...
# group 5  agnp20_po
# agnp20_po
# Name: treatment2, ...
#
#                                                      dose2  \
# group 0  control_iv
# control_iv
# Name: dose2, dty...
# group 1  control_po
# control_po
# Name: dose2, dty...
# group 2  agac_iv
# agac_iv
# Name: dose2, dtype: ob...
# group 3  agac_po
# agac_po
# Name: dose2, dtype: ob...
# group 4  agnp20_iv
# agnp20_iv
# Name: dose2, dtype...
# group 5  agnp20_po
# agnp20_po
# Name: dose2, dtype...
#
#                                                     units2
# group 0  control_iv
# control_iv
# Name: units2, dt...
# group 1  control_po
# control_po
# Name: units2, dt...
# group 2  agac_iv
# agac_iv
# Name: units2, dtype: o...
# group 3  agac_po
# agac_po
# Name: units2, dtype: o...
# group 4  agnp20_iv
# agnp20_iv
# Name: units2, dtyp...
# group 5  agnp20_po
# agnp20_po
# Name: units2, dtyp...  , 'mean_cols': defaultdict(<function <lambda> at 0x000001999B213CE0>, {'Liver': {'mean_col': 'Liver.mean', 'variation_col': 'Liver.SD', 'units': 'mug/g'}, 'Blood': {'mean_col': 'Blood.mean', 'variation_col': 'Blood.SD', 'units': 'mug/g'}, 'Spleen': {'mean_col': 'Spleen.mean', 'variation_col': 'Spleen.SD', 'units': 'mug/g'}, 'Lungs': {'mean_col': 'Lungs.mean', 'variation_col': 'Lungs.SD', 'units': 'mug/g'}, 'Heart': {'mean_col': 'Heart.mean', 'variation_col': 'Heart.SD', 'units': 'mug/g'}, 'Kidney': {'mean_col': 'Kidney.mean', 'variation_col': 'Kidney.SD', 'units': 'mug/g'}, 'Brain': {'mean_col': 'Brain.mean', 'variation_col': 'Brain.SD', 'units': 'mug/g'}, 'Skin': {'mean_col': 'Skin.mean', 'variation_col': 'Skin.SD', 'units': 'mug/g'}, 'Muscle': {'mean_col': 'Muscle.mean', 'variation_col': 'Muscle.SD', 'units': 'mug/g'}, 'Adipose': {'mean_col': 'Adipose.mean', 'variation_col': 'Adipose.SD', 'units': 'mug/g'}, 'Bone': {'mean_col': 'Bone.mean', 'variation_col': 'Bone.SD', 'units': 'mug/g'}, 'Stomach and Small Intestine': {'mean_col': 'Stomach and Small Intestine.mean', 'variation_col': 'Stomach and Small Intestine.SD', 'units': 'mug/g'}, 'Cecum and Large Intestine': {'mean_col': 'Cecum and Large Intestine.mean', 'variation_col': 'Cecum and Large Intestine.SD', 'units': 'mug/g'}, 'Pancreas': {'mean_col': 'Pancreas.mean', 'variation_col': 'Pancreas.SD', 'units': 'mug/g'}, 'Placenta': {'mean_col': 'Placenta.mean', 'variation_col': 'Placenta.SD', 'units': 'mug/g'}}), 'freq_cols': defaultdict(<function <lambda> at 0x000001999B213F60>, {})}
# {'label': 'b', 'caption': 'Percent recovered of administered dose of silver in tissues following i.v. administration (1 mg/kg) of AgAc, 20 nm AgNP or 110 nm AgNP to pregnant rats', 'markdown': '| Tissue | Liver.mean | Liver.SD | Blood.mean | Blood.SD | Spleen.mean | Spleen.SD | Lungs.mean | Lungs.SD | Heart.mean | Heart.SD | Kidney.mean | Kidney.SD | Brain.mean | Brain.SD | Skin.mean | Skin.SD | Muscle.mean | Muscle.SD | Adipose.mean | Adipose.SD | Bone.mean | Bone.SD | Stomach and Small Intestine.mean | Stomach and Small Intestine.SD | Cecum and Large Intestine.mean | Cecum and Large Intestine.SD | Pancreas.mean | Pancreas.SD | Placenta.mean | Placenta.SD |\n| --- | --- | --- | --- | --- | --- | --- | --- | --- | --- | --- | --- | --- | --- | --- | --- | --- | --- | --- | --- | --- | --- | --- | --- | --- | --- | --- | --- | --- | --- | --- |\n| AgAc.24 h | 4.33 | 1.63 | 4.88 | 1.39 | 0.529 | 0.124 | 0.534 | 0.402 | 0.0504 | 0.005 | 0.248 | 0.0583 | 0.0213 | 0.00126 | 4.34 | 0.995 | 3.42 | 2.53 | 0.324 | 0.143 | 2.21 | 0.302 | 1.11 | 0.567 | 1.33 | 0.0429 | 0.141 | 0.0523 | 1.41 | 0.304 |\n| AgAc.48 h | 2.08 | 2.02 | 1.33 | 0.257 | 0.114 | 0.118 | 0.496 | 0.325 | 0.0181 | 0.00348 | 0.125 | 0.0233 | 0.0215 | 0.000908 | 5.49 | 2.95 | 2.44 | 0.901 |  | nan | 0.902 | 0.273 | 0.530 | 0.197 | 1.49 | 0.599 | 0.109 | 0.0832 | 1.60 | 0.470 |\n| 20 nm AgNP.24 h | 1.44 | 0.203 | 2.80 | 0.346 | 0.274 | 0.0631 | 0.204 | 0.0454 | 0.0404 | 0.00715 | 0.265 | 0.0367 | 0.0169 | nan | 3.89 | 3.00 | 1.19 | 0.158 |  | nan | 1.77 | 0.609 | 1.36 | 0.442 | 3.63 | 1.58 | 0.161 | 0.114 | 1.28 | 0.274 |\n| 20 nm AgNP.48 h | 1.02 | 0.635 | 1.57 | 0.664 | 0.193 | 0.110 | 0.138 | 0.0379 | 0.0234 | nan | 0.125 | 0.0454 | 0.0240 | nan | 3.80 | 1.47 | 0.605 | 0.137 |  | nan | 0.995 | 0.486 | 0.593 | 0.419 | 1.15 | 0.563 | 0.103 | 0.0475 | 2.10 | 1.10 |\n| 110 nm AgNP.24 h | 8.69 | 6.04 | 4.41 | 0.418 | 1.44 | 0.587 | 0.157 | 0.0247 | 0.0332 | 0.00344 | 0.274 | 0.0505 | b | nan | 3.75 | 2.11 |  | nan |  | nan | 0.881 | 0.275 | 0.681 | 0.533 | 0.167 | 0.0650 | 0.0843 | 0.047 | 1.26 | 0.181 |\n| 110 nm AgNP .48 h | 12.1 | 7.11 | 2.55 | 0.516 | 0.780 | 0.0878 | 0.0974 | 0.0139 | 0.0317 | 0.000950 | 0.221 | 0.0734 |  | nan | 5.23 | 4.08 |  | nan |  | nan | 1.05 | 0.214 | 0.627 | 0.250 | 0.145 | 0.387 | 0.0797 | 0.037 | 1.93 | 0.483 |', 'footnotes': ['All data are reported as Mean +- SD (n= 3)', 'Only one rat had levels above quantitation limit.', '<LOQ = below limit of quantitation = quantitation limit; 0.0125 mug/g for tissues.'], 'col_labels': [['Tissue', 'group'], ['Liver.mean', 'biomarker', 'Liver', 'mean', 'percent'], ['Liver.SD', 'biomarker', 'Liver', 'variation', 'percent'], ['Blood.mean', 'biomarker', 'Blood', 'mean', 'percent'], ['Blood.SD', 'biomarker', 'Blood', 'variation', 'percent'], ['Spleen.mean', 'biomarker', 'Spleen', 'mean', 'percent'], ['Spleen.SD', 'biomarker', 'Spleen', 'variation', 'percent'], ['Lungs.mean', 'biomarker', 'Lungs', 'mean', 'percent'], ['Lungs.SD', 'biomarker', 'Lungs', 'variation', 'percent'], ['Heart.mean', 'biomarker', 'Heart', 'mean', 'percent'], ['Heart.SD', 'biomarker', 'Heart', 'variation', 'percent'], ['Kidney.mean', 'biomarker', 'Kidney', 'mean', 'percent'], ['Kidney.SD', 'biomarker', 'Kidney', 'variation', 'percent'], ['Brain.mean', 'biomarker', 'Brain', 'mean', 'percent'], ['Brain.SD', 'biomarker', 'Brain', 'variation', 'percent'], ['Skin.mean', 'biomarker', 'Skin', 'mean', 'percent'], ['Skin.SD', 'biomarker', 'Skin', 'variation', 'percent'], ['Muscle.mean', 'biomarker', 'Muscle', 'mean', 'percent'], ['Muscle.SD', 'biomarker', 'Muscle', 'variation', 'percent'], ['Adipose.mean', 'biomarker', 'Adipose', 'mean', 'percent'], ['Adipose.SD', 'biomarker', 'Adipose', 'variation', 'percent'], ['Bone.mean', 'biomarker', 'Bone', 'mean', 'percent'], ['Bone.SD', 'biomarker', 'Bone', 'variation', 'percent'], ['Stomach and Small Intestine.mean', 'biomarker', 'Stomach and Small Intestine', 'mean', 'percent'], ['Stomach and Small Int ...
# agac.24 h                  AgAc.24 h       4.33     1.63       4.88     1.39
# agac.48 h                  AgAc.48 h       2.08     2.02       1.33    0.257
# 20 nm agnp.24 h      20 nm AgNP.24 h       1.44    0.203       2.80    0.346
# 20 nm agnp.48 h      20 nm AgNP.48 h       1.02    0.635       1.57    0.664
# 110 nm agnp.24 h    110 nm AgNP.24 h       8.69     6.04       4.41    0.418
# 110 nm agnp .48 h  110 nm AgNP .48 h       12.1     7.11       2.55    0.516
#
#                   Spleen.mean Spleen.SD Lungs.mean Lungs.SD Heart.mean  ...  \
# agac.24 h               0.529     0.124      0.534    0.402     0.0504  ...
# agac.48 h               0.114     0.118      0.496    0.325     0.0181  ...
# 20 nm agnp.24 h         0.274    0.0631      0.204   0.0454     0.0404  ...
# 20 nm agnp.48 h         0.193     0.110      0.138   0.0379     0.0234  ...
# 110 nm agnp.24 h         1.44     0.587      0.157   0.0247     0.0332  ...
# 110 nm agnp .48 h       0.780    0.0878     0.0974   0.0139     0.0317  ...
#
#                   Bone.mean Bone.SD Stomach and Small Intestine.mean  \
# agac.24 h              2.21   0.302                             1.11
# agac.48 h             0.902   0.273                            0.530
# 20 nm agnp.24 h        1.77   0.609                             1.36
# 20 nm agnp.48 h       0.995   0.486                            0.593
# 110 nm agnp.24 h      0.881   0.275                            0.681
# 110 nm agnp .48 h      1.05   0.214                            0.627
#
#                   Stomach and Small Intestine.SD  \
# agac.24 h                                  0.567
# agac.48 h                                  0.197
# 20 nm agnp.24 h                            0.442
# 20 nm agnp.48 h                            0.419
# 110 nm agnp.24 h                           0.533
# 110 nm agnp .48 h                          0.250
#
#                   Cecum and Large Intestine.mean Cecum and Large Intestine.SD  \
# agac.24 h                                   1.33                       0.0429
# agac.48 h                                   1.49                        0.599
# 20 nm agnp.24 h                             3.63                         1.58
# 20 nm agnp.48 h                             1.15                        0.563
# 110 nm agnp.24 h                           0.167                       0.0650
# 110 nm agnp .48 h                          0.145                        0.387
#
#                   Pancreas.mean Pancreas.SD Placenta.mean Placenta.SD
# agac.24 h                 0.141      0.0523          1.41       0.304
# agac.48 h                 0.109      0.0832          1.60       0.470
# 20 nm agnp.24 h           0.161       0.114          1.28       0.274
# 20 nm agnp.48 h           0.103      0.0475          2.10        1.10
# 110 nm agnp.24 h         0.0843       0.047          1.26       0.181
# 110 nm agnp .48 h        0.0797       0.037          1.93       0.483
#
# [6 rows x 31 columns], 'table_groups':                                group  \
# agac.24 h                  AgAc.24 h
# agac.48 h                  AgAc.48 h
# 20 nm agnp.24 h      20 nm AgNP.24 h
# 20 nm agnp.48 h      20 nm AgNP.48 h
# 110 nm agnp.24 h    110 nm AgNP.24 h
# 110 nm agnp .48 h  110 nm AgNP .48 h
#
#                                                         animal_model  \
# agac.24 h          agac_iv    rat
# agac_iv    rat
# Name: animal_mod...
# agac.48 h          agac_iv    rat
# agac_iv    rat
# Name: animal_mod...
# 20 nm agnp.24 h    agnp20_iv    rat
# agnp20_iv    rat
# Name: animal...
# 20 nm agnp.48 h    agnp20_iv    rat
# agnp20_iv    rat
# Name: animal...
# 110 nm agnp.24 h   agnp110_iv    rat
# agnp110_iv    rat
# Name: anim...
# 110 nm agnp .48 h  agnp110_iv    rat
# agnp110_iv    rat
# Name: anim...
#
#                                                          sample_size  \
# agac.24 h          agac_iv    6
# agac_iv    6
# Name: sample_size, d...
# agac.48 h          agac_iv    6
# agac_iv    6
# Name: sample_size, d...
# 20 nm agnp.24 h    agnp20_iv    6
# agnp20_iv    6
# Name: sample_siz...
# 20 nm agnp.48 h    agnp20_iv    6
# agnp20_iv    6
# Name: sample_siz...
# 110 nm agnp.24 h   agnp110_iv    6
# agnp110_iv    6
# Name: sample_s...
# 110 nm agnp .48 h  agnp110_iv    6
# agnp110_iv    6
# Name: sample_s...
#
#                                                        terminal_time  \
# agac.24 h          agac_iv    24 hours
# agac_iv    48 hours
# Name: ...
# agac.48 h          agac_iv    24 hours
# agac_iv    48 hours
# Name: ...
# 20 nm agnp.24 h    agnp20_iv    24 hours
# agnp20_iv    48 hours
# Na...
# 20 nm agnp.48 h    agnp20_iv    24 hours
# agnp20_iv    48 hours
# Na...
# 110 nm agnp.24 h   agnp110_iv    24 hours
# agnp110_iv    48 hours
# ...
# 110 nm agnp .48 h  agnp110_iv    24 hours
# agnp110_iv    48 hours
# ...
#
#                                                           treatment1  \
# agac.24 h          agac_iv    silver acetate
# agac_iv    silver ac...
# agac.48 h          agac_iv    silver acetate
# agac_iv    silver ac...
# 20 nm agnp.24 h    agnp20_iv    silver nanoparticles (20 nm)
# agnp...
# 20 nm agnp.48 h    agnp20_iv    silver nanoparticles (20 nm)
# agnp...
# 110 nm agnp.24 h   agnp110_iv    silver nanoparticles (110 nm)
# ag...
# 110 nm agnp .48 h  agnp110_iv    silver nanoparticles (110 nm)
# ag...
#
#                                                                dose1  \
# agac.24 h          agac_iv    1
# agac_iv    1
# Name: dose1, dtype: ...
# agac.48 h          agac_iv    1
# agac_iv    1
# Name: dose1, dtype: ...
# 20 nm agnp.24 h    agnp20_iv    1
# agnp20_iv    1
# Name: dose1, dty...
# 20 nm agnp.48 h    agnp20_iv    1
# agnp20_iv    1
# Name: dose1, dty...
# 110 nm agnp.24 h   agnp110_iv    1
# agnp110_iv    1
# Name: dose1, d...
# 110 nm agnp .48 h  agnp110_iv    1
# agnp110_iv    1
# Name: dose1, d...
#
#                                                               units1  \
# agac.24 h          agac_iv    mg/kg
# agac_iv    mg/kg
# Name: units1...
# agac.48 h          agac_iv    mg/kg
# agac_iv    mg/kg
# Name: units1...
# 20 nm agnp.24 h    agnp20_iv    mg/kg
# agnp20_iv    mg/kg
# Name: un...
# 20 nm agnp.48 h    agnp20_iv    mg/kg
# agnp20_iv    mg/kg
# Name: un...
# 110 nm agnp.24 h   agnp110_iv    mg/kg
# agnp110_iv    mg/kg
# Name: ...
# 110 nm agnp .48 h  agnp110_iv    mg/kg
# agnp110_iv    mg/kg
# Name: ...
#
#                                                           treatment2  \
# agac.24 h          agac_iv
# agac_iv
# Name: treatment2, dtyp...
# agac.48 h          agac_iv
# agac_iv
# Name: treatment2, dtyp...
# 20 nm agnp.24 h    agnp20_iv
# agnp20_iv
# Name: treatment2, ...
# 20 nm agnp.48 h    agnp20_iv
# agnp20_iv
# Name: treatment2, ...
# 110 nm agnp.24 h   agnp110_iv
# agnp110_iv
# Name: treatment2...
# 110 nm agnp .48 h  agnp110_iv
# agnp110_iv
# Name: treatment2...
#
#                                                                dose2  \
# agac.24 h          agac_iv
# agac_iv
# Name: dose2, dtype: ob...
# agac.48 h          agac_iv
# agac_iv
# Name: dose2, dtype: ob...
# 20 nm agnp.24 h    agnp20_iv
# agnp20_iv
# Name: dose2, dtype...
# 20 nm agnp.48 h    agnp20_iv
# agnp20_iv
# Name: dose2, dtype...
# 110 nm agnp.24 h   agnp110_iv
# agnp110_iv
# Name: dose2, dty...
# 110 nm agnp .48 h  agnp110_iv
# agnp110_iv
# Name: dose2, dty...
#
#                                                               units2
# agac.24 h          agac_iv
# agac_iv
# Name: units2, dtype: o...
# agac.48 h          agac_iv
# agac_iv
# Name: units2, dtype: o...
# 20 nm agnp.24 h    agnp20_iv
# agnp20_iv
# Name: units2, dtyp...
# 20 nm agnp.48 h    agnp20_iv
# agnp20_iv
# Name: units2, dtyp...
# 110 nm agnp.24 h   agnp110_iv
# agnp110_iv
# Name: units2, dt...
# 110 nm agnp .48 h  agnp110_iv
# agnp110_iv
# Name: units2, dt...  , 'mean_cols': defaultdict(<function <lambda> at 0x00000199B367E7A0>, {'Liver': {'mean_col': 'Liver.mean', 'variation_col': 'Liver.SD', 'units': 'percent'}, 'Blood': {'mean_col': 'Blood.mean', 'variation_col': 'Blood.SD', 'units': 'percent'}, 'Spleen': {'mean_col': 'Spleen.mean', 'variation_col': 'Spleen.SD', 'units': 'percent'}, 'Lungs': {'mean_col': 'Lungs.mean', 'variation_col': 'Lungs.SD', 'units': 'percent'}, 'Heart': {'mean_col': 'Heart.mean', 'variation_col': 'Heart.SD', 'units': 'percent'}, 'Kidney': {'mean_col': 'Kidney.mean', 'variation_col': 'Kidney.SD', 'units': 'percent'}, 'Brain': {'mean_col': 'Brain.mean', 'variation_col': 'Brain.SD', 'units': 'percent'}, 'Skin': {'mean_col': 'Skin.mean', 'variation_col': 'Skin.SD', 'units': 'percent'}, 'Muscle': {'mean_col': 'Muscle.mean', 'variation_col': 'Muscle.SD', 'units': 'percent'}, 'Adipose': {'mean_col': 'Adipose.mean', 'variation_col': 'Adipose.SD', 'units': 'percent'}, 'Bone': {'mean_col': 'Bone.mean', 'variation_col': 'Bone.SD', 'units': 'percent'}, 'Stomach and Small Intestine': {'mean_col': 'Stomach and Small Intestine.mean', 'variation_col': 'Stomach and Small Intestine.SD', 'units': 'percent'}, 'Cecum and Large Intestine': {'mean_col': 'Cecum and Large Intestine.mean', 'variation_col': 'Cecum and Large Intestine.SD', 'units': 'percent'}, 'Pancreas': {'mean_col': 'Pancreas.mean', 'variation_col': 'Pancreas.SD', 'units': 'percent'}, 'Placenta': {'mean_col': 'Placenta.mean', 'variation_col': 'Placenta.SD', 'units': 'percent'}}), 'freq_cols': defaultdict(<function <lambda> at 0x00000199B367F740>, {})}
# {'label': 'b', 'caption': 'Concentration of silver (mug Ag/g) in tissues following p.o. administration (10 mg/kg) of AgAc, 20 nm AgNP or 110 nm AgNP to pregnant rats.', 'markdown': '| Tissue | Liver.mean | Liver.SD | Blood.mean | Blood.SD | Spleen.mean | Spleen.SD | Lungs.mean | Lungs.SD | Heart | Kidney.mean | Kidney.SD | Brain | Stomach and Small Intestine.mean | Stomach and Small Intestine.SD | Cecum and Large Intestine.mean | Cecum and Large Intestine.SD | Placenta.mean | Placenta.SD |\n| --- | --- | --- | --- | --- | --- | --- | --- | --- | --- | --- | --- | --- | --- | --- | --- | --- | --- | --- |\n| AgAc.24 h | 0.187 | 0.106 | b | nan | 0.0802 | 0.0648 | 0.137 | 0.0239 | 0.0604 | 0.461 | 0.506 |  | 1.55 | 2.51 | 16.0 | 25.6 | 0.751 | 0.0249 |\n| AgAc.48 h | 0.324 | 0.380 | 0.117 | 0.0168 | 0.104 | 0.0702 | 0.177 | nan |  | 0.147 | 0.0413 |  | 0.0726 | 0.0286 | 0.400 | 0.0248 | 0.919 | 0.271 |\n| 20 nm AgNP.24 h | 0.0592 | 0.0293 | 0.124 | 0.0120 | 0.220 | 0.0329 | 0.965 | nan |  | 0.187 | 0.0545 |  | 0.0657 | 0.0324 | 3.76 | 2.24 | 0.518 | 0.0302 |\n| 20 nm AgNP.48 h | 0.0380 | 0.0126 | 0.0646 | 0.00519 | 0.172 | nan |  | nan |  | 0.0868 | 0.0136 |  | 0.0307 | 0.0141 | 0.884 | 0.750 | 0.354 | 0.307 |\n| 110 nm AgNP.24 h | 0.0205 | 0.0150 |  | nan | 0.172 | nan |  | nan |  | 0.104 | 0.0387 |  | 0.584 | 0.468 | 3.02 | 1.04 | 0.201 | 0.125 |\n| 110 nm AgNP .48 h | 0.0170 | 0.00377 |  | nan |  | nan |  | nan |  | 0.0795 | 0.0179 |  | 0.0193 | 0.00657 | 0.901 | 0.449 | 0.351 | 0.106 |', 'footnotes': ['All data are reported as Mean +- SD (n= 3)', 'Only one rat had concentrations > quantitation limit.', '<LOQ = below limit of quantitation = quantitation limit; 0.0125 mug/g for tissues.'], 'col_labels': [['Tissue', 'group'], ['Liver.mean', 'biomarker', 'Liver', 'mean', 'mug Ag/g'], ['Liver.SD', 'biomarker', 'Liver', 'variation', 'mug Ag/g'], ['Blood.mean', 'biomarker', 'Blood', 'mean', 'mug Ag/g'], ['Blood.SD', 'biomarker', 'Blood', 'variation', 'mug Ag/g'], ['Spleen.mean', 'biomarker', 'Spleen', 'mean', 'mug Ag/g'], ['Spleen.SD', 'biomarker', 'Spleen', 'variation', 'mug Ag/g'], ['Lungs.mean', 'biomarker', 'Lungs', 'mean', 'mug Ag/g'], ['Lungs.SD', 'biomarker', 'Lungs', 'variation', 'mug Ag/g'], ['Heart', 'biomarker', 'Heart', 'mean', 'mug Ag/g'], ['Kidney.mean', 'biomarker', 'Kidney', 'mean', 'mug Ag/g'], ['Kidney.SD', 'biomarker', 'Kidney', 'variation', 'mug Ag/g'], ['Brain', 'biomarker', 'Brain', 'mean', 'mug Ag/g'], ['Stomach and Small Intestine.mean', 'biomarker', 'Stomach and Small Intestine', 'mean', 'mug Ag/g'], ['Stomach and Small Intestine.SD', 'biomarker', 'Stomach and Small Intestine', 'variation', 'mug Ag/g'], ['Cecum and Large Intestine.mean', 'biomarker', 'Cecum and Large Intestine', 'mean', 'mug Ag/g'], ['Cecum and Large Intestine.SD', 'biomarker', 'Cecum and Large Intestine', 'variation', 'mug Ag/g'], ['Placenta.mean', 'biomarker', 'Placenta', 'mean', 'mug Ag/g'], ['Placenta.SD', 'biomarker', 'Placenta', 'variation', 'mug Ag/g']], 'group_cols': [{'column': 'Tissue', 'label': 'group', 'units': [], 'link': None, 'name': None}], 'biomarker_cols': [{'column': 'Liver.mean', 'label': 'biomarker', 'type': 'mean', 'units': 'mug Ag/g', 'name': 'Liver'}, {'column': 'Liver.SD', 'label': 'biomarker', 'type': 'variation', 'units': 'mug Ag/g', 'name': 'Liver'}, {'column': 'Blood.mean', 'label': 'biomarker', 'type': 'mean', 'units': 'mug Ag/g', 'name': 'Blood'}, {'column': 'Blood.SD', 'label': 'biomarker', 'type': 'variation', 'units': 'mug Ag/g', 'name': 'Blood'}, {'column': 'Spleen.mean', 'label': 'biomarker', 'type': 'mean', 'units': 'mug Ag/g', 'name': 'Spleen'}, {'column': 'Spleen.SD', 'label': 'biomarker', 'type': 'variation', 'units': 'mug Ag/g', 'name': 'Spleen'}, {'column': 'Lungs.mean', 'label': 'biomarker', 'type': 'mean', 'units': 'mug Ag/g', 'name': 'Lungs'}, {'column': 'Lungs.SD', 'label': 'biomarker', 'type': 'variation', 'units': 'mug Ag/g', 'name': 'Lungs'}, {'column': 'Heart', 'label': 'biomarker', 'type':  ...
# agac.24 h                  AgAc.24 h      0.187    0.106          b      nan
# agac.48 h                  AgAc.48 h      0.324    0.380      0.117   0.0168
# 20 nm agnp.24 h      20 nm AgNP.24 h     0.0592   0.0293      0.124   0.0120
# 20 nm agnp.48 h      20 nm AgNP.48 h     0.0380   0.0126     0.0646  0.00519
# 110 nm agnp.24 h    110 nm AgNP.24 h     0.0205   0.0150                 nan
# 110 nm agnp .48 h  110 nm AgNP .48 h     0.0170  0.00377                 nan
#
#                   Spleen.mean Spleen.SD Lungs.mean Lungs.SD   Heart  \
# agac.24 h              0.0802    0.0648      0.137   0.0239  0.0604
# agac.48 h               0.104    0.0702      0.177      nan
# 20 nm agnp.24 h         0.220    0.0329      0.965      nan
# 20 nm agnp.48 h         0.172       nan                 nan
# 110 nm agnp.24 h        0.172       nan                 nan
# 110 nm agnp .48 h                   nan                 nan
#
#                   Kidney.mean Kidney.SD Brain  \
# agac.24 h               0.461     0.506
# agac.48 h               0.147    0.0413
# 20 nm agnp.24 h         0.187    0.0545
# 20 nm agnp.48 h        0.0868    0.0136
# 110 nm agnp.24 h        0.104    0.0387
# 110 nm agnp .48 h      0.0795    0.0179
#
#                   Stomach and Small Intestine.mean  \
# agac.24 h                                     1.55
# agac.48 h                                   0.0726
# 20 nm agnp.24 h                             0.0657
# 20 nm agnp.48 h                             0.0307
# 110 nm agnp.24 h                             0.584
# 110 nm agnp .48 h                           0.0193
#
#                   Stomach and Small Intestine.SD  \
# agac.24 h                                   2.51
# agac.48 h                                 0.0286
# 20 nm agnp.24 h                           0.0324
# 20 nm agnp.48 h                           0.0141
# 110 nm agnp.24 h                           0.468
# 110 nm agnp .48 h                        0.00657
#
#                   Cecum and Large Intestine.mean Cecum and Large Intestine.SD  \
# agac.24 h                                   16.0                         25.6
# agac.48 h                                  0.400                       0.0248
# 20 nm agnp.24 h                             3.76                         2.24
# 20 nm agnp.48 h                            0.884                        0.750
# 110 nm agnp.24 h                            3.02                         1.04
# 110 nm agnp .48 h                          0.901                        0.449
#
#                   Placenta.mean Placenta.SD
# agac.24 h                 0.751      0.0249
# agac.48 h                 0.919       0.271
# 20 nm agnp.24 h           0.518      0.0302
# 20 nm agnp.48 h           0.354       0.307
# 110 nm agnp.24 h          0.201       0.125
# 110 nm agnp .48 h         0.351       0.106  , 'table_groups':                                group  \
# agac.24 h                  AgAc.24 h
# agac.48 h                  AgAc.48 h
# 20 nm agnp.24 h      20 nm AgNP.24 h
# 20 nm agnp.48 h      20 nm AgNP.48 h
# 110 nm agnp.24 h    110 nm AgNP.24 h
# 110 nm agnp .48 h  110 nm AgNP .48 h
#
#                                                         animal_model  \
# agac.24 h          agac_iv    rat
# agac_iv    rat
# Name: animal_mod...
# agac.48 h          agac_iv    rat
# agac_iv    rat
# Name: animal_mod...
# 20 nm agnp.24 h    agnp20_iv    rat
# agnp20_iv    rat
# Name: animal...
# 20 nm agnp.48 h    agnp20_iv    rat
# agnp20_iv    rat
# Name: animal...
# 110 nm agnp.24 h   agnp110_iv    rat
# agnp110_iv    rat
# Name: anim...
# 110 nm agnp .48 h  agnp110_iv    rat
# agnp110_iv    rat
# Name: anim...
#
#                                                          sample_size  \
# agac.24 h          agac_iv    6
# agac_iv    6
# Name: sample_size, d...
# agac.48 h          agac_iv    6
# agac_iv    6
# Name: sample_size, d...
# 20 nm agnp.24 h    agnp20_iv    6
# agnp20_iv    6
# Name: sample_siz...
# 20 nm agnp.48 h    agnp20_iv    6
# agnp20_iv    6
# Name: sample_siz...
# 110 nm agnp.24 h   agnp110_iv    6
# agnp110_iv    6
# Name: sample_s...
# 110 nm agnp .48 h  agnp110_iv    6
# agnp110_iv    6
# Name: sample_s...
#
#                                                        terminal_time  \
# agac.24 h          agac_iv    24 hours
# agac_iv    48 hours
# Name: ...
# agac.48 h          agac_iv    24 hours
# agac_iv    48 hours
# Name: ...
# 20 nm agnp.24 h    agnp20_iv    24 hours
# agnp20_iv    48 hours
# Na...
# 20 nm agnp.48 h    agnp20_iv    24 hours
# agnp20_iv    48 hours
# Na...
# 110 nm agnp.24 h   agnp110_iv    24 hours
# agnp110_iv    48 hours
# ...
# 110 nm agnp .48 h  agnp110_iv    24 hours
# agnp110_iv    48 hours
# ...
#
#                                                           treatment1  \
# agac.24 h          agac_iv    silver acetate
# agac_iv    silver ac...
# agac.48 h          agac_iv    silver acetate
# agac_iv    silver ac...
# 20 nm agnp.24 h    agnp20_iv    silver nanoparticles (20 nm)
# agnp...
# 20 nm agnp.48 h    agnp20_iv    silver nanoparticles (20 nm)
# agnp...
# 110 nm agnp.24 h   agnp110_iv    silver nanoparticles (110 nm)
# ag...
# 110 nm agnp .48 h  agnp110_iv    silver nanoparticles (110 nm)
# ag...
#
#                                                                dose1  \
# agac.24 h          agac_iv    1
# agac_iv    1
# Name: dose1, dtype: ...
# agac.48 h          agac_iv    1
# agac_iv    1
# Name: dose1, dtype: ...
# 20 nm agnp.24 h    agnp20_iv    1
# agnp20_iv    1
# Name: dose1, dty...
# 20 nm agnp.48 h    agnp20_iv    1
# agnp20_iv    1
# Name: dose1, dty...
# 110 nm agnp.24 h   agnp110_iv    1
# agnp110_iv    1
# Name: dose1, d...
# 110 nm agnp .48 h  agnp110_iv    1
# agnp110_iv    1
# Name: dose1, d...
#
#                                                               units1  \
# agac.24 h          agac_iv    mg/kg
# agac_iv    mg/kg
# Name: units1...
# agac.48 h          agac_iv    mg/kg
# agac_iv    mg/kg
# Name: units1...
# 20 nm agnp.24 h    agnp20_iv    mg/kg
# agnp20_iv    mg/kg
# Name: un...
# 20 nm agnp.48 h    agnp20_iv    mg/kg
# agnp20_iv    mg/kg
# Name: un...
# 110 nm agnp.24 h   agnp110_iv    mg/kg
# agnp110_iv    mg/kg
# Name: ...
# 110 nm agnp .48 h  agnp110_iv    mg/kg
# agnp110_iv    mg/kg
# Name: ...
#
#                                                           treatment2  \
# agac.24 h          agac_iv
# agac_iv
# Name: treatment2, dtyp...
# agac.48 h          agac_iv
# agac_iv
# Name: treatment2, dtyp...
# 20 nm agnp.24 h    agnp20_iv
# agnp20_iv
# Name: treatment2, ...
# 20 nm agnp.48 h    agnp20_iv
# agnp20_iv
# Name: treatment2, ...
# 110 nm agnp.24 h   agnp110_iv
# agnp110_iv
# Name: treatment2...
# 110 nm agnp .48 h  agnp110_iv
# agnp110_iv
# Name: treatment2...
#
#                                                                dose2  \
# agac.24 h          agac_iv
# agac_iv
# Name: dose2, dtype: ob...
# agac.48 h          agac_iv
# agac_iv
# Name: dose2, dtype: ob...
# 20 nm agnp.24 h    agnp20_iv
# agnp20_iv
# Name: dose2, dtype...
# 20 nm agnp.48 h    agnp20_iv
# agnp20_iv
# Name: dose2, dtype...
# 110 nm agnp.24 h   agnp110_iv
# agnp110_iv
# Name: dose2, dty...
# 110 nm agnp .48 h  agnp110_iv
# agnp110_iv
# Name: dose2, dty...
#
#                                                               units2
# agac.24 h          agac_iv
# agac_iv
# Name: units2, dtype: o...
# agac.48 h          agac_iv
# agac_iv
# Name: units2, dtype: o...
# 20 nm agnp.24 h    agnp20_iv
# agnp20_iv
# Name: units2, dtyp...
# 20 nm agnp.48 h    agnp20_iv
# agnp20_iv
# Name: units2, dtyp...
# 110 nm agnp.24 h   agnp110_iv
# agnp110_iv
# Name: units2, dt...
# 110 nm agnp .48 h  agnp110_iv
# agnp110_iv
# Name: units2, dt...  , 'mean_cols': defaultdict(<function <lambda> at 0x00000199B367FD80>, {'Liver': {'mean_col': 'Liver.mean', 'variation_col': 'Liver.SD', 'units': 'mug Ag/g'}, 'Blood': {'mean_col': 'Blood.mean', 'variation_col': 'Blood.SD', 'units': 'mug Ag/g'}, 'Spleen': {'mean_col': 'Spleen.mean', 'variation_col': 'Spleen.SD', 'units': 'mug Ag/g'}, 'Lungs': {'mean_col': 'Lungs.mean', 'variation_col': 'Lungs.SD', 'units': 'mug Ag/g'}, 'Heart': {'mean_col': 'Heart', 'variation_col': None, 'units': 'mug Ag/g'}, 'Kidney': {'mean_col': 'Kidney.mean', 'variation_col': 'Kidney.SD', 'units': 'mug Ag/g'}, 'Brain': {'mean_col': 'Brain', 'variation_col': None, 'units': 'mug Ag/g'}, 'Stomach and Small Intestine': {'mean_col': 'Stomach and Small Intestine.mean', 'variation_col': 'Stomach and Small Intestine.SD', 'units': 'mug Ag/g'}, 'Cecum and Large Intestine': {'mean_col': 'Cecum and Large Intestine.mean', 'variation_col': 'Cecum and Large Intestine.SD', 'units': 'mug Ag/g'}, 'Placenta': {'mean_col': 'Placenta.mean', 'variation_col': 'Placenta.SD', 'units': 'mug Ag/g'}}), 'freq_cols': defaultdict(<function <lambda> at 0x00000199B367FEC0>, {})}
# {'label': 'b', 'caption': 'Percent recovered of administered dose of silver following p.o. administration (10 mg/kg) of AgAc, 20 nm AgNP or 110 nm AgNP to pregnant rats.', 'markdown': '| Tissue | Liver.mean | Liver.SD | Blood.mean | Blood.SD | Spleen.mean | Spleen.SD | Lungs.mean | Lungs.SD | Heart | Kidney.mean | Kidney.SD | Brain | Stomach and Small Intestine.mean | Stomach and Small Intestine.SD | Cecum and Large Intestine.mean | Cecum and Large Intestine.SD | Placenta.mean | Placenta.SD |\n| --- | --- | --- | --- | --- | --- | --- | --- | --- | --- | --- | --- | --- | --- | --- | --- | --- | --- | --- |\n| AgAc.24 h | 0.0836 | 0.0628 | b | nan | 0.00165 | 0.00155 | 0.00403 | 0.000107 | 0.00229 | 0.0286 | 0.0307 |  | 0.524 | 0.841 | 7.06 | 11.48 | 0.112 | 0.00432 |\n| AgAc.48 h | 0.134 | 0.150 | 0.0866 | 0.0117 | 0.00233 | 0.00116 | 0.00628 | nan |  | 0.00785 | 0.00210 |  | 0.0270 | 0.007 | 0.139 | 0.084 | 0.161 | 0.0216 |\n| 20 nm AgNP.24 h | 0.0287 | 0.0143 | 0.0993 | 0.0127 | 0.00540 | 0.00181 | 0.00316 | nan |  | 0.0123 | 0.00380 |  | 0.276 | 0.175 | 15.0 | 12.28 | 0.0908 | 0.00605 |\n| 20 nm AgNP.48 h | 0.0168 | 0.00584 | 0.0525 | 0.00494 | 0.00402 | nan |  | nan |  | 0.00535 | 0.000782 |  | 0.144 | 0.048 | 2.37 | 1.95 | 0.116 | 0.00232 |\n| 110 nm AgNP.24 h | 0.00967 | 0.00739 |  | nan | 0.00402 | nan |  | nan |  | 0.00631 | 0.00260 |  | 0.239 | 0.214 | 0.975 | 0.130 | 0.0372 | 0.0258 |\n| 110 nm AgNP .48 h | 0.00753 | 0.00139 |  | nan |  | nan |  | nan |  | 0.00444 | 0.00107 |  | 0.0079 | 0.004 | 0.314 | 0.151 | 0.0638 | 0.0104 |', 'footnotes': ['All data are reported as Mean +- SD (n= 3)', 'Only one rat had concentrations > quantitation limit.', '<LOQ = below limit of quantitation = quantitation limit; 0.0125 mug/g for tissues.'], 'col_labels': [['Liver.mean', 'biomarker', 'Liver', 'mean', 'percent'], ['Liver.SD', 'biomarker', 'Liver', 'variation', 'percent'], ['Blood.mean', 'biomarker', 'Blood', 'mean', 'percent'], ['Blood.SD', 'biomarker', 'Blood', 'variation', 'percent'], ['Spleen.mean', 'biomarker', 'Spleen', 'mean', 'percent'], ['Spleen.SD', 'biomarker', 'Spleen', 'variation', 'percent'], ['Lungs.mean', 'biomarker', 'Lungs', 'mean', 'percent'], ['Lungs.SD', 'biomarker', 'Lungs', 'variation', 'percent'], ['Kidney.mean', 'biomarker', 'Kidney', 'mean', 'percent'], ['Kidney.SD', 'biomarker', 'Kidney', 'variation', 'percent'], ['Stomach and Small Intestine.mean', 'biomarker', 'Stomach and Small Intestine', 'mean', 'percent'], ['Stomach and Small Intestine.SD', 'biomarker', 'Stomach and Small Intestine', 'variation', 'percent'], ['Cecum and Large Intestine.mean', 'biomarker', 'Cecum and Large Intestine', 'mean', 'percent'], ['Cecum and Large Intestine.SD', 'biomarker', 'Cecum and Large Intestine', 'variation', 'percent'], ['Placenta.mean', 'biomarker', 'Placenta', 'mean', 'percent'], ['Placenta.SD', 'biomarker', 'Placenta', 'variation', 'percent']], 'group_cols': [], 'biomarker_cols': [{'column': 'Liver.mean', 'label': 'biomarker', 'type': 'mean', 'units': 'percent', 'name': 'Liver'}, {'column': 'Liver.SD', 'label': 'biomarker', 'type': 'variation', 'units': 'percent', 'name': 'Liver'}, {'column': 'Blood.mean', 'label': 'biomarker', 'type': 'mean', 'units': 'percent', 'name': 'Blood'}, {'column': 'Blood.SD', 'label': 'biomarker', 'type': 'variation', 'units': 'percent', 'name': 'Blood'}, {'column': 'Spleen.mean', 'label': 'biomarker', 'type': 'mean', 'units': 'percent', 'name': 'Spleen'}, {'column': 'Spleen.SD', 'label': 'biomarker', 'type': 'variation', 'units': 'percent', 'name': 'Spleen'}, {'column': 'Lungs.mean', 'label': 'biomarker', 'type': 'mean', 'units': 'percent', 'name': 'Lungs'}, {'column': 'Lungs.SD', 'label': 'biomarker', 'type': 'variation', 'units': 'percent', 'name': 'Lungs'}, {'column': 'Kidney.mean', 'label': 'biomarker', 'type': 'mean', 'units': 'percent', 'name': 'Kidney'}, {'column': 'Kidney.SD', 'label': 'biomarker', 'type': 'variation', 'units': 'percent', 'name': 'Kidney'}, {'column': 'Stomac ...
# group 0          AgAc.24 h     0.0836   0.0628          b      nan
# group 1          AgAc.48 h      0.134    0.150     0.0866   0.0117
# group 2    20 nm AgNP.24 h     0.0287   0.0143     0.0993   0.0127
# group 3    20 nm AgNP.48 h     0.0168  0.00584     0.0525  0.00494
# group 4   110 nm AgNP.24 h    0.00967  0.00739                 nan
# group 5  110 nm AgNP .48 h    0.00753  0.00139                 nan
#
#         Spleen.mean Spleen.SD Lungs.mean  Lungs.SD    Heart Kidney.mean  \
# group 0     0.00165   0.00155    0.00403  0.000107  0.00229      0.0286
# group 1     0.00233   0.00116    0.00628       nan              0.00785
# group 2     0.00540   0.00181    0.00316       nan               0.0123
# group 3     0.00402       nan                  nan              0.00535
# group 4     0.00402       nan                  nan              0.00631
# group 5                   nan                  nan              0.00444
#
#         Kidney.SD Brain Stomach and Small Intestine.mean  \
# group 0    0.0307                                  0.524
# group 1   0.00210                                 0.0270
# group 2   0.00380                                  0.276
# group 3  0.000782                                  0.144
# group 4   0.00260                                  0.239
# group 5   0.00107                                 0.0079
#
#         Stomach and Small Intestine.SD Cecum and Large Intestine.mean  \
# group 0                          0.841                           7.06
# group 1                          0.007                          0.139
# group 2                          0.175                           15.0
# group 3                          0.048                           2.37
# group 4                          0.214                          0.975
# group 5                          0.004                          0.314
#
#         Cecum and Large Intestine.SD Placenta.mean Placenta.SD
# group 0                        11.48         0.112     0.00432
# group 1                        0.084         0.161      0.0216
# group 2                        12.28        0.0908     0.00605
# group 3                         1.95         0.116     0.00232
# group 4                        0.130        0.0372      0.0258
# group 5                        0.151        0.0638      0.0104  , 'table_groups':            group                                       animal_model  \
# group 0  Group 0  control_iv    rat
# control_iv    rat
# Name: anim...
# group 1  Group 1  control_po    rat
# control_po    rat
# Name: anim...
# group 2  Group 2  agac_iv    rat
# agac_iv    rat
# Name: animal_mod...
# group 3  Group 3  agac_po    rat
# agac_po    rat
# Name: animal_mod...
# group 4  Group 4  agnp20_iv    rat
# agnp20_iv    rat
# Name: animal...
# group 5  Group 5  agnp20_po    rat
# agnp20_po    rat
# Name: animal...
#
#                                                sample_size  \
# group 0  control_iv    6
# control_iv    6
# Name: sample_s...
# group 1  control_po    6
# control_po    6
# Name: sample_s...
# group 2  agac_iv    6
# agac_iv    6
# Name: sample_size, d...
# group 3  agac_po    6
# agac_po    6
# Name: sample_size, d...
# group 4  agnp20_iv    6
# agnp20_iv    6
# Name: sample_siz...
# group 5  agnp20_po    6
# agnp20_po    6
# Name: sample_siz...
#
#                                              terminal_time  \
# group 0  control_iv    24 hours
# control_iv    48 hours
# ...
# group 1  control_po    24 hours
# control_po    48 hours
# ...
# group 2  agac_iv    24 hours
# agac_iv    48 hours
# Name: ...
# group 3  agac_po    24 hours
# agac_po    48 hours
# Name: ...
# group 4  agnp20_iv    24 hours
# agnp20_iv    48 hours
# Na...
# group 5  agnp20_po    24 hours
# agnp20_po    48 hours
# Na...
#
#                                                 treatment1  \
# group 0  control_iv
# control_iv
# Name: treatment1...
# group 1  control_po
# control_po
# Name: treatment1...
# group 2  agac_iv    silver acetate
# agac_iv    silver ac...
# group 3  agac_po    silver acetate
# agac_po    silver ac...
# group 4  agnp20_iv    silver nanoparticles (20 nm)
# agnp...
# group 5  agnp20_po    silver nanoparticles (20 nm)
# agnp...
#
#                                                      dose1  \
# group 0  control_iv
# control_iv
# Name: dose1, dty...
# group 1  control_po
# control_po
# Name: dose1, dty...
# group 2  agac_iv    1
# agac_iv    1
# Name: dose1, dtype: ...
# group 3  agac_po    10
# agac_po    10
# Name: dose1, dtype...
# group 4  agnp20_iv    1
# agnp20_iv    1
# Name: dose1, dty...
# group 5  agnp20_po    10
# agnp20_po    10
# Name: dose1, d...
#
#                                                     units1  \
# group 0  control_iv
# control_iv
# Name: units1, dt...
# group 1  control_po
# control_po
# Name: units1, dt...
# group 2  agac_iv    mg/kg
# agac_iv    mg/kg
# Name: units1...
# group 3  agac_po    mg/kg
# agac_po    mg/kg
# Name: units1...
# group 4  agnp20_iv    mg/kg
# agnp20_iv    mg/kg
# Name: un...
# group 5  agnp20_po    mg/kg
# agnp20_po    mg/kg
# Name: un...
#
#                                                 treatment2  \
# group 0  control_iv
# control_iv
# Name: treatment2...
# group 1  control_po
# control_po
# Name: treatment2...
# group 2  agac_iv
# agac_iv
# Name: treatment2, dtyp...
# group 3  agac_po
# agac_po
# Name: treatment2, dtyp...
# group 4  agnp20_iv
# agnp20_iv
# Name: treatment2, ...
# group 5  agnp20_po
# agnp20_po
# Name: treatment2, ...
#
# ...
# group 0                         PAI-1 (mean                             std.)
# group 1                           vWF (mean                             std.)
#
#         Vehicle.24 h.i.v..mean Vehicle.24 h.i.v..SD  \
# group 0                  1,314                  156
# group 1                    222                 49.6
#
#         Vehicle.48 h.1,632+-1073.mean Vehicle.48 h.1,632+-1073.SD  \
# group 0                           272                         236
# group 1                                                       nan
#
#         AgAc.24 h.1,328+-437.mean AgAc.24 h.1,328+-437.SD  \
# group 0                       258                     135
# group 1                                               nan
#
#         AgAc.48 h.970+-266.mean AgAc.48 h.970+-266.SD  ...  \
# group 0                     502                   167  ...
# group 1                                           nan  ...
#
#         110 nm AgNP.48 h.406+-72.9.SD Vehicle.24 h.p.o..mean  \
# group 0                          77.1                    315
# group 1                           nan                   71.5
#
#         Vehicle.24 h.p.o..SD Vehicle.48 h.406+-73.mean  \
# group 0                 68.4                      88.1
# group 1                  101
#
#         Vehicle.48 h.406+-73.SD AgAc.24 h.398+-53.3.mean  \
# group 0                    77.1                      119
# group 1                     nan
#
#         AgAc.24 h.398+-53.3.SD AgAc.48 h.151+-95.6.mean  \
# group 0                   29.6                     26.5
# group 1                    nan
#
#         AgAc.48 h.151+-95.6.SD 110 nm AgNP.24 h.307+-56.2
# group 0                   41.7                         ND
# group 1                    nan
#
# [2 rows x 26 columns], 'table_groups':            group animal_model sample_size terminal_time treatment1 dose1  \
# group 0  Group 0         None        None          None       None  None
# group 1  Group 1         None        None          None       None  None
#
#         units1 treatment2 dose2 units2
# group 0   None       None  None   None
# group 1   None       None  None   None  , 'mean_cols': defaultdict(<function <lambda> at 0x00000199B3A7C040>, {'PAI-1': {'mean_col': '110 nm AgNP.24 h.307+-56.2', 'variation_col': 'AgAc.48 h.151+-95.6.SD', 'units': 'ng/ml'}, 'vWF': {'mean_col': '110 nm AgNP.24 h.307+-56.2', 'variation_col': 'AgAc.48 h.151+-95.6.SD', 'units': 'ng/ml'}}), 'freq_cols': defaultdict(<function <lambda> at 0x00000199B3A7C0E0>, {})}
# {'label': 'b', 'caption': 'Cytokine/Chemokine expression for pregnant rats exposed i.v. to AgAc, 20 nm AgNP and vehicle after 24 or 48 h. All data are reported as mean +- SEM pg/ml of plasma of duplicates.', 'markdown': '| Cytokine | Vehicle.24 h | Vehicle.48 h.mean | Vehicle.48 h.SD | AgAc.24 h.mean | AgAc.24 h.SD | AgAc.48 h.mean | AgAc.48 h.SD | 20 nm AgNP.24 h.mean | 20 nm AgNP.24 h.SD | 20 nm AgNP .48 h |\n| --- | --- | --- | --- | --- | --- | --- | --- | --- | --- | --- |\n| Eotaxin | 146 | 336 | 475 | ND | nan | ND | nan | ND | nan | 55.3 |\n| IL-1beta | ND | ND | nan | ND | nan | ND | nan | ND | nan | ND |\n| IL-4 | 263 | 779 | 1,072 | 44.5 | 77.2 | ND | nan | ND | nan | ND |\n| IL-5 | ND | ND | nan | ND | nan | ND | nan | ND | nan | ND |\n| IL-6 | 489 | 3,561 | 5,036 | 91.5 | 158 | 4.66 | 8.07 | 30.3 | 27.2 | ND |\n| MCP-1 | 78.1 | 57.7 | 81.6 | 57.4 | 52.1 | 42.2 | 36.5 | 62.8 | 42.7 | ND |\n| TNF-alpha | ND | ND | nan | ND | nan | ND | nan | ND | nan | ND |\n| VEGF | ND | ND | nan | ND | nan | ND | nan | ND | nan | ND |', 'footnotes': ['All data are reported as Mean +- SD pg/ml of plasma of duplicates (n= 3)', 'ND = not detected', 'n=1 (for vehicle - Error for all readings on rats 2 and 3, for 20 nm AgNP 48 h - only one sample analyzed.)'], 'col_labels': [['Vehicle.24 h', 'biomarker', 'Vehicle.24 h', 'mean', 'pg/ml'], ['Vehicle.48 h.mean', 'biomarker', 'Vehicle.48 h', 'mean', 'pg/ml'], ['Vehicle.48 h.SD', 'biomarker', 'Vehicle.48 h', 'variation', 'pg/ml'], ['AgAc.24 h.mean', 'biomarker', 'AgAc.24 h', 'mean', 'pg/ml'], ['AgAc.24 h.SD', 'biomarker', 'AgAc.24 h', 'variation', 'pg/ml'], ['AgAc.48 h.mean', 'biomarker', 'AgAc.48 h', 'mean', 'pg/ml'], ['AgAc.48 h.SD', 'biomarker', 'AgAc.48 h', 'variation', 'pg/ml'], ['20 nm AgNP.24 h.mean', 'biomarker', '20 nm AgNP.24 h', 'mean', 'pg/ml'], ['20 nm AgNP.24 h.SD', 'biomarker', '20 nm AgNP.24 h', 'variation', 'pg/ml'], ['20 nm AgNP .48 h', 'biomarker', '20 nm AgNP .48 h', 'mean', 'pg/ml']], 'group_cols': [], 'biomarker_cols': [{'column': 'Vehicle.24 h', 'label': 'biomarker', 'type': 'mean', 'units': 'pg/ml', 'name': 'Vehicle.24 h'}, {'column': 'Vehicle.48 h.mean', 'label': 'biomarker', 'type': 'mean', 'units': 'pg/ml', 'name': 'Vehicle.48 h'}, {'column': 'Vehicle.48 h.SD', 'label': 'biomarker', 'type': 'variation', 'units': 'pg/ml', 'name': 'Vehicle.48 h'}, {'column': 'AgAc.24 h.mean', 'label': 'biomarker', 'type': 'mean', 'units': 'pg/ml', 'name': 'AgAc.24 h'}, {'column': 'AgAc.24 h.SD', 'label': 'biomarker', 'type': 'variation', 'units': 'pg/ml', 'name': 'AgAc.24 h'}, {'column': 'AgAc.48 h.mean', 'label': 'biomarker', 'type': 'mean', 'units': 'pg/ml', 'name': 'AgAc.48 h'}, {'column': 'AgAc.48 h.SD', 'label': 'biomarker', 'type': 'variation', 'units': 'pg/ml', 'name': 'AgAc.48 h'}, {'column': '20 nm AgNP.24 h.mean', 'label': 'biomarker', 'type': 'mean', 'units': 'pg/ml', 'name': '20 nm AgNP.24 h'}, {'column': '20 nm AgNP.24 h.SD', 'label': 'biomarker', 'type': 'variation', 'units': 'pg/ml', 'name': '20 nm AgNP.24 h'}, {'column': '20 nm AgNP .48 h', 'label': 'biomarker', 'type': 'mean', 'units': 'pg/ml', 'name': '20 nm AgNP .48 h'}], 'df':           Cytokine Vehicle.24 h Vehicle.48 h.mean Vehicle.48 h.SD  \
# group 0    Eotaxin          146               336             475
# group 1   IL-1beta           ND                ND             nan
# group 2       IL-4          263               779           1,072
# group 3       IL-5           ND                ND             nan
# group 4       IL-6          489             3,561           5,036
# group 5      MCP-1         78.1              57.7            81.6
# group 6  TNF-alpha           ND                ND             nan
# group 7       VEGF           ND                ND             nan
#
#         AgAc.24 h.mean AgAc.24 h.SD AgAc.48 h.mean AgAc.48 h.SD  \
# group 0             ND          nan             ND          nan
# group 1             ND          nan             ND          nan
# group 2           44.5         77.2             ND          nan
# group 3             ND          nan             ND          nan
# group 4           91.5          158           4.66         8.07
# group 5           57.4         52.1           42.2         36.5
# group 6             ND          nan             ND          nan
# group 7             ND          nan             ND          nan
#
#         20 nm AgNP.24 h.mean 20 nm AgNP.24 h.SD 20 nm AgNP .48 h
# group 0                   ND                nan             55.3
# group 1                   ND                nan               ND
# group 2                   ND                nan               ND
# group 3                   ND                nan               ND
# group 4                 30.3               27.2               ND
# group 5                 62.8               42.7               ND
# group 6                   ND                nan               ND
# group 7                   ND                nan               ND  , 'table_groups':            group                                       animal_model  \
# group 0  Group 0  control_iv    rat
# control_iv    rat
# Name: anim...
# group 1  Group 1  control_po    rat
# control_po    rat
# Name: anim...
# group 2  Group 2  agac_iv    rat
# agac_iv    rat
# Name: animal_mod...
# group 3  Group 3  agac_po    rat
# agac_po    rat
# Name: animal_mod...
# group 4  Group 4  agnp20_iv    rat
# agnp20_iv    rat
# Name: animal...
# group 5  Group 5  agnp20_po    rat
# agnp20_po    rat
# Name: animal...
# group 6  Group 6  agnp110_iv    rat
# agnp110_iv    rat
# Name: anim...
# group 7  Group 7  agnp110_po    rat
# agnp110_po    rat
# Name: anim...
#
#                                                sample_size  \
# group 0  control_iv    6
# control_iv    6
# Name: sample_s...
# group 1  control_po    6
# control_po    6
# Name: sample_s...
# group 2  agac_iv    6
# agac_iv    6
# Name: sample_size, d...
# group 3  agac_po    6
# agac_po    6
# Name: sample_size, d...
# group 4  agnp20_iv    6
# agnp20_iv    6
# Name: sample_siz...
# group 5  agnp20_po    6
# agnp20_po    6
# Name: sample_siz...
# group 6  agnp110_iv    6
# agnp110_iv    6
# Name: sample_s...
# group 7  agnp110_po    6
# agnp110_po    6
# Name: sample_s...
#
#                                              terminal_time  \
# group 0  control_iv    24 hours
# control_iv    48 hours
# ...
# group 1  control_po    24 hours
# control_po    48 hours
# ...
# group 2  agac_iv    24 hours
# agac_iv    48 hours
# Name: ...
# group 3  agac_po    24 hours
# agac_po    48 hours
# Name: ...
# group 4  agnp20_iv    24 hours
# agnp20_iv    48 hours
# Na...
# group 5  agnp20_po    24 hours
# agnp20_po    48 hours
# Na...
# group 6  agnp110_iv    24 hours
# agnp110_iv    48 hours
# ...
# group 7  agnp110_po    24 hours
# agnp110_po    48 hours
# ...
#
#                                                 treatment1  \
# group 0  control_iv
# control_iv
# Name: treatment1...
# group 1  control_po
# control_po
# Name: treatment1...
# group 2  agac_iv    silver acetate
# agac_iv    silver ac...
# group 3  agac_po    silver acetate
# agac_po    silver ac...
# group 4  agnp20_iv    silver nanoparticles (20 nm)
# agnp...
# group 5  agnp20_po    silver nanoparticles (20 nm)
# agnp...
# group 6  agnp110_iv    silver nanoparticles (110 nm)
# ag...
# group 7  agnp110_po    silver nanoparticles (110 nm)
# ag...
#
#                                                      dose1  \
# group 0  control_iv
# control_iv
# Name: dose1, dty...
# group 1  control_po
# control_po
# Name: dose1, dty...
# group 2  agac_iv    1
# agac_iv    1
# Name: dose1, dtype: ...
# group 3  agac_po    10
# agac_po    10
# Name: dose1, dtype...
# group 4  agnp20_iv    1
# agnp20_iv    1
# Name: dose1, dty...
# group 5  agnp20_po    10
# agnp20_po    10
# Name: dose1, d...
# group 6  agnp110_iv    1
# agnp110_iv    1
# Name: dose1, d...
# group 7  agnp110_po    10
# agnp110_po    10
# Name: dose1,...
#
#                                                     units1  \
# group 0  control_iv
# control_iv
# Name: units1, dt...
# group 1  control_po
# control_po
# Name: units1, dt...
# group 2  agac_iv    mg/kg
# agac_iv    mg/kg
# Name: units1...
# group 3  agac_po    mg/kg
# agac_po    mg/kg
# Name: units1...
# group 4  agnp20_iv    mg/kg
# agnp20_iv    mg/kg
# Name: un...
# group 5  agnp20_po    mg/kg
# agnp20_po    mg/kg
# Name: un...
# group 6  agnp110_iv    mg/kg
# agnp110_iv    mg/kg
# Name: ...
# group 7  agnp110_po    mg/kg
# agnp110_po    mg/kg
# Name: ...
#
#                                                 treatment2  \
# group 0  control_iv
# control_iv
# Name: treatment2...
# group 1  control_po
# control_po
# Name: treatment2...
# group 2  agac_iv
# agac_iv
# Name: treatment2, dtyp...
# group 3  agac_po
# agac_po
# Name: treatment2, dtyp...
# group 4  agnp20_iv
# agnp20_iv
# Name: treatment2, ...
# group 5  agnp20_po
# agnp20_po
# Name: treatment2, ...
# group 6  agnp110_iv
# agnp110_iv
# Name: treatment2...
# group 7  agnp110_po
# agnp110_po
# Name: treatment2...
#
#                                                      dose2  \
# group 0  control_iv
# control_iv
# Name: dose2, dty...
# group 1  control_po
# control_po
# Name: dose2, dty...
# group 2  agac_iv
# agac_iv
# Name: dose2, dtype: ob...
# group 3  agac_po
# agac_po
# Name: dose2, dtype: ob...
# group 4  agnp20_iv
# agnp20_iv
# Name: dose2, dtype...
# group 5  agnp20_po
# agnp20_po
# Name: dose2, dtype...
# group 6  agnp110_iv
# agnp110_iv
# Name: dose2, dty...
# group 7  agnp110_po
# agnp110_po
# Name: dose2, dty...
#
#                                                     units2
# group 0  control_iv
# control_iv
# Name: units2, dt...
# group 1  control_po
# control_po
# Name: units2, dt...
# group 2  agac_iv
# agac_iv
# Name: units2, dtype: o...
# group 3  agac_po
# agac_po
# Name: units2, dtype: o...
# group 4  agnp20_iv
# agnp20_iv
# Name: units2, dtyp...
# group 5  agnp20_po
# agnp20_po
# Name: units2, dtyp...
# group 6  agnp110_iv
# agnp110_iv
# Name: units2, dt...
# group 7  agnp110_po
# agnp110_po
# Name: units2, dt...  , 'mean_cols': defaultdict(<function <lambda> at 0x00000199B3A7C180>, {'Vehicle.24 h': {'mean_col': 'Vehicle.24 h', 'variation_col': None, 'units': 'pg/ml'}, 'Vehicle.48 h': {'mean_col': 'Vehicle.48 h.mean', 'variation_col': 'Vehicle.48 h.SD', 'units': 'pg/ml'}, 'AgAc.24 h': {'mean_col': 'AgAc.24 h.mean', 'variation_col': 'AgAc.24 h.SD', 'units': 'pg/ml'}, 'AgAc.48 h': {'mean_col': 'AgAc.48 h.mean', 'variation_col': 'AgAc.48 h.SD', 'units': 'pg/ml'}, '20 nm AgNP.24 h': {'mean_col': '20 nm AgNP.24 h.mean', 'variation_col': '20 nm AgNP.24 h.SD', 'units': 'pg/ml'}, '20 nm AgNP .48 h': {'mean_col': '20 nm AgNP .48 h', 'variation_col': None, 'units': 'pg/ml'}}), 'freq_cols': defaultdict(<function <lambda> at 0x00000199B3A7C220>, {})}

# %%
for tid, info in formatted_tables.items():
    if info["label"] != "b": continue
    print(info["output_mean"])
    print(info["output_freq"])
# Out:
#                                          Animal Model  \
# 0   control_iv    rat
# control_iv    rat
# Name: anim...
# 1   control_iv    rat
# control_iv    rat
# Name: anim...
# 2   control_iv    rat
# control_iv    rat
# Name: anim...
# 3   control_iv    rat
# control_iv    rat
# Name: anim...
# 4   control_iv    rat
# control_iv    rat
# Name: anim...
# ..                                                ...
# 77  agnp20_po    rat
# agnp20_po    rat
# Name: animal...
# 78  agnp20_po    rat
# agnp20_po    rat
# Name: animal...
# 79  agnp20_po    rat
# agnp20_po    rat
# Name: animal...
# 80  agnp20_po    rat
# agnp20_po    rat
# Name: animal...
# 81  agnp20_po    rat
# agnp20_po    rat
# Name: animal...
#
#                                           Sample Size  \
# 0   control_iv    6
# control_iv    6
# Name: sample_s...
# 1   control_iv    6
# control_iv    6
# Name: sample_s...
# 2   control_iv    6
# control_iv    6
# Name: sample_s...
# 3   control_iv    6
# control_iv    6
# Name: sample_s...
# 4   control_iv    6
# control_iv    6
# Name: sample_s...
# ..                                                ...
# 77  agnp20_po    6
# agnp20_po    6
# Name: sample_siz...
# 78  agnp20_po    6
# agnp20_po    6
# Name: sample_siz...
# 79  agnp20_po    6
# agnp20_po    6
# Name: sample_siz...
# 80  agnp20_po    6
# agnp20_po    6
# Name: sample_siz...
# 81  agnp20_po    6
# agnp20_po    6
# Name: sample_siz...
#
#                                           Treatment 1  \
# 0   control_iv
# control_iv
# Name: treatment1...
# 1   control_iv
# control_iv
# Name: treatment1...
# 2   control_iv
# control_iv
# Name: treatment1...
# 3   control_iv
# control_iv
# Name: treatment1...
# 4   control_iv
# control_iv
# Name: treatment1...
# ..                                                ...
# 77  agnp20_po    silver nanoparticles (20 nm)
# agnp...
# 78  agnp20_po    silver nanoparticles (20 nm)
# agnp...
# 79  agnp20_po    silver nanoparticles (20 nm)
# agnp...
# 80  agnp20_po    silver nanoparticles (20 nm)
# agnp...
# 81  agnp20_po    silver nanoparticles (20 nm)
# agnp...
#
#                                                Dose 1  \
# 0   control_iv
# control_iv
# Name: dose1, dty...
# 1   control_iv
# control_iv
# Name: dose1, dty...
# 2   control_iv
# control_iv
# Name: dose1, dty...
# 3   control_iv
# control_iv
# Name: dose1, dty...
# 4   control_iv
# control_iv
# Name: dose1, dty...
# ..                                                ...
# 77  agnp20_po    10
# agnp20_po    10
# Name: dose1, d...
# 78  agnp20_po    10
# agnp20_po    10
# Name: dose1, d...
# 79  agnp20_po    10
# agnp20_po    10
# Name: dose1, d...
# 80  agnp20_po    10
# agnp20_po    10
# Name: dose1, d...
# 81  agnp20_po    10
# agnp20_po    10
# Name: dose1, d...
#
#                                               Units 1  \
# 0   control_iv
# control_iv
# Name: units1, dt...
# 1   control_iv
# control_iv
# Name: units1, dt...
# 2   control_iv
# control_iv
# Name: units1, dt...
# 3   control_iv
# control_iv
# Name: units1, dt...
# 4   control_iv
# control_iv
# Name: units1, dt...
# ..                                                ...
# 77  agnp20_po    mg/kg
# agnp20_po    mg/kg
# Name: un...
# 78  agnp20_po    mg/kg
# agnp20_po    mg/kg
# Name: un...
# 79  agnp20_po    mg/kg
# agnp20_po    mg/kg
# Name: un...
# 80  agnp20_po    mg/kg
# agnp20_po    mg/kg
# Name: un...
# 81  agnp20_po    mg/kg
# agnp20_po    mg/kg
# Name: un...
#
#                                           Treatment 2  \
# 0   control_iv
# control_iv
# Name: treatment2...
# 1   control_iv
# control_iv
# Name: treatment2...
# 2   control_iv
# control_iv
# Name: treatment2...
# 3   control_iv
# control_iv
# Name: treatment2...
# 4   control_iv
# control_iv
# Name: treatment2...
# ..                                                ...
# 77  agnp20_po
# agnp20_po
# Name: treatment2, ...
# 78  agnp20_po
# agnp20_po
# Name: treatment2, ...
# 79  agnp20_po
# agnp20_po
# Name: treatment2, ...
# 80  agnp20_po
# agnp20_po
# Name: treatment2, ...
# 81  agnp20_po
# agnp20_po
# Name: treatment2, ...
#
#                                                Dose 2  \
# 0   control_iv
# control_iv
# Name: dose2, dty...
# 1   control_iv
# control_iv
# Name: dose2, dty...
# 2   control_iv
# control_iv
# Name: dose2, dty...
# 3   control_iv
# control_iv
# Name: dose2, dty...
# 4   control_iv
# control_iv
# Name: dose2, dty...
# ..                                                ...
# 77  agnp20_po
# agnp20_po
# Name: dose2, dtype...
# 78  agnp20_po
# agnp20_po
# Name: dose2, dtype...
# 79  agnp20_po
# agnp20_po
# Name: dose2, dtype...
# 80  agnp20_po
# agnp20_po
# Name: dose2, dtype...
# 81  agnp20_po
# agnp20_po
# Name: dose2, dtype...
#
#                                               Units 2  \
# 0   control_iv
# control_iv
# Name: units2, dt...
# 1   control_iv
# control_iv
# Name: units2, dt...
# 2   control_iv
# control_iv
# Name: units2, dt...
# 3   control_iv
# control_iv
# Name: units2, dt...
# 4   control_iv
# control_iv
# Name: units2, dt...
# ..                                                ...
# 77  agnp20_po
# agnp20_po
# Name: units2, dtyp...
# 78  agnp20_po
# agnp20_po
# Name: units2, dtyp...
# 79  agnp20_po
# agnp20_po
# Name: units2, dtyp...
# 80  agnp20_po
# agnp20_po
# Name: units2, dtyp...
# 81  agnp20_po
# agnp20_po
# Name: units2, dtyp...
#
#                                         Terminal Time  \
# 0   control_iv    24 hours
# control_iv    48 hours
# ...
# 1   control_iv    24 hours
# control_iv    48 hours
# ...
# 2   control_iv    24 hours
# control_iv    48 hours
# ...
# 3   control_iv    24 hours
# control_iv    48 hours
# ...
# 4   control_iv    24 hours
# control_iv    48 hours
# ...
# ..                                                ...
# 77  agnp20_po    24 hours
# agnp20_po    48 hours
# Na...
# 78  agnp20_po    24 hours
# agnp20_po    48 hours
# Na...
# 79  agnp20_po    24 hours
# agnp20_po    48 hours
# Na...
# 80  agnp20_po    24 hours
# agnp20_po    48 hours
# Na...
# 81  agnp20_po    24 hours
# agnp20_po    48 hours
# Na...
#
#                       Biomarker   Value  Units Variation
# 0                         Liver    1.03  mug/g     0.399
# 1                         Blood   0.663  mug/g     0.195
# 2                        Spleen    2.95  mug/g     0.927
# 3                         Lungs    1.38  mug/g     0.958
# 4                         Heart   0.162  mug/g    0.0306
# ..                          ...     ...    ...       ...
# 77                         Bone   0.136  mug/g    0.0299
# 78  Stomach and Small Intestine   0.136  mug/g    0.0376
# 79    Cecum and Large Intestine   0.459  mug/g     0.153
# 80                     Pancreas  0.0831  mug/g    0.0485
# 81                     Placenta    1.15  mug/g     0.239
#
# [82 rows x 13 columns]
# Empty DataFrame
# Columns: []
# Index: []
#                                          Animal Model  \
# 0   agac_iv    rat
# agac_iv    rat
# Name: animal_mod...
# 1   agac_iv    rat
# agac_iv    rat
# Name: animal_mod...
# 2   agac_iv    rat
# agac_iv    rat
# Name: animal_mod...
# 3   agac_iv    rat
# agac_iv    rat
# Name: animal_mod...
# 4   agac_iv    rat
# agac_iv    rat
# Name: animal_mod...
# ..                                                ...
# 77  agnp110_iv    rat
# agnp110_iv    rat
# Name: anim...
# 78  agnp110_iv    rat
# agnp110_iv    rat
# Name: anim...
# 79  agnp110_iv    rat
# agnp110_iv    rat
# Name: anim...
# 80  agnp110_iv    rat
# agnp110_iv    rat
# Name: anim...
# 81  agnp110_iv    rat
# agnp110_iv    rat
# Name: anim...
#
#                                           Sample Size  \
# 0   agac_iv    6
# agac_iv    6
# Name: sample_size, d...
# 1   agac_iv    6
# agac_iv    6
# Name: sample_size, d...
# 2   agac_iv    6
# agac_iv    6
# Name: sample_size, d...
# 3   agac_iv    6
# agac_iv    6
# Name: sample_size, d...
# 4   agac_iv    6
# agac_iv    6
# Name: sample_size, d...
# ..                                                ...
# 77  agnp110_iv    6
# agnp110_iv    6
# Name: sample_s...
# 78  agnp110_iv    6
# agnp110_iv    6
# Name: sample_s...
# 79  agnp110_iv    6
# agnp110_iv    6
# Name: sample_s...
# 80  agnp110_iv    6
# agnp110_iv    6
# Name: sample_s...
# 81  agnp110_iv    6
# agnp110_iv    6
# Name: sample_s...
#
#                                           Treatment 1  \
# 0   agac_iv    silver acetate
# agac_iv    silver ac...
# 1   agac_iv    silver acetate
# agac_iv    silver ac...
# 2   agac_iv    silver acetate
# agac_iv    silver ac...
# 3   agac_iv    silver acetate
# agac_iv    silver ac...
# 4   agac_iv    silver acetate
# agac_iv    silver ac...
# ..                                                ...
# 77  agnp110_iv    silver nanoparticles (110 nm)
# ag...
# 78  agnp110_iv    silver nanoparticles (110 nm)
# ag...
# 79  agnp110_iv    silver nanoparticles (110 nm)
# ag...
# 80  agnp110_iv    silver nanoparticles (110 nm)
# ag...
# 81  agnp110_iv    silver nanoparticles (110 nm)
# ag...
#
#                                                Dose 1  \
# 0   agac_iv    1
# agac_iv    1
# Name: dose1, dtype: ...
# 1   agac_iv    1
# agac_iv    1
# Name: dose1, dtype: ...
# 2   agac_iv    1
# agac_iv    1
# Name: dose1, dtype: ...
# 3   agac_iv    1
# agac_iv    1
# Name: dose1, dtype: ...
# 4   agac_iv    1
# agac_iv    1
# Name: dose1, dtype: ...
# ..                                                ...
# 77  agnp110_iv    1
# agnp110_iv    1
# Name: dose1, d...
# 78  agnp110_iv    1
# agnp110_iv    1
# Name: dose1, d...
# 79  agnp110_iv    1
# agnp110_iv    1
# Name: dose1, d...
# 80  agnp110_iv    1
# agnp110_iv    1
# Name: dose1, d...
# 81  agnp110_iv    1
# agnp110_iv    1
# Name: dose1, d...
#
#                                               Units 1  \
# 0   agac_iv    mg/kg
# agac_iv    mg/kg
# Name: units1...
# 1   agac_iv    mg/kg
# agac_iv    mg/kg
# Name: units1...
# 2   agac_iv    mg/kg
# agac_iv    mg/kg
# Name: units1...
# 3   agac_iv    mg/kg
# agac_iv    mg/kg
# Name: units1...
# 4   agac_iv    mg/kg
# agac_iv    mg/kg
# Name: units1...
# ..                                                ...
# 77  agnp110_iv    mg/kg
# agnp110_iv    mg/kg
# Name: ...
# 78  agnp110_iv    mg/kg
# agnp110_iv    mg/kg
# Name: ...
# 79  agnp110_iv    mg/kg
# agnp110_iv    mg/kg
# Name: ...
# 80  agnp110_iv    mg/kg
# agnp110_iv    mg/kg
# Name: ...
# 81  agnp110_iv    mg/kg
# agnp110_iv    mg/kg
# Name: ...
#
#                                           Treatment 2  \
# 0   agac_iv
# agac_iv
# Name: treatment2, dtyp...
# 1   agac_iv
# agac_iv
# Name: treatment2, dtyp...
# 2   agac_iv
# agac_iv
# Name: treatment2, dtyp...
# 3   agac_iv
# agac_iv
# Name: treatment2, dtyp...
# 4   agac_iv
# agac_iv
# Name: treatment2, dtyp...
# ..                                                ...
# 77  agnp110_iv
# agnp110_iv
# Name: treatment2...
# 78  agnp110_iv
# agnp110_iv
# Name: treatment2...
# 79  agnp110_iv
# agnp110_iv
# Name: treatment2...
# 80  agnp110_iv
# agnp110_iv
# Name: treatment2...
# 81  agnp110_iv
# agnp110_iv
# Name: treatment2...
#
#                                                Dose 2  \
# 0   agac_iv
# agac_iv
# Name: dose2, dtype: ob...
# 1   agac_iv
# agac_iv
# Name: dose2, dtype: ob...
# 2   agac_iv
# agac_iv
# Name: dose2, dtype: ob...
# 3   agac_iv
# agac_iv
# Name: dose2, dtype: ob...
# 4   agac_iv
# agac_iv
# Name: dose2, dtype: ob...
# ..                                                ...
# 77  agnp110_iv
# agnp110_iv
# Name: dose2, dty...
# 78  agnp110_iv
# agnp110_iv
# Name: dose2, dty...
# 79  agnp110_iv
# agnp110_iv
# Name: dose2, dty...
# 80  agnp110_iv
# agnp110_iv
# Name: dose2, dty...
# 81  agnp110_iv
# agnp110_iv
# Name: dose2, dty...
#
#                                               Units 2  \
# 0   agac_iv
# agac_iv
# Name: units2, dtype: o...
# 1   agac_iv
# agac_iv
# Name: units2, dtype: o...
# 2   agac_iv
# agac_iv
# Name: units2, dtype: o...
# 3   agac_iv
# agac_iv
# Name: units2, dtype: o...
# 4   agac_iv
# agac_iv
# Name: units2, dtype: o...
# ..                                                ...
# 77  agnp110_iv
# agnp110_iv
# Name: units2, dt...
# 78  agnp110_iv
# agnp110_iv
# Name: units2, dt...
# 79  agnp110_iv
# agnp110_iv
# Name: units2, dt...
# 80  agnp110_iv
# agnp110_iv
# Name: units2, dt...
# 81  agnp110_iv
# agnp110_iv
# Name: units2, dt...
#
#                                         Terminal Time  \
# 0   agac_iv    24 hours
# agac_iv    48 hours
# Name: ...
# 1   agac_iv    24 hours
# agac_iv    48 hours
# Name: ...
# 2   agac_iv    24 hours
# agac_iv    48 hours
# Name: ...
# 3   agac_iv    24 hours
# agac_iv    48 hours
# Name: ...
# 4   agac_iv    24 hours
# agac_iv    48 hours
# Name: ...
# ..                                                ...
# 77  agnp110_iv    24 hours
# agnp110_iv    48 hours
# ...
# 78  agnp110_iv    24 hours
# agnp110_iv    48 hours
# ...
# 79  agnp110_iv    24 hours
# agnp110_iv    48 hours
# ...
# 80  agnp110_iv    24 hours
# agnp110_iv    48 hours
# ...
# 81  agnp110_iv    24 hours
# agnp110_iv    48 hours
# ...
#
#                       Biomarker   Value    Units Variation
# 0                         Liver    4.33  percent      1.63
# 1                         Blood    4.88  percent      1.39
# 2                        Spleen   0.529  percent     0.124
# 3                         Lungs   0.534  percent     0.402
# 4                         Heart  0.0504  percent     0.005
# ..                          ...     ...      ...       ...
# 77                         Bone    1.05  percent     0.214
# 78  Stomach and Small Intestine   0.627  percent     0.250
# 79    Cecum and Large Intestine   0.145  percent     0.387
# 80                     Pancreas  0.0797  percent     0.037
# 81                     Placenta    1.93  percent     0.483
#
# [82 rows x 13 columns]
# Empty DataFrame
# Columns: []
# Index: []
#                                          Animal Model  \
# 0   agac_iv    rat
# agac_iv    rat
# Name: animal_mod...
# 1   agac_iv    rat
# agac_iv    rat
# Name: animal_mod...
# 2   agac_iv    rat
# agac_iv    rat
# Name: animal_mod...
# 3   agac_iv    rat
# agac_iv    rat
# Name: animal_mod...
# 4   agac_iv    rat
# agac_iv    rat
# Name: animal_mod...
# 5   agac_iv    rat
# agac_iv    rat
# Name: animal_mod...
# 6   agac_iv    rat
# agac_iv    rat
# Name: animal_mod...
# 7   agac_iv    rat
# agac_iv    rat
# Name: animal_mod...
# 8   agac_iv    rat
# agac_iv    rat
# Name: animal_mod...
# 9   agac_iv    rat
# agac_iv    rat
# Name: animal_mod...
# 10  agac_iv    rat
# agac_iv    rat
# Name: animal_mod...
# 11  agac_iv    rat
# agac_iv    rat
# Name: animal_mod...
# 12  agac_iv    rat
# agac_iv    rat
# Name: animal_mod...
# 13  agac_iv    rat
# agac_iv    rat
# Name: animal_mod...
# 14  agac_iv    rat
# agac_iv    rat
# Name: animal_mod...
# 15  agac_iv    rat
# agac_iv    rat
# Name: animal_mod...
# 16  agac_iv    rat
# agac_iv    rat
# Name: animal_mod...
# 17  agnp20_iv    rat
# agnp20_iv    rat
# Name: animal...
# 18  agnp20_iv    rat
# agnp20_iv    rat
# Name: animal...
# 19  agnp20_iv    rat
# agnp20_iv    rat
# Name: animal...
# 20  agnp20_iv    rat
# agnp20_iv    rat
# Name: animal...
# 21  agnp20_iv    rat
# agnp20_iv    rat
# Name: animal...
# 22  agnp20_iv    rat
# agnp20_iv    rat
# Name: animal...
# 23  agnp20_iv    rat
# agnp20_iv    rat
# Name: animal...
# 24  agnp20_iv    rat
# agnp20_iv    rat
# Name: animal...
# 25  agnp20_iv    rat
# agnp20_iv    rat
# Name: animal...
# 26  agnp20_iv    rat
# agnp20_iv    rat
# Name: animal...
# 27  agnp20_iv    rat
# agnp20_iv    rat
# Name: animal...
# 28  agnp20_iv    rat
# agnp20_iv    rat
# Name: animal...
# 29  agnp20_iv    rat
# agnp20_iv    rat
# Name: animal...
# 30  agnp20_iv    rat
# agnp20_iv    rat
# Name: animal...
# 31  agnp20_iv    rat
# agnp20_iv    rat
# Name: animal...
# 32  agnp110_iv    rat
# agnp110_iv    rat
# Name: anim...
# 33  agnp110_iv    rat
# agnp110_iv    rat
# Name: anim...
# 34  agnp110_iv    rat
# agnp110_iv    rat
# Name: anim...
# 35  agnp110_iv    rat
# agnp110_iv    rat
# Name: anim...
# 36  agnp110_iv    rat
# agnp110_iv    rat
# Name: anim...
# 37  agnp110_iv    rat
# agnp110_iv    rat
# Name: anim...
# 38  agnp110_iv    rat
# agnp110_iv    rat
# Name: anim...
# 39  agnp110_iv    rat
# agnp110_iv    rat
# Name: anim...
# 40  agnp110_iv    rat
# agnp110_iv    rat
# Name: anim...
# 41  agnp110_iv    rat
# agnp110_iv    rat
# Name: anim...
# 42  agnp110_iv    rat
# agnp110_iv    rat
# Name: anim...
#
#                                           Sample Size  \
# 0   agac_iv    6
# agac_iv    6
# Name: sample_size, d...
# 1   agac_iv    6
# agac_iv    6
# Name: sample_size, d...
# 2   agac_iv    6
# agac_iv    6
# Name: sample_size, d...
# 3   agac_iv    6
# agac_iv    6
# Name: sample_size, d...
# 4   agac_iv    6
# agac_iv    6
# Name: sample_size, d...
# 5   agac_iv    6
# agac_iv    6
# Name: sample_size, d...
# 6   agac_iv    6
# agac_iv    6
# Name: sample_size, d...
# 7   agac_iv    6
# agac_iv    6
# Name: sample_size, d...
# 8   agac_iv    6
# agac_iv    6
# Name: sample_size, d...
# 9   agac_iv    6
# agac_iv    6
# Name: sample_size, d...
# 10  agac_iv    6
# agac_iv    6
# Name: sample_size, d...
# 11  agac_iv    6
# agac_iv    6
# Name: sample_size, d...
# 12  agac_iv    6
# agac_iv    6
# Name: sample_size, d...
# 13  agac_iv    6
# agac_iv    6
# Name: sample_size, d...
# 14  agac_iv    6
# agac_iv    6
# Name: sample_size, d...
# 15  agac_iv    6
# agac_iv    6
# Name: sample_size, d...
# 16  agac_iv    6
# agac_iv    6
# Name: sample_size, d...
# 17  agnp20_iv    6
# agnp20_iv    6
# Name: sample_siz...
# 18  agnp20_iv    6
# agnp20_iv    6
# Name: sample_siz...
# 19  agnp20_iv    6
# agnp20_iv    6
# Name: sample_siz...
# 20  agnp20_iv    6
# agnp20_iv    6
# Name: sample_siz...
# 21  agnp20_iv    6
# agnp20_iv    6
# Name: sample_siz...
# 22  agnp20_iv    6
# agnp20_iv    6
# Name: sample_siz...
# 23  agnp20_iv    6
# agnp20_iv    6
# Name: sample_siz...
# 24  agnp20_iv    6
# agnp20_iv    6
# Name: sample_siz...
# 25  agnp20_iv    6
# agnp20_iv    6
# Name: sample_siz...
# 26  agnp20_iv    6
# agnp20_iv    6
# Name: sample_siz...
# 27  agnp20_iv    6
# agnp20_iv    6
# Name: sample_siz...
# 28  agnp20_iv    6
# agnp20_iv    6
# Name: sample_siz...
# 29  agnp20_iv    6
# agnp20_iv    6
# Name: sample_siz...
# 30  agnp20_iv    6
# agnp20_iv    6
# Name: sample_siz...
# 31  agnp20_iv    6
# agnp20_iv    6
# Name: sample_siz...
# 32  agnp110_iv    6
# agnp110_iv    6
# Name: sample_s...
# 33  agnp110_iv    6
# agnp110_iv    6
# Name: sample_s...
# 34  agnp110_iv    6
# agnp110_iv    6
# Name: sample_s...
# 35  agnp110_iv    6
# agnp110_iv    6
# Name: sample_s...
# 36  agnp110_iv    6
# agnp110_iv    6
# Name: sample_s...
# 37  agnp110_iv    6
# agnp110_iv    6
# Name: sample_s...
# 38  agnp110_iv    6
# agnp110_iv    6
# Name: sample_s...
# 39  agnp110_iv    6
# agnp110_iv    6
# Name: sample_s...
# 40  agnp110_iv    6
# agnp110_iv    6
# Name: sample_s...
# 41  agnp110_iv    6
# agnp110_iv    6
# Name: sample_s...
# 42  agnp110_iv    6
# agnp110_iv    6
# Name: sample_s...
#
#                                           Treatment 1  \
# 0   agac_iv    silver acetate
# agac_iv    silver ac...
# 1   agac_iv    silver acetate
# agac_iv    silver ac...
# 2   agac_iv    silver acetate
# agac_iv    silver ac...
# 3   agac_iv    silver acetate
# agac_iv    silver ac...
# 4   agac_iv    silver acetate
# agac_iv    silver ac...
# 5   agac_iv    silver acetate
# agac_iv    silver ac...
# 6   agac_iv    silver acetate
# agac_iv    silver ac...
# 7   agac_iv    silver acetate
# agac_iv    silver ac...
# 8   agac_iv    silver acetate
# agac_iv    silver ac...
# 9   agac_iv    silver acetate
# agac_iv    silver ac...
# 10  agac_iv    silver acetate
# agac_iv    silver ac...
# 11  agac_iv    silver acetate
# agac_iv    silver ac...
# 12  agac_iv    silver acetate
# agac_iv    silver ac...
# 13  agac_iv    silver acetate
# agac_iv    silver ac...
# 14  agac_iv    silver acetate
# agac_iv    silver ac...
# 15  agac_iv    silver acetate
# agac_iv    silver ac...
# 16  agac_iv    silver acetate
# agac_iv    silver ac...
# 17  agnp20_iv    silver nanoparticles (20 nm)
# agnp...
# 18  agnp20_iv    silver nanoparticles (20 nm)
# agnp...
# 19  agnp20_iv    silver nanoparticles (20 nm)
# agnp...
# 20  agnp20_iv    silver nanoparticles (20 nm)
# agnp...
# 21  agnp20_iv    silver nanoparticles (20 nm)
# agnp...
# 22  agnp20_iv    silver nanoparticles (20 nm)
# agnp...
# 23  agnp20_iv    silver nanoparticles (20 nm)
# agnp...
# 24  agnp20_iv    silver nanoparticles (20 nm)
# agnp...
# 25  agnp20_iv    silver nanoparticles (20 nm)
# agnp...
# 26  agnp20_iv    silver nanoparticles (20 nm)
# agnp...
# 27  agnp20_iv    silver nanoparticles (20 nm)
# agnp...
# 28  agnp20_iv    silver nanoparticles (20 nm)
# agnp...
# 29  agnp20_iv    silver nanoparticles (20 nm)
# agnp...
# 30  agnp20_iv    silver nanoparticles (20 nm)
# agnp...
# 31  agnp20_iv    silver nanoparticles (20 nm)
# agnp...
# 32  agnp110_iv    silver nanoparticles (110 nm)
# ag...
# 33  agnp110_iv    silver nanoparticles (110 nm)
# ag...
# 34  agnp110_iv    silver nanoparticles (110 nm)
# ag...
# 35  agnp110_iv    silver nanoparticles (110 nm)
# ag...
# 36  agnp110_iv    silver nanoparticles (110 nm)
# ag...
# 37  agnp110_iv    silver nanoparticles (110 nm)
# ag...
# 38  agnp110_iv    silver nanoparticles (110 nm)
# ag...
# 39  agnp110_iv    silver nanoparticles (110 nm)
# ag...
# 40  agnp110_iv    silver nanoparticles (110 nm)
# ag...
# 41  agnp110_iv    silver nanoparticles (110 nm)
# ag...
# 42  agnp110_iv    silver nanoparticles (110 nm)
# ag...
#
#                                                Dose 1  \
# 0   agac_iv    1
# agac_iv    1
# Name: dose1, dtype: ...
# 1   agac_iv    1
# agac_iv    1
# Name: dose1, dtype: ...
# 2   agac_iv    1
# agac_iv    1
# Name: dose1, dtype: ...
# 3   agac_iv    1
# agac_iv    1
# Name: dose1, dtype: ...
# 4   agac_iv    1
# agac_iv    1
# Name: dose1, dtype: ...
# 5   agac_iv    1
# agac_iv    1
# Name: dose1, dtype: ...
# 6   agac_iv    1
# agac_iv    1
# Name: dose1, dtype: ...
# 7   agac_iv    1
# agac_iv    1
# Name: dose1, dtype: ...
# 8   agac_iv    1
# agac_iv    1
# Name: dose1, dtype: ...
# 9   agac_iv    1
# agac_iv    1
# Name: dose1, dtype: ...
# 10  agac_iv    1
# agac_iv    1
# Name: dose1, dtype: ...
# 11  agac_iv    1
# agac_iv    1
# Name: dose1, dtype: ...
# 12  agac_iv    1
# agac_iv    1
# Name: dose1, dtype: ...
# 13  agac_iv    1
# agac_iv    1
# Name: dose1, dtype: ...
# 14  agac_iv    1
# agac_iv    1
# Name: dose1, dtype: ...
# 15  agac_iv    1
# agac_iv    1
# Name: dose1, dtype: ...
# 16  agac_iv    1
# agac_iv    1
# Name: dose1, dtype: ...
# 17  agnp20_iv    1
# agnp20_iv    1
# Name: dose1, dty...
# 18  agnp20_iv    1
# agnp20_iv    1
# Name: dose1, dty...
# 19  agnp20_iv    1
# agnp20_iv    1
# Name: dose1, dty...
# 20  agnp20_iv    1
# agnp20_iv    1
# Name: dose1, dty...
# 21  agnp20_iv    1
# agnp20_iv    1
# Name: dose1, dty...
# 22  agnp20_iv    1
# agnp20_iv    1
# Name: dose1, dty...
# 23  agnp20_iv    1
# agnp20_iv    1
# Name: dose1, dty...
# 24  agnp20_iv    1
# agnp20_iv    1
# Name: dose1, dty...
# 25  agnp20_iv    1
# agnp20_iv    1
# Name: dose1, dty...
# 26  agnp20_iv    1
# agnp20_iv    1
# Name: dose1, dty...
# 27  agnp20_iv    1
# agnp20_iv    1
# Name: dose1, dty...
# 28  agnp20_iv    1
# agnp20_iv    1
# Name: dose1, dty...
# 29  agnp20_iv    1
# agnp20_iv    1
# Name: dose1, dty...
# 30  agnp20_iv    1
# agnp20_iv    1
# Name: dose1, dty...
# 31  agnp20_iv    1
# agnp20_iv    1
# Name: dose1, dty...
# 32  agnp110_iv    1
# agnp110_iv    1
# Name: dose1, d...
# 33  agnp110_iv    1
# agnp110_iv    1
# Name: dose1, d...
# 34  agnp110_iv    1
# agnp110_iv    1
# Name: dose1, d...
# 35  agnp110_iv    1
# agnp110_iv    1
# Name: dose1, d...
# 36  agnp110_iv    1
# agnp110_iv    1
# Name: dose1, d...
# 37  agnp110_iv    1
# agnp110_iv    1
# Name: dose1, d...
# 38  agnp110_iv    1
# agnp110_iv    1
# Name: dose1, d...
# 39  agnp110_iv    1
# agnp110_iv    1
# Name: dose1, d...
# 40  agnp110_iv    1
# agnp110_iv    1
# Name: dose1, d...
# 41  agnp110_iv    1
# agnp110_iv    1
# Name: dose1, d...
# 42  agnp110_iv    1
# agnp110_iv    1
# Name: dose1, d...
#
#                                               Units 1  \
# 0   agac_iv    mg/kg
# agac_iv    mg/kg
# Name: units1...
# 1   agac_iv    mg/kg
# agac_iv    mg/kg
# Name: units1...
# 2   agac_iv    mg/kg
# agac_iv    mg/kg
# Name: units1...
# 3   agac_iv    mg/kg
# agac_iv    mg/kg
# Name: units1...
# 4   agac_iv    mg/kg
# agac_iv    mg/kg
# Name: units1...
# 5   agac_iv    mg/kg
# agac_iv    mg/kg
# Name: units1...
# 6   agac_iv    mg/kg
# agac_iv    mg/kg
# Name: units1...
# 7   agac_iv    mg/kg
# agac_iv    mg/kg
# Name: units1...
# 8   agac_iv    mg/kg
# agac_iv    mg/kg
# Name: units1...
# 9   agac_iv    mg/kg
# agac_iv    mg/kg
# Name: units1...
# 10  agac_iv    mg/kg
# agac_iv    mg/kg
# Name: units1...
# 11  agac_iv    mg/kg
# agac_iv    mg/kg
# Name: units1...
# 12  agac_iv    mg/kg
# agac_iv    mg/kg
# Name: units1...
# 13  agac_iv    mg/kg
# agac_iv    mg/kg
# Name: units1...
# 14  agac_iv    mg/kg
# agac_iv    mg/kg
# Name: units1...
# 15  agac_iv    mg/kg
# agac_iv    mg/kg
# Name: units1...
# 16  agac_iv    mg/kg
# agac_iv    mg/kg
# Name: units1...
# 17  agnp20_iv    mg/kg
# agnp20_iv    mg/kg
# Name: un...
# 18  agnp20_iv    mg/kg
# agnp20_iv    mg/kg
# Name: un...
# 19  agnp20_iv    mg/kg
# agnp20_iv    mg/kg
# Name: un...
# 20  agnp20_iv    mg/kg
# agnp20_iv    mg/kg
# Name: un...
# 21  agnp20_iv    mg/kg
# agnp20_iv    mg/kg
# Name: un...
# 22  agnp20_iv    mg/kg
# agnp20_iv    mg/kg
# Name: un...
# 23  agnp20_iv    mg/kg
# agnp20_iv    mg/kg
# Name: un...
# 24  agnp20_iv    mg/kg
# agnp20_iv    mg/kg
# Name: un...
# 25  agnp20_iv    mg/kg
# agnp20_iv    mg/kg
# Name: un...
# 26  agnp20_iv    mg/kg
# agnp20_iv    mg/kg
# Name: un...
# 27  agnp20_iv    mg/kg
# agnp20_iv    mg/kg
# Name: un...
# 28  agnp20_iv    mg/kg
# agnp20_iv    mg/kg
# Name: un...
# 29  agnp20_iv    mg/kg
# agnp20_iv    mg/kg
# Name: un...
# 30  agnp20_iv    mg/kg
# agnp20_iv    mg/kg
# Name: un...
# 31  agnp20_iv    mg/kg
# agnp20_iv    mg/kg
# Name: un...
# 32  agnp110_iv    mg/kg
# agnp110_iv    mg/kg
# Name: ...
# 33  agnp110_iv    mg/kg
# agnp110_iv    mg/kg
# Name: ...
# 34  agnp110_iv    mg/kg
# agnp110_iv    mg/kg
# Name: ...
# 35  agnp110_iv    mg/kg
# agnp110_iv    mg/kg
# Name: ...
# 36  agnp110_iv    mg/kg
# agnp110_iv    mg/kg
# Name: ...
# 37  agnp110_iv    mg/kg
# agnp110_iv    mg/kg
# Name: ...
# 38  agnp110_iv    mg/kg
# agnp110_iv    mg/kg
# Name: ...
# 39  agnp110_iv    mg/kg
# agnp110_iv    mg/kg
# Name: ...
# 40  agnp110_iv    mg/kg
# agnp110_iv    mg/kg
# Name: ...
# 41  agnp110_iv    mg/kg
# agnp110_iv    mg/kg
# Name: ...
# 42  agnp110_iv    mg/kg
# agnp110_iv    mg/kg
# Name: ...
#
#                                           Treatment 2  \
# 0   agac_iv
# agac_iv
# Name: treatment2, dtyp...
# 1   agac_iv
# agac_iv
# Name: treatment2, dtyp...
# 2   agac_iv
# agac_iv
# Name: treatment2, dtyp...
# 3   agac_iv
# agac_iv
# Name: treatment2, dtyp...
# 4   agac_iv
# agac_iv
# Name: treatment2, dtyp...
# 5   agac_iv
# agac_iv
# Name: treatment2, dtyp...
# 6   agac_iv
# agac_iv
# Name: treatment2, dtyp...
# 7   agac_iv
# agac_iv
# Name: treatment2, dtyp...
# 8   agac_iv
# agac_iv
# Name: treatment2, dtyp...
# 9   agac_iv
# agac_iv
# Name: treatment2, dtyp...
# 10  agac_iv
# agac_iv
# Name: treatment2, dtyp...
# 11  agac_iv
# agac_iv
# Name: treatment2, dtyp...
# 12  agac_iv
# agac_iv
# Name: treatment2, dtyp...
# 13  agac_iv
# agac_iv
# Name: treatment2, dtyp...
# 14  agac_iv
# agac_iv
# Name: treatment2, dtyp...
# 15  agac_iv
# agac_iv
# Name: treatment2, dtyp...
# 16  agac_iv
# agac_iv
# Name: treatment2, dtyp...
# 17  agnp20_iv
# agnp20_iv
# Name: treatment2, ...
# 18  agnp20_iv
# agnp20_iv
# Name: treatment2, ...
# 19  agnp20_iv
# agnp20_iv
# Name: treatment2, ...
# 20  agnp20_iv
# agnp20_iv
# Name: treatment2, ...
# 21  agnp20_iv
# agnp20_iv
# Name: treatment2, ...
# 22  agnp20_iv
# agnp20_iv
# Name: treatment2, ...
# 23  agnp20_iv
# agnp20_iv
# Name: treatment2, ...
# 24  agnp20_iv
# agnp20_iv
# Name: treatment2, ...
# 25  agnp20_iv
# agnp20_iv
# Name: treatment2, ...
# 26  agnp20_iv
# agnp20_iv
# Name: treatment2, ...
# 27  agnp20_iv
# agnp20_iv
# Name: treatment2, ...
# 28  agnp20_iv
# agnp20_iv
# Name: treatment2, ...
# 29  agnp20_iv
# agnp20_iv
# Name: treatment2, ...
# 30  agnp20_iv
# agnp20_iv
# Name: treatment2, ...
# 31  agnp20_iv
# agnp20_iv
# Name: treatment2, ...
# 32  agnp110_iv
# agnp110_iv
# Name: treatment2...
# 33  agnp110_iv
# agnp110_iv
# Name: treatment2...
# 34  agnp110_iv
# agnp110_iv
# Name: treatment2...
# 35  agnp110_iv
# agnp110_iv
# Name: treatment2...
# 36  agnp110_iv
# agnp110_iv
# Name: treatment2...
# 37  agnp110_iv
# agnp110_iv
# Name: treatment2...
# 38  agnp110_iv
# agnp110_iv
# Name: treatment2...
# 39  agnp110_iv
# agnp110_iv
# Name: treatment2...
# 40  agnp110_iv
# agnp110_iv
# Name: treatment2...
# 41  agnp110_iv
# agnp110_iv
# Name: treatment2...
# 42  agnp110_iv
# agnp110_iv
# Name: treatment2...
#
#                                                Dose 2  \
# 0   agac_iv
# agac_iv
# Name: dose2, dtype: ob...
# 1   agac_iv
# agac_iv
# Name: dose2, dtype: ob...
# 2   agac_iv
# agac_iv
# Name: dose2, dtype: ob...
# 3   agac_iv
# agac_iv
# Name: dose2, dtype: ob...
# 4   agac_iv
# agac_iv
# Name: dose2, dtype: ob...
# 5   agac_iv
# agac_iv
# Name: dose2, dtype: ob...
# 6   agac_iv
# agac_iv
# Name: dose2, dtype: ob...
# 7   agac_iv
# agac_iv
# Name: dose2, dtype: ob...
# 8   agac_iv
# agac_iv
# Name: dose2, dtype: ob...
# 9   agac_iv
# agac_iv
# Name: dose2, dtype: ob...
# 10  agac_iv
# agac_iv
# Name: dose2, dtype: ob...
# 11  agac_iv
# agac_iv
# Name: dose2, dtype: ob...
# 12  agac_iv
# agac_iv
# Name: dose2, dtype: ob...
# 13  agac_iv
# agac_iv
# Name: dose2, dtype: ob...
# 14  agac_iv
# agac_iv
# Name: dose2, dtype: ob...
# 15  agac_iv
# agac_iv
# Name: dose2, dtype: ob...
# 16  agac_iv
# agac_iv
# Name: dose2, dtype: ob...
# 17  agnp20_iv
# agnp20_iv
# Name: dose2, dtype...
# 18  agnp20_iv
# agnp20_iv
# Name: dose2, dtype...
# 19  agnp20_iv
# agnp20_iv
# Name: dose2, dtype...
# 20  agnp20_iv
# agnp20_iv
# Name: dose2, dtype...
# 21  agnp20_iv
# agnp20_iv
# Name: dose2, dtype...
# 22  agnp20_iv
# agnp20_iv
# Name: dose2, dtype...
# 23  agnp20_iv
# agnp20_iv
# Name: dose2, dtype...
# 24  agnp20_iv
# agnp20_iv
# Name: dose2, dtype...
# 25  agnp20_iv
# agnp20_iv
# Name: dose2, dtype...
# 26  agnp20_iv
# agnp20_iv
# Name: dose2, dtype...
# 27  agnp20_iv
# agnp20_iv
# Name: dose2, dtype...
# 28  agnp20_iv
# agnp20_iv
# Name: dose2, dtype...
# 29  agnp20_iv
# agnp20_iv
# Name: dose2, dtype...
# 30  agnp20_iv
# agnp20_iv
# Name: dose2, dtype...
# 31  agnp20_iv
# agnp20_iv
# Name: dose2, dtype...
# 32  agnp110_iv
# agnp110_iv
# Name: dose2, dty...
# 33  agnp110_iv
# agnp110_iv
# Name: dose2, dty...
# 34  agnp110_iv
# agnp110_iv
# Name: dose2, dty...
# 35  agnp110_iv
# agnp110_iv
# Name: dose2, dty...
# 36  agnp110_iv
# agnp110_iv
# Name: dose2, dty...
# 37  agnp110_iv
# agnp110_iv
# Name: dose2, dty...
# 38  agnp110_iv
# agnp110_iv
# Name: dose2, dty...
# 39  agnp110_iv
# agnp110_iv
# Name: dose2, dty...
# 40  agnp110_iv
# agnp110_iv
# Name: dose2, dty...
# 41  agnp110_iv
# agnp110_iv
# Name: dose2, dty...
# 42  agnp110_iv
# agnp110_iv
# Name: dose2, dty...
#
#                                               Units 2  \
# 0   agac_iv
# agac_iv
# Name: units2, dtype: o...
# 1   agac_iv
# agac_iv
# Name: units2, dtype: o...
# 2   agac_iv
# agac_iv
# Name: units2, dtype: o...
# 3   agac_iv
# agac_iv
# Name: units2, dtype: o...
# 4   agac_iv
# agac_iv
# Name: units2, dtype: o...
# 5   agac_iv
# agac_iv
# Name: units2, dtype: o...
# 6   agac_iv
# agac_iv
# Name: units2, dtype: o...
# 7   agac_iv
# agac_iv
# Name: units2, dtype: o...
# 8   agac_iv
# agac_iv
# Name: units2, dtype: o...
# 9   agac_iv
# agac_iv
# Name: units2, dtype: o...
# 10  agac_iv
# agac_iv
# Name: units2, dtype: o...
# 11  agac_iv
# agac_iv
# Name: units2, dtype: o...
# 12  agac_iv
# agac_iv
# Name: units2, dtype: o...
# 13  agac_iv
# agac_iv
# Name: units2, dtype: o...
# 14  agac_iv
# agac_iv
# Name: units2, dtype: o...
# 15  agac_iv
# agac_iv
# Name: units2, dtype: o...
# 16  agac_iv
# agac_iv
# Name: units2, dtype: o...
# 17  agnp20_iv
# agnp20_iv
# Name: units2, dtyp...
# 18  agnp20_iv
# agnp20_iv
# Name: units2, dtyp...
# 19  agnp20_iv
# agnp20_iv
# Name: units2, dtyp...
# 20  agnp20_iv
# agnp20_iv
# Name: units2, dtyp...
# 21  agnp20_iv
# agnp20_iv
# Name: units2, dtyp...
# 22  agnp20_iv
# agnp20_iv
# Name: units2, dtyp...
# 23  agnp20_iv
# agnp20_iv
# Name: units2, dtyp...
# 24  agnp20_iv
# agnp20_iv
# Name: units2, dtyp...
# 25  agnp20_iv
# agnp20_iv
# Name: units2, dtyp...
# 26  agnp20_iv
# agnp20_iv
# Name: units2, dtyp...
# 27  agnp20_iv
# agnp20_iv
# Name: units2, dtyp...
# 28  agnp20_iv
# agnp20_iv
# Name: units2, dtyp...
# 29  agnp20_iv
# agnp20_iv
# Name: units2, dtyp...
# 30  agnp20_iv
# agnp20_iv
# Name: units2, dtyp...
# 31  agnp20_iv
# agnp20_iv
# Name: units2, dtyp...
# 32  agnp110_iv
# agnp110_iv
# Name: units2, dt...
# 33  agnp110_iv
# agnp110_iv
# Name: units2, dt...
# 34  agnp110_iv
# agnp110_iv
# Name: units2, dt...
# 35  agnp110_iv
# agnp110_iv
# Name: units2, dt...
# 36  agnp110_iv
# agnp110_iv
# Name: units2, dt...
# 37  agnp110_iv
# agnp110_iv
# Name: units2, dt...
# 38  agnp110_iv
# agnp110_iv
# Name: units2, dt...
# 39  agnp110_iv
# agnp110_iv
# Name: units2, dt...
# 40  agnp110_iv
# agnp110_iv
# Name: units2, dt...
# 41  agnp110_iv
# agnp110_iv
# Name: units2, dt...
# 42  agnp110_iv
# agnp110_iv
# Name: units2, dt...
#
#                                         Terminal Time  \
# 0   agac_iv    24 hours
# agac_iv    48 hours
# Name: ...
# 1   agac_iv    24 hours
# agac_iv    48 hours
# Name: ...
# 2   agac_iv    24 hours
# agac_iv    48 hours
# Name: ...
# 3   agac_iv    24 hours
# agac_iv    48 hours
# Name: ...
# 4   agac_iv    24 hours
# agac_iv    48 hours
# Name: ...
# 5   agac_iv    24 hours
# agac_iv    48 hours
# Name: ...
# 6   agac_iv    24 hours
# agac_iv    48 hours
# Name: ...
# 7   agac_iv    24 hours
# agac_iv    48 hours
# Name: ...
# 8   agac_iv    24 hours
# agac_iv    48 hours
# Name: ...
# 9   agac_iv    24 hours
# agac_iv    48 hours
# Name: ...
# 10  agac_iv    24 hours
# agac_iv    48 hours
# Name: ...
# 11  agac_iv    24 hours
# agac_iv    48 hours
# Name: ...
# 12  agac_iv    24 hours
# agac_iv    48 hours
# Name: ...
# 13  agac_iv    24 hours
# agac_iv    48 hours
# Name: ...
# 14  agac_iv    24 hours
# agac_iv    48 hours
# Name: ...
# 15  agac_iv    24 hours
# agac_iv    48 hours
# Name: ...
# 16  agac_iv    24 hours
# agac_iv    48 hours
# Name: ...
# 17  agnp20_iv    24 hours
# agnp20_iv    48 hours
# Na...
# 18  agnp20_iv    24 hours
# agnp20_iv    48 hours
# Na...
# 19  agnp20_iv    24 hours
# agnp20_iv    48 hours
# Na...
# 20  agnp20_iv    24 hours
# agnp20_iv    48 hours
# Na...
# 21  agnp20_iv    24 hours
# agnp20_iv    48 hours
# Na...
# 22  agnp20_iv    24 hours
# agnp20_iv    48 hours
# Na...
# 23  agnp20_iv    24 hours
# agnp20_iv    48 hours
# Na...
# 24  agnp20_iv    24 hours
# agnp20_iv    48 hours
# Na...
# 25  agnp20_iv    24 hours
# agnp20_iv    48 hours
# Na...
# 26  agnp20_iv    24 hours
# agnp20_iv    48 hours
# Na...
# 27  agnp20_iv    24 hours
# agnp20_iv    48 hours
# Na...
# 28  agnp20_iv    24 hours
# agnp20_iv    48 hours
# Na...
# 29  agnp20_iv    24 hours
# agnp20_iv    48 hours
# Na...
# 30  agnp20_iv    24 hours
# agnp20_iv    48 hours
# Na...
# 31  agnp20_iv    24 hours
# agnp20_iv    48 hours
# Na...
# 32  agnp110_iv    24 hours
# agnp110_iv    48 hours
# ...
# 33  agnp110_iv    24 hours
# agnp110_iv    48 hours
# ...
# 34  agnp110_iv    24 hours
# agnp110_iv    48 hours
# ...
# 35  agnp110_iv    24 hours
# agnp110_iv    48 hours
# ...
# 36  agnp110_iv    24 hours
# agnp110_iv    48 hours
# ...
# 37  agnp110_iv    24 hours
# agnp110_iv    48 hours
# ...
# 38  agnp110_iv    24 hours
# agnp110_iv    48 hours
# ...
# 39  agnp110_iv    24 hours
# agnp110_iv    48 hours
# ...
# 40  agnp110_iv    24 hours
# agnp110_iv    48 hours
# ...
# 41  agnp110_iv    24 hours
# agnp110_iv    48 hours
# ...
# 42  agnp110_iv    24 hours
# agnp110_iv    48 hours
# ...
#
#                       Biomarker   Value     Units Variation
# 0                         Liver   0.187  mug Ag/g     0.106
# 1                         Blood       b  mug Ag/g       nan
# 2                        Spleen  0.0802  mug Ag/g    0.0648
# 3                         Lungs   0.137  mug Ag/g    0.0239
# 4                         Heart  0.0604  mug Ag/g      None
# 5                        Kidney   0.461  mug Ag/g     0.506
# 6   Stomach and Small Intestine    1.55  mug Ag/g      2.51
# 7     Cecum and Large Intestine    16.0  mug Ag/g      25.6
# 8                      Placenta   0.751  mug Ag/g    0.0249
# 9                         Liver   0.324  mug Ag/g     0.380
# 10                        Blood   0.117  mug Ag/g    0.0168
# 11                       Spleen   0.104  mug Ag/g    0.0702
# 12                        Lungs   0.177  mug Ag/g       nan
# 13                       Kidney   0.147  mug Ag/g    0.0413
# 14  Stomach and Small Intestine  0.0726  mug Ag/g    0.0286
# 15    Cecum and Large Intestine   0.400  mug Ag/g    0.0248
# 16                     Placenta   0.919  mug Ag/g     0.271
# 17                        Liver  0.0592  mug Ag/g    0.0293
# 18                        Blood   0.124  mug Ag/g    0.0120
# 19                       Spleen   0.220  mug Ag/g    0.0329
# 20                        Lungs   0.965  mug Ag/g       nan
# 21                       Kidney   0.187  mug Ag/g    0.0545
# 22  Stomach and Small Intestine  0.0657  mug Ag/g    0.0324
# 23    Cecum and Large Intestine    3.76  mug Ag/g      2.24
# 24                     Placenta   0.518  mug Ag/g    0.0302
# 25                        Liver  0.0380  mug Ag/g    0.0126
# 26                        Blood  0.0646  mug Ag/g   0.00519
# 27                       Spleen   0.172  mug Ag/g       nan
# 28                       Kidney  0.0868  mug Ag/g    0.0136
# 29  Stomach and Small Intestine  0.0307  mug Ag/g    0.0141
# 30    Cecum and Large Intestine   0.884  mug Ag/g     0.750
# 31                     Placenta   0.354  mug Ag/g     0.307
# 32                        Liver  0.0205  mug Ag/g    0.0150
# 33                       Spleen   0.172  mug Ag/g       nan
# 34                       Kidney   0.104  mug Ag/g    0.0387
# 35  Stomach and Small Intestine   0.584  mug Ag/g     0.468
# 36    Cecum and Large Intestine    3.02  mug Ag/g      1.04
# 37                     Placenta   0.201  mug Ag/g     0.125
# 38                        Liver  0.0170  mug Ag/g   0.00377
# 39                       Kidney  0.0795  mug Ag/g    0.0179
# 40  Stomach and Small Intestine  0.0193  mug Ag/g   0.00657
# 41    Cecum and Large Intestine   0.901  mug Ag/g     0.449
# 42                     Placenta   0.351  mug Ag/g     0.106
# Empty DataFrame
# Columns: []
# Index: []
#                                          Animal Model  \
# 0   control_iv    rat
# control_iv    rat
# Name: anim...
# 1   control_iv    rat
# control_iv    rat
# Name: anim...
# 2   control_iv    rat
# control_iv    rat
# Name: anim...
# 3   control_iv    rat
# control_iv    rat
# Name: anim...
# 4   control_iv    rat
# control_iv    rat
# Name: anim...
# 5   control_iv    rat
# control_iv    rat
# Name: anim...
# 6   control_iv    rat
# control_iv    rat
# Name: anim...
# 7   control_iv    rat
# control_iv    rat
# Name: anim...
# 8   control_po    rat
# control_po    rat
# Name: anim...
# 9   control_po    rat
# control_po    rat
# Name: anim...
# 10  control_po    rat
# control_po    rat
# Name: anim...
# 11  control_po    rat
# control_po    rat
# Name: anim...
# 12  control_po    rat
# control_po    rat
# Name: anim...
# 13  control_po    rat
# control_po    rat
# Name: anim...
# 14  control_po    rat
# control_po    rat
# Name: anim...
# 15  control_po    rat
# control_po    rat
# Name: anim...
# 16  agac_iv    rat
# agac_iv    rat
# Name: animal_mod...
# 17  agac_iv    rat
# agac_iv    rat
# Name: animal_mod...
# 18  agac_iv    rat
# agac_iv    rat
# Name: animal_mod...
# 19  agac_iv    rat
# agac_iv    rat
# Name: animal_mod...
# 20  agac_iv    rat
# agac_iv    rat
# Name: animal_mod...
# 21  agac_iv    rat
# agac_iv    rat
# Name: animal_mod...
# 22  agac_iv    rat
# agac_iv    rat
# Name: animal_mod...
# 23  agac_iv    rat
# agac_iv    rat
# Name: animal_mod...
# 24  agac_po    rat
# agac_po    rat
# Name: animal_mod...
# 25  agac_po    rat
# agac_po    rat
# Name: animal_mod...
# 26  agac_po    rat
# agac_po    rat
# Name: animal_mod...
# 27  agac_po    rat
# agac_po    rat
# Name: animal_mod...
# 28  agac_po    rat
# agac_po    rat
# Name: animal_mod...
# 29  agac_po    rat
# agac_po    rat
# Name: animal_mod...
# 30  agac_po    rat
# agac_po    rat
# Name: animal_mod...
# 31  agnp20_iv    rat
# agnp20_iv    rat
# Name: animal...
# 32  agnp20_iv    rat
# agnp20_iv    rat
# Name: animal...
# 33  agnp20_iv    rat
# agnp20_iv    rat
# Name: animal...
# 34  agnp20_iv    rat
# agnp20_iv    rat
# Name: animal...
# 35  agnp20_iv    rat
# agnp20_iv    rat
# Name: animal...
# 36  agnp20_iv    rat
# agnp20_iv    rat
# Name: animal...
# 37  agnp20_po    rat
# agnp20_po    rat
# Name: animal...
# 38  agnp20_po    rat
# agnp20_po    rat
# Name: animal...
# 39  agnp20_po    rat
# agnp20_po    rat
# Name: animal...
# 40  agnp20_po    rat
# agnp20_po    rat
# Name: animal...
# 41  agnp20_po    rat
# agnp20_po    rat
# Name: animal...
#
#                                           Sample Size  \
# 0   control_iv    6
# control_iv    6
# Name: sample_s...
# 1   control_iv    6
# control_iv    6
# Name: sample_s...
# 2   control_iv    6
# control_iv    6
# Name: sample_s...
# 3   control_iv    6
# control_iv    6
# Name: sample_s...
# 4   control_iv    6
# control_iv    6
# Name: sample_s...
# 5   control_iv    6
# control_iv    6
# Name: sample_s...
# 6   control_iv    6
# control_iv    6
# Name: sample_s...
# 7   control_iv    6
# control_iv    6
# Name: sample_s...
# 8   control_po    6
# control_po    6
# Name: sample_s...
# 9   control_po    6
# control_po    6
# Name: sample_s...
# 10  control_po    6
# control_po    6
# Name: sample_s...
# 11  control_po    6
# control_po    6
# Name: sample_s...
# 12  control_po    6
# control_po    6
# Name: sample_s...
# 13  control_po    6
# control_po    6
# Name: sample_s...
# 14  control_po    6
# control_po    6
# Name: sample_s...
# 15  control_po    6
# control_po    6
# Name: sample_s...
# 16  agac_iv    6
# agac_iv    6
# Name: sample_size, d...
# 17  agac_iv    6
# agac_iv    6
# Name: sample_size, d...
# 18  agac_iv    6
# agac_iv    6
# Name: sample_size, d...
# 19  agac_iv    6
# agac_iv    6
# Name: sample_size, d...
# 20  agac_iv    6
# agac_iv    6
# Name: sample_size, d...
# 21  agac_iv    6
# agac_iv    6
# Name: sample_size, d...
# 22  agac_iv    6
# agac_iv    6
# Name: sample_size, d...
# 23  agac_iv    6
# agac_iv    6
# Name: sample_size, d...
# 24  agac_po    6
# agac_po    6
# Name: sample_size, d...
# 25  agac_po    6
# agac_po    6
# Name: sample_size, d...
# 26  agac_po    6
# agac_po    6
# Name: sample_size, d...
# 27  agac_po    6
# agac_po    6
# Name: sample_size, d...
# 28  agac_po    6
# agac_po    6
# Name: sample_size, d...
# 29  agac_po    6
# agac_po    6
# Name: sample_size, d...
# 30  agac_po    6
# agac_po    6
# Name: sample_size, d...
# 31  agnp20_iv    6
# agnp20_iv    6
# Name: sample_siz...
# 32  agnp20_iv    6
# agnp20_iv    6
# Name: sample_siz...
# 33  agnp20_iv    6
# agnp20_iv    6
# Name: sample_siz...
# 34  agnp20_iv    6
# agnp20_iv    6
# Name: sample_siz...
# 35  agnp20_iv    6
# agnp20_iv    6
# Name: sample_siz...
# 36  agnp20_iv    6
# agnp20_iv    6
# Name: sample_siz...
# 37  agnp20_po    6
# agnp20_po    6
# Name: sample_siz...
# 38  agnp20_po    6
# agnp20_po    6
# Name: sample_siz...
# 39  agnp20_po    6
# agnp20_po    6
# Name: sample_siz...
# 40  agnp20_po    6
# agnp20_po    6
# Name: sample_siz...
# 41  agnp20_po    6
# agnp20_po    6
# Name: sample_siz...
#
#                                           Treatment 1  \
# 0   control_iv
# control_iv
# Name: treatment1...
# 1   control_iv
# control_iv
# Name: treatment1...
# 2   control_iv
# control_iv
# Name: treatment1...
# 3   control_iv
# control_iv
# Name: treatment1...
# 4   control_iv
# control_iv
# Name: treatment1...
# 5   control_iv
# control_iv
# Name: treatment1...
# 6   control_iv
# control_iv
# Name: treatment1...
# 7   control_iv
# control_iv
# Name: treatment1...
# 8   control_po
# control_po
# Name: treatment1...
# 9   control_po
# control_po
# Name: treatment1...
# 10  control_po
# control_po
# Name: treatment1...
# 11  control_po
# control_po
# Name: treatment1...
# 12  control_po
# control_po
# Name: treatment1...
# 13  control_po
# control_po
# Name: treatment1...
# 14  control_po
# control_po
# Name: treatment1...
# 15  control_po
# control_po
# Name: treatment1...
# 16  agac_iv    silver acetate
# agac_iv    silver ac...
# 17  agac_iv    silver acetate
# agac_iv    silver ac...
# 18  agac_iv    silver acetate
# agac_iv    silver ac...
# 19  agac_iv    silver acetate
# agac_iv    silver ac...
# 20  agac_iv    silver acetate
# agac_iv    silver ac...
# 21  agac_iv    silver acetate
# agac_iv    silver ac...
# 22  agac_iv    silver acetate
# agac_iv    silver ac...
# 23  agac_iv    silver acetate
# agac_iv    silver ac...
# 24  agac_po    silver acetate
# agac_po    silver ac...
# 25  agac_po    silver acetate
# agac_po    silver ac...
# 26  agac_po    silver acetate
# agac_po    silver ac...
# 27  agac_po    silver acetate
# agac_po    silver ac...
# 28  agac_po    silver acetate
# agac_po    silver ac...
# 29  agac_po    silver acetate
# agac_po    silver ac...
# 30  agac_po    silver acetate
# agac_po    silver ac...
# 31  agnp20_iv    silver nanoparticles (20 nm)
# agnp...
# 32  agnp20_iv    silver nanoparticles (20 nm)
# agnp...
# 33  agnp20_iv    silver nanoparticles (20 nm)
# agnp...
# 34  agnp20_iv    silver nanoparticles (20 nm)
# agnp...
# 35  agnp20_iv    silver nanoparticles (20 nm)
# agnp...
# 36  agnp20_iv    silver nanoparticles (20 nm)
# agnp...
# 37  agnp20_po    silver nanoparticles (20 nm)
# agnp...
# 38  agnp20_po    silver nanoparticles (20 nm)
# agnp...
# 39  agnp20_po    silver nanoparticles (20 nm)
# agnp...
# 40  agnp20_po    silver nanoparticles (20 nm)
# agnp...
# 41  agnp20_po    silver nanoparticles (20 nm)
# agnp...
#
#                                                Dose 1  \
# 0   control_iv
# control_iv
# Name: dose1, dty...
# 1   control_iv
# control_iv
# Name: dose1, dty...
# 2   control_iv
# control_iv
# Name: dose1, dty...
# 3   control_iv
# control_iv
# Name: dose1, dty...
# 4   control_iv
# control_iv
# Name: dose1, dty...
# 5   control_iv
# control_iv
# Name: dose1, dty...
# 6   control_iv
# control_iv
# Name: dose1, dty...
# 7   control_iv
# control_iv
# Name: dose1, dty...
# 8   control_po
# control_po
# Name: dose1, dty...
# 9   control_po
# control_po
# Name: dose1, dty...
# 10  control_po
# control_po
# Name: dose1, dty...
# 11  control_po
# control_po
# Name: dose1, dty...
# 12  control_po
# control_po
# Name: dose1, dty...
# 13  control_po
# control_po
# Name: dose1, dty...
# 14  control_po
# control_po
# Name: dose1, dty...
# 15  control_po
# control_po
# Name: dose1, dty...
# 16  agac_iv    1
# agac_iv    1
# Name: dose1, dtype: ...
# 17  agac_iv    1
# agac_iv    1
# Name: dose1, dtype: ...
# 18  agac_iv    1
# agac_iv    1
# Name: dose1, dtype: ...
# 19  agac_iv    1
# agac_iv    1
# Name: dose1, dtype: ...
# 20  agac_iv    1
# agac_iv    1
# Name: dose1, dtype: ...
# 21  agac_iv    1
# agac_iv    1
# Name: dose1, dtype: ...
# 22  agac_iv    1
# agac_iv    1
# Name: dose1, dtype: ...
# 23  agac_iv    1
# agac_iv    1
# ...
# Name: units1, dt...
# 5   control_iv
# control_iv
# Name: units1, dt...
# 6   control_po
# control_po
# Name: units1, dt...
# 7   control_po
# control_po
# Name: units1, dt...
# 8   control_po
# control_po
# Name: units1, dt...
# 9   control_po
# control_po
# Name: units1, dt...
# 10  control_po
# control_po
# Name: units1, dt...
# 11  control_po
# control_po
# Name: units1, dt...
# 12  agac_iv    mg/kg
# agac_iv    mg/kg
# Name: units1...
# 13  agac_iv    mg/kg
# agac_iv    mg/kg
# Name: units1...
# 14  agac_iv    mg/kg
# agac_iv    mg/kg
# Name: units1...
# 15  agac_iv    mg/kg
# agac_iv    mg/kg
# Name: units1...
# 16  agac_iv    mg/kg
# agac_iv    mg/kg
# Name: units1...
# 17  agac_iv    mg/kg
# agac_iv    mg/kg
# Name: units1...
# 18  agac_po    mg/kg
# agac_po    mg/kg
# Name: units1...
# 19  agac_po    mg/kg
# agac_po    mg/kg
# Name: units1...
# 20  agac_po    mg/kg
# agac_po    mg/kg
# Name: units1...
# 21  agac_po    mg/kg
# agac_po    mg/kg
# Name: units1...
# 22  agac_po    mg/kg
# agac_po    mg/kg
# Name: units1...
# 23  agac_po    mg/kg
# agac_po    mg/kg
# Name: units1...
# 24  agnp20_iv    mg/kg
# agnp20_iv    mg/kg
# Name: un...
# 25  agnp20_iv    mg/kg
# agnp20_iv    mg/kg
# Name: un...
# 26  agnp20_iv    mg/kg
# agnp20_iv    mg/kg
# Name: un...
# 27  agnp20_iv    mg/kg
# agnp20_iv    mg/kg
# Name: un...
# 28  agnp20_iv    mg/kg
# agnp20_iv    mg/kg
# Name: un...
# 29  agnp20_iv    mg/kg
# agnp20_iv    mg/kg
# Name: un...
# 30  agnp20_po    mg/kg
# agnp20_po    mg/kg
# Name: un...
# 31  agnp20_po    mg/kg
# agnp20_po    mg/kg
# Name: un...
# 32  agnp20_po    mg/kg
# agnp20_po    mg/kg
# Name: un...
# 33  agnp20_po    mg/kg
# agnp20_po    mg/kg
# Name: un...
# 34  agnp20_po    mg/kg
# agnp20_po    mg/kg
# Name: un...
# 35  agnp20_po    mg/kg
# agnp20_po    mg/kg
# Name: un...
# 36  agnp110_iv    mg/kg
# agnp110_iv    mg/kg
# Name: ...
# 37  agnp110_iv    mg/kg
# agnp110_iv    mg/kg
# Name: ...
# 38  agnp110_iv    mg/kg
# agnp110_iv    mg/kg
# Name: ...
# 39  agnp110_iv    mg/kg
# agnp110_iv    mg/kg
# Name: ...
# 40  agnp110_iv    mg/kg
# agnp110_iv    mg/kg
# Name: ...
# 41  agnp110_iv    mg/kg
# agnp110_iv    mg/kg
# Name: ...
# 42  agnp110_po    mg/kg
# agnp110_po    mg/kg
# Name: ...
# 43  agnp110_po    mg/kg
# agnp110_po    mg/kg
# Name: ...
# 44  agnp110_po    mg/kg
# agnp110_po    mg/kg
# Name: ...
# 45  agnp110_po    mg/kg
# agnp110_po    mg/kg
# Name: ...
# 46  agnp110_po    mg/kg
# agnp110_po    mg/kg
# Name: ...
# 47  agnp110_po    mg/kg
# agnp110_po    mg/kg
# Name: ...
#
#                                           Treatment 2  \
# 0   control_iv
# control_iv
# Name: treatment2...
# 1   control_iv
# control_iv
# Name: treatment2...
# 2   control_iv
# control_iv
# Name: treatment2...
# 3   control_iv
# control_iv
# Name: treatment2...
# 4   control_iv
# control_iv
# Name: treatment2...
# 5   control_iv
# control_iv
# Name: treatment2...
# 6   control_po
# control_po
# Name: treatment2...
# 7   control_po
# control_po
# Name: treatment2...
# 8   control_po
# control_po
# Name: treatment2...
# 9   control_po
# control_po
# Name: treatment2...
# 10  control_po
# control_po
# Name: treatment2...
# 11  control_po
# control_po
# Name: treatment2...
# 12  agac_iv
# agac_iv
# Name: treatment2, dtyp...
# 13  agac_iv
# agac_iv
# Name: treatment2, dtyp...
# 14  agac_iv
# agac_iv
# Name: treatment2, dtyp...
# 15  agac_iv
# agac_iv
# Name: treatment2, dtyp...
# 16  agac_iv
# agac_iv
# Name: treatment2, dtyp...
# 17  agac_iv
# agac_iv
# Name: treatment2, dtyp...
# 18  agac_po
# agac_po
# Name: treatment2, dtyp...
# 19  agac_po
# agac_po
# Name: treatment2, dtyp...
# 20  agac_po
# agac_po
# Name: treatment2, dtyp...
# 21  agac_po
# agac_po
# Name: treatment2, dtyp...
# 22  agac_po
# agac_po
# Name: treatment2, dtyp...
# 23  agac_po
# agac_po
# Name: treatment2, dtyp...
# 24  agnp20_iv
# agnp20_iv
# Name: treatment2, ...
# 25  agnp20_iv
# agnp20_iv
# Name: treatment2, ...
# 26  agnp20_iv
# agnp20_iv
# Name: treatment2, ...
# 27  agnp20_iv
# agnp20_iv
# Name: treatment2, ...
# 28  agnp20_iv
# agnp20_iv
# Name: treatment2, ...
# 29  agnp20_iv
# agnp20_iv
# Name: treatment2, ...
# 30  agnp20_po
# agnp20_po
# Name: treatment2, ...
# 31  agnp20_po
# agnp20_po
# Name: treatment2, ...
# 32  agnp20_po
# agnp20_po
# Name: treatment2, ...
# 33  agnp20_po
# agnp20_po
# Name: treatment2, ...
# 34  agnp20_po
# agnp20_po
# Name: treatment2, ...
# 35  agnp20_po
# agnp20_po
# Name: treatment2, ...
# 36  agnp110_iv
# agnp110_iv
# Name: treatment2...
# 37  agnp110_iv
# agnp110_iv
# Name: treatment2...
# 38  agnp110_iv
# agnp110_iv
# Name: treatment2...
# 39  agnp110_iv
# agnp110_iv
# Name: treatment2...
# 40  agnp110_iv
# agnp110_iv
# Name: treatment2...
# 41  agnp110_iv
# agnp110_iv
# Name: treatment2...
# 42  agnp110_po
# agnp110_po
# Name: treatment2...
# 43  agnp110_po
# agnp110_po
# Name: treatment2...
# 44  agnp110_po
# agnp110_po
# Name: treatment2...
# 45  agnp110_po
# agnp110_po
# Name: treatment2...
# 46  agnp110_po
# agnp110_po
# Name: treatment2...
# 47  agnp110_po
# agnp110_po
# Name: treatment2...
#
#                                                Dose 2  \
# 0   control_iv
# control_iv
# Name: dose2, dty...
# 1   control_iv
# control_iv
# Name: dose2, dty...
# 2   control_iv
# control_iv
# Name: dose2, dty...
# 3   control_iv
# control_iv
# Name: dose2, dty...
# 4   control_iv
# control_iv
# Name: dose2, dty...
# 5   control_iv
# control_iv
# Name: dose2, dty...
# 6   control_po
# control_po
# Name: dose2, dty...
# 7   control_po
# control_po
# Name: dose2, dty...
# 8   control_po
# control_po
# Name: dose2, dty...
# 9   control_po
# control_po
# Name: dose2, dty...
# 10  control_po
# control_po
# Name: dose2, dty...
# 11  control_po
# control_po
# Name: dose2, dty...
# 12  agac_iv
# agac_iv
# Name: dose2, dtype: ob...
# 13  agac_iv
# agac_iv
# Name: dose2, dtype: ob...
# 14  agac_iv
# agac_iv
# Name: dose2, dtype: ob...
# 15  agac_iv
# agac_iv
# Name: dose2, dtype: ob...
# 16  agac_iv
# agac_iv
# Name: dose2, dtype: ob...
# 17  agac_iv
# agac_iv
# Name: dose2, dtype: ob...
# 18  agac_po
# agac_po
# Name: dose2, dtype: ob...
# 19  agac_po
# agac_po
# Name: dose2, dtype: ob...
# 20  agac_po
# agac_po
# Name: dose2, dtype: ob...
# 21  agac_po
# agac_po
# Name: dose2, dtype: ob...
# 22  agac_po
# agac_po
# Name: dose2, dtype: ob...
# 23  agac_po
# agac_po
# Name: dose2, dtype: ob...
# 24  agnp20_iv
# agnp20_iv
# Name: dose2, dtype...
# 25  agnp20_iv
# agnp20_iv
# Name: dose2, dtype...
# 26  agnp20_iv
# agnp20_iv
# Name: dose2, dtype...
# 27  agnp20_iv
# agnp20_iv
# Name: dose2, dtype...
# 28  agnp20_iv
# agnp20_iv
# Name: dose2, dtype...
# 29  agnp20_iv
# agnp20_iv
# Name: dose2, dtype...
# 30  agnp20_po
# agnp20_po
# Name: dose2, dtype...
# 31  agnp20_po
# agnp20_po
# Name: dose2, dtype...
# 32  agnp20_po
# agnp20_po
# Name: dose2, dtype...
# 33  agnp20_po
# agnp20_po
# Name: dose2, dtype...
# 34  agnp20_po
# agnp20_po
# Name: dose2, dtype...
# 35  agnp20_po
# agnp20_po
# Name: dose2, dtype...
# 36  agnp110_iv
# agnp110_iv
# Name: dose2, dty...
# 37  agnp110_iv
# agnp110_iv
# Name: dose2, dty...
# 38  agnp110_iv
# agnp110_iv
# Name: dose2, dty...
# 39  agnp110_iv
# agnp110_iv
# Name: dose2, dty...
# 40  agnp110_iv
# agnp110_iv
# Name: dose2, dty...
# 41  agnp110_iv
# agnp110_iv
# Name: dose2, dty...
# 42  agnp110_po
# agnp110_po
# Name: dose2, dty...
# 43  agnp110_po
# agnp110_po
# Name: dose2, dty...
# 44  agnp110_po
# agnp110_po
# Name: dose2, dty...
# 45  agnp110_po
# agnp110_po
# Name: dose2, dty...
# 46  agnp110_po
# agnp110_po
# Name: dose2, dty...
# 47  agnp110_po
# agnp110_po
# Name: dose2, dty...
#
#                                               Units 2  \
# 0   control_iv
# control_iv
# Name: units2, dt...
# 1   control_iv
# control_iv
# Name: units2, dt...
# 2   control_iv
# control_iv
# Name: units2, dt...
# 3   control_iv
# control_iv
# Name: units2, dt...
# 4   control_iv
# control_iv
# Name: units2, dt...
# 5   control_iv
# control_iv
# Name: units2, dt...
# 6   control_po
# control_po
# Name: units2, dt...
# 7   control_po
# control_po
# Name: units2, dt...
# 8   control_po
# control_po
# Name: units2, dt...
# 9   control_po
# control_po
# Name: units2, dt...
# 10  control_po
# control_po
# Name: units2, dt...
# 11  control_po
# control_po
# Name: units2, dt...
# 12  agac_iv
# agac_iv
# Name: units2, dtype: o...
# 13  agac_iv
# agac_iv
# Name: units2, dtype: o...
# 14  agac_iv
# agac_iv
# Name: units2, dtype: o...
# 15  agac_iv
# agac_iv
# Name: units2, dtype: o...
# 16  agac_iv
# agac_iv
# Name: units2, dtype: o...
# 17  agac_iv
# agac_iv
# Name: units2, dtype: o...
# 18  agac_po
# agac_po
# Name: units2, dtype: o...
# 19  agac_po
# agac_po
# Name: units2, dtype: o...
# 20  agac_po
# agac_po
# Name: units2, dtype: o...
# 21  agac_po
# agac_po
# Name: units2, dtype: o...
# 22  agac_po
# agac_po
# Name: units2, dtype: o...
# 23  agac_po
# agac_po
# Name: units2, dtype: o...
# 24  agnp20_iv
# agnp20_iv
# Name: units2, dtyp...
# 25  agnp20_iv
# agnp20_iv
# Name: units2, dtyp...
# 26  agnp20_iv
# agnp20_iv
# Name: units2, dtyp...
# 27  agnp20_iv
# agnp20_iv
# Name: units2, dtyp...
# 28  agnp20_iv
# agnp20_iv
# Name: units2, dtyp...
# 29  agnp20_iv
# agnp20_iv
# Name: units2, dtyp...
# 30  agnp20_po
# agnp20_po
# Name: units2, dtyp...
# 31  agnp20_po
# agnp20_po
# Name: units2, dtyp...
# 32  agnp20_po
# agnp20_po
# Name: units2, dtyp...
# 33  agnp20_po
# agnp20_po
# Name: units2, dtyp...
# 34  agnp20_po
# agnp20_po
# Name: units2, dtyp...
# 35  agnp20_po
# agnp20_po
# Name: units2, dtyp...
# 36  agnp110_iv
# agnp110_iv
# Name: units2, dt...
# 37  agnp110_iv
# agnp110_iv
# Name: units2, dt...
# 38  agnp110_iv
# agnp110_iv
# Name: units2, dt...
# 39  agnp110_iv
# agnp110_iv
# Name: units2, dt...
# 40  agnp110_iv
# agnp110_iv
# Name: units2, dt...
# 41  agnp110_iv
# agnp110_iv
# Name: units2, dt...
# 42  agnp110_po
# agnp110_po
# Name: units2, dt...
# 43  agnp110_po
# agnp110_po
# Name: units2, dt...
# 44  agnp110_po
# agnp110_po
# Name: units2, dt...
# 45  agnp110_po
# agnp110_po
# Name: units2, dt...
# 46  agnp110_po
# agnp110_po
# Name: units2, dt...
# 47  agnp110_po
# agnp110_po
# Name: units2, dt...
#
#                                         Terminal Time         Biomarker  \
# 0   control_iv    24 hours
# control_iv    48 hours
# ...      Vehicle.24 h
# 1   control_iv    24 hours
# control_iv    48 hours
# ...      Vehicle.48 h
# 2   control_iv    24 hours
# control_iv    48 hours
# ...         AgAc.24 h
# 3   control_iv    24 hours
# control_iv    48 hours
# ...         AgAc.48 h
# 4   control_iv    24 hours
# control_iv    48 hours
# ...   20 nm AgNP.24 h
# 5   control_iv    24 hours
# control_iv    48 hours
# ...  20 nm AgNP .48 h
# 6   control_po    24 hours
# control_po    48 hours
# ...      Vehicle.24 h
# 7   control_po    24 hours
# control_po    48 hours
# ...      Vehicle.48 h
# 8   control_po    24 hours
# control_po    48 hours
# ...         AgAc.24 h
# 9   control_po    24 hours
# control_po    48 hours
# ...         AgAc.48 h
# 10  control_po    24 hours
# control_po    48 hours
# ...   20 nm AgNP.24 h
# 11  control_po    24 hours
# control_po    48 hours
# ...  20 nm AgNP .48 h
# 12  agac_iv    24 hours
# agac_iv    48 hours
# Name: ...      Vehicle.24 h
# 13  agac_iv    24 hours
# agac_iv    48 hours
# Name: ...      Vehicle.48 h
# 14  agac_iv    24 hours
# agac_iv    48 hours
# Name: ...         AgAc.24 h
# 15  agac_iv    24 hours
# agac_iv    48 hours
# Name: ...         AgAc.48 h
# 16  agac_iv    24 hours
# agac_iv    48 hours
# Name: ...   20 nm AgNP.24 h
# 17  agac_iv    24 hours
# agac_iv    48 hours
# Name: ...  20 nm AgNP .48 h
# 18  agac_po    24 hours
# agac_po    48 hours
# Name: ...      Vehicle.24 h
# 19  agac_po    24 hours
# agac_po    48 hours
# Name: ...      Vehicle.48 h
# 20  agac_po    24 hours
# agac_po    48 hours
# Name: ...         AgAc.24 h
# 21  agac_po    24 hours
# agac_po    48 hours
# Name: ...         AgAc.48 h
# 22  agac_po    24 hours
# agac_po    48 hours
# Name: ...   20 nm AgNP.24 h
# 23  agac_po    24 hours
# agac_po    48 hours
# Name: ...  20 nm AgNP .48 h
# 24  agnp20_iv    24 hours
# agnp20_iv    48 hours
# Na...      Vehicle.24 h
# 25  agnp20_iv    24 hours
# agnp20_iv    48 hours
# Na...      Vehicle.48 h
# 26  agnp20_iv    24 hours
# agnp20_iv    48 hours
# Na...         AgAc.24 h
# 27  agnp20_iv    24 hours
# agnp20_iv    48 hours
# Na...         AgAc.48 h
# 28  agnp20_iv    24 hours
# agnp20_iv    48 hours
# Na...   20 nm AgNP.24 h
# 29  agnp20_iv    24 hours
# agnp20_iv    48 hours
# Na...  20 nm AgNP .48 h
# 30  agnp20_po    24 hours
# agnp20_po    48 hours
# Na...      Vehicle.24 h
# 31  agnp20_po    24 hours
# agnp20_po    48 hours
# Na...      Vehicle.48 h
# 32  agnp20_po    24 hours
# agnp20_po    48 hours
# Na...         AgAc.24 h
# 33  agnp20_po    24 hours
# agnp20_po    48 hours
# Na...         AgAc.48 h
# 34  agnp20_po    24 hours
# agnp20_po    48 hours
# Na...   20 nm AgNP.24 h
# 35  agnp20_po    24 hours
# agnp20_po    48 hours
# Na...  20 nm AgNP .48 h
# 36  agnp110_iv    24 hours
# agnp110_iv    48 hours
# ...      Vehicle.24 h
# 37  agnp110_iv    24 hours
# agnp110_iv    48 hours
# ...      Vehicle.48 h
# 38  agnp110_iv    24 hours
# agnp110_iv    48 hours
# ...         AgAc.24 h
# 39  agnp110_iv    24 hours
# agnp110_iv    48 hours
# ...         AgAc.48 h
# 40  agnp110_iv    24 hours
# agnp110_iv    48 hours
# ...   20 nm AgNP.24 h
# 41  agnp110_iv    24 hours
# agnp110_iv    48 hours
# ...  20 nm AgNP .48 h
# 42  agnp110_po    24 hours
# agnp110_po    48 hours
# ...      Vehicle.24 h
# 43  agnp110_po    24 hours
# agnp110_po    48 hours
# ...      Vehicle.48 h
# 44  agnp110_po    24 hours
# agnp110_po    48 hours
# ...         AgAc.24 h
# 45  agnp110_po    24 hours
# agnp110_po    48 hours
# ...         AgAc.48 h
# 46  agnp110_po    24 hours
# agnp110_po    48 hours
# ...   20 nm AgNP.24 h
# 47  agnp110_po    24 hours
# agnp110_po    48 hours
# ...  20 nm AgNP .48 h
#
#     Value  Units Variation
# 0     146  pg/ml      None
# 1     336  pg/ml       475
# 2      ND  pg/ml       nan
# 3      ND  pg/ml       nan
# 4      ND  pg/ml       nan
# 5    55.3  pg/ml      None
# 6      ND  pg/ml      None
# 7      ND  pg/ml       nan
# 8      ND  pg/ml       nan
# 9      ND  pg/ml       nan
# 10     ND  pg/ml       nan
# 11     ND  pg/ml      None
# 12    263  pg/ml      None
# 13    779  pg/ml     1,072
# 14   44.5  pg/ml      77.2
# 15     ND  pg/ml       nan
# 16     ND  pg/ml       nan
# 17     ND  pg/ml      None
# 18     ND  pg/ml      None
# 19     ND  pg/ml       nan
# 20     ND  pg/ml       nan
# 21     ND  pg/ml       nan
# 22     ND  pg/ml       nan
# 23     ND  pg/ml      None
# 24    489  pg/ml      None
# 25  3,561  pg/ml     5,036
# 26   91.5  pg/ml       158
# 27   4.66  pg/ml      8.07
# 28   30.3  pg/ml      27.2
# 29     ND  pg/ml      None
# 30   78.1  pg/ml      None
# 31   57.7  pg/ml      81.6
# 32   57.4  pg/ml      52.1
# 33   42.2  pg/ml      36.5
# 34   62.8  pg/ml      42.7
# 35     ND  pg/ml      None
# 36     ND  pg/ml      None
# 37     ND  pg/ml       nan
# 38     ND  pg/ml       nan
# 39     ND  pg/ml       nan
# 40     ND  pg/ml       nan
# 41     ND  pg/ml      None
# 42     ND  pg/ml      None
# 43     ND  pg/ml       nan
# 44     ND  pg/ml       nan
# 45     ND  pg/ml       nan
# 46     ND  pg/ml       nan
# 47     ND  pg/ml      None
# Empty DataFrame
# Columns: []
# Index: []
